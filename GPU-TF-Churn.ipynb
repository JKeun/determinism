# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename="./data/Churn_Modelling.csv"
ds = DataSource(filename)
ds.data_load_split(target=['Exited'], 
                   ignore=["RowNumber", "CustomerId", "Surname"])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)

# %%
# tensorflow
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.3671551048755646, 0.847000002861023]
# sequential model is trained. best val loss is: [0.33915790915489197, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.339575856924057, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3470676839351654, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.9540075063705444, 0.3100000023841858]
# sequential model is trained. best val loss is: [0.8261832594871521, 0.4009999930858612]
# sequential model is trained. best val loss is: [0.7236412167549133, 0.5260000228881836]
# sequential model is trained. best val loss is: [0.46120572090148926, 0.7950000166893005]
# sequential model is trained. best val loss is: [0.40630513429641724, 0.8255000114440918]
# sequential model is trained. best val loss is: [0.3418385982513428, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3430313169956207, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.33853796124458313, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.6710687875747681, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.410530149936676, 0.8230000138282776]
# sequential model is trained. best val loss is: [0.3923799991607666, 0.8345000147819519]
# sequential model is trained. best val loss is: [0.3416776955127716, 0.862500011920929]
# sequential model is trained. best val loss is: [0.5497998595237732, 0.7515000104904175]
# sequential model is trained. best val loss is: [0.4201567471027374, 0.8159999847412109]
# sequential model is trained. best val loss is: [0.4055735170841217, 0.8259999752044678]
# sequential model is trained. best val loss is: [0.34290486574172974, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.36242642998695374, 0.8479999899864197]
# sequential model is trained. best val loss is: [0.3494996726512909, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3586001992225647, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.37930628657341003, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.34468287229537964, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3395279049873352, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.33610808849334717, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3450326919555664, 0.859000027179718]
# sequential model is trained. best val loss is: [0.9231100678443909, 0.265500009059906]
# sequential model is trained. best val loss is: [0.7629086375236511, 0.4284999966621399]
# sequential model is trained. best val loss is: [0.6511119604110718, 0.6309999823570251]
# sequential model is trained. best val loss is: [0.4357247054576874, 0.8115000128746033]
# sequential model is trained. best val loss is: [0.3794189393520355, 0.8489999771118164]
# sequential model is trained. best val loss is: [0.3430437743663788, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3412110507488251, 0.859000027179718]
# sequential model is trained. best val loss is: [0.33265364170074463, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.6115629076957703, 0.6974999904632568]
# sequential model is trained. best val loss is: [0.3906386196613312, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.35799816250801086, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.341030091047287, 0.8644999861717224]
# sequential model is trained. best val loss is: [0.5617370009422302, 0.7599999904632568]
# sequential model is trained. best val loss is: [0.41361647844314575, 0.824999988079071]
# sequential model is trained. best val loss is: [0.3881741166114807, 0.8410000205039978]
# sequential model is trained. best val loss is: [0.34159302711486816, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.34439966082572937, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3520788252353668, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.36145690083503723, 0.8495000004768372]
# sequential model is trained. best val loss is: [0.3512856364250183, 0.862500011920929]
# sequential model is trained. best val loss is: [0.34344929456710815, 0.859499990940094]
# sequential model is trained. best val loss is: [0.334846168756485, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.33723825216293335, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3532027006149292, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.8330687880516052, 0.2615000009536743]
# sequential model is trained. best val loss is: [0.6366292238235474, 0.6915000081062317]
# sequential model is trained. best val loss is: [0.5351181626319885, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.4122122824192047, 0.8195000290870667]
# sequential model is trained. best val loss is: [0.36516886949539185, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.3432044982910156, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34260860085487366, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.33834734559059143, 0.8665000200271606]
# sequential model is trained. best val loss is: [0.5171692371368408, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.38227710127830505, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.3538415729999542, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34167104959487915, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.5144930481910706, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.4065798819065094, 0.8205000162124634]
# sequential model is trained. best val loss is: [0.3830214738845825, 0.8399999737739563]
# sequential model is trained. best val loss is: [0.3427636921405792, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3430963456630707, 0.859000027179718]
# sequential model is trained. best val loss is: [0.35784780979156494, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.3549739718437195, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.3765105903148651, 0.8504999876022339]
# sequential model is trained. best val loss is: [0.3422966003417969, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3373963236808777, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.33693939447402954, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3660440444946289, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.7713926434516907, 0.33649998903274536]
# sequential model is trained. best val loss is: [0.5619669556617737, 0.8080000281333923]
# sequential model is trained. best val loss is: [0.47978052496910095, 0.8065000176429749]
# sequential model is trained. best val loss is: [0.39869365096092224, 0.8259999752044678]
# sequential model is trained. best val loss is: [0.3546229600906372, 0.8525000214576721]
# sequential model is trained. best val loss is: [0.3409733772277832, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3386186957359314, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3411053717136383, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.4788329303264618, 0.8054999709129333]
# sequential model is trained. best val loss is: [0.3767738938331604, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.3494015336036682, 0.8539999723434448]
# sequential model is trained. best val loss is: [0.3417448401451111, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.49532079696655273, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.4039991497993469, 0.8234999775886536]
# sequential model is trained. best val loss is: [0.38293370604515076, 0.8339999914169312]
# sequential model is trained. best val loss is: [0.3416711091995239, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3416704535484314, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3532397150993347, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3433544337749481, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3801465332508087, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.34225478768348694, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.33687275648117065, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.344414621591568, 0.862500011920929]
# sequential model is trained. best val loss is: [0.35149049758911133, 0.8525000214576721]
# sequential model is trained. best val loss is: [0.7791601419448853, 0.24799999594688416]
# sequential model is trained. best val loss is: [0.528006911277771, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4604283273220062, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3904016613960266, 0.8309999704360962]
# sequential model is trained. best val loss is: [0.34551143646240234, 0.859499990940094]
# sequential model is trained. best val loss is: [0.337333083152771, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3378222584724426, 0.859000027179718]
# sequential model is trained. best val loss is: [0.34857940673828125, 0.859499990940094]
# sequential model is trained. best val loss is: [0.4718968868255615, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.37448838353157043, 0.8429999947547913]
# sequential model is trained. best val loss is: [0.3470505177974701, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3423142433166504, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.5000166296958923, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.40762239694595337, 0.8230000138282776]
# sequential model is trained. best val loss is: [0.3857395052909851, 0.8355000019073486]
# sequential model is trained. best val loss is: [0.34157899022102356, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.34198451042175293, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.358846515417099, 0.8519999980926514]
# sequential model is trained. best val loss is: [0.3400508761405945, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3820534348487854, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.34599730372428894, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3420345187187195, 0.862500011920929]
# sequential model is trained. best val loss is: [0.34593304991722107, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3495842218399048, 0.862500011920929]
# sequential model is trained. best val loss is: [0.6231532096862793, 0.7440000176429749]
# sequential model is trained. best val loss is: [0.5552067756652832, 0.7979999780654907]
# sequential model is trained. best val loss is: [0.5186877250671387, 0.8025000095367432]
# sequential model is trained. best val loss is: [0.43939557671546936, 0.8075000047683716]
# sequential model is trained. best val loss is: [0.39583176374435425, 0.8320000171661377]
# sequential model is trained. best val loss is: [0.34165698289871216, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.33862805366516113, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.34040528535842896, 0.8654999732971191]
# sequential model is trained. best val loss is: [0.506583571434021, 0.8029999732971191]
# sequential model is trained. best val loss is: [0.40326595306396484, 0.8289999961853027]
# sequential model is trained. best val loss is: [0.36459770798683167, 0.8535000085830688]
# sequential model is trained. best val loss is: [0.3416198194026947, 0.859000027179718]
# sequential model is trained. best val loss is: [0.511121392250061, 0.8029999732971191]
# sequential model is trained. best val loss is: [0.42714834213256836, 0.809499979019165]
# sequential model is trained. best val loss is: [0.4044710397720337, 0.828499972820282]
# sequential model is trained. best val loss is: [0.3466455340385437, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.34677428007125854, 0.859000027179718]
# sequential model is trained. best val loss is: [0.35097548365592957, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.35727056860923767, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.36769387125968933, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3386823534965515, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3419865071773529, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3437436521053314, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3467307984828949, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.6672011017799377, 0.6169999837875366]
# sequential model is trained. best val loss is: [0.5413121581077576, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.49572378396987915, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4109586179256439, 0.8174999952316284]
# sequential model is trained. best val loss is: [0.36771705746650696, 0.8450000286102295]
# sequential model is trained. best val loss is: [0.3413970172405243, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3404493033885956, 0.8650000095367432]
# sequential model is trained. best val loss is: [0.340269535779953, 0.8650000095367432]
# sequential model is trained. best val loss is: [0.49235212802886963, 0.8040000200271606]
# sequential model is trained. best val loss is: [0.3840475380420685, 0.8345000147819519]
# sequential model is trained. best val loss is: [0.34910884499549866, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.3381032645702362, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.5105447769165039, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.41500818729400635, 0.815500020980835]
# sequential model is trained. best val loss is: [0.390237420797348, 0.8324999809265137]
# sequential model is trained. best val loss is: [0.34032386541366577, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.33928146958351135, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.3569142520427704, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.35164618492126465, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3866375684738159, 0.8539999723434448]
# sequential model is trained. best val loss is: [0.34386301040649414, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.34173116087913513, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3430943191051483, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.3662859797477722, 0.8475000262260437]
# sequential model is trained. best val loss is: [0.6189232468605042, 0.7720000147819519]
# sequential model is trained. best val loss is: [0.4956754148006439, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.45618993043899536, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.3808564245700836, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.34587690234184265, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3433395326137543, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3452695608139038, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.34378987550735474, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.46954354643821716, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.356118381023407, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.34279587864875793, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.3475632071495056, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.5040714740753174, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.39615991711616516, 0.8289999961853027]
# sequential model is trained. best val loss is: [0.36492830514907837, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.347842276096344, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3459424376487732, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.36013180017471313, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3565935492515564, 0.859499990940094]
# sequential model is trained. best val loss is: [0.38751763105392456, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3378932774066925, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.3465563654899597, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.34368762373924255, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3454359769821167, 0.8504999876022339]
# sequential model is trained. best val loss is: [0.6840266585350037, 0.5640000104904175]
# sequential model is trained. best val loss is: [0.4698559641838074, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4342300295829773, 0.8100000023841858]
# sequential model is trained. best val loss is: [0.36480674147605896, 0.8485000133514404]
# sequential model is trained. best val loss is: [0.34086620807647705, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.34319260716438293, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3494044244289398, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3499141037464142, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.461294949054718, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3545437753200531, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34162747859954834, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34494706988334656, 0.859499990940094]
# sequential model is trained. best val loss is: [0.5004314184188843, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.39993205666542053, 0.828499972820282]
# sequential model is trained. best val loss is: [0.3686417043209076, 0.8460000157356262]
# sequential model is trained. best val loss is: [0.3444756865501404, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.34373122453689575, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.3606829345226288, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3835119307041168, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.5021090507507324, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3412170112133026, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3404409885406494, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.3503914475440979, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3981499671936035, 0.8355000019073486]
# sequential model is trained. best val loss is: [0.5811377763748169, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4424109160900116, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.41199854016304016, 0.8245000243186951]
# sequential model is trained. best val loss is: [0.3496718108654022, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3399554193019867, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.34524720907211304, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3433529734611511, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.34515276551246643, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.4495523273944855, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.34898123145103455, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3406459093093872, 0.862500011920929]
# sequential model is trained. best val loss is: [0.35362690687179565, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.4870305359363556, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3949832618236542, 0.8330000042915344]
# sequential model is trained. best val loss is: [0.3643827736377716, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.3449043333530426, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3560656011104584, 0.8489999771118164]
# sequential model is trained. best val loss is: [0.35607630014419556, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.3720186650753021, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.47290799021720886, 0.8245000243186951]
# sequential model is trained. best val loss is: [0.34348058700561523, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3370814323425293, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.3455876111984253, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.36783844232559204, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.7284529805183411, 0.30799999833106995]
# sequential model is trained. best val loss is: [0.6267436146736145, 0.7820000052452087]
# sequential model is trained. best val loss is: [0.5361929535865784, 0.8029999732971191]
# sequential model is trained. best val loss is: [0.4178326427936554, 0.8224999904632568]
# sequential model is trained. best val loss is: [0.3871173560619354, 0.8360000252723694]
# sequential model is trained. best val loss is: [0.3377993404865265, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.33579739928245544, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.33554062247276306, 0.8659999966621399]
# sequential model is trained. best val loss is: [0.551663875579834, 0.8025000095367432]
# sequential model is trained. best val loss is: [0.3982965648174286, 0.8299999833106995]
# sequential model is trained. best val loss is: [0.3666152358055115, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.33801785111427307, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.5392270088195801, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.42220255732536316, 0.8230000138282776]
# sequential model is trained. best val loss is: [0.3987619876861572, 0.8295000195503235]
# sequential model is trained. best val loss is: [0.3464560806751251, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.34480586647987366, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.35318121314048767, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3390136957168579, 0.859499990940094]
# sequential model is trained. best val loss is: [0.37803781032562256, 0.8529999852180481]
# sequential model is trained. best val loss is: [0.3430677056312561, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.33990076184272766, 0.8644999861717224]
# sequential model is trained. best val loss is: [0.3523227572441101, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3502921164035797, 0.859000027179718]
# sequential model is trained. best val loss is: [0.6869110465049744, 0.5740000009536743]
# sequential model is trained. best val loss is: [0.5452713966369629, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.48587459325790405, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4043606221675873, 0.8209999799728394]
# sequential model is trained. best val loss is: [0.3536933660507202, 0.8535000085830688]
# sequential model is trained. best val loss is: [0.3441661298274994, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3455246686935425, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3449167311191559, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.5059145092964172, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.37709105014801025, 0.8429999947547913]
# sequential model is trained. best val loss is: [0.34706100821495056, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.34015709161758423, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.5281097292900085, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.42995890974998474, 0.8100000023841858]
# sequential model is trained. best val loss is: [0.3928728699684143, 0.8270000219345093]
# sequential model is trained. best val loss is: [0.3456578254699707, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3448764383792877, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3614662289619446, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3494124710559845, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.41299065947532654, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3440844714641571, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.34955766797065735, 0.8644999861717224]
# sequential model is trained. best val loss is: [0.34135642647743225, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3535733222961426, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.684236466884613, 0.559499979019165]
# sequential model is trained. best val loss is: [0.5020015239715576, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4513565003871918, 0.8040000200271606]
# sequential model is trained. best val loss is: [0.3659287393093109, 0.8489999771118164]
# sequential model is trained. best val loss is: [0.34284162521362305, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.34390297532081604, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.33977067470550537, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.34577807784080505, 0.859000027179718]
# sequential model is trained. best val loss is: [0.48860296607017517, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3504349887371063, 0.8560000061988831]
# sequential model is trained. best val loss is: [0.34194886684417725, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.3524693548679352, 0.8560000061988831]
# sequential model is trained. best val loss is: [0.5293371677398682, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4006996154785156, 0.8245000243186951]
# sequential model is trained. best val loss is: [0.3617538809776306, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.35541123151779175, 0.8535000085830688]
# sequential model is trained. best val loss is: [0.35344427824020386, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.36138325929641724, 0.862500011920929]
# sequential model is trained. best val loss is: [0.36288464069366455, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.38502436876296997, 0.8454999923706055]
# sequential model is trained. best val loss is: [0.35139840841293335, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3507310450077057, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.34370264410972595, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.49560537934303284, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.6344272494316101, 0.7979999780654907]
# sequential model is trained. best val loss is: [0.4635167419910431, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.42206597328186035, 0.8144999742507935]
# sequential model is trained. best val loss is: [0.3465496301651001, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3418459892272949, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3490542769432068, 0.8560000061988831]
# sequential model is trained. best val loss is: [0.35090962052345276, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.35350877046585083, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.46996790170669556, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3447234332561493, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3410490155220032, 0.8665000200271606]
# sequential model is trained. best val loss is: [0.3388735055923462, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.5121172666549683, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3973877429962158, 0.8349999785423279]
# sequential model is trained. best val loss is: [0.35840821266174316, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.34747394919395447, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.34341004490852356, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.3461627662181854, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3600998818874359, 0.8665000200271606]
# sequential model is trained. best val loss is: [0.4807949662208557, 0.8109999895095825]
# sequential model is trained. best val loss is: [0.3430633842945099, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.347594290971756, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.34585848450660706, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.4790407419204712, 0.8270000219345093]
# sequential model is trained. best val loss is: [0.5691248178482056, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.43445873260498047, 0.8040000200271606]
# sequential model is trained. best val loss is: [0.40079233050346375, 0.8289999961853027]
# sequential model is trained. best val loss is: [0.3422237038612366, 0.859000027179718]
# sequential model is trained. best val loss is: [0.34642016887664795, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.35428619384765625, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3541233539581299, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3477003276348114, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.45396560430526733, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.34291064739227295, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.3446117341518402, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.34005773067474365, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.4939132630825043, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.39116421341896057, 0.8360000252723694]
# sequential model is trained. best val loss is: [0.35412847995758057, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3566915988922119, 0.8500000238418579]
# sequential model is trained. best val loss is: [0.34940820932388306, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3616636097431183, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.35655835270881653, 0.8690000176429749]
# sequential model is trained. best val loss is: [0.4957270324230194, 0.8034999966621399]
# ==== 12.224066185951234 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[1], units=[32],
         optimizers=['adamax'], lrs=[0.1],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.33265361189842224, 0.8610000014305115]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7fb2cb7e8f60>],
#  [{'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.1}],
#  [0.33265361189842224])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.3671551048755646, 0.847000002861023]
# sequential model is trained. best val loss is: [0.33915790915489197, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.339575856924057, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3470676839351654, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.9540075063705444, 0.3100000023841858]
# sequential model is trained. best val loss is: [0.8261832594871521, 0.4009999930858612]
# sequential model is trained. best val loss is: [0.7236412167549133, 0.5260000228881836]
# sequential model is trained. best val loss is: [0.46120572090148926, 0.7950000166893005]
# sequential model is trained. best val loss is: [0.40630513429641724, 0.8255000114440918]
# sequential model is trained. best val loss is: [0.3418385982513428, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3430313169956207, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.33853796124458313, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.6710687875747681, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.410530149936676, 0.8230000138282776]
# sequential model is trained. best val loss is: [0.3923799991607666, 0.8345000147819519]
# sequential model is trained. best val loss is: [0.3416776955127716, 0.862500011920929]
# sequential model is trained. best val loss is: [0.5497998595237732, 0.7515000104904175]
# sequential model is trained. best val loss is: [0.4201567471027374, 0.8159999847412109]
# sequential model is trained. best val loss is: [0.4055735170841217, 0.8259999752044678]
# sequential model is trained. best val loss is: [0.34290486574172974, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.36242642998695374, 0.8479999899864197]
# sequential model is trained. best val loss is: [0.3494996726512909, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3586001992225647, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.37930628657341003, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.34468287229537964, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3395279049873352, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.33610811829566956, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3450326919555664, 0.859000027179718]
# sequential model is trained. best val loss is: [0.9231100678443909, 0.265500009059906]
# sequential model is trained. best val loss is: [0.7629086375236511, 0.4284999966621399]
# sequential model is trained. best val loss is: [0.6511119604110718, 0.6309999823570251]
# sequential model is trained. best val loss is: [0.4357247054576874, 0.8115000128746033]
# sequential model is trained. best val loss is: [0.3794189393520355, 0.8489999771118164]
# sequential model is trained. best val loss is: [0.3430437743663788, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3412110507488251, 0.859000027179718]
# sequential model is trained. best val loss is: [0.33265361189842224, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.6115629076957703, 0.6974999904632568]
# sequential model is trained. best val loss is: [0.3906386196613312, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.35799819231033325, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3410300612449646, 0.8644999861717224]
# sequential model is trained. best val loss is: [0.5617370009422302, 0.7599999904632568]
# sequential model is trained. best val loss is: [0.41361647844314575, 0.824999988079071]
# sequential model is trained. best val loss is: [0.3881741166114807, 0.8410000205039978]
# sequential model is trained. best val loss is: [0.3415810465812683, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3443996012210846, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3520788550376892, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3633512556552887, 0.8479999899864197]
# sequential model is trained. best val loss is: [0.35057583451271057, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.34346887469291687, 0.859499990940094]
# sequential model is trained. best val loss is: [0.33433640003204346, 0.862500011920929]
# sequential model is trained. best val loss is: [0.33723828196525574, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3532027006149292, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.8330687880516052, 0.2615000009536743]
# sequential model is trained. best val loss is: [0.6366292238235474, 0.6915000081062317]
# sequential model is trained. best val loss is: [0.5351181626319885, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.4122123420238495, 0.8195000290870667]
# sequential model is trained. best val loss is: [0.36516883969306946, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.3432044982910156, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3422611653804779, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.33834734559059143, 0.8665000200271606]
# sequential model is trained. best val loss is: [0.5171692371368408, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.38227710127830505, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.3538415729999542, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34167104959487915, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.5144930481910706, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.4065798819065094, 0.8205000162124634]
# sequential model is trained. best val loss is: [0.38302144408226013, 0.8399999737739563]
# sequential model is trained. best val loss is: [0.3427636921405792, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3430963456630707, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3586600124835968, 0.8529999852180481]
# sequential model is trained. best val loss is: [0.3565113842487335, 0.8525000214576721]
# sequential model is trained. best val loss is: [0.3692100942134857, 0.8504999876022339]
# sequential model is trained. best val loss is: [0.3422965705394745, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3373963236808777, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.33693942427635193, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.36009085178375244, 0.859499990940094]
# sequential model is trained. best val loss is: [0.7713926434516907, 0.33649998903274536]
# sequential model is trained. best val loss is: [0.5619668960571289, 0.8080000281333923]
# sequential model is trained. best val loss is: [0.47978052496910095, 0.8065000176429749]
# sequential model is trained. best val loss is: [0.39869365096092224, 0.8259999752044678]
# sequential model is trained. best val loss is: [0.3546229600906372, 0.8525000214576721]
# sequential model is trained. best val loss is: [0.34093520045280457, 0.859499990940094]
# sequential model is trained. best val loss is: [0.33805933594703674, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3411053419113159, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.4788329303264618, 0.8054999709129333]
# sequential model is trained. best val loss is: [0.3767738938331604, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.349401593208313, 0.8539999723434448]
# sequential model is trained. best val loss is: [0.3417448401451111, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.49532079696655273, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.4039991497993469, 0.8234999775886536]
# sequential model is trained. best val loss is: [0.38293370604515076, 0.8339999914169312]
# sequential model is trained. best val loss is: [0.3416711091995239, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3416704535484314, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3543621301651001, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.34494131803512573, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.41200998425483704, 0.8360000252723694]
# sequential model is trained. best val loss is: [0.34225478768348694, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3370392620563507, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3380248248577118, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.35143768787384033, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.7791601419448853, 0.24799999594688416]
# sequential model is trained. best val loss is: [0.528006911277771, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.46042829751968384, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3904016613960266, 0.8309999704360962]
# sequential model is trained. best val loss is: [0.34551143646240234, 0.859499990940094]
# sequential model is trained. best val loss is: [0.33673417568206787, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3380974531173706, 0.859499990940094]
# sequential model is trained. best val loss is: [0.34497418999671936, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.4718968868255615, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.37448838353157043, 0.8429999947547913]
# sequential model is trained. best val loss is: [0.3470504879951477, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3423142433166504, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.5000166296958923, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.40762239694595337, 0.8230000138282776]
# sequential model is trained. best val loss is: [0.3857395052909851, 0.8355000019073486]
# sequential model is trained. best val loss is: [0.34157899022102356, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3420044183731079, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3588310778141022, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.3602330684661865, 0.8539999723434448]
# sequential model is trained. best val loss is: [0.3703460693359375, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.34599730372428894, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3420345187187195, 0.862500011920929]
# sequential model is trained. best val loss is: [0.34593304991722107, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3495842218399048, 0.862500011920929]
# sequential model is trained. best val loss is: [0.6231532096862793, 0.7440000176429749]
# sequential model is trained. best val loss is: [0.5552067756652832, 0.7979999780654907]
# sequential model is trained. best val loss is: [0.5186877250671387, 0.8025000095367432]
# sequential model is trained. best val loss is: [0.43939557671546936, 0.8075000047683716]
# sequential model is trained. best val loss is: [0.39583176374435425, 0.8320000171661377]
# sequential model is trained. best val loss is: [0.34165698289871216, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.33862805366516113, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.34040528535842896, 0.8654999732971191]
# sequential model is trained. best val loss is: [0.506583571434021, 0.8029999732971191]
# sequential model is trained. best val loss is: [0.40326595306396484, 0.8289999961853027]
# sequential model is trained. best val loss is: [0.36459770798683167, 0.8535000085830688]
# sequential model is trained. best val loss is: [0.3416198194026947, 0.859000027179718]
# sequential model is trained. best val loss is: [0.511121392250061, 0.8029999732971191]
# sequential model is trained. best val loss is: [0.42714834213256836, 0.809499979019165]
# sequential model is trained. best val loss is: [0.4044710397720337, 0.828499972820282]
# sequential model is trained. best val loss is: [0.3466455340385437, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.34677428007125854, 0.859000027179718]
# sequential model is trained. best val loss is: [0.35097548365592957, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.35727056860923767, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.36769387125968933, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3386823534965515, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3419865369796753, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3437436521053314, 0.859000027179718]
# sequential model is trained. best val loss is: [0.34673047065734863, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.6672011017799377, 0.6169999837875366]
# sequential model is trained. best val loss is: [0.5413121581077576, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.49572378396987915, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4109586179256439, 0.8174999952316284]
# sequential model is trained. best val loss is: [0.36771705746650696, 0.8450000286102295]
# sequential model is trained. best val loss is: [0.3413970172405243, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34044933319091797, 0.8650000095367432]
# sequential model is trained. best val loss is: [0.3402695059776306, 0.8650000095367432]
# sequential model is trained. best val loss is: [0.49235209822654724, 0.8040000200271606]
# sequential model is trained. best val loss is: [0.3840475380420685, 0.8345000147819519]
# sequential model is trained. best val loss is: [0.34910887479782104, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.3382645547389984, 0.8644999861717224]
# sequential model is trained. best val loss is: [0.5105447769165039, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.41500818729400635, 0.815500020980835]
# sequential model is trained. best val loss is: [0.39023837447166443, 0.8324999809265137]
# sequential model is trained. best val loss is: [0.34032386541366577, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.33928152918815613, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.3447699546813965, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3478361964225769, 0.859499990940094]
# sequential model is trained. best val loss is: [0.38104110956192017, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.3440686762332916, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.34173116087913513, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3430943191051483, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.35779592394828796, 0.8460000157356262]
# sequential model is trained. best val loss is: [0.6189232468605042, 0.7720000147819519]
# sequential model is trained. best val loss is: [0.4956754148006439, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.45618993043899536, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.3808564245700836, 0.8395000100135803]
# sequential model is trained. best val loss is: [0.345877468585968, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3433395326137543, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3452695608139038, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.3437899053096771, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.46954354643821716, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3561168313026428, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.34279587864875793, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.3466087579727173, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.5040714740753174, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.39615991711616516, 0.8289999961853027]
# sequential model is trained. best val loss is: [0.36492830514907837, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.3478423058986664, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3459424376487732, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.34350597858428955, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3728337287902832, 0.862500011920929]
# sequential model is trained. best val loss is: [0.4485132098197937, 0.8504999876022339]
# sequential model is trained. best val loss is: [0.3378932774066925, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.3465563952922821, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3421638011932373, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3812221884727478, 0.8255000114440918]
# sequential model is trained. best val loss is: [0.6840266585350037, 0.5640000104904175]
# sequential model is trained. best val loss is: [0.4698559641838074, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4342300593852997, 0.8100000023841858]
# sequential model is trained. best val loss is: [0.3648069500923157, 0.8485000133514404]
# sequential model is trained. best val loss is: [0.34085673093795776, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.34319257736206055, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3494044244289398, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3526080846786499, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.461294949054718, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.35454443097114563, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34162747859954834, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34494706988334656, 0.859499990940094]
# sequential model is trained. best val loss is: [0.5004314184188843, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.39993205666542053, 0.828499972820282]
# sequential model is trained. best val loss is: [0.3686417043209076, 0.8460000157356262]
# sequential model is trained. best val loss is: [0.34447571635246277, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.3438323140144348, 0.859000027179718]
# sequential model is trained. best val loss is: [0.36063581705093384, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3605252206325531, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.43466052412986755, 0.8360000252723694]
# sequential model is trained. best val loss is: [0.3412170112133026, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3512333929538727, 0.859499990940094]
# sequential model is trained. best val loss is: [0.34345725178718567, 0.862500011920929]
# sequential model is trained. best val loss is: [0.36717554926872253, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.5811377763748169, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4424109160900116, 0.8044999837875366]
# sequential model is trained. best val loss is: [0.41199854016304016, 0.8245000243186951]
# sequential model is trained. best val loss is: [0.34966930747032166, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.33988550305366516, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.34541457891464233, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3433529734611511, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.34515276551246643, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.4495523273944855, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.34898123145103455, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.34060201048851013, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.3530263304710388, 0.8535000085830688]
# sequential model is trained. best val loss is: [0.4870305359363556, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3949832618236542, 0.8330000042915344]
# sequential model is trained. best val loss is: [0.364382803440094, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.34495025873184204, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.35578951239585876, 0.8485000133514404]
# sequential model is trained. best val loss is: [0.3570886552333832, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.3474191725254059, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.4051057994365692, 0.8535000085830688]
# sequential model is trained. best val loss is: [0.34348058700561523, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3370814323425293, 0.8544999957084656]
# sequential model is trained. best val loss is: [0.3455876111984253, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.36783844232559204, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.7284529805183411, 0.30799999833106995]
# sequential model is trained. best val loss is: [0.6267436146736145, 0.7820000052452087]
# sequential model is trained. best val loss is: [0.5361929535865784, 0.8029999732971191]
# sequential model is trained. best val loss is: [0.4178326427936554, 0.8224999904632568]
# sequential model is trained. best val loss is: [0.3871173560619354, 0.8360000252723694]
# sequential model is trained. best val loss is: [0.3377993404865265, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.33579739928245544, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.33554062247276306, 0.8659999966621399]
# sequential model is trained. best val loss is: [0.551663875579834, 0.8025000095367432]
# sequential model is trained. best val loss is: [0.3982965648174286, 0.8299999833106995]
# sequential model is trained. best val loss is: [0.3666152358055115, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.33801785111427307, 0.8634999990463257]
# sequential model is trained. best val loss is: [0.5392270088195801, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.42220255732536316, 0.8230000138282776]
# sequential model is trained. best val loss is: [0.3987619876861572, 0.8295000195503235]
# sequential model is trained. best val loss is: [0.3464560806751251, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.34480586647987366, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.35318121314048767, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.3390136957168579, 0.859499990940094]
# sequential model is trained. best val loss is: [0.37803781032562256, 0.8529999852180481]
# sequential model is trained. best val loss is: [0.3430677354335785, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.34330418705940247, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3507120609283447, 0.862500011920929]
# sequential model is trained. best val loss is: [0.37913164496421814, 0.8205000162124634]
# sequential model is trained. best val loss is: [0.6869110465049744, 0.5740000009536743]
# sequential model is trained. best val loss is: [0.5452713966369629, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.48587459325790405, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4043606221675873, 0.8209999799728394]
# sequential model is trained. best val loss is: [0.353681743144989, 0.8535000085830688]
# sequential model is trained. best val loss is: [0.3441661596298218, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3449896574020386, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3437286615371704, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.5059145092964172, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3770862817764282, 0.8429999947547913]
# sequential model is trained. best val loss is: [0.34706100821495056, 0.8550000190734863]
# sequential model is trained. best val loss is: [0.3401571214199066, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.5281097292900085, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.42995890974998474, 0.8100000023841858]
# sequential model is trained. best val loss is: [0.3928728401660919, 0.8270000219345093]
# sequential model is trained. best val loss is: [0.3456578552722931, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3450334370136261, 0.8579999804496765]
# sequential model is trained. best val loss is: [0.36205723881721497, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.35280489921569824, 0.8644999861717224]
# sequential model is trained. best val loss is: [0.3826638460159302, 0.8514999747276306]
# sequential model is trained. best val loss is: [0.3440844416618347, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.35671088099479675, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3486703932285309, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.36064064502716064, 0.859499990940094]
# sequential model is trained. best val loss is: [0.684236466884613, 0.559499979019165]
# sequential model is trained. best val loss is: [0.5020015835762024, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4513565003871918, 0.8040000200271606]
# sequential model is trained. best val loss is: [0.3659287393093109, 0.8489999771118164]
# sequential model is trained. best val loss is: [0.34284162521362305, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.34390297532081604, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.35301175713539124, 0.859499990940094]
# sequential model is trained. best val loss is: [0.3457780182361603, 0.859000027179718]
# sequential model is trained. best val loss is: [0.48860296607017517, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3504432737827301, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3420330286026001, 0.8640000224113464]
# sequential model is trained. best val loss is: [0.35152915120124817, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.5293371677398682, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.4006996154785156, 0.8245000243186951]
# sequential model is trained. best val loss is: [0.3617538809776306, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.3553551733493805, 0.8525000214576721]
# sequential model is trained. best val loss is: [0.35344427824020386, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.3557666838169098, 0.859499990940094]
# sequential model is trained. best val loss is: [0.34488433599472046, 0.8629999756813049]
# sequential model is trained. best val loss is: [0.5011451840400696, 0.8414999842643738]
# sequential model is trained. best val loss is: [0.35179468989372253, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3456907868385315, 0.859000027179718]
# sequential model is trained. best val loss is: [0.3461942672729492, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.4488533139228821, 0.8130000233650208]
# sequential model is trained. best val loss is: [0.6344272494316101, 0.7979999780654907]
# sequential model is trained. best val loss is: [0.4635167717933655, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.42206597328186035, 0.8144999742507935]
# sequential model is trained. best val loss is: [0.3465496301651001, 0.862500011920929]
# sequential model is trained. best val loss is: [0.34175580739974976, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.34797438979148865, 0.8569999933242798]
# sequential model is trained. best val loss is: [0.34111931920051575, 0.8615000247955322]
# sequential model is trained. best val loss is: [0.3535088896751404, 0.8510000109672546]
# sequential model is trained. best val loss is: [0.46996790170669556, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3447234332561493, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.3410552740097046, 0.8659999966621399]
# sequential model is trained. best val loss is: [0.3389248251914978, 0.859000027179718]
# sequential model is trained. best val loss is: [0.5121172666549683, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3973877727985382, 0.8349999785423279]
# sequential model is trained. best val loss is: [0.358408123254776, 0.8554999828338623]
# sequential model is trained. best val loss is: [0.34784355759620667, 0.8585000038146973]
# sequential model is trained. best val loss is: [0.3434537351131439, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.3560766577720642, 0.862500011920929]
# sequential model is trained. best val loss is: [0.36184021830558777, 0.8529999852180481]
# sequential model is trained. best val loss is: [0.4414665699005127, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.3430708944797516, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3502748906612396, 0.8600000143051147]
# sequential model is trained. best val loss is: [0.35130774974823, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.4955122470855713, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.5691248178482056, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.43445754051208496, 0.8040000200271606]
# sequential model is trained. best val loss is: [0.4007926881313324, 0.8289999961853027]
# sequential model is trained. best val loss is: [0.34221023321151733, 0.859000027179718]
# sequential model is trained. best val loss is: [0.34625810384750366, 0.862500011920929]
# sequential model is trained. best val loss is: [0.35428619384765625, 0.8575000166893005]
# sequential model is trained. best val loss is: [0.3552686274051666, 0.8560000061988831]
# sequential model is trained. best val loss is: [0.35952264070510864, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.4539657235145569, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.34289881587028503, 0.862500011920929]
# sequential model is trained. best val loss is: [0.3446117341518402, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.3401723802089691, 0.8610000014305115]
# sequential model is trained. best val loss is: [0.49391329288482666, 0.8034999966621399]
# sequential model is trained. best val loss is: [0.39116421341896057, 0.8360000252723694]
# sequential model is trained. best val loss is: [0.35412847995758057, 0.8565000295639038]
# sequential model is trained. best val loss is: [0.3564620316028595, 0.8504999876022339]
# sequential model is trained. best val loss is: [0.3499564826488495, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.35123395919799805, 0.8604999780654907]
# sequential model is trained. best val loss is: [0.35010021924972534, 0.8619999885559082]
# sequential model is trained. best val loss is: [0.4957270324230194, 0.8034999966621399]
# ==== 12.441763730843862 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.1}
