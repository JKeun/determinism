# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename="./data/Churn_Modelling.csv"
ds = DataSource(filename)
ds.data_load_split(target=['Exited'], 
                   ignore=["RowNumber", "CustomerId", "Surname"])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)
# Out:
# sequential model is trained. best val loss is: [0.3651177641293034, 0.847]
# sequential model is trained. best val loss is: [0.3332989389179015, 0.8665]
# sequential model is trained. best val loss is: [0.33474753865864104, 0.861]
# sequential model is trained. best val loss is: [0.3398817882835807, 0.8565]
# sequential model is trained. best val loss is: [0.9962370734475553, 0.2415]
# sequential model is trained. best val loss is: [0.8888054571114481, 0.286]
# sequential model is trained. best val loss is: [0.7989294683597982, 0.3725]
# sequential model is trained. best val loss is: [0.4820044072913006, 0.8065]
# sequential model is trained. best val loss is: [0.40893219015933574, 0.8205]
# sequential model is trained. best val loss is: [0.3392588627015939, 0.866]
# sequential model is trained. best val loss is: [0.3385017901233914, 0.865]
# sequential model is trained. best val loss is: [0.33057562967271736, 0.864]
# sequential model is trained. best val loss is: [0.7473904768116773, 0.445]
# sequential model is trained. best val loss is: [0.4245469536595047, 0.811]
# sequential model is trained. best val loss is: [0.3907040553716943, 0.829]
# sequential model is trained. best val loss is: [0.3378178930365375, 0.8655]
# sequential model is trained. best val loss is: [0.6254522183667869, 0.701]
# sequential model is trained. best val loss is: [0.4588379436992109, 0.8035]
# sequential model is trained. best val loss is: [0.4227294994518161, 0.817]
# sequential model is trained. best val loss is: [0.34281308486970374, 0.8675]
# sequential model is trained. best val loss is: [0.3595496505650226, 0.849]
# sequential model is trained. best val loss is: [0.33867161968131065, 0.862]
# sequential model is trained. best val loss is: [0.33706729076087294, 0.863]
# sequential model is trained. best val loss is: [0.3488951375163674, 0.8565]
# sequential model is trained. best val loss is: [0.3437223328060354, 0.858]
# sequential model is trained. best val loss is: [0.3339652743726974, 0.868]
# sequential model is trained. best val loss is: [0.32911002930673383, 0.8665]
# sequential model is trained. best val loss is: [0.3414220345833912, 0.858]
# sequential model is trained. best val loss is: [0.752408390790224, 0.508]
# sequential model is trained. best val loss is: [0.6698531559407711, 0.6305]
# sequential model is trained. best val loss is: [0.6081135409250855, 0.722]
# sequential model is trained. best val loss is: [0.4385161325354129, 0.814]
# sequential model is trained. best val loss is: [0.3876954791592434, 0.84]
# sequential model is trained. best val loss is: [0.33882403207400147, 0.8635]
# sequential model is trained. best val loss is: [0.33930146662059135, 0.866]
# sequential model is trained. best val loss is: [0.3341910587256698, 0.8605]
# sequential model is trained. best val loss is: [0.5831197929419577, 0.755]
# sequential model is trained. best val loss is: [0.39792147488333285, 0.83]
# sequential model is trained. best val loss is: [0.3653116056169383, 0.85]
# sequential model is trained. best val loss is: [0.33958975695355365, 0.8675]
# sequential model is trained. best val loss is: [0.5785473781451583, 0.765]
# sequential model is trained. best val loss is: [0.42177850706782194, 0.8195]
# sequential model is trained. best val loss is: [0.39571931861154735, 0.833]
# sequential model is trained. best val loss is: [0.3402179043799188, 0.86]
# sequential model is trained. best val loss is: [0.34319286532342086, 0.861]
# sequential model is trained. best val loss is: [0.33744447799011856, 0.8635]
# sequential model is trained. best val loss is: [0.33866744996041814, 0.858]
# sequential model is trained. best val loss is: [0.35745222095234963, 0.8625]
# sequential model is trained. best val loss is: [0.34236709593611886, 0.8615]
# sequential model is trained. best val loss is: [0.3330993313664362, 0.8635]
# sequential model is trained. best val loss is: [0.3330528840346209, 0.8615]
# sequential model is trained. best val loss is: [0.34214594555908673, 0.8615]
# sequential model is trained. best val loss is: [0.7595692180395126, 0.417]
# sequential model is trained. best val loss is: [0.6067133660316467, 0.708]
# sequential model is trained. best val loss is: [0.5243265310972929, 0.808]
# sequential model is trained. best val loss is: [0.41268955620378256, 0.823]
# sequential model is trained. best val loss is: [0.37113538753334435, 0.845]
# sequential model is trained. best val loss is: [0.3394003080929419, 0.863]
# sequential model is trained. best val loss is: [0.3373759569364606, 0.862]
# sequential model is trained. best val loss is: [0.33794828222781736, 0.8625]
# sequential model is trained. best val loss is: [0.5081392748169601, 0.805]
# sequential model is trained. best val loss is: [0.38625260975584386, 0.8365]
# sequential model is trained. best val loss is: [0.35659371575107796, 0.8565]
# sequential model is trained. best val loss is: [0.3396228359484703, 0.8635]
# sequential model is trained. best val loss is: [0.5125730385482311, 0.8035]
# sequential model is trained. best val loss is: [0.40813457443378864, 0.8205]
# sequential model is trained. best val loss is: [0.3872556623923592, 0.835]
# sequential model is trained. best val loss is: [0.34140189714422015, 0.86]
# sequential model is trained. best val loss is: [0.34267019174512825, 0.8605]
# sequential model is trained. best val loss is: [0.3348993649933048, 0.865]
# sequential model is trained. best val loss is: [0.3354593603458025, 0.8605]
# sequential model is trained. best val loss is: [0.3488920167079373, 0.8545]
# sequential model is trained. best val loss is: [0.3381036494588188, 0.8655]
# sequential model is trained. best val loss is: [0.3335497506034169, 0.8665]
# sequential model is trained. best val loss is: [0.3334396196794112, 0.863]
# sequential model is trained. best val loss is: [0.34038655174797433, 0.8575]
# sequential model is trained. best val loss is: [0.7183548983484507, 0.441]
# sequential model is trained. best val loss is: [0.5472225116193294, 0.8015]
# sequential model is trained. best val loss is: [0.48122388173639774, 0.8035]
# sequential model is trained. best val loss is: [0.40306553438771514, 0.8235]
# sequential model is trained. best val loss is: [0.35620634153927677, 0.857]
# sequential model is trained. best val loss is: [0.3353550288387678, 0.865]
# sequential model is trained. best val loss is: [0.3344799932535715, 0.865]
# sequential model is trained. best val loss is: [0.3363984028021622, 0.8645]
# sequential model is trained. best val loss is: [0.4815865207090974, 0.8035]
# sequential model is trained. best val loss is: [0.3804658116712235, 0.839]
# sequential model is trained. best val loss is: [0.34878209489909934, 0.8595]
# sequential model is trained. best val loss is: [0.33745139437168925, 0.8655]
# sequential model is trained. best val loss is: [0.5049886581450701, 0.8035]
# sequential model is trained. best val loss is: [0.4101861749226227, 0.8235]
# sequential model is trained. best val loss is: [0.38937667628796774, 0.836]
# sequential model is trained. best val loss is: [0.33866064003246354, 0.8645]
# sequential model is trained. best val loss is: [0.33908294191792265, 0.8645]
# sequential model is trained. best val loss is: [0.3356405608188714, 0.8655]
# sequential model is trained. best val loss is: [0.33589098283533736, 0.8615]
# sequential model is trained. best val loss is: [0.34433957430055967, 0.8575]
# sequential model is trained. best val loss is: [0.33913112953121616, 0.865]
# sequential model is trained. best val loss is: [0.33140718589265056, 0.8665]
# sequential model is trained. best val loss is: [0.3342577527836464, 0.859]
# sequential model is trained. best val loss is: [0.3430798893387187, 0.86]
# sequential model is trained. best val loss is: [0.6804750096648932, 0.556]
# sequential model is trained. best val loss is: [0.49754353288561104, 0.8045]
# sequential model is trained. best val loss is: [0.4491919123642147, 0.8055]
# sequential model is trained. best val loss is: [0.3891441032239236, 0.8305]
# sequential model is trained. best val loss is: [0.34594678461330475, 0.858]
# sequential model is trained. best val loss is: [0.333183722852839, 0.8675]
# sequential model is trained. best val loss is: [0.33199295820150576, 0.8675]
# sequential model is trained. best val loss is: [0.33699723753587285, 0.8585]
# sequential model is trained. best val loss is: [0.45871990745142105, 0.805]
# sequential model is trained. best val loss is: [0.37254502483224494, 0.844]
# sequential model is trained. best val loss is: [0.3471153528013965, 0.8565]
# sequential model is trained. best val loss is: [0.3382369328077275, 0.8645]
# sequential model is trained. best val loss is: [0.486788034170866, 0.8035]
# sequential model is trained. best val loss is: [0.40515716518927364, 0.819]
# sequential model is trained. best val loss is: [0.3840912715001032, 0.836]
# sequential model is trained. best val loss is: [0.3414722118164027, 0.864]
# sequential model is trained. best val loss is: [0.3406435621152004, 0.8665]
# sequential model is trained. best val loss is: [0.33573972483678416, 0.863]
# sequential model is trained. best val loss is: [0.3344739496153766, 0.8665]
# sequential model is trained. best val loss is: [0.34214924926443896, 0.8615]
# sequential model is trained. best val loss is: [0.34290851905881575, 0.864]
# sequential model is trained. best val loss is: [0.3397799781619142, 0.864]
# sequential model is trained. best val loss is: [0.334105687849237, 0.86]
# sequential model is trained. best val loss is: [0.3486299220936171, 0.8575]
# sequential model is trained. best val loss is: [0.7552162458896637, 0.3475]
# sequential model is trained. best val loss is: [0.6588061263263225, 0.6475]
# sequential model is trained. best val loss is: [0.5926704151257872, 0.7765]
# sequential model is trained. best val loss is: [0.4395817268779501, 0.8095]
# sequential model is trained. best val loss is: [0.3785216185366735, 0.8425]
# sequential model is trained. best val loss is: [0.3339308903243455, 0.8675]
# sequential model is trained. best val loss is: [0.3385793987865859, 0.86]
# sequential model is trained. best val loss is: [0.3329641706099501, 0.864]
# sequential model is trained. best val loss is: [0.5741249851733446, 0.7945]
# sequential model is trained. best val loss is: [0.38877673277677965, 0.838]
# sequential model is trained. best val loss is: [0.3497170753417886, 0.8625]
# sequential model is trained. best val loss is: [0.33548616142449467, 0.8635]
# sequential model is trained. best val loss is: [0.5509780460000038, 0.806]
# sequential model is trained. best val loss is: [0.4285809415075928, 0.8135]
# sequential model is trained. best val loss is: [0.3882582081761211, 0.8415]
# sequential model is trained. best val loss is: [0.3389197984944258, 0.866]
# sequential model is trained. best val loss is: [0.3449000031594369, 0.861]
# sequential model is trained. best val loss is: [0.3379702114593181, 0.863]
# sequential model is trained. best val loss is: [0.3339311945601899, 0.867]
# sequential model is trained. best val loss is: [0.3450407573101345, 0.866]
# sequential model is trained. best val loss is: [0.34034544791713417, 0.863]
# sequential model is trained. best val loss is: [0.33755305610395636, 0.8595]
# sequential model is trained. best val loss is: [0.3372346231386685, 0.865]
# sequential model is trained. best val loss is: [0.3540537374208767, 0.858]
# sequential model is trained. best val loss is: [0.6496074435561895, 0.6945]
# sequential model is trained. best val loss is: [0.5541444020122289, 0.804]
# sequential model is trained. best val loss is: [0.5067909246236086, 0.8035]
# sequential model is trained. best val loss is: [0.4171470362637192, 0.812]
# sequential model is trained. best val loss is: [0.37418775937496684, 0.8415]
# sequential model is trained. best val loss is: [0.3366934050302889, 0.8615]
# sequential model is trained. best val loss is: [0.33632972628136065, 0.865]
# sequential model is trained. best val loss is: [0.3350356673123803, 0.86]
# sequential model is trained. best val loss is: [0.5034665884003043, 0.8035]
# sequential model is trained. best val loss is: [0.387665414331248, 0.8305]
# sequential model is trained. best val loss is: [0.35078163946210406, 0.86]
# sequential model is trained. best val loss is: [0.33597741500405026, 0.864]
# sequential model is trained. best val loss is: [0.5234377843886614, 0.8035]
# sequential model is trained. best val loss is: [0.41726160908397286, 0.8135]
# sequential model is trained. best val loss is: [0.39269806194398554, 0.825]
# sequential model is trained. best val loss is: [0.3393771130895184, 0.8655]
# sequential model is trained. best val loss is: [0.34159188872095547, 0.8655]
# sequential model is trained. best val loss is: [0.3376983802128828, 0.8585]
# sequential model is trained. best val loss is: [0.3361247065872314, 0.86]
# sequential model is trained. best val loss is: [0.36859521796573474, 0.852]
# sequential model is trained. best val loss is: [0.33863402835474515, 0.8585]
# sequential model is trained. best val loss is: [0.3410477446346266, 0.86]
# sequential model is trained. best val loss is: [0.338156154991031, 0.861]
# sequential model is trained. best val loss is: [0.3433939111110196, 0.8605]
# sequential model is trained. best val loss is: [0.7224252429008484, 0.3885]
# sequential model is trained. best val loss is: [0.5387675292491912, 0.8035]
# sequential model is trained. best val loss is: [0.4773157733641565, 0.8035]
# sequential model is trained. best val loss is: [0.3960533351539634, 0.831]
# sequential model is trained. best val loss is: [0.3511853828681633, 0.8535]
# sequential model is trained. best val loss is: [0.33367580773435795, 0.8595]
# sequential model is trained. best val loss is: [0.3396878480738617, 0.859]
# sequential model is trained. best val loss is: [0.3332069856923714, 0.8655]
# sequential model is trained. best val loss is: [0.5035844005942345, 0.8035]
# sequential model is trained. best val loss is: [0.3785325912684202, 0.843]
# sequential model is trained. best val loss is: [0.34756784405803776, 0.8585]
# sequential model is trained. best val loss is: [0.3394929269359418, 0.862]
# sequential model is trained. best val loss is: [0.5331953501924872, 0.8035]
# sequential model is trained. best val loss is: [0.4141374556235969, 0.8205]
# sequential model is trained. best val loss is: [0.3878651767661795, 0.8405]
# sequential model is trained. best val loss is: [0.3420791828227739, 0.86]
# sequential model is trained. best val loss is: [0.3392469795955194, 0.8605]
# sequential model is trained. best val loss is: [0.33672362277777695, 0.863]
# sequential model is trained. best val loss is: [0.33769729085178646, 0.8615]
# sequential model is trained. best val loss is: [0.35185804125812786, 0.8645]
# sequential model is trained. best val loss is: [0.3339400467378239, 0.861]
# sequential model is trained. best val loss is: [0.3445583092666751, 0.8605]
# sequential model is trained. best val loss is: [0.3407555425596996, 0.859]
# sequential model is trained. best val loss is: [0.35836066656698007, 0.8475]
# sequential model is trained. best val loss is: [0.6348351359814406, 0.771]
# sequential model is trained. best val loss is: [0.45710749524086713, 0.8035]
# sequential model is trained. best val loss is: [0.42728071682341395, 0.8105]
# sequential model is trained. best val loss is: [0.36482013115333395, 0.8515]
# sequential model is trained. best val loss is: [0.3387411778398091, 0.8625]
# sequential model is trained. best val loss is: [0.3388604978661331, 0.863]
# sequential model is trained. best val loss is: [0.34114278335786435, 0.859]
# sequential model is trained. best val loss is: [0.3443993237626433, 0.8615]
# sequential model is trained. best val loss is: [0.44959692941978574, 0.8035]
# sequential model is trained. best val loss is: [0.35547926343465225, 0.856]
# sequential model is trained. best val loss is: [0.34066811744017467, 0.8655]
# sequential model is trained. best val loss is: [0.3367296091140256, 0.862]
# sequential model is trained. best val loss is: [0.48080057137459514, 0.8035]
# sequential model is trained. best val loss is: [0.401399200853426, 0.825]
# sequential model is trained. best val loss is: [0.3726261355872266, 0.846]
# sequential model is trained. best val loss is: [0.33802008917487547, 0.8645]
# sequential model is trained. best val loss is: [0.3373580184992159, 0.8655]
# sequential model is trained. best val loss is: [0.3382796046709901, 0.8605]
# sequential model is trained. best val loss is: [0.339840430431325, 0.8615]
# sequential model is trained. best val loss is: [0.3815399791514502, 0.8505]
# sequential model is trained. best val loss is: [0.33592336345661694, 0.8645]
# sequential model is trained. best val loss is: [0.34528425481841907, 0.8625]
# sequential model is trained. best val loss is: [0.3373284144220499, 0.8565]
# sequential model is trained. best val loss is: [0.33903715169333776, 0.8535]
# sequential model is trained. best val loss is: [0.6027166375368833, 0.803]
# sequential model is trained. best val loss is: [0.44487499389797447, 0.8035]
# sequential model is trained. best val loss is: [0.4137963204924017, 0.8195]
# sequential model is trained. best val loss is: [0.3491445021177642, 0.857]
# sequential model is trained. best val loss is: [0.33898901854505675, 0.861]
# sequential model is trained. best val loss is: [0.33982586049124813, 0.863]
# sequential model is trained. best val loss is: [0.3400060937103933, 0.8615]
# sequential model is trained. best val loss is: [0.33765612863908057, 0.86]
# sequential model is trained. best val loss is: [0.45408155573531983, 0.8035]
# sequential model is trained. best val loss is: [0.3484832042057533, 0.857]
# sequential model is trained. best val loss is: [0.33933452987438795, 0.861]
# sequential model is trained. best val loss is: [0.3348646654083143, 0.868]
# sequential model is trained. best val loss is: [0.495169354505837, 0.8035]
# sequential model is trained. best val loss is: [0.3966933939834125, 0.833]
# sequential model is trained. best val loss is: [0.36453963590133937, 0.847]
# sequential model is trained. best val loss is: [0.3373375023365479, 0.864]
# sequential model is trained. best val loss is: [0.34034866965805805, 0.8625]
# sequential model is trained. best val loss is: [0.3379982114200401, 0.8645]
# sequential model is trained. best val loss is: [0.34105810981277546, 0.8585]
# sequential model is trained. best val loss is: [0.3618016225949543, 0.8605]
# sequential model is trained. best val loss is: [0.3419657139192113, 0.867]
# sequential model is trained. best val loss is: [0.3359240032436828, 0.864]
# sequential model is trained. best val loss is: [0.34070462563989984, 0.8635]
# sequential model is trained. best val loss is: [0.35313322903291555, 0.8515]
# sequential model is trained. best val loss is: [0.6979712659269571, 0.4825]
# sequential model is trained. best val loss is: [0.6176743504405021, 0.788]
# sequential model is trained. best val loss is: [0.5716023884266614, 0.8035]
# sequential model is trained. best val loss is: [0.4560360614378005, 0.8035]
# sequential model is trained. best val loss is: [0.37852173643838616, 0.8425]
# sequential model is trained. best val loss is: [0.3389400748055164, 0.8665]
# sequential model is trained. best val loss is: [0.33260801787520655, 0.864]
# sequential model is trained. best val loss is: [0.34152072545851114, 0.8565]
# sequential model is trained. best val loss is: [0.5609018458724022, 0.8035]
# sequential model is trained. best val loss is: [0.3901373786712065, 0.8385]
# sequential model is trained. best val loss is: [0.34360094940132696, 0.8585]
# sequential model is trained. best val loss is: [0.3347376062027265, 0.8625]
# sequential model is trained. best val loss is: [0.555523298997432, 0.8035]
# sequential model is trained. best val loss is: [0.4773626481257379, 0.8035]
# sequential model is trained. best val loss is: [0.4098797433441505, 0.8245]
# sequential model is trained. best val loss is: [0.3355902279656366, 0.863]
# sequential model is trained. best val loss is: [0.34333076818066094, 0.865]
# sequential model is trained. best val loss is: [0.3362622814956194, 0.8645]
# sequential model is trained. best val loss is: [0.34045122195415856, 0.865]
# sequential model is trained. best val loss is: [0.35245947536439054, 0.855]
# sequential model is trained. best val loss is: [0.3406461238910797, 0.863]
# sequential model is trained. best val loss is: [0.3414542396625559, 0.861]
# sequential model is trained. best val loss is: [0.34218585492629133, 0.8585]
# sequential model is trained. best val loss is: [0.4926539643332362, 0.8035]
# sequential model is trained. best val loss is: [0.7410670538395643, 0.256]
# sequential model is trained. best val loss is: [0.5592722579240799, 0.8035]
# sequential model is trained. best val loss is: [0.4934372316971421, 0.8035]
# sequential model is trained. best val loss is: [0.40434509407775476, 0.8185]
# sequential model is trained. best val loss is: [0.3507947237690678, 0.86]
# sequential model is trained. best val loss is: [0.3380136293101441, 0.861]
# sequential model is trained. best val loss is: [0.3423824177795568, 0.86]
# sequential model is trained. best val loss is: [0.34196279171615607, 0.865]
# sequential model is trained. best val loss is: [0.5082438985258341, 0.8035]
# sequential model is trained. best val loss is: [0.3731942488625646, 0.846]
# sequential model is trained. best val loss is: [0.34430850741558244, 0.859]
# sequential model is trained. best val loss is: [0.33447425383755397, 0.8695]
# sequential model is trained. best val loss is: [0.5218426392748952, 0.8035]
# sequential model is trained. best val loss is: [0.42267739377729596, 0.809]
# sequential model is trained. best val loss is: [0.38288861139514485, 0.841]
# sequential model is trained. best val loss is: [0.3400521534507279, 0.867]
# sequential model is trained. best val loss is: [0.3412488171166933, 0.865]
# sequential model is trained. best val loss is: [0.344436663266, 0.859]
# sequential model is trained. best val loss is: [0.34084642395465153, 0.863]
# sequential model is trained. best val loss is: [0.3590500470735563, 0.857]
# sequential model is trained. best val loss is: [0.3391771645672634, 0.8635]
# sequential model is trained. best val loss is: [0.3420361935151528, 0.862]
# sequential model is trained. best val loss is: [0.33598699290366574, 0.862]
# sequential model is trained. best val loss is: [0.43538823517046155, 0.833]
# sequential model is trained. best val loss is: [0.7073266632705927, 0.4235]
# sequential model is trained. best val loss is: [0.511775784060359, 0.8035]
# sequential model is trained. best val loss is: [0.46416984718479215, 0.8035]
# sequential model is trained. best val loss is: [0.3814283916950226, 0.84]
# sequential model is trained. best val loss is: [0.3441281256830989, 0.8555]
# sequential model is trained. best val loss is: [0.3363323355836255, 0.8605]
# sequential model is trained. best val loss is: [0.3385725808305433, 0.8555]
# sequential model is trained. best val loss is: [0.3358308451071805, 0.8645]
# sequential model is trained. best val loss is: [0.4940728733539581, 0.8035]
# sequential model is trained. best val loss is: [0.3661305443267338, 0.8525]
# sequential model is trained. best val loss is: [0.34355673283129, 0.86]
# sequential model is trained. best val loss is: [0.3361940952759542, 0.87]
# sequential model is trained. best val loss is: [0.5223453188054263, 0.8035]
# sequential model is trained. best val loss is: [0.4130295820105821, 0.8185]
# sequential model is trained. best val loss is: [0.3833573607145809, 0.8405]
# sequential model is trained. best val loss is: [0.3381640569442243, 0.86]
# sequential model is trained. best val loss is: [0.34200221398881875, 0.861]
# sequential model is trained. best val loss is: [0.3413163217637978, 0.8645]
# sequential model is trained. best val loss is: [0.33390456517542294, 0.857]
# sequential model is trained. best val loss is: [0.3678386541149382, 0.861]
# sequential model is trained. best val loss is: [0.33858080946719565, 0.8545]
# sequential model is trained. best val loss is: [0.33844060721933306, 0.861]
# sequential model is trained. best val loss is: [0.3400630770766802, 0.863]
# sequential model is trained. best val loss is: [0.45875964779751305, 0.8255]
# sequential model is trained. best val loss is: [0.6110974026173354, 0.801]
# sequential model is trained. best val loss is: [0.4534549915120006, 0.8035]
# sequential model is trained. best val loss is: [0.4186301208678633, 0.8135]
# sequential model is trained. best val loss is: [0.3445595902784262, 0.8605]
# sequential model is trained. best val loss is: [0.3382347756645686, 0.859]
# sequential model is trained. best val loss is: [0.34932708898440096, 0.8605]
# sequential model is trained. best val loss is: [0.33617149089374654, 0.863]
# sequential model is trained. best val loss is: [0.3432575134108556, 0.8615]
# sequential model is trained. best val loss is: [0.45689858885295687, 0.8035]
# sequential model is trained. best val loss is: [0.3439100566022098, 0.8595]
# sequential model is trained. best val loss is: [0.3374578593893966, 0.862]
# sequential model is trained. best val loss is: [0.3356157598403806, 0.8605]
# sequential model is trained. best val loss is: [0.4949716975837946, 0.8035]
# sequential model is trained. best val loss is: [0.39962233463907615, 0.828]
# sequential model is trained. best val loss is: [0.36105072268727234, 0.8545]
# sequential model is trained. best val loss is: [0.33634084519122187, 0.866]
# sequential model is trained. best val loss is: [0.3391230563020108, 0.8555]
# sequential model is trained. best val loss is: [0.33981015166337925, 0.8605]
# sequential model is trained. best val loss is: [0.3393427077365835, 0.862]
# sequential model is trained. best val loss is: [0.4906127112805844, 0.8065]
# sequential model is trained. best val loss is: [0.33750427068108185, 0.8625]
# sequential model is trained. best val loss is: [0.3341784183349846, 0.864]
# sequential model is trained. best val loss is: [0.3438515921431105, 0.8605]
# sequential model is trained. best val loss is: [0.4935836775584612, 0.804]
# sequential model is trained. best val loss is: [0.560603587821126, 0.8035]
# sequential model is trained. best val loss is: [0.4250084718847647, 0.81]
# sequential model is trained. best val loss is: [0.39565494571486487, 0.8315]
# sequential model is trained. best val loss is: [0.3403962982041412, 0.8615]
# sequential model is trained. best val loss is: [0.33884872969587015, 0.8595]
# sequential model is trained. best val loss is: [0.3380013959472308, 0.8585]
# sequential model is trained. best val loss is: [0.3369652705118642, 0.857]
# sequential model is trained. best val loss is: [0.35890293002504303, 0.8565]
# sequential model is trained. best val loss is: [0.447478292459622, 0.8035]
# sequential model is trained. best val loss is: [0.3412257139271824, 0.863]
# sequential model is trained. best val loss is: [0.3379682052530115, 0.864]
# sequential model is trained. best val loss is: [0.3358072682826387, 0.861]
# sequential model is trained. best val loss is: [0.48980262263864277, 0.8035]
# sequential model is trained. best val loss is: [0.3885702126999386, 0.835]
# sequential model is trained. best val loss is: [0.35152753173559903, 0.8575]
# sequential model is trained. best val loss is: [0.33588011219469627, 0.8655]
# sequential model is trained. best val loss is: [0.33725695284892937, 0.86]
# sequential model is trained. best val loss is: [0.3428401988384063, 0.8625]
# sequential model is trained. best val loss is: [0.3472146009600078, 0.8595]
# sequential model is trained. best val loss is: [0.4955255789756775, 0.8035]

# %%
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
# Out:
# sequential model is trained. best val loss is: [0.3651177641293034, 0.847]
# sequential model is trained. best val loss is: [0.3332989389179015, 0.8665]
# sequential model is trained. best val loss is: [0.33474753865864104, 0.861]
# sequential model is trained. best val loss is: [0.35720893557758554, 0.852]
# sequential model is trained. best val loss is: [0.9962370734475553, 0.2415]
# sequential model is trained. best val loss is: [0.8888054571114481, 0.286]
# sequential model is trained. best val loss is: [0.7989294683597982, 0.3725]
# sequential model is trained. best val loss is: [0.4820044072913006, 0.8065]
# sequential model is trained. best val loss is: [0.40893219015933574, 0.8205]
# sequential model is trained. best val loss is: [0.3392588627015939, 0.866]
# sequential model is trained. best val loss is: [0.3385017901233914, 0.865]
# sequential model is trained. best val loss is: [0.33057562967271736, 0.864]
# sequential model is trained. best val loss is: [0.7473904768116773, 0.445]
# sequential model is trained. best val loss is: [0.4245469536595047, 0.811]
# sequential model is trained. best val loss is: [0.3907040553716943, 0.829]
# sequential model is trained. best val loss is: [0.3378178930365375, 0.8655]
# sequential model is trained. best val loss is: [0.6254522183667869, 0.701]
# sequential model is trained. best val loss is: [0.4588379436992109, 0.8035]
# sequential model is trained. best val loss is: [0.4227294994518161, 0.817]
# sequential model is trained. best val loss is: [0.34281308486970374, 0.8675]
# sequential model is trained. best val loss is: [0.3595496505650226, 0.849]
# sequential model is trained. best val loss is: [0.33867161968131065, 0.862]
# sequential model is trained. best val loss is: [0.33706729076087294, 0.863]
# sequential model is trained. best val loss is: [0.3488951375163674, 0.8565]
# sequential model is trained. best val loss is: [0.3437223328060354, 0.858]
# sequential model is trained. best val loss is: [0.3339652743726974, 0.868]
# sequential model is trained. best val loss is: [0.32911002930673383, 0.8665]
# sequential model is trained. best val loss is: [0.3453483267284822, 0.863]
# sequential model is trained. best val loss is: [0.752408390790224, 0.508]
# sequential model is trained. best val loss is: [0.6698531559407711, 0.6305]
# sequential model is trained. best val loss is: [0.6081135409250855, 0.722]
# sequential model is trained. best val loss is: [0.4385161325354129, 0.814]
# sequential model is trained. best val loss is: [0.3876954791592434, 0.84]
# sequential model is trained. best val loss is: [0.33882403207400147, 0.8635]
# sequential model is trained. best val loss is: [0.33930146662059135, 0.866]
# sequential model is trained. best val loss is: [0.33889502955188716, 0.862]
# sequential model is trained. best val loss is: [0.5831197929419577, 0.755]
# sequential model is trained. best val loss is: [0.39792147488333285, 0.83]
# sequential model is trained. best val loss is: [0.3653116056169383, 0.85]
# sequential model is trained. best val loss is: [0.33958975695355365, 0.8675]
# sequential model is trained. best val loss is: [0.5785473781451583, 0.765]
# sequential model is trained. best val loss is: [0.42177850706782194, 0.8195]
# sequential model is trained. best val loss is: [0.39571931861154735, 0.833]
# sequential model is trained. best val loss is: [0.3402179043799188, 0.86]
# sequential model is trained. best val loss is: [0.34319286532342086, 0.861]
# sequential model is trained. best val loss is: [0.33744447799011856, 0.8635]
# sequential model is trained. best val loss is: [0.33881704130239193, 0.867]
# sequential model is trained. best val loss is: [0.35745222095234963, 0.8625]
# sequential model is trained. best val loss is: [0.34236709593611886, 0.8615]
# sequential model is trained. best val loss is: [0.3330993313664362, 0.8635]
# sequential model is trained. best val loss is: [0.3330528840346209, 0.8615]
# sequential model is trained. best val loss is: [0.3457553595418232, 0.864]
# sequential model is trained. best val loss is: [0.7595692180395126, 0.417]
# sequential model is trained. best val loss is: [0.6067133660316467, 0.708]
# sequential model is trained. best val loss is: [0.5243265310972929, 0.808]
# sequential model is trained. best val loss is: [0.41268955620378256, 0.823]
# sequential model is trained. best val loss is: [0.37113538753334435, 0.845]
# sequential model is trained. best val loss is: [0.3394003080929419, 0.863]
# sequential model is trained. best val loss is: [0.3373759569364606, 0.862]
# sequential model is trained. best val loss is: [0.33794828222781736, 0.8625]
# sequential model is trained. best val loss is: [0.5081392748169601, 0.805]
# sequential model is trained. best val loss is: [0.38625260975584386, 0.8365]
# sequential model is trained. best val loss is: [0.35659371575107796, 0.8565]
# sequential model is trained. best val loss is: [0.3396228359484703, 0.8635]
# sequential model is trained. best val loss is: [0.5125730385482311, 0.8035]
# sequential model is trained. best val loss is: [0.40813457443378864, 0.8205]
# sequential model is trained. best val loss is: [0.3872556623923592, 0.835]
# sequential model is trained. best val loss is: [0.34140189714422015, 0.86]
# sequential model is trained. best val loss is: [0.34267019174512825, 0.8605]
# sequential model is trained. best val loss is: [0.3348993649933048, 0.865]
# sequential model is trained. best val loss is: [0.33951535865805654, 0.865]
# sequential model is trained. best val loss is: [0.3488920167079373, 0.8545]
# sequential model is trained. best val loss is: [0.3381036494588188, 0.8655]
# sequential model is trained. best val loss is: [0.3335497506034169, 0.8665]
# sequential model is trained. best val loss is: [0.3334396196794112, 0.863]
# sequential model is trained. best val loss is: [0.3654264445651845, 0.8565]
# sequential model is trained. best val loss is: [0.7183548983484507, 0.441]
# sequential model is trained. best val loss is: [0.5472225116193294, 0.8015]
# sequential model is trained. best val loss is: [0.48122388173639774, 0.8035]
# sequential model is trained. best val loss is: [0.40306553438771514, 0.8235]
# sequential model is trained. best val loss is: [0.35620634153927677, 0.857]
# sequential model is trained. best val loss is: [0.3353550288387678, 0.865]
# sequential model is trained. best val loss is: [0.3344799932535715, 0.865]
# sequential model is trained. best val loss is: [0.34701648571462224, 0.858]
# sequential model is trained. best val loss is: [0.4815865207090974, 0.8035]
# sequential model is trained. best val loss is: [0.3804658116712235, 0.839]
# sequential model is trained. best val loss is: [0.34878209489909934, 0.8595]
# sequential model is trained. best val loss is: [0.33745139437168925, 0.8655]
# sequential model is trained. best val loss is: [0.5049886581450701, 0.8035]
# sequential model is trained. best val loss is: [0.4101861749226227, 0.8235]
# sequential model is trained. best val loss is: [0.38937667628796774, 0.836]
# sequential model is trained. best val loss is: [0.33866064003246354, 0.8645]
# sequential model is trained. best val loss is: [0.33908294191792265, 0.8645]
# sequential model is trained. best val loss is: [0.3362911049950297, 0.8655]
# sequential model is trained. best val loss is: [0.33831684603670253, 0.865]
# sequential model is trained. best val loss is: [0.34433957430055967, 0.8575]
# sequential model is trained. best val loss is: [0.33913112953121616, 0.865]
# sequential model is trained. best val loss is: [0.33140718589265056, 0.8665]
# sequential model is trained. best val loss is: [0.33644942836859093, 0.8595]
# sequential model is trained. best val loss is: [0.35520636584709503, 0.852]
# sequential model is trained. best val loss is: [0.6804750096648932, 0.556]
# sequential model is trained. best val loss is: [0.49754353288561104, 0.8045]
# sequential model is trained. best val loss is: [0.4491919123642147, 0.8055]
# sequential model is trained. best val loss is: [0.3891441032239236, 0.8305]
# sequential model is trained. best val loss is: [0.34594678461330475, 0.858]
# sequential model is trained. best val loss is: [0.333183722852839, 0.8675]
# sequential model is trained. best val loss is: [0.33199295820150576, 0.8675]
# sequential model is trained. best val loss is: [0.3411236817060934, 0.8675]
# sequential model is trained. best val loss is: [0.45871990745142105, 0.805]
# sequential model is trained. best val loss is: [0.37254502483224494, 0.844]
# sequential model is trained. best val loss is: [0.3471153528013965, 0.8565]
# sequential model is trained. best val loss is: [0.3382369328077275, 0.8645]
# sequential model is trained. best val loss is: [0.486788034170866, 0.8035]
# sequential model is trained. best val loss is: [0.40515716518927364, 0.819]
# sequential model is trained. best val loss is: [0.3840912715001032, 0.836]
# sequential model is trained. best val loss is: [0.3414722118164027, 0.864]
# sequential model is trained. best val loss is: [0.3406435621152004, 0.8665]
# sequential model is trained. best val loss is: [0.3394338488670512, 0.864]
# sequential model is trained. best val loss is: [0.3438773656099369, 0.8645]
# sequential model is trained. best val loss is: [0.3664958018863195, 0.8525]
# sequential model is trained. best val loss is: [0.34290851905881575, 0.864]
# sequential model is trained. best val loss is: [0.3397799781619142, 0.864]
# sequential model is trained. best val loss is: [0.334105687849237, 0.86]
# sequential model is trained. best val loss is: [0.35877215134830426, 0.855]
# sequential model is trained. best val loss is: [0.7552162458896637, 0.3475]
# sequential model is trained. best val loss is: [0.6588061263263225, 0.6475]
# sequential model is trained. best val loss is: [0.5926704151257872, 0.7765]
# sequential model is trained. best val loss is: [0.4395817268779501, 0.8095]
# sequential model is trained. best val loss is: [0.3785216185366735, 0.8425]
# sequential model is trained. best val loss is: [0.3339308903243455, 0.8675]
# sequential model is trained. best val loss is: [0.3385793987865859, 0.86]
# sequential model is trained. best val loss is: [0.3329641706099501, 0.864]
# sequential model is trained. best val loss is: [0.5741249851733446, 0.7945]
# sequential model is trained. best val loss is: [0.38877673277677965, 0.838]
# sequential model is trained. best val loss is: [0.3497170753417886, 0.8625]
# sequential model is trained. best val loss is: [0.33548616142449467, 0.8635]
# sequential model is trained. best val loss is: [0.5509780460000038, 0.806]
# sequential model is trained. best val loss is: [0.4285809415075928, 0.8135]
# sequential model is trained. best val loss is: [0.3882582081761211, 0.8415]
# sequential model is trained. best val loss is: [0.3389197984944258, 0.866]
# sequential model is trained. best val loss is: [0.3449000031594369, 0.861]
# sequential model is trained. best val loss is: [0.3413935912045144, 0.861]
# sequential model is trained. best val loss is: [0.3339311945601899, 0.867]
# sequential model is trained. best val loss is: [0.3450407573101345, 0.866]
# sequential model is trained. best val loss is: [0.34034544791713417, 0.863]
# sequential model is trained. best val loss is: [0.34081399191325035, 0.86]
# sequential model is trained. best val loss is: [0.3372346231386685, 0.865]
# sequential model is trained. best val loss is: [0.3540537374208767, 0.858]
# sequential model is trained. best val loss is: [0.6496074435561895, 0.6945]
# sequential model is trained. best val loss is: [0.5541444020122289, 0.804]
# sequential model is trained. best val loss is: [0.5067909246236086, 0.8035]
# sequential model is trained. best val loss is: [0.4171470362637192, 0.812]
# sequential model is trained. best val loss is: [0.37418775937496684, 0.8415]
# sequential model is trained. best val loss is: [0.3366934050302889, 0.8615]
# sequential model is trained. best val loss is: [0.33632972628136065, 0.865]
# sequential model is trained. best val loss is: [0.3350356673123803, 0.86]
# sequential model is trained. best val loss is: [0.5034665884003043, 0.8035]
# sequential model is trained. best val loss is: [0.387665414331248, 0.8305]
# sequential model is trained. best val loss is: [0.35078163946210406, 0.86]
# sequential model is trained. best val loss is: [0.33597741500405026, 0.864]
# sequential model is trained. best val loss is: [0.5234377843886614, 0.8035]
# sequential model is trained. best val loss is: [0.41726160908397286, 0.8135]
# sequential model is trained. best val loss is: [0.39269806194398554, 0.825]
# sequential model is trained. best val loss is: [0.3393771130895184, 0.8655]
# sequential model is trained. best val loss is: [0.34159188872095547, 0.8655]
# sequential model is trained. best val loss is: [0.34306809372258146, 0.86]
# sequential model is trained. best val loss is: [0.34257633831776796, 0.8645]
# sequential model is trained. best val loss is: [0.36859521796573474, 0.852]
# sequential model is trained. best val loss is: [0.33863402835474515, 0.8585]
# sequential model is trained. best val loss is: [0.3410477446346266, 0.86]
# sequential model is trained. best val loss is: [0.33862975785085503, 0.863]
# sequential model is trained. best val loss is: [0.3433939111110196, 0.8605]
# sequential model is trained. best val loss is: [0.7224252429008484, 0.3885]
# sequential model is trained. best val loss is: [0.5387675292491912, 0.8035]
# sequential model is trained. best val loss is: [0.4773157733641565, 0.8035]
# sequential model is trained. best val loss is: [0.3960533351539634, 0.831]
# sequential model is trained. best val loss is: [0.3511853828681633, 0.8535]
# sequential model is trained. best val loss is: [0.33367580773435795, 0.8595]
# sequential model is trained. best val loss is: [0.3396878480738617, 0.859]
# sequential model is trained. best val loss is: [0.3332069856923714, 0.8655]
# sequential model is trained. best val loss is: [0.5035844005942345, 0.8035]
# sequential model is trained. best val loss is: [0.3785325912684202, 0.843]
# sequential model is trained. best val loss is: [0.34756784405803776, 0.8585]
# sequential model is trained. best val loss is: [0.3394929269359418, 0.862]
# sequential model is trained. best val loss is: [0.5331953501924872, 0.8035]
# sequential model is trained. best val loss is: [0.4141374556235969, 0.8205]
# sequential model is trained. best val loss is: [0.3878651767661795, 0.8405]
# sequential model is trained. best val loss is: [0.3420791828227739, 0.86]
# sequential model is trained. best val loss is: [0.3392469795955194, 0.8605]
# sequential model is trained. best val loss is: [0.3534209011988302, 0.8585]
# sequential model is trained. best val loss is: [0.3573375266545437, 0.8565]
# sequential model is trained. best val loss is: [0.35185804125812786, 0.8645]
# sequential model is trained. best val loss is: [0.3339400467378239, 0.861]
# sequential model is trained. best val loss is: [0.3445583092666751, 0.8605]
# sequential model is trained. best val loss is: [0.3407555425596996, 0.859]
# sequential model is trained. best val loss is: [0.35836066656698007, 0.8475]
# sequential model is trained. best val loss is: [0.6348351359814406, 0.771]
# sequential model is trained. best val loss is: [0.45710749524086713, 0.8035]
# sequential model is trained. best val loss is: [0.42728071682341395, 0.8105]
# sequential model is trained. best val loss is: [0.36482013115333395, 0.8515]
# sequential model is trained. best val loss is: [0.3387411778398091, 0.8625]
# sequential model is trained. best val loss is: [0.3388604978661331, 0.863]
# sequential model is trained. best val loss is: [0.34114278335786435, 0.859]
# sequential model is trained. best val loss is: [0.3443993237626433, 0.8615]
# sequential model is trained. best val loss is: [0.44959692941978574, 0.8035]
# sequential model is trained. best val loss is: [0.35547926343465225, 0.856]
# sequential model is trained. best val loss is: [0.34066811744017467, 0.8655]
# sequential model is trained. best val loss is: [0.3367296091140256, 0.862]
# sequential model is trained. best val loss is: [0.48080057137459514, 0.8035]
# sequential model is trained. best val loss is: [0.401399200853426, 0.825]
# sequential model is trained. best val loss is: [0.3726261355872266, 0.846]
# sequential model is trained. best val loss is: [0.33802008917487547, 0.8645]
# sequential model is trained. best val loss is: [0.3373580184992159, 0.8655]
# sequential model is trained. best val loss is: [0.34960585552441364, 0.864]
# sequential model is trained. best val loss is: [0.3475580082187855, 0.861]
# sequential model is trained. best val loss is: [0.47100446524998113, 0.8245]
# sequential model is trained. best val loss is: [0.33592336345661694, 0.8645]
# sequential model is trained. best val loss is: [0.34528425481841907, 0.8625]
# sequential model is trained. best val loss is: [0.33965135072853014, 0.86]
# sequential model is trained. best val loss is: [0.33903715169333776, 0.8535]
# sequential model is trained. best val loss is: [0.6027166375368833, 0.803]
# sequential model is trained. best val loss is: [0.44487499389797447, 0.8035]
# sequential model is trained. best val loss is: [0.4137963204924017, 0.8195]
# sequential model is trained. best val loss is: [0.3491445021177642, 0.857]
# sequential model is trained. best val loss is: [0.33898901854505675, 0.861]
# sequential model is trained. best val loss is: [0.33982586049124813, 0.863]
# sequential model is trained. best val loss is: [0.3400060937103933, 0.8615]
# sequential model is trained. best val loss is: [0.3453411101737325, 0.8615]
# sequential model is trained. best val loss is: [0.45408155573531983, 0.8035]
# sequential model is trained. best val loss is: [0.3484832042057533, 0.857]
# sequential model is trained. best val loss is: [0.33933452987438795, 0.861]
# sequential model is trained. best val loss is: [0.3348646654083143, 0.868]
# sequential model is trained. best val loss is: [0.495169354505837, 0.8035]
# sequential model is trained. best val loss is: [0.3966933939834125, 0.833]
# sequential model is trained. best val loss is: [0.36453963590133937, 0.847]
# sequential model is trained. best val loss is: [0.3373375023365479, 0.864]
# sequential model is trained. best val loss is: [0.3437405905250042, 0.8615]
# sequential model is trained. best val loss is: [0.3515649872762987, 0.8605]
# sequential model is trained. best val loss is: [0.3485412137078346, 0.86]
# sequential model is trained. best val loss is: [0.3618016225949543, 0.8605]
# sequential model is trained. best val loss is: [0.3419657139192113, 0.867]
# sequential model is trained. best val loss is: [0.3359240032436828, 0.864]
# sequential model is trained. best val loss is: [0.34070462563989984, 0.8635]
# sequential model is trained. best val loss is: [0.3679837551329256, 0.8555]
# sequential model is trained. best val loss is: [0.6979712659269571, 0.4825]
# sequential model is trained. best val loss is: [0.6176743504405021, 0.788]
# sequential model is trained. best val loss is: [0.5716023884266614, 0.8035]
# sequential model is trained. best val loss is: [0.4560360614378005, 0.8035]
# sequential model is trained. best val loss is: [0.37852173643838616, 0.8425]
# sequential model is trained. best val loss is: [0.3389400748055164, 0.8665]
# sequential model is trained. best val loss is: [0.33260801787520655, 0.864]
# sequential model is trained. best val loss is: [0.3515342241381295, 0.866]
# sequential model is trained. best val loss is: [0.5609018458724022, 0.8035]
# sequential model is trained. best val loss is: [0.3901373786712065, 0.8385]
# sequential model is trained. best val loss is: [0.34360094940132696, 0.8585]
# sequential model is trained. best val loss is: [0.3347376062027265, 0.8625]
# sequential model is trained. best val loss is: [0.555523298997432, 0.8035]
# sequential model is trained. best val loss is: [0.4773626481257379, 0.8035]
# sequential model is trained. best val loss is: [0.4098797433441505, 0.8245]
# sequential model is trained. best val loss is: [0.3355902279656366, 0.863]
# sequential model is trained. best val loss is: [0.34333076818066094, 0.865]
# sequential model is trained. best val loss is: [0.3508029692382637, 0.8595]
# sequential model is trained. best val loss is: [0.34908094153157987, 0.857]
# sequential model is trained. best val loss is: [0.45820206046899953, 0.8305]
# sequential model is trained. best val loss is: [0.3406461238910797, 0.863]
# sequential model is trained. best val loss is: [0.3441300069412441, 0.8585]
# sequential model is trained. best val loss is: [0.34218585492629133, 0.8585]
# sequential model is trained. best val loss is: [0.4926539643332362, 0.8035]
# sequential model is trained. best val loss is: [0.7410670538395643, 0.256]
# sequential model is trained. best val loss is: [0.5592722579240799, 0.8035]
# sequential model is trained. best val loss is: [0.4934372316971421, 0.8035]
# sequential model is trained. best val loss is: [0.40434509407775476, 0.8185]
# sequential model is trained. best val loss is: [0.3507947237690678, 0.86]
# sequential model is trained. best val loss is: [0.3380136293101441, 0.861]
# sequential model is trained. best val loss is: [0.3423824177795568, 0.86]
# sequential model is trained. best val loss is: [0.34196279171615607, 0.865]
# sequential model is trained. best val loss is: [0.5082438985258341, 0.8035]
# sequential model is trained. best val loss is: [0.3731942488625646, 0.846]
# sequential model is trained. best val loss is: [0.34430850741558244, 0.859]
# sequential model is trained. best val loss is: [0.33447425383755397, 0.8695]
# sequential model is trained. best val loss is: [0.5218426392748952, 0.8035]
# sequential model is trained. best val loss is: [0.42267739377729596, 0.809]
# sequential model is trained. best val loss is: [0.38288861139514485, 0.841]
# sequential model is trained. best val loss is: [0.3400521534507279, 0.867]
# sequential model is trained. best val loss is: [0.3412488171166933, 0.865]
# sequential model is trained. best val loss is: [0.35559227084839107, 0.8555]
# sequential model is trained. best val loss is: [0.34084642395465153, 0.863]
# sequential model is trained. best val loss is: [0.3590500470735563, 0.857]
# sequential model is trained. best val loss is: [0.3391771645672634, 0.8635]
# sequential model is trained. best val loss is: [0.3420361935151528, 0.862]
# sequential model is trained. best val loss is: [0.33598699290366574, 0.862]
# sequential model is trained. best val loss is: [0.4526027906090021, 0.8035]
# sequential model is trained. best val loss is: [0.7073266632705927, 0.4235]
# sequential model is trained. best val loss is: [0.511775784060359, 0.8035]
# sequential model is trained. best val loss is: [0.46416984718479215, 0.8035]
# sequential model is trained. best val loss is: [0.3814283916950226, 0.84]
# sequential model is trained. best val loss is: [0.3441281256830989, 0.8555]
# sequential model is trained. best val loss is: [0.33826884098208393, 0.8645]
# sequential model is trained. best val loss is: [0.34517672453338605, 0.853]
# sequential model is trained. best val loss is: [0.3358308451071805, 0.8645]
# sequential model is trained. best val loss is: [0.4940728733539581, 0.8035]
# sequential model is trained. best val loss is: [0.3661305443267338, 0.8525]
# sequential model is trained. best val loss is: [0.34355673283129, 0.86]
# sequential model is trained. best val loss is: [0.3361940952759542, 0.87]
# sequential model is trained. best val loss is: [0.5223453188054263, 0.8035]
# sequential model is trained. best val loss is: [0.4130295820105821, 0.8185]
# sequential model is trained. best val loss is: [0.3833573607145809, 0.8405]
# sequential model is trained. best val loss is: [0.3381640569442243, 0.86]
# sequential model is trained. best val loss is: [0.34200221398881875, 0.861]
# sequential model is trained. best val loss is: [0.3521391084268096, 0.859]
# sequential model is trained. best val loss is: [0.33390456517542294, 0.857]
# sequential model is trained. best val loss is: [0.42840362534058046, 0.8425]
# sequential model is trained. best val loss is: [0.3428905850785877, 0.8555]
# sequential model is trained. best val loss is: [0.33844060721933306, 0.861]
# sequential model is trained. best val loss is: [0.3400630770766802, 0.863]
# sequential model is trained. best val loss is: [0.45903726074811857, 0.8265]
# sequential model is trained. best val loss is: [0.6110974026173354, 0.801]
# sequential model is trained. best val loss is: [0.4534549915120006, 0.8035]
# sequential model is trained. best val loss is: [0.4186301208678633, 0.8135]
# sequential model is trained. best val loss is: [0.3445595902784262, 0.8605]
# sequential model is trained. best val loss is: [0.3382347756645686, 0.859]
# sequential model is trained. best val loss is: [0.34932708898440096, 0.8605]
# sequential model is trained. best val loss is: [0.33761410766924826, 0.862]
# sequential model is trained. best val loss is: [0.34727236200725886, 0.8595]
# sequential model is trained. best val loss is: [0.45689858885295687, 0.8035]
# sequential model is trained. best val loss is: [0.3439100566022098, 0.8595]
# sequential model is trained. best val loss is: [0.3374578593893966, 0.862]
# sequential model is trained. best val loss is: [0.34149955879244365, 0.862]
# sequential model is trained. best val loss is: [0.4949716975837946, 0.8035]
# sequential model is trained. best val loss is: [0.39962233463907615, 0.828]
# sequential model is trained. best val loss is: [0.36105072268727234, 0.8545]
# sequential model is trained. best val loss is: [0.33634084519122187, 0.866]
# sequential model is trained. best val loss is: [0.34960164627030554, 0.857]
# sequential model is trained. best val loss is: [0.33981015166337925, 0.8605]
# sequential model is trained. best val loss is: [0.3393427077365835, 0.862]
# sequential model is trained. best val loss is: [0.4906127112805844, 0.8065]
# sequential model is trained. best val loss is: [0.3382366272090485, 0.866]
# sequential model is trained. best val loss is: [0.33572176791577185, 0.863]
# sequential model is trained. best val loss is: [0.3438515921431105, 0.8605]
# sequential model is trained. best val loss is: [0.49624625995755195, 0.8035]
# sequential model is trained. best val loss is: [0.560603587821126, 0.8035]
# sequential model is trained. best val loss is: [0.4250084718847647, 0.81]
# sequential model is trained. best val loss is: [0.39565494571486487, 0.8315]
# sequential model is trained. best val loss is: [0.3403962982041412, 0.8615]
# sequential model is trained. best val loss is: [0.33884872969587015, 0.8595]
# sequential model is trained. best val loss is: [0.3426448351060909, 0.863]
# sequential model is trained. best val loss is: [0.33935682102009845, 0.8625]
# sequential model is trained. best val loss is: [0.35890293002504303, 0.8565]
# sequential model is trained. best val loss is: [0.447478292459622, 0.8035]
# sequential model is trained. best val loss is: [0.3412257139271824, 0.863]
# sequential model is trained. best val loss is: [0.3379682052530115, 0.864]
# sequential model is trained. best val loss is: [0.34450501198898154, 0.8645]
# sequential model is trained. best val loss is: [0.48980262263864277, 0.8035]
# sequential model is trained. best val loss is: [0.3885702126999386, 0.835]
# sequential model is trained. best val loss is: [0.35152753173559903, 0.8575]
# sequential model is trained. best val loss is: [0.33588011219469627, 0.8655]
# sequential model is trained. best val loss is: [0.3617500697001594, 0.852]
# sequential model is trained. best val loss is: [0.3428401988384063, 0.8625]
# sequential model is trained. best val loss is: [0.3477345886466658, 0.8635]
# sequential model is trained. best val loss is: [0.495718670219183, 0.8035]

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adam', 'lr': 0.02}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[1], units=[32],
         optimizers=['adam'], lrs=[0.02],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.32911002930673383, 0.8665]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x156b95f10>],
#  [{'hidden_layer': 1, 'unit': 32, 'optimizer': 'adam', 'lr': 0.02}],
#  [0.32911002930673383])

# %%
# 2nd trial
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
# Out:
# sequential model is trained. best val loss is: [0.3651177641293034, 0.847]
# sequential model is trained. best val loss is: [0.3332989389179015, 0.8665]
# sequential model is trained. best val loss is: [0.33474753865864104, 0.861]
# sequential model is trained. best val loss is: [0.35720893557758554, 0.852]
# sequential model is trained. best val loss is: [0.9962370734475553, 0.2415]
# sequential model is trained. best val loss is: [0.8888054571114481, 0.286]
# sequential model is trained. best val loss is: [0.7989294683597982, 0.3725]
# sequential model is trained. best val loss is: [0.4820044072913006, 0.8065]
# sequential model is trained. best val loss is: [0.40893219015933574, 0.8205]
# sequential model is trained. best val loss is: [0.3392588627015939, 0.866]
# sequential model is trained. best val loss is: [0.3385017901233914, 0.865]
# sequential model is trained. best val loss is: [0.33057562967271736, 0.864]
# sequential model is trained. best val loss is: [0.7473904768116773, 0.445]
# sequential model is trained. best val loss is: [0.4245469536595047, 0.811]
# sequential model is trained. best val loss is: [0.3907040553716943, 0.829]
# sequential model is trained. best val loss is: [0.3378178930365375, 0.8655]
# sequential model is trained. best val loss is: [0.6254522183667869, 0.701]
# sequential model is trained. best val loss is: [0.4588379436992109, 0.8035]
# sequential model is trained. best val loss is: [0.4227294994518161, 0.817]
# sequential model is trained. best val loss is: [0.34281308486970374, 0.8675]
# sequential model is trained. best val loss is: [0.3595496505650226, 0.849]
# sequential model is trained. best val loss is: [0.33867161968131065, 0.862]
# sequential model is trained. best val loss is: [0.33706729076087294, 0.863]
# sequential model is trained. best val loss is: [0.3488951375163674, 0.8565]
# sequential model is trained. best val loss is: [0.3437223328060354, 0.858]
# sequential model is trained. best val loss is: [0.3339652743726974, 0.868]
# sequential model is trained. best val loss is: [0.32911002930673383, 0.8665]
# sequential model is trained. best val loss is: [0.3453483267284822, 0.863]
# sequential model is trained. best val loss is: [0.752408390790224, 0.508]
# sequential model is trained. best val loss is: [0.6698531559407711, 0.6305]
# sequential model is trained. best val loss is: [0.6081135409250855, 0.722]
# sequential model is trained. best val loss is: [0.4385161325354129, 0.814]
# sequential model is trained. best val loss is: [0.3876954791592434, 0.84]
# sequential model is trained. best val loss is: [0.33882403207400147, 0.8635]
# sequential model is trained. best val loss is: [0.33930146662059135, 0.866]
# sequential model is trained. best val loss is: [0.33889502955188716, 0.862]
# sequential model is trained. best val loss is: [0.5831197929419577, 0.755]
# sequential model is trained. best val loss is: [0.39792147488333285, 0.83]
# sequential model is trained. best val loss is: [0.3653116056169383, 0.85]
# sequential model is trained. best val loss is: [0.33958975695355365, 0.8675]
# sequential model is trained. best val loss is: [0.5785473781451583, 0.765]
# sequential model is trained. best val loss is: [0.42177850706782194, 0.8195]
# sequential model is trained. best val loss is: [0.39571931861154735, 0.833]
# sequential model is trained. best val loss is: [0.3402179043799188, 0.86]
# sequential model is trained. best val loss is: [0.34319286532342086, 0.861]
# sequential model is trained. best val loss is: [0.33744447799011856, 0.8635]
# sequential model is trained. best val loss is: [0.33881704130239193, 0.867]
# sequential model is trained. best val loss is: [0.35745222095234963, 0.8625]
# sequential model is trained. best val loss is: [0.34236709593611886, 0.8615]
# sequential model is trained. best val loss is: [0.3330993313664362, 0.8635]
# sequential model is trained. best val loss is: [0.3330528840346209, 0.8615]
# sequential model is trained. best val loss is: [0.3457553595418232, 0.864]
# sequential model is trained. best val loss is: [0.7595692180395126, 0.417]
# sequential model is trained. best val loss is: [0.6067133660316467, 0.708]
# sequential model is trained. best val loss is: [0.5243265310972929, 0.808]
# sequential model is trained. best val loss is: [0.41268955620378256, 0.823]
# sequential model is trained. best val loss is: [0.37113538753334435, 0.845]
# sequential model is trained. best val loss is: [0.3394003080929419, 0.863]
# sequential model is trained. best val loss is: [0.3373759569364606, 0.862]
# sequential model is trained. best val loss is: [0.33794828222781736, 0.8625]
# sequential model is trained. best val loss is: [0.5081392748169601, 0.805]
# sequential model is trained. best val loss is: [0.38625260975584386, 0.8365]
# sequential model is trained. best val loss is: [0.35659371575107796, 0.8565]
# sequential model is trained. best val loss is: [0.3396228359484703, 0.8635]
# sequential model is trained. best val loss is: [0.5125730385482311, 0.8035]
# sequential model is trained. best val loss is: [0.40813457443378864, 0.8205]
# sequential model is trained. best val loss is: [0.3872556623923592, 0.835]
# sequential model is trained. best val loss is: [0.34140189714422015, 0.86]
# sequential model is trained. best val loss is: [0.34267019174512825, 0.8605]
# sequential model is trained. best val loss is: [0.3348993649933048, 0.865]
# sequential model is trained. best val loss is: [0.33951535865805654, 0.865]
# sequential model is trained. best val loss is: [0.3488920167079373, 0.8545]
# sequential model is trained. best val loss is: [0.3381036494588188, 0.8655]
# sequential model is trained. best val loss is: [0.3335497506034169, 0.8665]
# sequential model is trained. best val loss is: [0.3334396196794112, 0.863]
# sequential model is trained. best val loss is: [0.3654264445651845, 0.8565]
# sequential model is trained. best val loss is: [0.7183548983484507, 0.441]
# sequential model is trained. best val loss is: [0.5472225116193294, 0.8015]
# sequential model is trained. best val loss is: [0.48122388173639774, 0.8035]
# sequential model is trained. best val loss is: [0.40306553438771514, 0.8235]
# sequential model is trained. best val loss is: [0.35620634153927677, 0.857]
# sequential model is trained. best val loss is: [0.3353550288387678, 0.865]
# sequential model is trained. best val loss is: [0.3344799932535715, 0.865]
# sequential model is trained. best val loss is: [0.34701648571462224, 0.858]
# sequential model is trained. best val loss is: [0.4815865207090974, 0.8035]
# sequential model is trained. best val loss is: [0.3804658116712235, 0.839]
# sequential model is trained. best val loss is: [0.34878209489909934, 0.8595]
# sequential model is trained. best val loss is: [0.33745139437168925, 0.8655]
# sequential model is trained. best val loss is: [0.5049886581450701, 0.8035]
# sequential model is trained. best val loss is: [0.4101861749226227, 0.8235]
# sequential model is trained. best val loss is: [0.38937667628796774, 0.836]
# sequential model is trained. best val loss is: [0.33866064003246354, 0.8645]
# sequential model is trained. best val loss is: [0.33908294191792265, 0.8645]
# sequential model is trained. best val loss is: [0.3362911049950297, 0.8655]
# sequential model is trained. best val loss is: [0.33831684603670253, 0.865]
# sequential model is trained. best val loss is: [0.34433957430055967, 0.8575]
# sequential model is trained. best val loss is: [0.33913112953121616, 0.865]
# sequential model is trained. best val loss is: [0.33140718589265056, 0.8665]
# sequential model is trained. best val loss is: [0.33644942836859093, 0.8595]
# sequential model is trained. best val loss is: [0.35520636584709503, 0.852]
# sequential model is trained. best val loss is: [0.6804750096648932, 0.556]
# sequential model is trained. best val loss is: [0.49754353288561104, 0.8045]
# sequential model is trained. best val loss is: [0.4491919123642147, 0.8055]
# sequential model is trained. best val loss is: [0.3891441032239236, 0.8305]
# sequential model is trained. best val loss is: [0.34594678461330475, 0.858]
# sequential model is trained. best val loss is: [0.333183722852839, 0.8675]
# sequential model is trained. best val loss is: [0.33199295820150576, 0.8675]
# sequential model is trained. best val loss is: [0.3411236817060934, 0.8675]
# sequential model is trained. best val loss is: [0.45871990745142105, 0.805]
# sequential model is trained. best val loss is: [0.37254502483224494, 0.844]
# sequential model is trained. best val loss is: [0.3471153528013965, 0.8565]
# sequential model is trained. best val loss is: [0.3382369328077275, 0.8645]
# sequential model is trained. best val loss is: [0.486788034170866, 0.8035]
# sequential model is trained. best val loss is: [0.40515716518927364, 0.819]
# sequential model is trained. best val loss is: [0.3840912715001032, 0.836]
# sequential model is trained. best val loss is: [0.3414722118164027, 0.864]
# sequential model is trained. best val loss is: [0.3406435621152004, 0.8665]
# sequential model is trained. best val loss is: [0.3394338488670512, 0.864]
# sequential model is trained. best val loss is: [0.3438773656099369, 0.8645]
# sequential model is trained. best val loss is: [0.3664958018863195, 0.8525]
# sequential model is trained. best val loss is: [0.34290851905881575, 0.864]
# sequential model is trained. best val loss is: [0.3397799781619142, 0.864]
# sequential model is trained. best val loss is: [0.334105687849237, 0.86]
# sequential model is trained. best val loss is: [0.35877215134830426, 0.855]
# sequential model is trained. best val loss is: [0.7552162458896637, 0.3475]
# sequential model is trained. best val loss is: [0.6588061263263225, 0.6475]
# sequential model is trained. best val loss is: [0.5926704151257872, 0.7765]
# sequential model is trained. best val loss is: [0.4395817268779501, 0.8095]
# sequential model is trained. best val loss is: [0.3785216185366735, 0.8425]
# sequential model is trained. best val loss is: [0.3339308903243455, 0.8675]
# sequential model is trained. best val loss is: [0.3385793987865859, 0.86]
# sequential model is trained. best val loss is: [0.3329641706099501, 0.864]
# sequential model is trained. best val loss is: [0.5741249851733446, 0.7945]
# sequential model is trained. best val loss is: [0.38877673277677965, 0.838]
# sequential model is trained. best val loss is: [0.3497170753417886, 0.8625]
# sequential model is trained. best val loss is: [0.33548616142449467, 0.8635]
# sequential model is trained. best val loss is: [0.5509780460000038, 0.806]
# sequential model is trained. best val loss is: [0.4285809415075928, 0.8135]
# sequential model is trained. best val loss is: [0.3882582081761211, 0.8415]
# sequential model is trained. best val loss is: [0.3389197984944258, 0.866]
# sequential model is trained. best val loss is: [0.3449000031594369, 0.861]
# sequential model is trained. best val loss is: [0.3413935912045144, 0.861]
# sequential model is trained. best val loss is: [0.3339311945601899, 0.867]
# sequential model is trained. best val loss is: [0.3450407573101345, 0.866]
# sequential model is trained. best val loss is: [0.34034544791713417, 0.863]
# sequential model is trained. best val loss is: [0.34081399191325035, 0.86]
# sequential model is trained. best val loss is: [0.3372346231386685, 0.865]
# sequential model is trained. best val loss is: [0.3540537374208767, 0.858]
# sequential model is trained. best val loss is: [0.6496074435561895, 0.6945]
# sequential model is trained. best val loss is: [0.5541444020122289, 0.804]
# sequential model is trained. best val loss is: [0.5067909246236086, 0.8035]
# sequential model is trained. best val loss is: [0.4171470362637192, 0.812]
# sequential model is trained. best val loss is: [0.37418775937496684, 0.8415]
# sequential model is trained. best val loss is: [0.3366934050302889, 0.8615]
# sequential model is trained. best val loss is: [0.33632972628136065, 0.865]
# sequential model is trained. best val loss is: [0.3350356673123803, 0.86]
# sequential model is trained. best val loss is: [0.5034665884003043, 0.8035]
# sequential model is trained. best val loss is: [0.387665414331248, 0.8305]
# sequential model is trained. best val loss is: [0.35078163946210406, 0.86]
# sequential model is trained. best val loss is: [0.33597741500405026, 0.864]
# sequential model is trained. best val loss is: [0.5234377843886614, 0.8035]
# sequential model is trained. best val loss is: [0.41726160908397286, 0.8135]
# sequential model is trained. best val loss is: [0.39269806194398554, 0.825]
# sequential model is trained. best val loss is: [0.3393771130895184, 0.8655]
# sequential model is trained. best val loss is: [0.34159188872095547, 0.8655]
# sequential model is trained. best val loss is: [0.34306809372258146, 0.86]
# sequential model is trained. best val loss is: [0.34257633831776796, 0.8645]
# sequential model is trained. best val loss is: [0.36859521796573474, 0.852]
# sequential model is trained. best val loss is: [0.33863402835474515, 0.8585]
# sequential model is trained. best val loss is: [0.3410477446346266, 0.86]
# sequential model is trained. best val loss is: [0.33862975785085503, 0.863]
# sequential model is trained. best val loss is: [0.3433939111110196, 0.8605]
# sequential model is trained. best val loss is: [0.7224252429008484, 0.3885]
# sequential model is trained. best val loss is: [0.5387675292491912, 0.8035]
# sequential model is trained. best val loss is: [0.4773157733641565, 0.8035]
# sequential model is trained. best val loss is: [0.3960533351539634, 0.831]
# sequential model is trained. best val loss is: [0.3511853828681633, 0.8535]
# sequential model is trained. best val loss is: [0.33367580773435795, 0.8595]
# sequential model is trained. best val loss is: [0.3396878480738617, 0.859]
# sequential model is trained. best val loss is: [0.3332069856923714, 0.8655]
# sequential model is trained. best val loss is: [0.5035844005942345, 0.8035]
# sequential model is trained. best val loss is: [0.3785325912684202, 0.843]
# sequential model is trained. best val loss is: [0.34756784405803776, 0.8585]
# sequential model is trained. best val loss is: [0.3394929269359418, 0.862]
# sequential model is trained. best val loss is: [0.5331953501924872, 0.8035]
# sequential model is trained. best val loss is: [0.4141374556235969, 0.8205]
# sequential model is trained. best val loss is: [0.3878651767661795, 0.8405]
# sequential model is trained. best val loss is: [0.3420791828227739, 0.86]
# sequential model is trained. best val loss is: [0.3392469795955194, 0.8605]
# sequential model is trained. best val loss is: [0.3534209011988302, 0.8585]
# sequential model is trained. best val loss is: [0.3573375266545437, 0.8565]
# sequential model is trained. best val loss is: [0.35185804125812786, 0.8645]
# sequential model is trained. best val loss is: [0.3339400467378239, 0.861]
# sequential model is trained. best val loss is: [0.3445583092666751, 0.8605]
# sequential model is trained. best val loss is: [0.3407555425596996, 0.859]
# sequential model is trained. best val loss is: [0.35836066656698007, 0.8475]
# sequential model is trained. best val loss is: [0.6348351359814406, 0.771]
# sequential model is trained. best val loss is: [0.45710749524086713, 0.8035]
# sequential model is trained. best val loss is: [0.42728071682341395, 0.8105]
# sequential model is trained. best val loss is: [0.36482013115333395, 0.8515]
# sequential model is trained. best val loss is: [0.3387411778398091, 0.8625]
# sequential model is trained. best val loss is: [0.3388604978661331, 0.863]
# sequential model is trained. best val loss is: [0.34114278335786435, 0.859]
# sequential model is trained. best val loss is: [0.3443993237626433, 0.8615]
# sequential model is trained. best val loss is: [0.44959692941978574, 0.8035]
# sequential model is trained. best val loss is: [0.35547926343465225, 0.856]
# sequential model is trained. best val loss is: [0.34066811744017467, 0.8655]
# sequential model is trained. best val loss is: [0.3367296091140256, 0.862]
# sequential model is trained. best val loss is: [0.48080057137459514, 0.8035]
# sequential model is trained. best val loss is: [0.401399200853426, 0.825]
# sequential model is trained. best val loss is: [0.3726261355872266, 0.846]
# sequential model is trained. best val loss is: [0.33802008917487547, 0.8645]
# sequential model is trained. best val loss is: [0.3373580184992159, 0.8655]
# sequential model is trained. best val loss is: [0.34960585552441364, 0.864]
# sequential model is trained. best val loss is: [0.3475580082187855, 0.861]
# sequential model is trained. best val loss is: [0.47100446524998113, 0.8245]
# sequential model is trained. best val loss is: [0.33592336345661694, 0.8645]
# sequential model is trained. best val loss is: [0.34528425481841907, 0.8625]
# sequential model is trained. best val loss is: [0.33965135072853014, 0.86]
# sequential model is trained. best val loss is: [0.33903715169333776, 0.8535]
# sequential model is trained. best val loss is: [0.6027166375368833, 0.803]
# sequential model is trained. best val loss is: [0.44487499389797447, 0.8035]
# sequential model is trained. best val loss is: [0.4137963204924017, 0.8195]
# sequential model is trained. best val loss is: [0.3491445021177642, 0.857]
# sequential model is trained. best val loss is: [0.33898901854505675, 0.861]
# sequential model is trained. best val loss is: [0.33982586049124813, 0.863]
# sequential model is trained. best val loss is: [0.3400060937103933, 0.8615]
# sequential model is trained. best val loss is: [0.3453411101737325, 0.8615]
# sequential model is trained. best val loss is: [0.45408155573531983, 0.8035]
# sequential model is trained. best val loss is: [0.3484832042057533, 0.857]
# sequential model is trained. best val loss is: [0.33933452987438795, 0.861]
# sequential model is trained. best val loss is: [0.3348646654083143, 0.868]
# sequential model is trained. best val loss is: [0.495169354505837, 0.8035]
# sequential model is trained. best val loss is: [0.3966933939834125, 0.833]
# sequential model is trained. best val loss is: [0.36453963590133937, 0.847]
# sequential model is trained. best val loss is: [0.3373375023365479, 0.864]
# sequential model is trained. best val loss is: [0.3437405905250042, 0.8615]
# sequential model is trained. best val loss is: [0.3515649872762987, 0.8605]
# sequential model is trained. best val loss is: [0.3485412137078346, 0.86]
# sequential model is trained. best val loss is: [0.3618016225949543, 0.8605]
# sequential model is trained. best val loss is: [0.3419657139192113, 0.867]
# sequential model is trained. best val loss is: [0.3359240032436828, 0.864]
# sequential model is trained. best val loss is: [0.34070462563989984, 0.8635]
# sequential model is trained. best val loss is: [0.3679837551329256, 0.8555]
# sequential model is trained. best val loss is: [0.6979712659269571, 0.4825]
# sequential model is trained. best val loss is: [0.6176743504405021, 0.788]
# sequential model is trained. best val loss is: [0.5716023884266614, 0.8035]
# sequential model is trained. best val loss is: [0.4560360614378005, 0.8035]
# sequential model is trained. best val loss is: [0.37852173643838616, 0.8425]
# sequential model is trained. best val loss is: [0.3389400748055164, 0.8665]
# sequential model is trained. best val loss is: [0.33260801787520655, 0.864]
# sequential model is trained. best val loss is: [0.3515342241381295, 0.866]
# sequential model is trained. best val loss is: [0.5609018458724022, 0.8035]
# sequential model is trained. best val loss is: [0.3901373786712065, 0.8385]
# sequential model is trained. best val loss is: [0.34360094940132696, 0.8585]
# sequential model is trained. best val loss is: [0.3347376062027265, 0.8625]
# sequential model is trained. best val loss is: [0.555523298997432, 0.8035]
# sequential model is trained. best val loss is: [0.4773626481257379, 0.8035]
# sequential model is trained. best val loss is: [0.4098797433441505, 0.8245]
# sequential model is trained. best val loss is: [0.3355902279656366, 0.863]
# sequential model is trained. best val loss is: [0.34333076818066094, 0.865]
# sequential model is trained. best val loss is: [0.3508029692382637, 0.8595]
# sequential model is trained. best val loss is: [0.34908094153157987, 0.857]
# sequential model is trained. best val loss is: [0.45820206046899953, 0.8305]
# sequential model is trained. best val loss is: [0.3406461238910797, 0.863]
# sequential model is trained. best val loss is: [0.3441300069412441, 0.8585]
# sequential model is trained. best val loss is: [0.34218585492629133, 0.8585]
# sequential model is trained. best val loss is: [0.4926539643332362, 0.8035]
# sequential model is trained. best val loss is: [0.7410670538395643, 0.256]
# sequential model is trained. best val loss is: [0.5592722579240799, 0.8035]
# sequential model is trained. best val loss is: [0.4934372316971421, 0.8035]
# sequential model is trained. best val loss is: [0.40434509407775476, 0.8185]
# sequential model is trained. best val loss is: [0.3507947237690678, 0.86]
# sequential model is trained. best val loss is: [0.3380136293101441, 0.861]
# sequential model is trained. best val loss is: [0.3423824177795568, 0.86]
# sequential model is trained. best val loss is: [0.34196279171615607, 0.865]
# sequential model is trained. best val loss is: [0.5082438985258341, 0.8035]
# sequential model is trained. best val loss is: [0.3731942488625646, 0.846]
# sequential model is trained. best val loss is: [0.34430850741558244, 0.859]
# sequential model is trained. best val loss is: [0.33447425383755397, 0.8695]
# sequential model is trained. best val loss is: [0.5218426392748952, 0.8035]
# sequential model is trained. best val loss is: [0.42267739377729596, 0.809]
# sequential model is trained. best val loss is: [0.38288861139514485, 0.841]
# sequential model is trained. best val loss is: [0.3400521534507279, 0.867]
# sequential model is trained. best val loss is: [0.3412488171166933, 0.865]
# sequential model is trained. best val loss is: [0.35559227084839107, 0.8555]
# sequential model is trained. best val loss is: [0.34084642395465153, 0.863]
# sequential model is trained. best val loss is: [0.3590500470735563, 0.857]
# sequential model is trained. best val loss is: [0.3391771645672634, 0.8635]
# sequential model is trained. best val loss is: [0.3420361935151528, 0.862]
# sequential model is trained. best val loss is: [0.33598699290366574, 0.862]
# sequential model is trained. best val loss is: [0.4526027906090021, 0.8035]
# sequential model is trained. best val loss is: [0.7073266632705927, 0.4235]
# sequential model is trained. best val loss is: [0.511775784060359, 0.8035]
# sequential model is trained. best val loss is: [0.46416984718479215, 0.8035]
# sequential model is trained. best val loss is: [0.3814283916950226, 0.84]
# sequential model is trained. best val loss is: [0.3441281256830989, 0.8555]
# sequential model is trained. best val loss is: [0.33826884098208393, 0.8645]
# sequential model is trained. best val loss is: [0.34517672453338605, 0.853]
# sequential model is trained. best val loss is: [0.3358308451071805, 0.8645]
# sequential model is trained. best val loss is: [0.4940728733539581, 0.8035]
# sequential model is trained. best val loss is: [0.3661305443267338, 0.8525]
# sequential model is trained. best val loss is: [0.34355673283129, 0.86]
# sequential model is trained. best val loss is: [0.3361940952759542, 0.87]
# sequential model is trained. best val loss is: [0.5223453188054263, 0.8035]
# sequential model is trained. best val loss is: [0.4130295820105821, 0.8185]
# sequential model is trained. best val loss is: [0.3833573607145809, 0.8405]
# sequential model is trained. best val loss is: [0.3381640569442243, 0.86]
# sequential model is trained. best val loss is: [0.34200221398881875, 0.861]
# sequential model is trained. best val loss is: [0.3521391084268096, 0.859]
# sequential model is trained. best val loss is: [0.33390456517542294, 0.857]
# sequential model is trained. best val loss is: [0.42840362534058046, 0.8425]
# sequential model is trained. best val loss is: [0.3428905850785877, 0.8555]
# sequential model is trained. best val loss is: [0.33844060721933306, 0.861]
# sequential model is trained. best val loss is: [0.3400630770766802, 0.863]
# sequential model is trained. best val loss is: [0.45903726074811857, 0.8265]
# sequential model is trained. best val loss is: [0.6110974026173354, 0.801]
# sequential model is trained. best val loss is: [0.4534549915120006, 0.8035]
# sequential model is trained. best val loss is: [0.4186301208678633, 0.8135]
# sequential model is trained. best val loss is: [0.3445595902784262, 0.8605]
# sequential model is trained. best val loss is: [0.3382347756645686, 0.859]
# sequential model is trained. best val loss is: [0.34932708898440096, 0.8605]
# sequential model is trained. best val loss is: [0.33761410766924826, 0.862]
# sequential model is trained. best val loss is: [0.34727236200725886, 0.8595]
# sequential model is trained. best val loss is: [0.45689858885295687, 0.8035]
# sequential model is trained. best val loss is: [0.3439100566022098, 0.8595]
# sequential model is trained. best val loss is: [0.3374578593893966, 0.862]
# sequential model is trained. best val loss is: [0.34149955879244365, 0.862]
# sequential model is trained. best val loss is: [0.4949716975837946, 0.8035]
# sequential model is trained. best val loss is: [0.39962233463907615, 0.828]
# sequential model is trained. best val loss is: [0.36105072268727234, 0.8545]
# sequential model is trained. best val loss is: [0.33634084519122187, 0.866]
# sequential model is trained. best val loss is: [0.34960164627030554, 0.857]
# sequential model is trained. best val loss is: [0.33981015166337925, 0.8605]
# sequential model is trained. best val loss is: [0.3393427077365835, 0.862]
# sequential model is trained. best val loss is: [0.4906127112805844, 0.8065]
# sequential model is trained. best val loss is: [0.3382366272090485, 0.866]
# sequential model is trained. best val loss is: [0.33572176791577185, 0.863]
# sequential model is trained. best val loss is: [0.3438515921431105, 0.8605]
# sequential model is trained. best val loss is: [0.49624625995755195, 0.8035]
# sequential model is trained. best val loss is: [0.560603587821126, 0.8035]
# sequential model is trained. best val loss is: [0.4250084718847647, 0.81]
# sequential model is trained. best val loss is: [0.39565494571486487, 0.8315]
# sequential model is trained. best val loss is: [0.3403962982041412, 0.8615]
# sequential model is trained. best val loss is: [0.33884872969587015, 0.8595]
# sequential model is trained. best val loss is: [0.3426448351060909, 0.863]
# sequential model is trained. best val loss is: [0.33935682102009845, 0.8625]
# sequential model is trained. best val loss is: [0.35890293002504303, 0.8565]
# sequential model is trained. best val loss is: [0.447478292459622, 0.8035]
# sequential model is trained. best val loss is: [0.3412257139271824, 0.863]
# sequential model is trained. best val loss is: [0.3379682052530115, 0.864]
# sequential model is trained. best val loss is: [0.34450501198898154, 0.8645]
# sequential model is trained. best val loss is: [0.48980262263864277, 0.8035]
# sequential model is trained. best val loss is: [0.3885702126999386, 0.835]
# sequential model is trained. best val loss is: [0.35152753173559903, 0.8575]
# sequential model is trained. best val loss is: [0.33588011219469627, 0.8655]
# sequential model is trained. best val loss is: [0.3617500697001594, 0.852]
# sequential model is trained. best val loss is: [0.3428401988384063, 0.8625]
# sequential model is trained. best val loss is: [0.3477345886466658, 0.8635]
# sequential model is trained. best val loss is: [0.495718670219183, 0.8035]

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adam', 'lr': 0.02}
