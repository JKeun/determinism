# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename = "./data/iris.csv"
ds = DataSource(filename)
ds.data_load_split(target=[' class'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)

# %%
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.8948086500167847, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.3042512536048889, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.1684466004371643, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.05178288742899895, 1.0]
# sequential model is trained. best val loss is: [1.0220500230789185, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0203001499176025, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0183641910552979, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0032187700271606, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.9166278839111328, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.4026220142841339, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.23372167348861694, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.08493918925523758, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9939824342727661, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.7909755706787109, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.6319096088409424, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.2521807849407196, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.0069911479949951, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.8889452815055847, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.7965953350067139, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.4269596338272095, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.8437656164169312, 0.46666666865348816]
# sequential model is trained. best val loss is: [0.24143721163272858, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.15070059895515442, 1.0]
# sequential model is trained. best val loss is: [0.06338169425725937, 1.0]
# sequential model is trained. best val loss is: [0.7721022367477417, 0.699999988079071]
# sequential model is trained. best val loss is: [0.22953061759471893, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.12892654538154602, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.05582595616579056, 1.0]
# sequential model is trained. best val loss is: [0.9474985599517822, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.9449185729026794, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.942066490650177, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.9199926853179932, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.8032220602035522, 0.46666666865348816]
# sequential model is trained. best val loss is: [0.2973260283470154, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.19168904423713684, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.08931221812963486, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9155178666114807, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.7006193995475769, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5532103180885315, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.24831263720989227, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9334153532981873, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.8253442049026489, 0.4333333373069763]
# sequential model is trained. best val loss is: [0.732542097568512, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.41083672642707825, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.7147781252861023, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.18744723498821259, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.11599648743867874, 1.0]
# sequential model is trained. best val loss is: [0.053478412330150604, 1.0]
# sequential model is trained. best val loss is: [0.8770542144775391, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.18844006955623627, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0953771099448204, 1.0]
# sequential model is trained. best val loss is: [0.06809782236814499, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.2351359128952026, 0.03333333507180214]
# sequential model is trained. best val loss is: [1.2295501232147217, 0.06666667014360428]
# sequential model is trained. best val loss is: [1.2233866453170776, 0.06666667014360428]
# sequential model is trained. best val loss is: [1.175524115562439, 0.1666666716337204]
# sequential model is trained. best val loss is: [0.9316224455833435, 0.699999988079071]
# sequential model is trained. best val loss is: [0.2648845314979553, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.16007539629936218, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.05299995839595795, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.167357325553894, 0.20000000298023224]
# sequential model is trained. best val loss is: [0.7644309401512146, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5606667399406433, 0.800000011920929]
# sequential model is trained. best val loss is: [0.23320163786411285, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.206541895866394, 0.13333334028720856]
# sequential model is trained. best val loss is: [0.9911403656005859, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8291399478912354, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4148615896701813, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.7701936960220337, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.13947290182113647, 1.0]
# sequential model is trained. best val loss is: [0.08266200870275497, 1.0]
# sequential model is trained. best val loss is: [0.05161895602941513, 1.0]
# sequential model is trained. best val loss is: [0.6560815572738647, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.12933559715747833, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07934840768575668, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.05876690521836281, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0596752166748047, 0.46666666865348816]
# sequential model is trained. best val loss is: [1.052883505821228, 0.46666666865348816]
# sequential model is trained. best val loss is: [1.0454188585281372, 0.46666666865348816]
# sequential model is trained. best val loss is: [0.9885272979736328, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.7189347743988037, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.18923188745975494, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.1065841019153595, 1.0]
# sequential model is trained. best val loss is: [0.0404348149895668, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0026729106903076, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.6711685061454773, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5082637667655945, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.22544115781784058, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0388100147247314, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.8767832517623901, 0.800000011920929]
# sequential model is trained. best val loss is: [0.7493253350257874, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.40031349658966064, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5611743927001953, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.09495892375707626, 1.0]
# sequential model is trained. best val loss is: [0.06694848090410233, 1.0]
# sequential model is trained. best val loss is: [0.05544325336813927, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.5126374959945679, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.08955151587724686, 1.0]
# sequential model is trained. best val loss is: [0.04657663404941559, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.1183876097202301, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.970770537853241, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.9618514180183411, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.9521111845970154, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.8799510598182678, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5819817781448364, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.15095433592796326, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07570966333150864, 1.0]
# sequential model is trained. best val loss is: [0.09700366854667664, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9190195798873901, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.6294302344322205, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.48842138051986694, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.2220868617296219, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9532021880149841, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.8155290484428406, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.7079447507858276, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.39573681354522705, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.4335491359233856, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.07514116168022156, 1.0]
# sequential model is trained. best val loss is: [0.05522609129548073, 1.0]
# sequential model is trained. best val loss is: [0.08016650378704071, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.811688244342804, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.21681174635887146, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.12420801818370819, 1.0]
# sequential model is trained. best val loss is: [0.07935448735952377, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9720953106880188, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.9699716567993164, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.9676231145858765, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.9488154053688049, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8435077667236328, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.2755257487297058, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.1822836995124817, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.059191685169935226, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9521028995513916, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.7759557366371155, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.6096150875091553, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.24163439869880676, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9646046757698059, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8957690000534058, 0.699999988079071]
# sequential model is trained. best val loss is: [0.8223148584365845, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.4371228516101837, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.742660403251648, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.16764593124389648, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.09754970669746399, 1.0]
# sequential model is trained. best val loss is: [0.11291047930717468, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.8542525172233582, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.14996910095214844, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.07557783275842667, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.04657234996557236, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.169670581817627, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.1648480892181396, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.159525752067566, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.1180745363235474, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.9173084497451782, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.20239032804965973, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.12960423529148102, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07196041941642761, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1303988695144653, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.8628259301185608, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.6596184968948364, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.1937919557094574, 1.0]
# sequential model is trained. best val loss is: [1.1549193859100342, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.0359312295913696, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.9307984113693237, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.46570539474487305, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.7363963723182678, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.10139301419258118, 1.0]
# sequential model is trained. best val loss is: [0.05433627590537071, 1.0]
# sequential model is trained. best val loss is: [0.16619940102100372, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5138218402862549, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.09778228402137756, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0295706894248724, 1.0]
# sequential model is trained. best val loss is: [0.14622391760349274, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9676138162612915, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.9594261050224304, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.9504770040512085, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8814772963523865, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.5876811146736145, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.13935256004333496, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0636913850903511, 1.0]
# sequential model is trained. best val loss is: [0.07470621913671494, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9267475008964539, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.6488350033760071, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.48545733094215393, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.17858174443244934, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9538350701332092, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8359438180923462, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.7291174530982971, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.3719615936279297, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.41091442108154297, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.05584598705172539, 1.0]
# sequential model is trained. best val loss is: [0.04660564288496971, 1.0]
# sequential model is trained. best val loss is: [0.3032655417919159, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.4013437330722809, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.06202083081007004, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.06353084743022919, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.13266190886497498, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.1267458200454712, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.1100796461105347, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.0919263362884521, 0.20000000298023224]
# sequential model is trained. best val loss is: [0.9595282077789307, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.4976980984210968, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.1034674122929573, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.06428121030330658, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.060938723385334015, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0672333240509033, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.7098274827003479, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.5138456225395203, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.17914818227291107, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.107344388961792, 0.20000000298023224]
# sequential model is trained. best val loss is: [0.9454873204231262, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.8129331469535828, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.38857829570770264, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.3034990131855011, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.051161423325538635, 1.0]
# sequential model is trained. best val loss is: [0.057712070643901825, 1.0]
# sequential model is trained. best val loss is: [0.4106307327747345, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.2790198028087616, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.09244724363088608, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.042644206434488297, 1.0]
# sequential model is trained. best val loss is: [0.18492737412452698, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1782981157302856, 0.2666666805744171]
# sequential model is trained. best val loss is: [1.1502448320388794, 0.2666666805744171]
# sequential model is trained. best val loss is: [1.1200664043426514, 0.2666666805744171]
# sequential model is trained. best val loss is: [0.9131168127059937, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.366330623626709, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.08106228709220886, 1.0]
# sequential model is trained. best val loss is: [0.08454032242298126, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.1312086284160614, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.118848204612732, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.7583553791046143, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5583211183547974, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.18471434712409973, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1603014469146729, 0.2666666805744171]
# sequential model is trained. best val loss is: [0.9996109008789062, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8671294450759888, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.4249054193496704, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.21256011724472046, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0529911182820797, 1.0]
# sequential model is trained. best val loss is: [0.06971393525600433, 1.0]
# sequential model is trained. best val loss is: [0.19427724182605743, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0093199014663696, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.24881133437156677, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.12433268129825592, 1.0]
# sequential model is trained. best val loss is: [0.05224185064435005, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1495320796966553, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.1471494436264038, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.144532322883606, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.1249878406524658, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.0379282236099243, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.3858204483985901, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.20506587624549866, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.083234503865242, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1309969425201416, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.0153965950012207, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8699373602867126, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.2930143475532532, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.1428463459014893, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.0941041707992554, 0.3333333432674408]
# sequential model is trained. best val loss is: [1.0532312393188477, 0.5]
# sequential model is trained. best val loss is: [0.6576854586601257, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9252120852470398, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.14767245948314667, 1.0]
# sequential model is trained. best val loss is: [0.09675295650959015, 1.0]
# sequential model is trained. best val loss is: [0.20700617134571075, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.6625603437423706, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.13751618564128876, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.029978072270751, 1.0]
# sequential model is trained. best val loss is: [0.10584501922130585, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9837121367454529, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.9792648553848267, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.9743484854698181, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9345226883888245, 0.699999988079071]
# sequential model is trained. best val loss is: [0.73191237449646, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.162470281124115, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.11098206043243408, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0938938707113266, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9600458741188049, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.756683886051178, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5755448937416077, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.19731378555297852, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9759521484375, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9034903645515442, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.826181948184967, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4285232722759247, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.52003014087677, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.1254623383283615, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.02949385717511177, 1.0]
# sequential model is trained. best val loss is: [0.8857434391975403, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.521038293838501, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.08509194850921631, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0979427769780159, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.24241501092910767, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.051369071006775, 0.5333333611488342]
# sequential model is trained. best val loss is: [1.0433506965637207, 0.5333333611488342]
# sequential model is trained. best val loss is: [1.0345847606658936, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9647654891014099, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.6379128098487854, 0.800000011920929]
# sequential model is trained. best val loss is: [0.11567378044128418, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0714341253042221, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0373651348054409, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0232058763504028, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.781732439994812, 0.800000011920929]
# sequential model is trained. best val loss is: [0.555469810962677, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.1560264229774475, 1.0]
# sequential model is trained. best val loss is: [1.0425852537155151, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9579458236694336, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.870874285697937, 0.800000011920929]
# sequential model is trained. best val loss is: [0.39444124698638916, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.33706486225128174, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.07843024283647537, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.057797398418188095, 1.0]
# sequential model is trained. best val loss is: [0.0912628024816513, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.31059160828590393, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.08390961587429047, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0854664221405983, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.24903196096420288, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.0810787677764893, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0628398656845093, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0432554483413696, 0.4333333373069763]
# sequential model is trained. best val loss is: [0.8879608511924744, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.4095252454280853, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.07312942296266556, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.059242844581604004, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.08963244408369064, 1.0]
# sequential model is trained. best val loss is: [1.0366870164871216, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.7250545620918274, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.5093425512313843, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.17132170498371124, 1.0]
# sequential model is trained. best val loss is: [1.0674926042556763, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.9429005980491638, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.8310959935188293, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.374589741230011, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.20986150205135345, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.05638774856925011, 1.0]
# sequential model is trained. best val loss is: [0.08966576308012009, 1.0]
# sequential model is trained. best val loss is: [1.0241119861602783, 0.699999988079071]
# sequential model is trained. best val loss is: [0.17436781525611877, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.019552920013666153, 1.0]
# sequential model is trained. best val loss is: [0.08983200043439865, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.00772359361872077, 1.0]
# sequential model is trained. best val loss is: [1.0849015712738037, 0.3333333432674408]
# sequential model is trained. best val loss is: [1.0567476749420166, 0.5666666626930237]
# sequential model is trained. best val loss is: [1.026375651359558, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8047395348548889, 0.800000011920929]
# sequential model is trained. best val loss is: [0.2563032805919647, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.06695897877216339, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.05483153834939003, 1.0]
# sequential model is trained. best val loss is: [0.0744626522064209, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0462236404418945, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.7535245418548584, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5461952686309814, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.16220851242542267, 1.0]
# sequential model is trained. best val loss is: [1.0744081735610962, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.963925302028656, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.8582537174224854, 0.800000011920929]
# sequential model is trained. best val loss is: [0.40697166323661804, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.15633779764175415, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07193199545145035, 1.0]
# sequential model is trained. best val loss is: [0.06021280959248543, 1.0]
# sequential model is trained. best val loss is: [34.69099426269531, 0.699999988079071]
# ==== 2.8959500034650167 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'adam', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info['hidden_layer']], units=[best_model_info['unit']],
         optimizers=[best_model_info['optimizer']], lrs=[best_model_info['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.00772359361872077, 1.0]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7f4723da6b70>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'adam', 'lr': 0.1}],
#  [0.00772359361872077])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.8948086500167847, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.3042512536048889, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.1684466004371643, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.05178288742899895, 1.0]
# sequential model is trained. best val loss is: [1.0220500230789185, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0203001499176025, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0183641910552979, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0032187700271606, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.9166278839111328, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.4026220142841339, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.23372167348861694, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.08493918925523758, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9939824342727661, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.7909755706787109, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.6319096088409424, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.2521807849407196, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.0069911479949951, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.8889452815055847, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.7965953350067139, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.4269596338272095, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.8437656164169312, 0.46666666865348816]
# sequential model is trained. best val loss is: [0.24143721163272858, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.15070059895515442, 1.0]
# sequential model is trained. best val loss is: [0.06338169425725937, 1.0]
# sequential model is trained. best val loss is: [0.7721022367477417, 0.699999988079071]
# sequential model is trained. best val loss is: [0.22953061759471893, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.12892654538154602, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.05582595616579056, 1.0]
# sequential model is trained. best val loss is: [0.9474985599517822, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.9449185729026794, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.942066490650177, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.9199926853179932, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.8032220602035522, 0.46666666865348816]
# sequential model is trained. best val loss is: [0.2973260283470154, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.19168904423713684, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.08931221812963486, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9155178666114807, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.7006193995475769, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5532103180885315, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.24831263720989227, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9334153532981873, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.8253442049026489, 0.4333333373069763]
# sequential model is trained. best val loss is: [0.732542097568512, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.41083672642707825, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.7147781252861023, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.18744723498821259, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.11599648743867874, 1.0]
# sequential model is trained. best val loss is: [0.053478412330150604, 1.0]
# sequential model is trained. best val loss is: [0.8770542144775391, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.18844006955623627, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0953771099448204, 1.0]
# sequential model is trained. best val loss is: [0.06809782236814499, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.2351359128952026, 0.03333333507180214]
# sequential model is trained. best val loss is: [1.2295501232147217, 0.06666667014360428]
# sequential model is trained. best val loss is: [1.2233866453170776, 0.06666667014360428]
# sequential model is trained. best val loss is: [1.175524115562439, 0.1666666716337204]
# sequential model is trained. best val loss is: [0.9316224455833435, 0.699999988079071]
# sequential model is trained. best val loss is: [0.2648845314979553, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.16007539629936218, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.05299995839595795, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.167357325553894, 0.20000000298023224]
# sequential model is trained. best val loss is: [0.7644309401512146, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5606667399406433, 0.800000011920929]
# sequential model is trained. best val loss is: [0.23320163786411285, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.206541895866394, 0.13333334028720856]
# sequential model is trained. best val loss is: [0.9911403656005859, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8291399478912354, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4148615896701813, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.7701936960220337, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.13947290182113647, 1.0]
# sequential model is trained. best val loss is: [0.08266200870275497, 1.0]
# sequential model is trained. best val loss is: [0.05161895602941513, 1.0]
# sequential model is trained. best val loss is: [0.6560815572738647, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.12933559715747833, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07934840768575668, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.05876690521836281, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0596752166748047, 0.46666666865348816]
# sequential model is trained. best val loss is: [1.052883505821228, 0.46666666865348816]
# sequential model is trained. best val loss is: [1.0454188585281372, 0.46666666865348816]
# sequential model is trained. best val loss is: [0.9885272979736328, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.7189347743988037, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.18923188745975494, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.1065841019153595, 1.0]
# sequential model is trained. best val loss is: [0.0404348149895668, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0026729106903076, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.6711685061454773, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5082637667655945, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.22544115781784058, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0388100147247314, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.8767832517623901, 0.800000011920929]
# sequential model is trained. best val loss is: [0.7493253350257874, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.40031349658966064, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5611743927001953, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.09495892375707626, 1.0]
# sequential model is trained. best val loss is: [0.06694848090410233, 1.0]
# sequential model is trained. best val loss is: [0.05544325336813927, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.5126374959945679, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.08955151587724686, 1.0]
# sequential model is trained. best val loss is: [0.04657663404941559, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.1183876097202301, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.970770537853241, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.9618514180183411, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.9521111845970154, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.8799510598182678, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5819817781448364, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.15095433592796326, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07570966333150864, 1.0]
# sequential model is trained. best val loss is: [0.09700366854667664, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9190195798873901, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.6294302344322205, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.48842138051986694, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.2220868617296219, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9532021880149841, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.8155290484428406, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.7079447507858276, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.39573681354522705, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.4335491359233856, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.07514116168022156, 1.0]
# sequential model is trained. best val loss is: [0.05522609129548073, 1.0]
# sequential model is trained. best val loss is: [0.08016650378704071, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.811688244342804, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.21681174635887146, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.12420801818370819, 1.0]
# sequential model is trained. best val loss is: [0.07935448735952377, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9720953106880188, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.9699716567993164, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.9676231145858765, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.9488154053688049, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8435077667236328, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.2755257487297058, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.1822836995124817, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.059191685169935226, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9521028995513916, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.7759557366371155, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.6096150875091553, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.24163439869880676, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9646046757698059, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8957690000534058, 0.699999988079071]
# sequential model is trained. best val loss is: [0.8223148584365845, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.4371228516101837, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.742660403251648, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.16764593124389648, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.09754970669746399, 1.0]
# sequential model is trained. best val loss is: [0.11291047930717468, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.8542525172233582, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.14996910095214844, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.07557783275842667, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.04657234996557236, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.169670581817627, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.1648480892181396, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.159525752067566, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.1180745363235474, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.9173084497451782, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.20239032804965973, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.12960423529148102, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07196041941642761, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1303988695144653, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.8628259301185608, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.6596184968948364, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.1937919557094574, 1.0]
# sequential model is trained. best val loss is: [1.1549193859100342, 0.30000001192092896]
# sequential model is trained. best val loss is: [1.0359312295913696, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.9307984113693237, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.46570539474487305, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.7363963723182678, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.10139301419258118, 1.0]
# sequential model is trained. best val loss is: [0.05433627590537071, 1.0]
# sequential model is trained. best val loss is: [0.16619940102100372, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5138218402862549, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.09778228402137756, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0295706894248724, 1.0]
# sequential model is trained. best val loss is: [0.14622391760349274, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9676138162612915, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.9594261050224304, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.9504770040512085, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8814772963523865, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.5876811146736145, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.13935256004333496, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0636913850903511, 1.0]
# sequential model is trained. best val loss is: [0.07470621913671494, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9267475008964539, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.6488350033760071, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.48545733094215393, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.17858174443244934, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9538350701332092, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8359438180923462, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.7291174530982971, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.3719615936279297, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.41091442108154297, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.05584598705172539, 1.0]
# sequential model is trained. best val loss is: [0.04660564288496971, 1.0]
# sequential model is trained. best val loss is: [0.3032655417919159, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.4013437330722809, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.06202083081007004, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.06353084743022919, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.13266190886497498, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.1267458200454712, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.1100796461105347, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.0919263362884521, 0.20000000298023224]
# sequential model is trained. best val loss is: [0.9595282077789307, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.4976980984210968, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.1034674122929573, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.06428121030330658, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.060938723385334015, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0672333240509033, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.7098274827003479, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.5138456225395203, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.17914818227291107, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.107344388961792, 0.20000000298023224]
# sequential model is trained. best val loss is: [0.9454873204231262, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.8129331469535828, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.38857829570770264, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.3034990131855011, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.051161423325538635, 1.0]
# sequential model is trained. best val loss is: [0.057712070643901825, 1.0]
# sequential model is trained. best val loss is: [0.4106307327747345, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.2790198028087616, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.09244724363088608, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.042644206434488297, 1.0]
# sequential model is trained. best val loss is: [0.18492737412452698, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1782981157302856, 0.2666666805744171]
# sequential model is trained. best val loss is: [1.1502448320388794, 0.2666666805744171]
# sequential model is trained. best val loss is: [1.1200664043426514, 0.2666666805744171]
# sequential model is trained. best val loss is: [0.9131168127059937, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.366330623626709, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.08106228709220886, 1.0]
# sequential model is trained. best val loss is: [0.08454032242298126, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.1312086284160614, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.118848204612732, 0.30000001192092896]
# sequential model is trained. best val loss is: [0.7583553791046143, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.5583211183547974, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.18471434712409973, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1603014469146729, 0.2666666805744171]
# sequential model is trained. best val loss is: [0.9996109008789062, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.8671294450759888, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.4249054193496704, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.21256011724472046, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0529911182820797, 1.0]
# sequential model is trained. best val loss is: [0.06971393525600433, 1.0]
# sequential model is trained. best val loss is: [0.19427724182605743, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0093199014663696, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.24881133437156677, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.12433268129825592, 1.0]
# sequential model is trained. best val loss is: [0.05224185064435005, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1495320796966553, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.1471494436264038, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.144532322883606, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.1249878406524658, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.0379282236099243, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.3858204483985901, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.20506587624549866, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.083234503865242, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.1309969425201416, 0.20000000298023224]
# sequential model is trained. best val loss is: [1.0153965950012207, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8699373602867126, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.2930143475532532, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.1428463459014893, 0.1666666716337204]
# sequential model is trained. best val loss is: [1.0941041707992554, 0.3333333432674408]
# sequential model is trained. best val loss is: [1.0532312393188477, 0.5]
# sequential model is trained. best val loss is: [0.6576854586601257, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9252120852470398, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.14767245948314667, 1.0]
# sequential model is trained. best val loss is: [0.09675295650959015, 1.0]
# sequential model is trained. best val loss is: [0.20700617134571075, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.6625603437423706, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.13751618564128876, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.029978072270751, 1.0]
# sequential model is trained. best val loss is: [0.10584501922130585, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9837121367454529, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.9792648553848267, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.9743484854698181, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9345226883888245, 0.699999988079071]
# sequential model is trained. best val loss is: [0.73191237449646, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.162470281124115, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.11098206043243408, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0938938707113266, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.9600458741188049, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.756683886051178, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5755448937416077, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.19731378555297852, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.9759521484375, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9034903645515442, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.826181948184967, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4285232722759247, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.52003014087677, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.1254623383283615, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.02949385717511177, 1.0]
# sequential model is trained. best val loss is: [0.8857434391975403, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.521038293838501, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.08509194850921631, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0979427769780159, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.24241501092910767, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.051369071006775, 0.5333333611488342]
# sequential model is trained. best val loss is: [1.0433506965637207, 0.5333333611488342]
# sequential model is trained. best val loss is: [1.0345847606658936, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9647654891014099, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.6379128098487854, 0.800000011920929]
# sequential model is trained. best val loss is: [0.11567378044128418, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.0714341253042221, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0373651348054409, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0232058763504028, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.781732439994812, 0.800000011920929]
# sequential model is trained. best val loss is: [0.555469810962677, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.1560264229774475, 1.0]
# sequential model is trained. best val loss is: [1.0425852537155151, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.9579458236694336, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.870874285697937, 0.800000011920929]
# sequential model is trained. best val loss is: [0.39444124698638916, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.33706486225128174, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.07843024283647537, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.057797398418188095, 1.0]
# sequential model is trained. best val loss is: [0.0912628024816513, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.31059160828590393, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.08390961587429047, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.0854664221405983, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.24903196096420288, 0.9333333373069763]
# sequential model is trained. best val loss is: [1.0810787677764893, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0628398656845093, 0.36666667461395264]
# sequential model is trained. best val loss is: [1.0432554483413696, 0.4333333373069763]
# sequential model is trained. best val loss is: [0.8879608511924744, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.4095252454280853, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.07312942296266556, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.059242844581604004, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.08963244408369064, 1.0]
# sequential model is trained. best val loss is: [1.0366870164871216, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.7250545620918274, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.5093425512313843, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.17132170498371124, 1.0]
# sequential model is trained. best val loss is: [1.0674926042556763, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.9429005980491638, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.8310959935188293, 0.8666666746139526]
# sequential model is trained. best val loss is: [0.374589741230011, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.20986150205135345, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.05638774856925011, 1.0]
# sequential model is trained. best val loss is: [0.08966576308012009, 1.0]
# sequential model is trained. best val loss is: [1.0241119861602783, 0.699999988079071]
# sequential model is trained. best val loss is: [0.17436781525611877, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.019552920013666153, 1.0]
# sequential model is trained. best val loss is: [0.08983200043439865, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.00772359361872077, 1.0]
# sequential model is trained. best val loss is: [1.0849015712738037, 0.3333333432674408]
# sequential model is trained. best val loss is: [1.0567476749420166, 0.5666666626930237]
# sequential model is trained. best val loss is: [1.026375651359558, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.8047395348548889, 0.800000011920929]
# sequential model is trained. best val loss is: [0.2563032805919647, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.06695897877216339, 0.9333333373069763]
# sequential model is trained. best val loss is: [0.05483153834939003, 1.0]
# sequential model is trained. best val loss is: [0.0744626522064209, 0.9666666388511658]
# sequential model is trained. best val loss is: [1.0462236404418945, 0.5666666626930237]
# sequential model is trained. best val loss is: [0.7535245418548584, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5461952686309814, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.16220851242542267, 1.0]
# sequential model is trained. best val loss is: [1.0744081735610962, 0.4000000059604645]
# sequential model is trained. best val loss is: [0.963925302028656, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.8582537174224854, 0.800000011920929]
# sequential model is trained. best val loss is: [0.40697166323661804, 0.8999999761581421]
# sequential model is trained. best val loss is: [0.15633779764175415, 0.9666666388511658]
# sequential model is trained. best val loss is: [0.07193199545145035, 1.0]
# sequential model is trained. best val loss is: [0.06021280959248543, 1.0]
# sequential model is trained. best val loss is: [34.69099426269531, 0.699999988079071]
# ==== 2.8290132959683736 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'adam', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info_2nd['hidden_layer']], units=[best_model_info_2nd['unit']],
         optimizers=[best_model_info_2nd['optimizer']], lrs=[best_model_info_2nd['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.00772359361872077, 1.0]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7f470266e6a0>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'adam', 'lr': 0.1}],
#  [0.00772359361872077])
