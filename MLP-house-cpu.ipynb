# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename="./data/sberbank_train_reduced_10k.csv"
ds = DataSource(filename)
ds.data_load_split(target=['price_doc'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
# Out:
# sequential model is trained. best val loss is: [73454379964456.95, 73454380097888.73, 7172281.708348428]
# sequential model is trained. best val loss is: [72828751398957.06, 72828751335676.02, 7132047.7618691735]
# sequential model is trained. best val loss is: [71011273017205.25, 71011272880901.83, 7014428.850468745]
# sequential model is trained. best val loss is: [38570525418725.6, 38570525265272.945, 4484969.605246276]
# sequential model is trained. best val loss is: [73460333839806.47, 73460333949512.83, 7172668.114773389]
# sequential model is trained. best val loss is: [73460325638365.19, 73460325622286.06, 7172667.514616857]
# sequential model is trained. best val loss is: [73460309622820.86, 73460309523065.62, 7172666.380470432]
# sequential model is trained. best val loss is: [73156273344581.62, 73156273373803.56, 7154579.9582081465]
# sequential model is trained. best val loss is: [73459152205885.44, 73459152188087.62, 7172583.924522385]
# sequential model is trained. best val loss is: [73364977841946.62, 73364977902330.69, 7165952.554265001]
# sequential model is trained. best val loss is: [73066341769834.5, 73066341648554.03, 7145165.344248414]
# sequential model is trained. best val loss is: [62313726305635.44, 62313726296813.49, 6328814.199089588]
# sequential model is trained. best val loss is: [73460297874198.53, 73460297910349.48, 7172665.669298582]
# sequential model is trained. best val loss is: [73458664214441.98, 73458664316504.9, 7172562.7021404365]
# sequential model is trained. best val loss is: [73454005542977.53, 73454005478430.2, 7172268.137160025]
# sequential model is trained. best val loss is: [73295341444210.69, 73295341484809.31, 7162350.099754413]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73457438480379.9, 73457438449493.05, 7172474.144283745]
# sequential model is trained. best val loss is: [73182503322263.55, 73182503410174.5, 7154843.991354049]
# sequential model is trained. best val loss is: [72236961761374.2, 72236961737008.89, 7094347.502512051]
# sequential model is trained. best val loss is: [51043319546290.016, 51043319632749.07, 5632426.940469239]
# sequential model is trained. best val loss is: [73449997564719.11, 73449997487310.8, 7172024.465397313]
# sequential model is trained. best val loss is: [72197505983574.02, 72197506071802.23, 7089210.560442801]
# sequential model is trained. best val loss is: [67809301090453.51, 67809300929231.336, 6777730.703454561]
# sequential model is trained. best val loss is: [26855792162767.65, 26855792077218.79, 3262846.7011088463]
# sequential model is trained. best val loss is: [73460335401521.16, 73460335370356.0, 7172668.251447379]
# sequential model is trained. best val loss is: [73460323535171.58, 73460323737141.31, 7172667.515513269]
# sequential model is trained. best val loss is: [73460303886655.48, 73460304117544.48, 7172666.25967184]
# sequential model is trained. best val loss is: [68692686797709.31, 68692686718430.05, 6784671.089452756]
# sequential model is trained. best val loss is: [73458655660691.45, 73458655787511.34, 7172555.548050767]
# sequential model is trained. best val loss is: [73292878278545.4, 73292878264595.81, 7161039.937286232]
# sequential model is trained. best val loss is: [72662060928763.9, 72662060942321.69, 7115882.900584031]
# sequential model is trained. best val loss is: [52899574530791.695, 52899574687092.62, 5515959.452580461]
# sequential model is trained. best val loss is: [73460280125845.5, 73460280339968.25, 7172664.938035809]
# sequential model is trained. best val loss is: [73457576200081.4, 73457576259784.56, 7172494.195835308]
# sequential model is trained. best val loss is: [73449471759503.36, 73449471679251.8, 7171972.343864496]
# sequential model is trained. best val loss is: [73096051408941.06, 73096051426243.88, 7148623.473529919]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73454893538611.2, 73454893804743.64, 7172324.332756333]
# sequential model is trained. best val loss is: [72895661767188.48, 72895661681742.78, 7135233.156459598]
# sequential model is trained. best val loss is: [71052723254860.8, 71052723407240.9, 7011621.980454713]
# sequential model is trained. best val loss is: [37774480286437.38, 37774480441810.16, 4437347.866890392]
# sequential model is trained. best val loss is: [73438565554749.44, 73438565516631.61, 7171271.717683272]
# sequential model is trained. best val loss is: [70904131532342.78, 70904131640727.72, 7005749.259623507]
# sequential model is trained. best val loss is: [63192598318066.24, 63192598340153.26, 6464522.248249876]
# sequential model is trained. best val loss is: [19446369600951.96, 19446369527906.41, 2636727.810750041]
# sequential model is trained. best val loss is: [73460338383286.27, 73460338551601.84, 7172668.348712676]
# sequential model is trained. best val loss is: [73460320619032.58, 73460320501733.7, 7172667.099747179]
# sequential model is trained. best val loss is: [73460275032309.77, 73460274760306.48, 7172663.830944014]
# sequential model is trained. best val loss is: [41760065467248.6, 41760065468981.67, 4142592.164811951]
# sequential model is trained. best val loss is: [73456773924347.9, 73456773958520.56, 7172419.951803138]
# sequential model is trained. best val loss is: [73128808146169.86, 73128808135180.77, 7150203.9338411]
# sequential model is trained. best val loss is: [71746401108098.05, 71746401008534.39, 7050588.858302352]
# sequential model is trained. best val loss is: [41818822416270.84, 41818822438130.39, 4588269.696353637]
# sequential model is trained. best val loss is: [73460249403727.88, 73460249258435.6, 7172662.558473992]
# sequential model is trained. best val loss is: [73454589889560.58, 73454589774261.97, 7172303.411778236]
# sequential model is trained. best val loss is: [73437307361304.58, 73437307264731.08, 7171189.542236305]
# sequential model is trained. best val loss is: [72701916630151.17, 72701916719913.61, 7122740.473879127]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73449408751280.12, 73449409034297.34, 7171959.658414175]
# sequential model is trained. best val loss is: [72299009235795.97, 72299009181709.6, 7094889.327879482]
# sequential model is trained. best val loss is: [68555427700794.88, 68555427683105.17, 6834970.800504169]
# sequential model is trained. best val loss is: [23980144267889.887, 23980144240743.46, 3033642.0019842256]
# sequential model is trained. best val loss is: [73414749569392.64, 73414749544063.33, 7169774.787184155]
# sequential model is trained. best val loss is: [67892848902514.016, 67892848920336.59, 6787746.588157612]
# sequential model is trained. best val loss is: [55878517256091.22, 55878517227347.53, 5965298.051658524]
# sequential model is trained. best val loss is: [15773953381772.387, 15773953330845.482, 2350382.249954832]
# sequential model is trained. best val loss is: [73460333536264.19, 73460333551073.64, 7172668.149154248]
# sequential model is trained. best val loss is: [73460291290972.16, 73460291280477.64, 7172665.165831132]
# sequential model is trained. best val loss is: [73458681808445.44, 73458681830640.1, 7172538.234622272]
# sequential model is trained. best val loss is: [38602577908615.375, 38602578049560.44, 3809368.3433191055]
# sequential model is trained. best val loss is: [73453298792857.6, 73453298834689.64, 7172174.165965791]
# sequential model is trained. best val loss is: [72671376394725.38, 72671376479088.53, 7117084.914055623]
# sequential model is trained. best val loss is: [69856429280517.12, 69856429401679.39, 6912744.2232732]
# sequential model is trained. best val loss is: [31484525905045.992, 31484525825596.723, 3574021.92669083]
# sequential model is trained. best val loss is: [73460184441053.19, 73460184647401.78, 7172658.675333142]
# sequential model is trained. best val loss is: [73448611971330.05, 73448611828498.8, 7171924.142316064]
# sequential model is trained. best val loss is: [73410867576393.73, 73410867585991.92, 7169512.9884862825]
# sequential model is trained. best val loss is: [71907937052102.66, 71907937116916.94, 7072736.953380372]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73437343301992.45, 73437343521871.06, 7171176.0751263825]
# sequential model is trained. best val loss is: [70968600098898.3, 70968599902101.86, 7004920.602441414]
# sequential model is trained. best val loss is: [63986670643837.56, 63986670665780.36, 6512813.266551462]
# sequential model is trained. best val loss is: [17333262645372.053, 17333262712149.777, 2495689.6556461593]
# sequential model is trained. best val loss is: [73361661782966.27, 73361661870245.45, 7166373.095009342]
# sequential model is trained. best val loss is: [63085731749012.53, 63085731747508.9, 6444087.613873117]
# sequential model is trained. best val loss is: [45320649674314.914, 45320649861771.13, 5065057.222606735]
# sequential model is trained. best val loss is: [13814999745758.191, 13814999676096.11, 2101766.71985624]
# sequential model is trained. best val loss is: [73460334879059.97, 73460334661241.97, 7172668.168750844]
# sequential model is trained. best val loss is: [73460286283239.42, 73460286138256.06, 7172664.913248297]
# sequential model is trained. best val loss is: [73460107267608.58, 73460107240392.27, 7172652.671771908]
# sequential model is trained. best val loss is: [28573379596449.543, 28573379599326.293, 3198527.5539529696]
# sequential model is trained. best val loss is: [73446191971360.77, 73446191824902.25, 7171691.938090237]
# sequential model is trained. best val loss is: [71686843302444.55, 71686843430909.03, 7045305.655431998]
# sequential model is trained. best val loss is: [65878240585202.46, 65878240695705.07, 6602683.572513459]
# sequential model is trained. best val loss is: [25087468756213.27, 25087468706329.26, 3010576.3715729765]
# sequential model is trained. best val loss is: [73460076882817.03, 73460077093674.27, 7172651.970091983]
# sequential model is trained. best val loss is: [73435288718954.5, 73435288904964.38, 7171042.05519258]
# sequential model is trained. best val loss is: [73358010731266.05, 73358010784710.2, 7165905.6014321195]
# sequential model is trained. best val loss is: [70442255904381.77, 70442256080548.53, 6969164.407343851]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73412299315765.25, 73412299520099.14, 7169515.7178091565]
# sequential model is trained. best val loss is: [68465822979791.586, 68465822690422.13, 6824224.1845100615]
# sequential model is trained. best val loss is: [56359498362866.125, 56359498323725.42, 5973470.933893919]
# sequential model is trained. best val loss is: [14249661114748.078, 14249661119393.87, 2157668.703794016]
# sequential model is trained. best val loss is: [73208940392751.11, 73208940568956.9, 7156005.808304328]
# sequential model is trained. best val loss is: [25806765957424.26, 25806766003381.723, 3165739.604497881]
# sequential model is trained. best val loss is: [15496389198371.543, 15496389172775.664, 2323661.182968895]
# sequential model is trained. best val loss is: [11398555412604.635, 11398555404045.87, 1790952.4683113897]
# sequential model is trained. best val loss is: [73460335801266.17, 73460335792810.45, 7172668.207073115]
# sequential model is trained. best val loss is: [73460324507189.25, 73460324461290.75, 7172667.373017956]
# sequential model is trained. best val loss is: [73460265575620.61, 73460265779709.9, 7172662.923646781]
# sequential model is trained. best val loss is: [10960514577804.89, 10960514585661.596, 1775899.3764131712]
# sequential model is trained. best val loss is: [73446765986914.3, 73446766077080.14, 7171686.467467643]
# sequential model is trained. best val loss is: [63081204981630.48, 63081204783928.3, 6392663.456827931]
# sequential model is trained. best val loss is: [32593783031187.992, 32593783015884.793, 3653844.2578442553]
# sequential model is trained. best val loss is: [13307859686472.36, 13307859630670.562, 1970326.8296444968]
# sequential model is trained. best val loss is: [73460270095167.48, 73460270089715.69, 7172663.661445314]
# sequential model is trained. best val loss is: [73427139107168.25, 73427139172712.44, 7170467.839049391]
# sequential model is trained. best val loss is: [73202005121511.42, 73202005149205.94, 7155216.251306417]
# sequential model is trained. best val loss is: [50090129354294.9, 50090129489305.46, 5401371.563831913]
# sequential model is trained. best val loss is: [2.2102668018878708e+25, 2.210266788501793e+25, 105326200168.3685]
# sequential model is trained. best val loss is: [inf, 2.209717744877981e+37, 1.0511226732357749e+17]
# sequential model is trained. best val loss is: [inf, 9.050928881612965e+40, 6.727157230814744e+18]
# sequential model is trained. best val loss is: [inf, 2.209685897930062e+49, 1.0511150978675128e+23]
# sequential model is trained. best val loss is: [73411504962011.14, 73411504862110.28, 7169423.760397852]
# sequential model is trained. best val loss is: [43859476652300.16, 43859476614116.99, 4902151.73940397]
# sequential model is trained. best val loss is: [20565113794379.81, 20565113774266.4, 2713152.1447558342]
# sequential model is trained. best val loss is: [11503152613947.543, 11503152578097.916, 1778778.1994220603]
# sequential model is trained. best val loss is: [72545068246042.62, 72545068109435.62, 7113632.909248341]
# sequential model is trained. best val loss is: [16684217335798.195, 16684217403799.64, 2443807.586255467]
# sequential model is trained. best val loss is: [12699576924625.262, 12699576931234.45, 1964818.2812516785]
# sequential model is trained. best val loss is: [11136609562810.736, 11136609622096.367, 1767147.8210733235]
# sequential model is trained. best val loss is: [73460339087441.92, 73460339061167.78, 7172668.491979044]
# sequential model is trained. best val loss is: [73460321238183.94, 73460321385442.52, 7172667.29534904]
# sequential model is trained. best val loss is: [73447788831449.1, 73447788778740.88, 7171708.231819449]
# sequential model is trained. best val loss is: [10913806834798.613, 10913806870984.79, 1738227.8039131118]
# sequential model is trained. best val loss is: [73423831517237.25, 73423831475552.61, 7170162.102579808]
# sequential model is trained. best val loss is: [49025879467065.97, 49025879468340.96, 5341345.522052398]
# sequential model is trained. best val loss is: [24740186935110.168, 24740186913161.426, 3014334.247068446]
# sequential model is trained. best val loss is: [12002614973351.764, 12002614973975.123, 1844488.7046918408]
# sequential model is trained. best val loss is: [73460180961165.31, 73460180985862.25, 7172658.545390379]
# sequential model is trained. best val loss is: [73339267924561.92, 73339267771543.75, 7165042.439032697]
# sequential model is trained. best val loss is: [72518770175109.12, 72518770081062.89, 7111511.323857576]
# sequential model is trained. best val loss is: [36485239749692.36, 36485239727819.81, 4281585.935927511]
# sequential model is trained. best val loss is: [4.16964938920687e+16, 4.169649370709458e+16, 204143284.3396767]
# sequential model is trained. best val loss is: [22014013819913.977, 22014013821355.52, 2858536.1643186565]
# sequential model is trained. best val loss is: [22013184604107.734, 22013184646213.113, 2864901.3611983946]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [73299010080419.84, 73299010201043.64, 7162699.240108671]
# sequential model is trained. best val loss is: [26353037812828.44, 26353037748083.164, 3170990.257810677]
# sequential model is trained. best val loss is: [13806799738006.049, 13806799780567.51, 2133538.9451270592]
# sequential model is trained. best val loss is: [11391517730123.57, 11391517851938.912, 1772500.450511539]
# sequential model is trained. best val loss is: [69774314767326.25, 69774314689413.45, 6926548.75382297]
# sequential model is trained. best val loss is: [13750629500285.352, 13750629454338.363, 2093802.7995783184]
# sequential model is trained. best val loss is: [11842841096036.8, 11842841085244.547, 1817921.2035860552]
# sequential model is trained. best val loss is: [11014884836543.234, 11014884902988.365, 1753400.890700949]
# sequential model is trained. best val loss is: [73460335326810.11, 73460335198403.83, 7172668.205158761]
# sequential model is trained. best val loss is: [11326111024801.602, 11326111074763.08, 1863219.389903512]
# sequential model is trained. best val loss is: [10918596307093.215, 10918596297625.51, 1789705.539659159]
# sequential model is trained. best val loss is: [10929205097772.248, 10929205029709.215, 1722841.8327939443]
# sequential model is trained. best val loss is: [73296275145809.92, 73296275256925.97, 7161246.268851761]
# sequential model is trained. best val loss is: [28567852443262.523, 28567852559522.086, 3296952.224333106]
# sequential model is trained. best val loss is: [18110598059691.39, 18110598073028.934, 2542788.127928282]
# sequential model is trained. best val loss is: [11617486834127.844, 11617486827709.707, 1778968.4621609047]
# sequential model is trained. best val loss is: [73459703707242.5, 73459703881760.77, 7172626.897774106]
# sequential model is trained. best val loss is: [72954118357987.33, 72954118386176.38, 7139666.16384432]
# sequential model is trained. best val loss is: [69674254799207.805, 69674254945848.02, 6915241.817709421]
# sequential model is trained. best val loss is: [20014950536811.297, 20014950515074.848, 2704084.868607229]
# sequential model is trained. best val loss is: [1.4922723701976307e+17, 1.492272362907321e+17, 386270919.3359338]
# sequential model is trained. best val loss is: [22014028408665.07, 22014028361942.453, 2858474.25223316]
# sequential model is trained. best val loss is: [22013184604107.734, 22013184646213.113, 2864901.3611983876]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [72780416155942.9, 72780416121840.34, 7127568.591794513]
# sequential model is trained. best val loss is: [15591192720825.283, 15591192737395.65, 2346170.0667390064]
# sequential model is trained. best val loss is: [12006614557369.775, 12006614593603.416, 1843915.9884318018]
# sequential model is trained. best val loss is: [11239139251884.867, 11239139273293.877, 1758631.376646263]
# sequential model is trained. best val loss is: [60522705527148.33, 60522705595896.02, 6293187.846495037]
# sequential model is trained. best val loss is: [12222576476040.23, 12222576454965.916, 1866299.1313061432]
# sequential model is trained. best val loss is: [11554621951582.078, 11554621924794.088, 1794608.0266063863]
# sequential model is trained. best val loss is: [11104390806518.262, 11104390896486.723, 1749389.0619996006]
# sequential model is trained. best val loss is: [73460329936916.48, 73460330138463.19, 7172667.870187513]
# sequential model is trained. best val loss is: [12730867089181.406, 12730867087294.754, 2026034.5484698997]
# sequential model is trained. best val loss is: [11021064572197.02, 11021064544648.533, 1774378.469488104]
# sequential model is trained. best val loss is: [10931988183962.928, 10931988167291.4, 1720432.6292121613]
# sequential model is trained. best val loss is: [72726364645722.11, 72726364684843.56, 7120752.48681407]
# sequential model is trained. best val loss is: [21045332223450.344, 21045332197313.895, 2746970.0937907314]
# sequential model is trained. best val loss is: [14032370134584.879, 14032370088392.559, 2134053.692467789]
# sequential model is trained. best val loss is: [11456080479986.26, 11456080467926.523, 1776208.1575791934]
# sequential model is trained. best val loss is: [73457618803511.3, 73457618840259.27, 7172492.00124493]
# sequential model is trained. best val loss is: [71412165104926.2, 71412164858819.38, 7035513.077161005]
# sequential model is trained. best val loss is: [60619409164482.14, 60619409289905.24, 6295027.811137764]
# sequential model is trained. best val loss is: [15149354462123.04, 15149354505242.586, 2277867.6041456764]
# sequential model is trained. best val loss is: [2.401636305018678e+19, 2.401636308569665e+19, 4900647005.501468]
# sequential model is trained. best val loss is: [181658753656127.5, 181658753878894.2, 12994111.39827834]
# sequential model is trained. best val loss is: [22013184604056.8, 22013184646053.85, 2864901.3660064517]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [70671115114206.6, 70671115031041.12, 6986444.926219695]
# sequential model is trained. best val loss is: [12529231782965.154, 12529231725539.312, 1924439.540994198]
# sequential model is trained. best val loss is: [11826626824866.943, 11826626919062.51, 1797382.6438131034]
# sequential model is trained. best val loss is: [11079787596990.072, 11079787499637.688, 1737896.41242462]
# sequential model is trained. best val loss is: [43321428585524.695, 43321428593378.25, 4922223.354615633]
# sequential model is trained. best val loss is: [11722328077080.725, 11722328004417.703, 1796783.3521027141]
# sequential model is trained. best val loss is: [11301335861129.965, 11301335806348.455, 1780761.450454918]
# sequential model is trained. best val loss is: [11627321149545.805, 11627321168286.572, 1817664.338810365]
# sequential model is trained. best val loss is: [73460324026691.58, 73460323945225.39, 7172667.411721204]
# sequential model is trained. best val loss is: [10959415409438.242, 10959415432345.43, 1768662.3611184289]
# sequential model is trained. best val loss is: [10888500689752.568, 10888500636331.152, 1731715.0339204632]
# sequential model is trained. best val loss is: [10888290422008.904, 10888290563433.586, 1706319.2626263066]
# sequential model is trained. best val loss is: [70828308248376.77, 70828308190115.44, 6986262.165685709]
# sequential model is trained. best val loss is: [15671914249851.633, 15671914307991.4, 2322175.02932916]
# sequential model is trained. best val loss is: [12544104631009.814, 12544104707187.83, 1884900.6064954214]
# sequential model is trained. best val loss is: [11211271260475.877, 11211271189332.184, 1756083.4404941315]
# sequential model is trained. best val loss is: [73450169724706.81, 73450169646555.95, 7172015.10945544]
# sequential model is trained. best val loss is: [66221821479331.805, 66221821623600.53, 6669027.52912923]
# sequential model is trained. best val loss is: [43188503156924.83, 43188503201890.08, 4881983.538608672]
# sequential model is trained. best val loss is: [12659449680516.3, 12659449677751.047, 1925059.8995521897]
# sequential model is trained. best val loss is: [9.186599413777171e+16, 9.186599425715354e+16, 303057719.0751774]
# sequential model is trained. best val loss is: [26394695666232.496, 26394695755227.65, 3845476.0405807]
# sequential model is trained. best val loss is: [22013184605598.246, 22013184646185.84, 2864901.3620215347]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [63723950761840.16, 63723950741362.516, 6513633.524825559]
# sequential model is trained. best val loss is: [12006722488021.238, 12006722518965.828, 1815020.1773618732]
# sequential model is trained. best val loss is: [11477669554735.79, 11477669500971.748, 1775408.6623581508]
# sequential model is trained. best val loss is: [11006076595673.111, 11006076625321.686, 1720846.4932482038]
# sequential model is trained. best val loss is: [61831086174799.484, 61831086082329.68, 6347571.512477068]
# sequential model is trained. best val loss is: [12181076704821.031, 12181076644616.342, 1846413.2103169938]
# sequential model is trained. best val loss is: [11635556694567.63, 11635556637575.455, 1798022.2240865412]
# sequential model is trained. best val loss is: [11540797663197.773, 11540797590745.225, 1800014.0564782538]
# sequential model is trained. best val loss is: [73460337954738.17, 73460338038788.55, 7172668.365723803]
# sequential model is trained. best val loss is: [73460322337320.95, 73460322415129.81, 7172667.21879503]
# sequential model is trained. best val loss is: [12284977441748.14, 12284977513161.207, 1928682.5979663525]
# sequential model is trained. best val loss is: [11009689125750.84, 11009689210867.914, 1732400.0209297768]
# sequential model is trained. best val loss is: [73296954081267.72, 73296954022557.52, 7160997.286052768]
# sequential model is trained. best val loss is: [21078063251970.055, 21078063208197.98, 2747330.9393010777]
# sequential model is trained. best val loss is: [13733293715783.646, 13733293719697.988, 2083904.950636239]
# sequential model is trained. best val loss is: [11406005088117.969, 11406005132314.654, 1782716.6159526648]
# sequential model is trained. best val loss is: [73460176037625.86, 73460176251556.98, 7172657.634752318]
# sequential model is trained. best val loss is: [72510724420030.47, 72510724472115.98, 7109096.12024548]
# sequential model is trained. best val loss is: [61378902138490.1, 61378902167165.94, 6319325.269494622]
# sequential model is trained. best val loss is: [14278094136310.178, 14278094127234.248, 2194205.647256435]
# sequential model is trained. best val loss is: [inf, 5.782024754765655e+90, 2.4045841126410286e+45]
# sequential model is trained. best val loss is: [inf, 1.2414340306350813e+119, 3.5233989706462196e+59]
# sequential model is trained. best val loss is: [inf, 2.952488578124001e+119, 5.43368068451211e+59]
# sequential model is trained. best val loss is: [inf, 1.4697738012671274e+48, 1.2123422789241994e+24]
# sequential model is trained. best val loss is: [72563268615434.23, 72563268654941.02, 7112610.550098092]
# sequential model is trained. best val loss is: [12517178409537.12, 12517178432858.688, 1886017.957520099]
# sequential model is trained. best val loss is: [11753376489397.348, 11753376374154.42, 1792697.1066876901]
# sequential model is trained. best val loss is: [11103866185375.955, 11103866159174.268, 1748023.0124344241]
# sequential model is trained. best val loss is: [38163040909404.195, 38163040953440.45, 4422980.235659732]
# sequential model is trained. best val loss is: [11605773478361.764, 11605773426118.994, 1801790.650012977]
# sequential model is trained. best val loss is: [11183460600255.314, 11183460574358.465, 1770662.4889775787]
# sequential model is trained. best val loss is: [11885474952959.408, 11885474979239.268, 1834527.2751053171]
# sequential model is trained. best val loss is: [73460335400210.44, 73460335122961.97, 7172668.200756554]
# sequential model is trained. best val loss is: [20186797756622.934, 20186797798891.93, 2814579.856636406]
# sequential model is trained. best val loss is: [10925112355960.834, 10925112307441.623, 1753999.5514305313]
# sequential model is trained. best val loss is: [10892075170226.678, 10892075051037.484, 1714519.598212722]
# sequential model is trained. best val loss is: [72512189823623.17, 72512189757356.14, 7107971.805662227]
# sequential model is trained. best val loss is: [14679607790038.664, 14679607672739.89, 2221326.8167771497]
# sequential model is trained. best val loss is: [12143569162393.133, 12143569139591.96, 1852302.6307310543]
# sequential model is trained. best val loss is: [11081675680687.74, 11081675681665.246, 1749802.303534877]
# sequential model is trained. best val loss is: [73459476152676.36, 73459475963630.22, 7172613.660546201]
# sequential model is trained. best val loss is: [66639635543923.74, 66639635663044.305, 6703307.168924735]
# sequential model is trained. best val loss is: [36008690842414.516, 36008690667306.48, 4182014.4369784635]
# sequential model is trained. best val loss is: [12307936528600.984, 12307936553544.307, 1874058.3881393531]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [66882151475801.33, 66882151447643.24, 6733710.683624736]
# sequential model is trained. best val loss is: [11804904424020.037, 11804904531158.295, 1797433.6146415595]
# sequential model is trained. best val loss is: [11445463079540.602, 11445463101438.004, 1775077.761829068]
# sequential model is trained. best val loss is: [11014685950491.604, 11014686003565.139, 1724483.4103680584]
# sequential model is trained. best val loss is: [19339188831388.74, 19339188901117.57, 2667757.9028849066]
# sequential model is trained. best val loss is: [11208900050241.453, 11208900081193.225, 1775519.9388688535]
# sequential model is trained. best val loss is: [11062054648355.924, 11062054725173.795, 1752974.9607966652]
# sequential model is trained. best val loss is: [11107541360400.408, 11107541290025.283, 1837201.6042127612]
# sequential model is trained. best val loss is: [73460331938930.69, 73460331894323.88, 7172667.991858233]
# sequential model is trained. best val loss is: [11199625337544.764, 11199625283528.623, 1779212.9618260146]
# sequential model is trained. best val loss is: [10986075676666.885, 10986075585927.256, 1720336.1477822643]
# sequential model is trained. best val loss is: [10954626602794.629, 10954626740334.04, 1725867.172876438]
# sequential model is trained. best val loss is: [65632129506927.25, 65632129695059.07, 6597611.474894818]
# sequential model is trained. best val loss is: [12479867525937.29, 12479867527793.283, 1919704.3596794412]
# sequential model is trained. best val loss is: [11399807592207.453, 11399807595647.545, 1778431.2883979892]
# sequential model is trained. best val loss is: [11148439413317.482, 11148439323883.242, 1752828.9243315435]
# sequential model is trained. best val loss is: [73452672489984.0, 73452672653431.95, 7172173.3324577315]
# sequential model is trained. best val loss is: [46891249344286.83, 46891249431924.17, 5244908.128141548]
# sequential model is trained. best val loss is: [20145619679659.69, 20145619592113.31, 2716911.749326882]
# sequential model is trained. best val loss is: [11448453049989.2, 11448453017731.744, 1778794.3051816027]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [inf, 8.868422015699838e+182, 2.9779895929468634e+91]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [43838683155714.18, 43838683109670.59, 4933115.847975129]
# sequential model is trained. best val loss is: [11398624236491.172, 11398624147369.668, 1765964.1208705043]
# sequential model is trained. best val loss is: [11177482051157.312, 11177481997919.271, 1751150.6216647734]
# sequential model is trained. best val loss is: [11029796982684.99, 11029797021546.69, 1697694.6741998822]
# sequential model is trained. best val loss is: [14638552018445.492, 14638552123922.574, 2217967.283644746]
# sequential model is trained. best val loss is: [11077005938210.744, 11077006030236.695, 1754183.4137709672]
# sequential model is trained. best val loss is: [11363346554705.99, 11363346616397.027, 1770460.598869917]
# sequential model is trained. best val loss is: [13572306776076.592, 13572306757731.32, 2518437.2431648965]
# sequential model is trained. best val loss is: [73460329029402.62, 73460329205500.88, 7172667.794321889]
# sequential model is trained. best val loss is: [10980675790908.033, 10980675771130.129, 1730476.9620887337]
# sequential model is trained. best val loss is: [11051952358543.006, 11051952451308.87, 1716505.3036285383]
# sequential model is trained. best val loss is: [11015774584171.057, 11015774557626.018, 1706418.7542474316]
# sequential model is trained. best val loss is: [37401609798354.445, 37401609825994.25, 4124658.929149894]
# sequential model is trained. best val loss is: [11812552246185.227, 11812552305825.102, 1798392.7776511526]
# sequential model is trained. best val loss is: [11396701398110.783, 11396701417791.777, 1772342.1475305748]
# sequential model is trained. best val loss is: [11283925302785.123, 11283925345464.469, 1754045.0658321562]
# sequential model is trained. best val loss is: [73402540060065.8, 73402539927611.94, 7168875.532664221]
# sequential model is trained. best val loss is: [24484096802977.867, 24484096772537.457, 3035895.3780169706]
# sequential model is trained. best val loss is: [14777319250123.088, 14777319175733.145, 2250826.9899287997]
# sequential model is trained. best val loss is: [11478835614763.865, 11478835542754.072, 1762594.0530127236]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [21386495281375.26, 21386495321521.348, 2782812.216640739]
# sequential model is trained. best val loss is: [11311010108534.87, 11311010157137.76, 1764806.5636593406]
# sequential model is trained. best val loss is: [11087865267237.746, 11087865423568.846, 1738191.888166485]
# sequential model is trained. best val loss is: [10783442691345.139, 10783442754150.979, 1678622.2715503229]
# sequential model is trained. best val loss is: [12265198281090.357, 12265198252212.213, 1879306.681716761]
# sequential model is trained. best val loss is: [11171472353346.309, 11171472245434.174, 1744886.9608030303]
# sequential model is trained. best val loss is: [11943020029361.195, 11943020029641.453, 1842570.8289384989]
# sequential model is trained. best val loss is: [15613169972364.852, 15613170048313.795, 2927056.8890302824]
# sequential model is trained. best val loss is: [73460318206316.55, 73460318101395.33, 7172666.97661615]
# sequential model is trained. best val loss is: [11018820670217.18, 11018820640033.252, 1709160.9897115228]
# sequential model is trained. best val loss is: [10983536029923.873, 10983535945113.623, 1699774.0994712876]
# sequential model is trained. best val loss is: [11075222397497.654, 11075222360520.193, 1702657.9648842327]
# sequential model is trained. best val loss is: [24220969823161.54, 24220969740286.76, 2974528.8757943204]
# sequential model is trained. best val loss is: [11415726146044.7, 11415726099995.186, 1768768.1329760072]
# sequential model is trained. best val loss is: [11165759627627.0, 11165759531030.145, 1753402.8729573316]
# sequential model is trained. best val loss is: [11682219224509.334, 11682219175777.09, 1792025.214492108]
# sequential model is trained. best val loss is: [73041160863756.28, 73041160836202.92, 7145652.295751386]
# sequential model is trained. best val loss is: [15930376087079.201, 15930376045144.273, 2384320.1619910863]
# sequential model is trained. best val loss is: [12415262384385.287, 12415262330779.615, 1917000.3782793498]
# sequential model is trained. best val loss is: [11137314724557.934, 11137314835613.191, 1730615.2370134962]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [13332298623035.531, 13332298547708.984, 2060438.4274737563]
# sequential model is trained. best val loss is: [11128983447065.023, 11128983321924.188, 1746606.0684618785]
# sequential model is trained. best val loss is: [10962024429010.197, 10962024487305.107, 1717974.6808243506]
# sequential model is trained. best val loss is: [9740409998439.133, 9740410033936.143, 1668752.7624608986]

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[3], units=[256],
         optimizers=['rmsprop'], lrs=[0.1],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [9740409998439.133, 9740410033936.143, 1668752.7624608986]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x1603aaf50>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}],
#  [9740409998439.133])

# %%
# 2nd trial
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
# Out:
# sequential model is trained. best val loss is: [73454379964456.95, 73454380097888.73, 7172281.708348428]
# sequential model is trained. best val loss is: [72828751398957.06, 72828751335676.02, 7132047.7618691735]
# sequential model is trained. best val loss is: [71011273017205.25, 71011272880901.83, 7014428.850468745]
# sequential model is trained. best val loss is: [38570525418725.6, 38570525265272.945, 4484969.605246276]
# sequential model is trained. best val loss is: [73460333839806.47, 73460333949512.83, 7172668.114773389]
# sequential model is trained. best val loss is: [73460325638365.19, 73460325622286.06, 7172667.514616857]
# sequential model is trained. best val loss is: [73460309622820.86, 73460309523065.62, 7172666.380470432]
# sequential model is trained. best val loss is: [73156273344581.62, 73156273373803.56, 7154579.9582081465]
# sequential model is trained. best val loss is: [73459152205885.44, 73459152188087.62, 7172583.924522385]
# sequential model is trained. best val loss is: [73364977841946.62, 73364977902330.69, 7165952.554265001]
# sequential model is trained. best val loss is: [73066341769834.5, 73066341648554.03, 7145165.344248414]
# sequential model is trained. best val loss is: [62313726305635.44, 62313726296813.49, 6328814.199089588]
# sequential model is trained. best val loss is: [73460297874198.53, 73460297910349.48, 7172665.669298582]
# sequential model is trained. best val loss is: [73458664214441.98, 73458664316504.9, 7172562.7021404365]
# sequential model is trained. best val loss is: [73454005542977.53, 73454005478430.2, 7172268.137160025]
# sequential model is trained. best val loss is: [73295341444210.69, 73295341484809.31, 7162350.099754413]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73457438480379.9, 73457438449493.05, 7172474.144283745]
# sequential model is trained. best val loss is: [73182503322263.55, 73182503410174.5, 7154843.991354049]
# sequential model is trained. best val loss is: [72236961761374.2, 72236961737008.89, 7094347.502512051]
# sequential model is trained. best val loss is: [51043319546290.016, 51043319632749.07, 5632426.940469239]
# sequential model is trained. best val loss is: [73449997564719.11, 73449997487310.8, 7172024.465397313]
# sequential model is trained. best val loss is: [72197505983574.02, 72197506071802.23, 7089210.560442801]
# sequential model is trained. best val loss is: [67809301090453.51, 67809300929231.336, 6777730.703454561]
# sequential model is trained. best val loss is: [26855792162767.65, 26855792077218.79, 3262846.7011088463]
# sequential model is trained. best val loss is: [73460335401521.16, 73460335370356.0, 7172668.251447379]
# sequential model is trained. best val loss is: [73460323535171.58, 73460323737141.31, 7172667.515513269]
# sequential model is trained. best val loss is: [73460303886655.48, 73460304117544.48, 7172666.25967184]
# sequential model is trained. best val loss is: [68692686797709.31, 68692686718430.05, 6784671.089452756]
# sequential model is trained. best val loss is: [73458655660691.45, 73458655787511.34, 7172555.548050767]
# sequential model is trained. best val loss is: [73292878278545.4, 73292878264595.81, 7161039.937286232]
# sequential model is trained. best val loss is: [72662060928763.9, 72662060942321.69, 7115882.900584031]
# sequential model is trained. best val loss is: [52899574530791.695, 52899574687092.62, 5515959.452580461]
# sequential model is trained. best val loss is: [73460280125845.5, 73460280339968.25, 7172664.938035809]
# sequential model is trained. best val loss is: [73457576200081.4, 73457576259784.56, 7172494.195835308]
# sequential model is trained. best val loss is: [73449471759503.36, 73449471679251.8, 7171972.343864496]
# sequential model is trained. best val loss is: [73096051408941.06, 73096051426243.88, 7148623.473529919]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73454893538611.2, 73454893804743.64, 7172324.332756333]
# sequential model is trained. best val loss is: [72895661767188.48, 72895661681742.78, 7135233.156459598]
# sequential model is trained. best val loss is: [71052723254860.8, 71052723407240.9, 7011621.980454713]
# sequential model is trained. best val loss is: [37774480286437.38, 37774480441810.16, 4437347.866890392]
# sequential model is trained. best val loss is: [73438565554749.44, 73438565516631.61, 7171271.717683272]
# sequential model is trained. best val loss is: [70904131532342.78, 70904131640727.72, 7005749.259623507]
# sequential model is trained. best val loss is: [63192598318066.24, 63192598340153.26, 6464522.248249876]
# sequential model is trained. best val loss is: [19446369600951.96, 19446369527906.41, 2636727.810750041]
# sequential model is trained. best val loss is: [73460338383286.27, 73460338551601.84, 7172668.348712676]
# sequential model is trained. best val loss is: [73460320619032.58, 73460320501733.7, 7172667.099747179]
# sequential model is trained. best val loss is: [73460275032309.77, 73460274760306.48, 7172663.830944014]
# sequential model is trained. best val loss is: [41760065467248.6, 41760065468981.67, 4142592.164811951]
# sequential model is trained. best val loss is: [73456773924347.9, 73456773958520.56, 7172419.951803138]
# sequential model is trained. best val loss is: [73128808146169.86, 73128808135180.77, 7150203.9338411]
# sequential model is trained. best val loss is: [71746401108098.05, 71746401008534.39, 7050588.858302352]
# sequential model is trained. best val loss is: [41818822416270.84, 41818822438130.39, 4588269.696353637]
# sequential model is trained. best val loss is: [73460249403727.88, 73460249258435.6, 7172662.558473992]
# sequential model is trained. best val loss is: [73454589889560.58, 73454589774261.97, 7172303.411778236]
# sequential model is trained. best val loss is: [73437307361304.58, 73437307264731.08, 7171189.542236305]
# sequential model is trained. best val loss is: [72701916630151.17, 72701916719913.61, 7122740.473879127]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73449408751280.12, 73449409034297.34, 7171959.658414175]
# sequential model is trained. best val loss is: [72299009235795.97, 72299009181709.6, 7094889.327879482]
# sequential model is trained. best val loss is: [68555427700794.88, 68555427683105.17, 6834970.800504169]
# sequential model is trained. best val loss is: [23980144267889.887, 23980144240743.46, 3033642.0019842256]
# sequential model is trained. best val loss is: [73414749569392.64, 73414749544063.33, 7169774.787184155]
# sequential model is trained. best val loss is: [67892848902514.016, 67892848920336.59, 6787746.588157612]
# sequential model is trained. best val loss is: [55878517256091.22, 55878517227347.53, 5965298.051658524]
# sequential model is trained. best val loss is: [15773953381772.387, 15773953330845.482, 2350382.249954832]
# sequential model is trained. best val loss is: [73460333536264.19, 73460333551073.64, 7172668.149154248]
# sequential model is trained. best val loss is: [73460291290972.16, 73460291280477.64, 7172665.165831132]
# sequential model is trained. best val loss is: [73458681808445.44, 73458681830640.1, 7172538.234622272]
# sequential model is trained. best val loss is: [38602577908615.375, 38602578049560.44, 3809368.3433191055]
# sequential model is trained. best val loss is: [73453298792857.6, 73453298834689.64, 7172174.165965791]
# sequential model is trained. best val loss is: [72671376394725.38, 72671376479088.53, 7117084.914055623]
# sequential model is trained. best val loss is: [69856429280517.12, 69856429401679.39, 6912744.2232732]
# sequential model is trained. best val loss is: [31484525905045.992, 31484525825596.723, 3574021.92669083]
# sequential model is trained. best val loss is: [73460184441053.19, 73460184647401.78, 7172658.675333142]
# sequential model is trained. best val loss is: [73448611971330.05, 73448611828498.8, 7171924.142316064]
# sequential model is trained. best val loss is: [73410867576393.73, 73410867585991.92, 7169512.9884862825]
# sequential model is trained. best val loss is: [71907937052102.66, 71907937116916.94, 7072736.953380372]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73437343301992.45, 73437343521871.06, 7171176.0751263825]
# sequential model is trained. best val loss is: [70968600098898.3, 70968599902101.86, 7004920.602441414]
# sequential model is trained. best val loss is: [63986670643837.56, 63986670665780.36, 6512813.266551462]
# sequential model is trained. best val loss is: [17333262645372.053, 17333262712149.777, 2495689.6556461593]
# sequential model is trained. best val loss is: [73361661782966.27, 73361661870245.45, 7166373.095009342]
# sequential model is trained. best val loss is: [63085731749012.53, 63085731747508.9, 6444087.613873117]
# sequential model is trained. best val loss is: [45320649674314.914, 45320649861771.13, 5065057.222606735]
# sequential model is trained. best val loss is: [13814999745758.191, 13814999676096.11, 2101766.71985624]
# sequential model is trained. best val loss is: [73460334879059.97, 73460334661241.97, 7172668.168750844]
# sequential model is trained. best val loss is: [73460286283239.42, 73460286138256.06, 7172664.913248297]
# sequential model is trained. best val loss is: [73460107267608.58, 73460107240392.27, 7172652.671771908]
# sequential model is trained. best val loss is: [28573379596449.543, 28573379599326.293, 3198527.5539529696]
# sequential model is trained. best val loss is: [73446191971360.77, 73446191824902.25, 7171691.938090237]
# sequential model is trained. best val loss is: [71686843302444.55, 71686843430909.03, 7045305.655431998]
# sequential model is trained. best val loss is: [65878240585202.46, 65878240695705.07, 6602683.572513459]
# sequential model is trained. best val loss is: [25087468756213.27, 25087468706329.26, 3010576.3715729765]
# sequential model is trained. best val loss is: [73460076882817.03, 73460077093674.27, 7172651.970091983]
# sequential model is trained. best val loss is: [73435288718954.5, 73435288904964.38, 7171042.05519258]
# sequential model is trained. best val loss is: [73358010731266.05, 73358010784710.2, 7165905.6014321195]
# sequential model is trained. best val loss is: [70442255904381.77, 70442256080548.53, 6969164.407343851]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73412299315765.25, 73412299520099.14, 7169515.7178091565]
# sequential model is trained. best val loss is: [68465822979791.586, 68465822690422.13, 6824224.1845100615]
# sequential model is trained. best val loss is: [56359498362866.125, 56359498323725.42, 5973470.933893919]
# sequential model is trained. best val loss is: [14249661114748.078, 14249661119393.87, 2157668.703794016]
# sequential model is trained. best val loss is: [73208940392751.11, 73208940568956.9, 7156005.808304328]
# sequential model is trained. best val loss is: [25806765957424.26, 25806766003381.723, 3165739.604497881]
# sequential model is trained. best val loss is: [15496389198371.543, 15496389172775.664, 2323661.182968895]
# sequential model is trained. best val loss is: [11398555412604.635, 11398555404045.87, 1790952.4683113897]
# sequential model is trained. best val loss is: [73460335801266.17, 73460335792810.45, 7172668.207073115]
# sequential model is trained. best val loss is: [73460324507189.25, 73460324461290.75, 7172667.373017956]
# sequential model is trained. best val loss is: [73460265575620.61, 73460265779709.9, 7172662.923646781]
# sequential model is trained. best val loss is: [10960514577804.89, 10960514585661.596, 1775899.3764131712]
# sequential model is trained. best val loss is: [73446765986914.3, 73446766077080.14, 7171686.467467643]
# sequential model is trained. best val loss is: [63081204981630.48, 63081204783928.3, 6392663.456827931]
# sequential model is trained. best val loss is: [32593783031187.992, 32593783015884.793, 3653844.2578442553]
# sequential model is trained. best val loss is: [13307859686472.36, 13307859630670.562, 1970326.8296444968]
# sequential model is trained. best val loss is: [73460270095167.48, 73460270089715.69, 7172663.661445314]
# sequential model is trained. best val loss is: [73427139107168.25, 73427139172712.44, 7170467.839049391]
# sequential model is trained. best val loss is: [73202005121511.42, 73202005149205.94, 7155216.251306417]
# sequential model is trained. best val loss is: [50090129354294.9, 50090129489305.46, 5401371.563831913]
# sequential model is trained. best val loss is: [2.2102668018878708e+25, 2.210266788501793e+25, 105326200168.3685]
# sequential model is trained. best val loss is: [inf, 2.209717744877981e+37, 1.0511226732357749e+17]
# sequential model is trained. best val loss is: [inf, 9.050928881612965e+40, 6.727157230814744e+18]
# sequential model is trained. best val loss is: [inf, 2.209685897930062e+49, 1.0511150978675128e+23]
# sequential model is trained. best val loss is: [73411504962011.14, 73411504862110.28, 7169423.760397852]
# sequential model is trained. best val loss is: [43859476652300.16, 43859476614116.99, 4902151.73940397]
# sequential model is trained. best val loss is: [20565113794379.81, 20565113774266.4, 2713152.1447558342]
# sequential model is trained. best val loss is: [11503152613947.543, 11503152578097.916, 1778778.1994220603]
# sequential model is trained. best val loss is: [72545068246042.62, 72545068109435.62, 7113632.909248341]
# sequential model is trained. best val loss is: [16684217335798.195, 16684217403799.64, 2443807.586255467]
# sequential model is trained. best val loss is: [12699576924625.262, 12699576931234.45, 1964818.2812516785]
# sequential model is trained. best val loss is: [11136609562810.736, 11136609622096.367, 1767147.8210733235]
# sequential model is trained. best val loss is: [73460339087441.92, 73460339061167.78, 7172668.491979044]
# sequential model is trained. best val loss is: [73460321238183.94, 73460321385442.52, 7172667.29534904]
# sequential model is trained. best val loss is: [73447788831449.1, 73447788778740.88, 7171708.231819449]
# sequential model is trained. best val loss is: [10913806834798.613, 10913806870984.79, 1738227.8039131118]
# sequential model is trained. best val loss is: [73423831517237.25, 73423831475552.61, 7170162.102579808]
# sequential model is trained. best val loss is: [49025879467065.97, 49025879468340.96, 5341345.522052398]
# sequential model is trained. best val loss is: [24740186935110.168, 24740186913161.426, 3014334.247068446]
# sequential model is trained. best val loss is: [12002614973351.764, 12002614973975.123, 1844488.7046918408]
# sequential model is trained. best val loss is: [73460180961165.31, 73460180985862.25, 7172658.545390379]
# sequential model is trained. best val loss is: [73339267924561.92, 73339267771543.75, 7165042.439032697]
# sequential model is trained. best val loss is: [72518770175109.12, 72518770081062.89, 7111511.323857576]
# sequential model is trained. best val loss is: [36485239749692.36, 36485239727819.81, 4281585.935927511]
# sequential model is trained. best val loss is: [4.16964938920687e+16, 4.169649370709458e+16, 204143284.3396767]
# sequential model is trained. best val loss is: [22014013819913.977, 22014013821355.52, 2858536.1643186565]
# sequential model is trained. best val loss is: [22013184604107.734, 22013184646213.113, 2864901.3611983946]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [73299010080419.84, 73299010201043.64, 7162699.240108671]
# sequential model is trained. best val loss is: [26353037812828.44, 26353037748083.164, 3170990.257810677]
# sequential model is trained. best val loss is: [13806799738006.049, 13806799780567.51, 2133538.9451270592]
# sequential model is trained. best val loss is: [11391517730123.57, 11391517851938.912, 1772500.450511539]
# sequential model is trained. best val loss is: [69774314767326.25, 69774314689413.45, 6926548.75382297]
# sequential model is trained. best val loss is: [13750629500285.352, 13750629454338.363, 2093802.7995783184]
# sequential model is trained. best val loss is: [11842841096036.8, 11842841085244.547, 1817921.2035860552]
# sequential model is trained. best val loss is: [11014884836543.234, 11014884902988.365, 1753400.890700949]
# sequential model is trained. best val loss is: [73460335326810.11, 73460335198403.83, 7172668.205158761]
# sequential model is trained. best val loss is: [11326111024801.602, 11326111074763.08, 1863219.389903512]
# sequential model is trained. best val loss is: [10918596307093.215, 10918596297625.51, 1789705.539659159]
# sequential model is trained. best val loss is: [10929205097772.248, 10929205029709.215, 1722841.8327939443]
# sequential model is trained. best val loss is: [73296275145809.92, 73296275256925.97, 7161246.268851761]
# sequential model is trained. best val loss is: [28567852443262.523, 28567852559522.086, 3296952.224333106]
# sequential model is trained. best val loss is: [18110598059691.39, 18110598073028.934, 2542788.127928282]
# sequential model is trained. best val loss is: [11617486834127.844, 11617486827709.707, 1778968.4621609047]
# sequential model is trained. best val loss is: [73459703707242.5, 73459703881760.77, 7172626.897774106]
# sequential model is trained. best val loss is: [72954118357987.33, 72954118386176.38, 7139666.16384432]
# sequential model is trained. best val loss is: [69674254799207.805, 69674254945848.02, 6915241.817709421]
# sequential model is trained. best val loss is: [20014950536811.297, 20014950515074.848, 2704084.868607229]
# sequential model is trained. best val loss is: [1.4922723701976307e+17, 1.492272362907321e+17, 386270919.3359338]
# sequential model is trained. best val loss is: [22014028408665.07, 22014028361942.453, 2858474.25223316]
# sequential model is trained. best val loss is: [22013184604107.734, 22013184646213.113, 2864901.3611983876]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [72780416155942.9, 72780416121840.34, 7127568.591794513]
# sequential model is trained. best val loss is: [15591192720825.283, 15591192737395.65, 2346170.0667390064]
# sequential model is trained. best val loss is: [12006614557369.775, 12006614593603.416, 1843915.9884318018]
# sequential model is trained. best val loss is: [11239139251884.867, 11239139273293.877, 1758631.376646263]
# sequential model is trained. best val loss is: [60522705527148.33, 60522705595896.02, 6293187.846495037]
# sequential model is trained. best val loss is: [12222576476040.23, 12222576454965.916, 1866299.1313061432]
# sequential model is trained. best val loss is: [11554621951582.078, 11554621924794.088, 1794608.0266063863]
# sequential model is trained. best val loss is: [11104390806518.262, 11104390896486.723, 1749389.0619996006]
# sequential model is trained. best val loss is: [73460329936916.48, 73460330138463.19, 7172667.870187513]
# sequential model is trained. best val loss is: [12730867089181.406, 12730867087294.754, 2026034.5484698997]
# sequential model is trained. best val loss is: [11021064572197.02, 11021064544648.533, 1774378.469488104]
# sequential model is trained. best val loss is: [10931988183962.928, 10931988167291.4, 1720432.6292121613]
# sequential model is trained. best val loss is: [72726364645722.11, 72726364684843.56, 7120752.48681407]
# sequential model is trained. best val loss is: [21045332223450.344, 21045332197313.895, 2746970.0937907314]
# sequential model is trained. best val loss is: [14032370134584.879, 14032370088392.559, 2134053.692467789]
# sequential model is trained. best val loss is: [11456080479986.26, 11456080467926.523, 1776208.1575791934]
# sequential model is trained. best val loss is: [73457618803511.3, 73457618840259.27, 7172492.00124493]
# sequential model is trained. best val loss is: [71412165104926.2, 71412164858819.38, 7035513.077161005]
# sequential model is trained. best val loss is: [60619409164482.14, 60619409289905.24, 6295027.811137764]
# sequential model is trained. best val loss is: [15149354462123.04, 15149354505242.586, 2277867.6041456764]
# sequential model is trained. best val loss is: [2.401636305018678e+19, 2.401636308569665e+19, 4900647005.501468]
# sequential model is trained. best val loss is: [181658753656127.5, 181658753878894.2, 12994111.39827834]
# sequential model is trained. best val loss is: [22013184604056.8, 22013184646053.85, 2864901.3660064517]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [70671115114206.6, 70671115031041.12, 6986444.926219695]
# sequential model is trained. best val loss is: [12529231782965.154, 12529231725539.312, 1924439.540994198]
# sequential model is trained. best val loss is: [11826626824866.943, 11826626919062.51, 1797382.6438131034]
# sequential model is trained. best val loss is: [11079787596990.072, 11079787499637.688, 1737896.41242462]
# sequential model is trained. best val loss is: [43321428585524.695, 43321428593378.25, 4922223.354615633]
# sequential model is trained. best val loss is: [11722328077080.725, 11722328004417.703, 1796783.3521027141]
# sequential model is trained. best val loss is: [11301335861129.965, 11301335806348.455, 1780761.450454918]
# sequential model is trained. best val loss is: [11627321149545.805, 11627321168286.572, 1817664.338810365]
# sequential model is trained. best val loss is: [73460324026691.58, 73460323945225.39, 7172667.411721204]
# sequential model is trained. best val loss is: [10959415409438.242, 10959415432345.43, 1768662.3611184289]
# sequential model is trained. best val loss is: [10888500689752.568, 10888500636331.152, 1731715.0339204632]
# sequential model is trained. best val loss is: [10888290422008.904, 10888290563433.586, 1706319.2626263066]
# sequential model is trained. best val loss is: [70828308248376.77, 70828308190115.44, 6986262.165685709]
# sequential model is trained. best val loss is: [15671914249851.633, 15671914307991.4, 2322175.02932916]
# sequential model is trained. best val loss is: [12544104631009.814, 12544104707187.83, 1884900.6064954214]
# sequential model is trained. best val loss is: [11211271260475.877, 11211271189332.184, 1756083.4404941315]
# sequential model is trained. best val loss is: [73450169724706.81, 73450169646555.95, 7172015.10945544]
# sequential model is trained. best val loss is: [66221821479331.805, 66221821623600.53, 6669027.52912923]
# sequential model is trained. best val loss is: [43188503156924.83, 43188503201890.08, 4881983.538608672]
# sequential model is trained. best val loss is: [12659449680516.3, 12659449677751.047, 1925059.8995521897]
# sequential model is trained. best val loss is: [9.186599413777171e+16, 9.186599425715354e+16, 303057719.0751774]
# sequential model is trained. best val loss is: [26394695666232.496, 26394695755227.65, 3845476.0405807]
# sequential model is trained. best val loss is: [22013184605598.246, 22013184646185.84, 2864901.3620215347]
# sequential model is trained. best val loss is: [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential model is trained. best val loss is: [63723950761840.16, 63723950741362.516, 6513633.524825559]
# sequential model is trained. best val loss is: [12006722488021.238, 12006722518965.828, 1815020.1773618732]
# sequential model is trained. best val loss is: [11477669554735.79, 11477669500971.748, 1775408.6623581508]
# sequential model is trained. best val loss is: [11006076595673.111, 11006076625321.686, 1720846.4932482038]
# sequential model is trained. best val loss is: [61831086174799.484, 61831086082329.68, 6347571.512477068]
# sequential model is trained. best val loss is: [12181076704821.031, 12181076644616.342, 1846413.2103169938]
# sequential model is trained. best val loss is: [11635556694567.63, 11635556637575.455, 1798022.2240865412]
# sequential model is trained. best val loss is: [11540797663197.773, 11540797590745.225, 1800014.0564782538]
# sequential model is trained. best val loss is: [73460337954738.17, 73460338038788.55, 7172668.365723803]
# sequential model is trained. best val loss is: [73460322337320.95, 73460322415129.81, 7172667.21879503]
# sequential model is trained. best val loss is: [12284977441748.14, 12284977513161.207, 1928682.5979663525]
# sequential model is trained. best val loss is: [11009689125750.84, 11009689210867.914, 1732400.0209297768]
# sequential model is trained. best val loss is: [73296954081267.72, 73296954022557.52, 7160997.286052768]
# sequential model is trained. best val loss is: [21078063251970.055, 21078063208197.98, 2747330.9393010777]
# sequential model is trained. best val loss is: [13733293715783.646, 13733293719697.988, 2083904.950636239]
# sequential model is trained. best val loss is: [11406005088117.969, 11406005132314.654, 1782716.6159526648]
# sequential model is trained. best val loss is: [73460176037625.86, 73460176251556.98, 7172657.634752318]
# sequential model is trained. best val loss is: [72510724420030.47, 72510724472115.98, 7109096.12024548]
# sequential model is trained. best val loss is: [61378902138490.1, 61378902167165.94, 6319325.269494622]
# sequential model is trained. best val loss is: [14278094136310.178, 14278094127234.248, 2194205.647256435]
# sequential model is trained. best val loss is: [inf, 5.782024754765655e+90, 2.4045841126410286e+45]
# sequential model is trained. best val loss is: [inf, 1.2414340306350813e+119, 3.5233989706462196e+59]
# sequential model is trained. best val loss is: [inf, 2.952488578124001e+119, 5.43368068451211e+59]
# sequential model is trained. best val loss is: [inf, 1.4697738012671274e+48, 1.2123422789241994e+24]
# sequential model is trained. best val loss is: [72563268615434.23, 72563268654941.02, 7112610.550098092]
# sequential model is trained. best val loss is: [12517178409537.12, 12517178432858.688, 1886017.957520099]
# sequential model is trained. best val loss is: [11753376489397.348, 11753376374154.42, 1792697.1066876901]
# sequential model is trained. best val loss is: [11103866185375.955, 11103866159174.268, 1748023.0124344241]
# sequential model is trained. best val loss is: [38163040909404.195, 38163040953440.45, 4422980.235659732]
# sequential model is trained. best val loss is: [11605773478361.764, 11605773426118.994, 1801790.650012977]
# sequential model is trained. best val loss is: [11183460600255.314, 11183460574358.465, 1770662.4889775787]
# sequential model is trained. best val loss is: [11885474952959.408, 11885474979239.268, 1834527.2751053171]
# sequential model is trained. best val loss is: [73460335400210.44, 73460335122961.97, 7172668.200756554]
# sequential model is trained. best val loss is: [20186797756622.934, 20186797798891.93, 2814579.856636406]
# sequential model is trained. best val loss is: [10925112355960.834, 10925112307441.623, 1753999.5514305313]
# sequential model is trained. best val loss is: [10892075170226.678, 10892075051037.484, 1714519.598212722]
# sequential model is trained. best val loss is: [72512189823623.17, 72512189757356.14, 7107971.805662227]
# sequential model is trained. best val loss is: [14679607790038.664, 14679607672739.89, 2221326.8167771497]
# sequential model is trained. best val loss is: [12143569162393.133, 12143569139591.96, 1852302.6307310543]
# sequential model is trained. best val loss is: [11081675680687.74, 11081675681665.246, 1749802.303534877]
# sequential model is trained. best val loss is: [73459476152676.36, 73459475963630.22, 7172613.660546201]
# sequential model is trained. best val loss is: [66639635543923.74, 66639635663044.305, 6703307.168924735]
# sequential model is trained. best val loss is: [36008690842414.516, 36008690667306.48, 4182014.4369784635]
# sequential model is trained. best val loss is: [12307936528600.984, 12307936553544.307, 1874058.3881393531]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [66882151475801.33, 66882151447643.24, 6733710.683624736]
# sequential model is trained. best val loss is: [11804904424020.037, 11804904531158.295, 1797433.6146415595]
# sequential model is trained. best val loss is: [11445463079540.602, 11445463101438.004, 1775077.761829068]
# sequential model is trained. best val loss is: [11014685950491.604, 11014686003565.139, 1724483.4103680584]
# sequential model is trained. best val loss is: [19339188831388.74, 19339188901117.57, 2667757.9028849066]
# sequential model is trained. best val loss is: [11208900050241.453, 11208900081193.225, 1775519.9388688535]
# sequential model is trained. best val loss is: [11062054648355.924, 11062054725173.795, 1752974.9607966652]
# sequential model is trained. best val loss is: [11107541360400.408, 11107541290025.283, 1837201.6042127612]
# sequential model is trained. best val loss is: [73460331938930.69, 73460331894323.88, 7172667.991858233]
# sequential model is trained. best val loss is: [11199625337544.764, 11199625283528.623, 1779212.9618260146]
# sequential model is trained. best val loss is: [10986075676666.885, 10986075585927.256, 1720336.1477822643]
# sequential model is trained. best val loss is: [10954626602794.629, 10954626740334.04, 1725867.172876438]
# sequential model is trained. best val loss is: [65632129506927.25, 65632129695059.07, 6597611.474894818]
# sequential model is trained. best val loss is: [12479867525937.29, 12479867527793.283, 1919704.3596794412]
# sequential model is trained. best val loss is: [11399807592207.453, 11399807595647.545, 1778431.2883979892]
# sequential model is trained. best val loss is: [11148439413317.482, 11148439323883.242, 1752828.9243315435]
# sequential model is trained. best val loss is: [73452672489984.0, 73452672653431.95, 7172173.3324577315]
# sequential model is trained. best val loss is: [46891249344286.83, 46891249431924.17, 5244908.128141548]
# sequential model is trained. best val loss is: [20145619679659.69, 20145619592113.31, 2716911.749326882]
# sequential model is trained. best val loss is: [11448453049989.2, 11448453017731.744, 1778794.3051816027]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [inf, 8.868422015699838e+182, 2.9779895929468634e+91]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [43838683155714.18, 43838683109670.59, 4933115.847975129]
# sequential model is trained. best val loss is: [11398624236491.172, 11398624147369.668, 1765964.1208705043]
# sequential model is trained. best val loss is: [11177482051157.312, 11177481997919.271, 1751150.6216647734]
# sequential model is trained. best val loss is: [11029796982684.99, 11029797021546.69, 1697694.6741998822]
# sequential model is trained. best val loss is: [14638552018445.492, 14638552123922.574, 2217967.283644746]
# sequential model is trained. best val loss is: [11077005938210.744, 11077006030236.695, 1754183.4137709672]
# sequential model is trained. best val loss is: [11363346554705.99, 11363346616397.027, 1770460.598869917]
# sequential model is trained. best val loss is: [13572306776076.592, 13572306757731.32, 2518437.2431648965]
# sequential model is trained. best val loss is: [73460329029402.62, 73460329205500.88, 7172667.794321889]
# sequential model is trained. best val loss is: [10980675790908.033, 10980675771130.129, 1730476.9620887337]
# sequential model is trained. best val loss is: [11051952358543.006, 11051952451308.87, 1716505.3036285383]
# sequential model is trained. best val loss is: [11015774584171.057, 11015774557626.018, 1706418.7542474316]
# sequential model is trained. best val loss is: [37401609798354.445, 37401609825994.25, 4124658.929149894]
# sequential model is trained. best val loss is: [11812552246185.227, 11812552305825.102, 1798392.7776511526]
# sequential model is trained. best val loss is: [11396701398110.783, 11396701417791.777, 1772342.1475305748]
# sequential model is trained. best val loss is: [11283925302785.123, 11283925345464.469, 1754045.0658321562]
# sequential model is trained. best val loss is: [73402540060065.8, 73402539927611.94, 7168875.532664221]
# sequential model is trained. best val loss is: [24484096802977.867, 24484096772537.457, 3035895.3780169706]
# sequential model is trained. best val loss is: [14777319250123.088, 14777319175733.145, 2250826.9899287997]
# sequential model is trained. best val loss is: [11478835614763.865, 11478835542754.072, 1762594.0530127236]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [21386495281375.26, 21386495321521.348, 2782812.216640739]
# sequential model is trained. best val loss is: [11311010108534.87, 11311010157137.76, 1764806.5636593406]
# sequential model is trained. best val loss is: [11087865267237.746, 11087865423568.846, 1738191.888166485]
# sequential model is trained. best val loss is: [10783442691345.139, 10783442754150.979, 1678622.2715503229]
# sequential model is trained. best val loss is: [12265198281090.357, 12265198252212.213, 1879306.681716761]
# sequential model is trained. best val loss is: [11171472353346.309, 11171472245434.174, 1744886.9608030303]
# sequential model is trained. best val loss is: [11943020029361.195, 11943020029641.453, 1842570.8289384989]
# sequential model is trained. best val loss is: [15613169972364.852, 15613170048313.795, 2927056.8890302824]
# sequential model is trained. best val loss is: [73460318206316.55, 73460318101395.33, 7172666.97661615]
# sequential model is trained. best val loss is: [11018820670217.18, 11018820640033.252, 1709160.9897115228]
# sequential model is trained. best val loss is: [10983536029923.873, 10983535945113.623, 1699774.0994712876]
# sequential model is trained. best val loss is: [11075222397497.654, 11075222360520.193, 1702657.9648842327]
# sequential model is trained. best val loss is: [24220969823161.54, 24220969740286.76, 2974528.8757943204]
# sequential model is trained. best val loss is: [11415726146044.7, 11415726099995.186, 1768768.1329760072]
# sequential model is trained. best val loss is: [11165759627627.0, 11165759531030.145, 1753402.8729573316]
# sequential model is trained. best val loss is: [11682219224509.334, 11682219175777.09, 1792025.214492108]
# sequential model is trained. best val loss is: [73041160863756.28, 73041160836202.92, 7145652.295751386]
# sequential model is trained. best val loss is: [15930376087079.201, 15930376045144.273, 2384320.1619910863]
# sequential model is trained. best val loss is: [12415262384385.287, 12415262330779.615, 1917000.3782793498]
# sequential model is trained. best val loss is: [11137314724557.934, 11137314835613.191, 1730615.2370134962]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [13332298623035.531, 13332298547708.984, 2060438.4274737563]
# sequential model is trained. best val loss is: [11128983447065.023, 11128983321924.188, 1746606.0684618785]
# sequential model is trained. best val loss is: [10962024429010.197, 10962024487305.107, 1717974.6808243506]
# sequential model is trained. best val loss is: [9740409998439.133, 9740410033936.143, 1668752.7624608986]

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}
