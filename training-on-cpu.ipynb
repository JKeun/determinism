# %%
from src.DataSource import DataSource
from src.MLP import MLP, select_best_model

# %% [markdown]
# ## Titanic

# %%
filename="./data/titanic_train.csv"
ds_titanic = DataSource(filename)

ds_titanic.data_load_split(target=['Survived'], 
                   ignore=["Name", "Cabin", "Ticket"])
ds_titanic.define_problem()
ds_titanic.train_val_split(ratio=0.2, random_state=42)
ds_titanic.data_preprocess(ds_titanic.X_train, ds_titanic.y_train, train_set=True)
ds_titanic.data_preprocess(ds_titanic.X_val, ds_titanic.y_val, train_set=False)

# %%
mlp_titanic = MLP(ds_titanic.trans_X_train, ds_titanic.trans_y_train, problem=ds_titanic.problem)
mlp_titanic.build_structure(max_hidden_layers=1, units=[16], use_all=True)
mlp_titanic.create_optimizer(optimizers=['adam'], lrs=[0.01], use_all=True)
mlp_titanic.compile_model()

mlp_titanic.train_models(mlp_titanic.compiled_models,
                         ds_titanic.trans_X_train, ds_titanic.trans_y_train,
                         ds_titanic.trans_X_val, ds_titanic.trans_y_val,
                         batch_size=64, epochs=10)
# Out:
# sequential_30 model is trained. best val loss is : [0.6893095464933486, 0.6095238095238096]
# sequential_30 model is trained. best val loss is : [0.6872799440508797, 0.4714285714285714]
# sequential_30 model is trained. best val loss is : [0.7026587750230516, 0.3952380952380952]
# sequential_30 model is trained. best val loss is : [0.6371105954760596, 0.7476190476190476]
# sequential_30 model is trained. best val loss is : [0.7161075369233176, 0.4238095238095238]
# sequential_30 model is trained. best val loss is : [0.5872712013976914, 0.7]
# sequential_30 model is trained. best val loss is : [0.5753086182333175, 0.7428571428571429]
# sequential_30 model is trained. best val loss is : [0.47682202466364415, 0.7952380952380952]
# sequential_30 model is trained. best val loss is : [0.46156686373675865, 0.8]
# sequential_30 model is trained. best val loss is : [0.7684512538338785, 0.7904761904761904]
# sequential_30 model is trained. best val loss is : [0.7173159052500883, 0.7904761904761904]
# sequential_30 model is trained. best val loss is : [1.031233274847132, 0.7571428571428571]
# sequential_30 model is trained. best val loss is : [0.6889727544216883, 0.5952380952380952]
# sequential_30 model is trained. best val loss is : [0.5048527246784597, 0.8095238095238095]
# sequential_30 model is trained. best val loss is : [0.49242925867438314, 0.8]
# sequential_30 model is trained. best val loss is : [0.4739246557012112, 0.819047619047619]
# sequential_30 model is trained. best val loss is : [0.5689690281237875, 0.7619047619047619]
# sequential_30 model is trained. best val loss is : [0.4217826736573313, 0.819047619047619]
# sequential_30 model is trained. best val loss is : [0.4796252175371992, 0.8]
# sequential_30 model is trained. best val loss is : [0.7043928172273624, 0.8095238095238095]
# sequential_30 model is trained. best val loss is : [0.46508433316346437, 0.8]
# sequential_30 model is trained. best val loss is : [1.1081881371129596, 0.7952380952380952]
# sequential_30 model is trained. best val loss is : [1.7335029542197862, 0.8095238095238095]
# sequential_30 model is trained. best val loss is : [4.249131337255917, 0.7619047619047619]
# sequential_31 model is trained. best val loss is : [0.6972343461854117, 0.44285714285714284]
# sequential_31 model is trained. best val loss is : [0.6802120877163751, 0.6238095238095238]
# sequential_31 model is trained. best val loss is : [0.6709888472443535, 0.6047619047619047]
# sequential_31 model is trained. best val loss is : [0.6272472673938387, 0.6571428571428571]
# sequential_31 model is trained. best val loss is : [0.674912755262284, 0.638095238095238]
# sequential_31 model is trained. best val loss is : [0.6356592069069544, 0.719047619047619]
# sequential_31 model is trained. best val loss is : [0.5778930159551757, 0.7285714285714285]
# sequential_31 model is trained. best val loss is : [0.48446330256937514, 0.780952380952381]
# sequential_31 model is trained. best val loss is : [0.43344240116712174, 0.8142857142857143]
# sequential_31 model is trained. best val loss is : [0.7547194606394709, 0.7904761904761904]
# sequential_31 model is trained. best val loss is : [1.0012443776816708, 0.8095238095238095]
# sequential_31 model is trained. best val loss is : [1.2936880862030915, 0.7714285714285715]
# sequential_31 model is trained. best val loss is : [0.6626541171755109, 0.6523809523809524]
# sequential_31 model is trained. best val loss is : [0.5525433079117821, 0.7714285714285715]
# sequential_31 model is trained. best val loss is : [0.49358790341232506, 0.7857142857142857]
# sequential_31 model is trained. best val loss is : [0.4725226003931658, 0.8]
# sequential_31 model is trained. best val loss is : [0.5305401837541943, 0.780952380952381]
# sequential_31 model is trained. best val loss is : [0.4105562478960824, 0.8333333333333334]
# sequential_31 model is trained. best val loss is : [0.5798295342756232, 0.7857142857142857]
# sequential_31 model is trained. best val loss is : [0.9339970623033942, 0.819047619047619]
# sequential_31 model is trained. best val loss is : [0.45288583863349186, 0.7904761904761904]
# sequential_31 model is trained. best val loss is : [1.3880907994018696, 0.7857142857142857]
# sequential_31 model is trained. best val loss is : [1.9418594782694927, 0.7857142857142857]
# sequential_31 model is trained. best val loss is : [2.9868890311916023, 0.7666666666666667]
# sequential_32 model is trained. best val loss is : [0.6682801953383855, 0.6238095238095238]
# sequential_32 model is trained. best val loss is : [0.6828402022520701, 0.6571428571428571]
# sequential_32 model is trained. best val loss is : [0.6871347748097919, 0.6047619047619047]
# sequential_32 model is trained. best val loss is : [0.6348731841359819, 0.7333333333333333]
# sequential_32 model is trained. best val loss is : [0.7006323746272496, 0.41904761904761906]
# sequential_32 model is trained. best val loss is : [0.6283327607881455, 0.6238095238095238]
# sequential_32 model is trained. best val loss is : [0.5821279995498203, 0.7238095238095238]
# sequential_32 model is trained. best val loss is : [0.4904866457961145, 0.7571428571428571]
# sequential_32 model is trained. best val loss is : [0.45792714162740766, 0.7904761904761904]
# sequential_32 model is trained. best val loss is : [1.1670412581081753, 0.8]
# sequential_32 model is trained. best val loss is : [1.282852907961824, 0.780952380952381]
# sequential_32 model is trained. best val loss is : [0.8595652441977363, 0.7571428571428571]
# sequential_32 model is trained. best val loss is : [0.6795038407757169, 0.6333333333333333]
# sequential_32 model is trained. best val loss is : [0.5523348339256786, 0.7571428571428571]
# sequential_32 model is trained. best val loss is : [0.49755320332589603, 0.7904761904761904]
# sequential_32 model is trained. best val loss is : [0.4822918428695716, 0.8047619047619048]
# sequential_32 model is trained. best val loss is : [0.5666908469938097, 0.7761904761904762]
# sequential_32 model is trained. best val loss is : [0.43132877600465214, 0.780952380952381]
# sequential_32 model is trained. best val loss is : [0.6066008141127116, 0.7714285714285715]
# sequential_32 model is trained. best val loss is : [0.8423333314987714, 0.780952380952381]
# sequential_32 model is trained. best val loss is : [0.4589026821045471, 0.7857142857142857]
# sequential_32 model is trained. best val loss is : [1.5204391951423417, 0.8047619047619048]
# sequential_32 model is trained. best val loss is : [1.611994230261149, 0.7619047619047619]
# sequential_32 model is trained. best val loss is : [1.3075090129371414, 0.7857142857142857]
# sequential_33 model is trained. best val loss is : [0.6793563266595205, 0.6857142857142857]
# sequential_33 model is trained. best val loss is : [0.6917997118972596, 0.5380952380952381]
# sequential_33 model is trained. best val loss is : [0.6861179326261793, 0.5904761904761905]
# sequential_33 model is trained. best val loss is : [0.6149874109597433, 0.7666666666666667]
# sequential_33 model is trained. best val loss is : [0.6883494433902558, 0.6]
# sequential_33 model is trained. best val loss is : [0.6518855373064677, 0.6047619047619047]
# sequential_33 model is trained. best val loss is : [0.6060793497732707, 0.6857142857142857]
# sequential_33 model is trained. best val loss is : [0.492865520697974, 0.7761904761904762]
# sequential_33 model is trained. best val loss is : [0.5079340067857543, 0.7714285714285715]
# sequential_33 model is trained. best val loss is : [1.2275749093976163, 0.8]
# sequential_33 model is trained. best val loss is : [0.9595038086165514, 0.8047619047619048]
# sequential_33 model is trained. best val loss is : [1.9087706215820297, 0.5380952380952381]
# sequential_33 model is trained. best val loss is : [0.6765288398379371, 0.6142857142857143]
# sequential_33 model is trained. best val loss is : [0.5898509179552396, 0.7238095238095238]
# sequential_33 model is trained. best val loss is : [0.49481709954284486, 0.7761904761904762]
# sequential_33 model is trained. best val loss is : [0.47992070728824254, 0.8095238095238095]
# sequential_33 model is trained. best val loss is : [0.5113499126973606, 0.780952380952381]
# sequential_33 model is trained. best val loss is : [0.47643215550446516, 0.780952380952381]
# sequential_33 model is trained. best val loss is : [0.619505085181226, 0.780952380952381]
# sequential_33 model is trained. best val loss is : [0.9037808120640707, 0.8047619047619048]
# sequential_33 model is trained. best val loss is : [0.432694703412597, 0.8095238095238095]
# sequential_33 model is trained. best val loss is : [1.955632695809967, 0.780952380952381]
# sequential_33 model is trained. best val loss is : [3.2124871539815834, 0.780952380952381]
# sequential_33 model is trained. best val loss is : [2.192083913052677, 0.780952380952381]
# sequential_34 model is trained. best val loss is : [0.6951233460789635, 0.48095238095238096]
# sequential_34 model is trained. best val loss is : [0.6895413940861111, 0.6095238095238096]
# sequential_34 model is trained. best val loss is : [0.6758042122636523, 0.7047619047619048]
# sequential_34 model is trained. best val loss is : [0.6035779158274333, 0.7333333333333333]
# sequential_34 model is trained. best val loss is : [0.6916651802403586, 0.5714285714285714]
# sequential_34 model is trained. best val loss is : [0.6425466077668326, 0.6238095238095238]
# sequential_34 model is trained. best val loss is : [0.629129107225509, 0.6619047619047619]
# sequential_34 model is trained. best val loss is : [0.4885724238962645, 0.7714285714285715]
# sequential_34 model is trained. best val loss is : [0.5966161336117867, 0.7761904761904762]
# sequential_34 model is trained. best val loss is : [1.453646492755238, 0.7857142857142857]
# sequential_34 model is trained. best val loss is : [1.3836204103428946, 0.7666666666666667]
# sequential_34 model is trained. best val loss is : [0.7255730059706563, 0.4523809523809524]
# sequential_34 model is trained. best val loss is : [0.6834953373386746, 0.6238095238095238]
# sequential_34 model is trained. best val loss is : [0.5772551702601569, 0.7619047619047619]
# sequential_34 model is trained. best val loss is : [0.5103202623980386, 0.7761904761904762]
# sequential_34 model is trained. best val loss is : [0.47274467570019796, 0.8]
# sequential_34 model is trained. best val loss is : [0.5099795186448665, 0.7857142857142857]
# sequential_34 model is trained. best val loss is : [0.5203395335058238, 0.7904761904761904]
# sequential_34 model is trained. best val loss is : [0.7247812752601321, 0.7761904761904762]
# sequential_34 model is trained. best val loss is : [1.215732873202496, 0.7857142857142857]
# sequential_34 model is trained. best val loss is : [0.45198125446359405, 0.8047619047619048]
# sequential_34 model is trained. best val loss is : [1.0458766909264752, 0.7904761904761904]
# sequential_34 model is trained. best val loss is : [2.361911697588535, 0.7523809523809524]
# sequential_34 model is trained. best val loss is : [5.53184758611332, 0.7285714285714285]
# sequential_35 model is trained. best val loss is : [0.6872848243940444, 0.6190476190476191]
# sequential_35 model is trained. best val loss is : [0.7012804468472799, 0.4523809523809524]
# sequential_35 model is trained. best val loss is : [0.6882139688446408, 0.6095238095238096]
# sequential_35 model is trained. best val loss is : [0.6721345929872422, 0.6476190476190476]
# sequential_35 model is trained. best val loss is : [0.662388299192701, 0.6047619047619047]
# sequential_35 model is trained. best val loss is : [0.6320841217324847, 0.6428571428571429]
# sequential_35 model is trained. best val loss is : [0.6421422851937157, 0.6047619047619047]
# sequential_35 model is trained. best val loss is : [0.49052550157620795, 0.8142857142857143]
# sequential_35 model is trained. best val loss is : [0.5242511010892312, 0.7666666666666667]
# sequential_35 model is trained. best val loss is : [1.1568326368097885, 0.7904761904761904]
# sequential_35 model is trained. best val loss is : [1.0511121452256367, 0.8095238095238095]
# sequential_35 model is trained. best val loss is : [0.6669021856217158, 0.6047619047619047]
# sequential_35 model is trained. best val loss is : [0.6624989364828382, 0.6047619047619047]
# sequential_35 model is trained. best val loss is : [0.5846362179233915, 0.7095238095238096]
# sequential_35 model is trained. best val loss is : [0.48770357444882395, 0.7761904761904762]
# sequential_35 model is trained. best val loss is : [0.5010270765250815, 0.8]
# sequential_35 model is trained. best val loss is : [0.5837232044055348, 0.7619047619047619]
# sequential_35 model is trained. best val loss is : [0.4339197847973472, 0.8142857142857143]
# sequential_35 model is trained. best val loss is : [0.6287473825216559, 0.780952380952381]
# sequential_35 model is trained. best val loss is : [1.0400606065211473, 0.7952380952380952]
# sequential_35 model is trained. best val loss is : [0.45412338346331604, 0.8095238095238095]
# sequential_35 model is trained. best val loss is : [1.3733786661368201, 0.7904761904761904]
# sequential_35 model is trained. best val loss is : [1.1874011167478207, 0.8]
# sequential_35 model is trained. best val loss is : [1.1176328083250613, 0.7476190476190476]
# sequential_36 model is trained. best val loss is : [0.6894676736422948, 0.5761904761904761]
# sequential_36 model is trained. best val loss is : [0.6946535419850123, 0.5476190476190477]
# sequential_36 model is trained. best val loss is : [0.6732175557386307, 0.6285714285714286]
# sequential_36 model is trained. best val loss is : [0.6286678867680686, 0.680952380952381]
# sequential_36 model is trained. best val loss is : [0.6752895467338108, 0.580952380952381]
# sequential_36 model is trained. best val loss is : [0.6317695914279847, 0.7047619047619048]
# sequential_36 model is trained. best val loss is : [0.6395903997478031, 0.6047619047619047]
# sequential_36 model is trained. best val loss is : [0.47532980198129304, 0.7857142857142857]
# sequential_36 model is trained. best val loss is : [0.5887765944994431, 0.7857142857142857]
# sequential_36 model is trained. best val loss is : [1.4156702378173895, 0.8]
# sequential_36 model is trained. best val loss is : [1.1706561987401982, 0.7904761904761904]
# sequential_36 model is trained. best val loss is : [0.6719692494188036, 0.6047619047619047]
# sequential_36 model is trained. best val loss is : [0.6763556057498569, 0.6190476190476191]
# sequential_36 model is trained. best val loss is : [0.5612972655466625, 0.7666666666666667]
# sequential_36 model is trained. best val loss is : [0.4883235755066077, 0.7952380952380952]
# sequential_36 model is trained. best val loss is : [0.47976183837967085, 0.7952380952380952]
# sequential_36 model is trained. best val loss is : [0.5299353692503203, 0.7857142857142857]
# sequential_36 model is trained. best val loss is : [0.490450272637567, 0.7857142857142857]
# sequential_36 model is trained. best val loss is : [0.6749965754260976, 0.8142857142857143]
# sequential_36 model is trained. best val loss is : [1.08670984215316, 0.7857142857142857]
# sequential_36 model is trained. best val loss is : [0.44539676617964036, 0.8]
# sequential_36 model is trained. best val loss is : [2.3179234604140406, 0.7619047619047619]
# sequential_36 model is trained. best val loss is : [1.7423514969422937, 0.7952380952380952]
# sequential_36 model is trained. best val loss is : [4.637133208143865, 0.7619047619047619]
# sequential_37 model is trained. best val loss is : [0.6927383360408601, 0.46190476190476193]
# sequential_37 model is trained. best val loss is : [0.6845680231139774, 0.6095238095238096]
# sequential_37 model is trained. best val loss is : [0.6778286150523595, 0.7142857142857143]
# sequential_37 model is trained. best val loss is : [0.6004406905600003, 0.6047619047619047]
# sequential_37 model is trained. best val loss is : [0.6879700762884957, 0.5857142857142857]
# sequential_37 model is trained. best val loss is : [0.6621253349951335, 0.6047619047619047]
# sequential_37 model is trained. best val loss is : [0.6014643622296197, 0.7380952380952381]
# sequential_37 model is trained. best val loss is : [0.4781360386471663, 0.780952380952381]
# sequential_37 model is trained. best val loss is : [0.795356802200059, 0.7761904761904762]
# sequential_37 model is trained. best val loss is : [1.5701640860644872, 0.8095238095238095]
# sequential_37 model is trained. best val loss is : [1.6269128247784463, 0.7857142857142857]
# sequential_37 model is trained. best val loss is : [0.6680909329936617, 0.6047619047619047]
# sequential_37 model is trained. best val loss is : [0.6812665192853837, 0.6190476190476191]
# sequential_37 model is trained. best val loss is : [0.5688933527185803, 0.7476190476190476]
# sequential_37 model is trained. best val loss is : [0.4829908011215074, 0.7714285714285715]
# sequential_37 model is trained. best val loss is : [0.4962248034642211, 0.8095238095238095]
# sequential_37 model is trained. best val loss is : [0.5178866529659856, 0.7619047619047619]
# sequential_37 model is trained. best val loss is : [0.6376124966498489, 0.7857142857142857]
# sequential_37 model is trained. best val loss is : [0.7406275898058704, 0.8047619047619048]
# sequential_37 model is trained. best val loss is : [1.4124974971370439, 0.7714285714285715]
# sequential_37 model is trained. best val loss is : [0.44162277596658983, 0.8142857142857143]
# sequential_37 model is trained. best val loss is : [1.08939661558647, 0.7666666666666667]
# sequential_37 model is trained. best val loss is : [2.0588852045446977, 0.7952380952380952]
# sequential_37 model is trained. best val loss is : [1.8554222275220655, 0.7904761904761904]
# sequential_38 model is trained. best val loss is : [0.6887404512791406, 0.6047619047619047]
# sequential_38 model is trained. best val loss is : [0.6908774869782585, 0.5714285714285714]
# sequential_38 model is trained. best val loss is : [0.6819774971121834, 0.6857142857142857]
# sequential_38 model is trained. best val loss is : [0.5714865089172408, 0.7666666666666667]
# sequential_38 model is trained. best val loss is : [0.6902697699410575, 0.6238095238095238]
# sequential_38 model is trained. best val loss is : [0.6701684225173223, 0.6047619047619047]
# sequential_38 model is trained. best val loss is : [0.6256736961149034, 0.6047619047619047]
# sequential_38 model is trained. best val loss is : [0.49475814198986406, 0.7904761904761904]
# sequential_38 model is trained. best val loss is : [0.7959006143667482, 0.8]
# sequential_38 model is trained. best val loss is : [1.194718115774685, 0.780952380952381]
# sequential_38 model is trained. best val loss is : [1.0204961992356858, 0.7619047619047619]
# sequential_38 model is trained. best val loss is : [0.6722477532568432, 0.6047619047619047]
# sequential_38 model is trained. best val loss is : [0.6854636589686076, 0.638095238095238]
# sequential_38 model is trained. best val loss is : [0.5858536430767605, 0.7380952380952381]
# sequential_38 model is trained. best val loss is : [0.4944906850301084, 0.780952380952381]
# sequential_38 model is trained. best val loss is : [0.49218273564640963, 0.7857142857142857]
# sequential_38 model is trained. best val loss is : [0.4981275585258291, 0.7857142857142857]
# sequential_38 model is trained. best val loss is : [0.7699168874711156, 0.7761904761904762]
# sequential_38 model is trained. best val loss is : [0.7889727991774783, 0.8047619047619048]
# sequential_38 model is trained. best val loss is : [1.0989184481498488, 0.819047619047619]
# sequential_38 model is trained. best val loss is : [0.4405815841415287, 0.8238095238095238]
# sequential_38 model is trained. best val loss is : [1.7817882995662953, 0.7904761904761904]
# sequential_38 model is trained. best val loss is : [2.5343882840978096, 0.7857142857142857]
# sequential_38 model is trained. best val loss is : [0.6054561597588969, 0.8]
# sequential_39 model is trained. best val loss is : [0.6960592647393544, 0.38571428571428573]
# sequential_39 model is trained. best val loss is : [0.6745572342759087, 0.6047619047619047]
# sequential_39 model is trained. best val loss is : [0.6839812863440741, 0.6047619047619047]
# sequential_39 model is trained. best val loss is : [0.5776634568969409, 0.7380952380952381]
# sequential_39 model is trained. best val loss is : [0.6927470845835549, 0.5142857142857142]
# sequential_39 model is trained. best val loss is : [0.654761689049857, 0.6047619047619047]
# sequential_39 model is trained. best val loss is : [0.6324919626826332, 0.6047619047619047]
# sequential_39 model is trained. best val loss is : [0.48814681480150846, 0.7904761904761904]
# sequential_39 model is trained. best val loss is : [0.9323370965029889, 0.8]
# sequential_39 model is trained. best val loss is : [1.022532611846587, 0.7857142857142857]
# sequential_39 model is trained. best val loss is : [1.3893633381625878, 0.7952380952380952]
# sequential_39 model is trained. best val loss is : [0.6718129030295781, 0.6047619047619047]
# sequential_39 model is trained. best val loss is : [0.6866626969405583, 0.6142857142857143]
# sequential_39 model is trained. best val loss is : [0.577870622135344, 0.7238095238095238]
# sequential_39 model is trained. best val loss is : [0.5163569880028566, 0.780952380952381]
# sequential_39 model is trained. best val loss is : [0.48304703266670307, 0.7952380952380952]
# sequential_39 model is trained. best val loss is : [0.4605692789235729, 0.7952380952380952]
# sequential_39 model is trained. best val loss is : [0.6900805667170288, 0.8]
# sequential_39 model is trained. best val loss is : [0.9710149397513019, 0.780952380952381]
# sequential_39 model is trained. best val loss is : [1.5984719736168749, 0.7904761904761904]
# sequential_39 model is trained. best val loss is : [0.5112711289300239, 0.8095238095238095]
# sequential_39 model is trained. best val loss is : [1.968024819577099, 0.7857142857142857]
# sequential_39 model is trained. best val loss is : [1.2976829135347228, 0.7952380952380952]
# sequential_39 model is trained. best val loss is : [2.1700964756215932, 0.7333333333333333]
# sequential_40 model is trained. best val loss is : [0.6920946938650948, 0.5476190476190477]
# sequential_40 model is trained. best val loss is : [0.6966592748959859, 0.38571428571428573]
# sequential_40 model is trained. best val loss is : [0.6716132910478683, 0.6047619047619047]
# sequential_40 model is trained. best val loss is : [0.6580784928231013, 0.6142857142857143]
# sequential_40 model is trained. best val loss is : [0.6661019932656062, 0.6047619047619047]
# sequential_40 model is trained. best val loss is : [0.6654102123918988, 0.6047619047619047]
# sequential_40 model is trained. best val loss is : [0.6212379387446813, 0.6714285714285714]
# sequential_40 model is trained. best val loss is : [0.48548547927112806, 0.8047619047619048]
# sequential_40 model is trained. best val loss is : [0.7259110470039883, 0.7952380952380952]
# sequential_40 model is trained. best val loss is : [0.7698181054797986, 0.8238095238095238]
# sequential_40 model is trained. best val loss is : [1.0740951337398879, 0.8095238095238095]
# sequential_40 model is trained. best val loss is : [0.6712136613471168, 0.6047619047619047]
# sequential_40 model is trained. best val loss is : [0.6737023563612075, 0.6047619047619047]
# sequential_40 model is trained. best val loss is : [0.5763050334794181, 0.7619047619047619]
# sequential_40 model is trained. best val loss is : [0.5755503793912274, 0.6952380952380952]
# sequential_40 model is trained. best val loss is : [0.498749163365435, 0.7952380952380952]
# sequential_40 model is trained. best val loss is : [0.5585107215813228, 0.7619047619047619]
# sequential_40 model is trained. best val loss is : [0.5848310724250463, 0.7619047619047619]
# sequential_40 model is trained. best val loss is : [0.685427108290135, 0.7857142857142857]
# sequential_40 model is trained. best val loss is : [0.8933162118361033, 0.7714285714285715]
# sequential_40 model is trained. best val loss is : [0.45122065525501964, 0.8095238095238095]
# sequential_40 model is trained. best val loss is : [1.0189082156193434, 0.7952380952380952]
# sequential_40 model is trained. best val loss is : [1.3470512027060992, 0.8047619047619048]
# sequential_40 model is trained. best val loss is : [1.2573966723325614, 0.7857142857142857]
# sequential_41 model is trained. best val loss is : [0.6766764442125957, 0.6095238095238096]
# sequential_41 model is trained. best val loss is : [0.687997449579693, 0.5714285714285714]
# sequential_41 model is trained. best val loss is : [0.6894766177449908, 0.6523809523809524]
# sequential_41 model is trained. best val loss is : [0.622622131166004, 0.7047619047619048]
# sequential_41 model is trained. best val loss is : [0.679310203166235, 0.6095238095238096]
# sequential_41 model is trained. best val loss is : [0.657680708311853, 0.6095238095238096]
# sequential_41 model is trained. best val loss is : [0.6108693917592366, 0.6619047619047619]
# sequential_41 model is trained. best val loss is : [0.4900554784795358, 0.8047619047619048]
# sequential_41 model is trained. best val loss is : [0.6122938016667232, 0.8238095238095238]
# sequential_41 model is trained. best val loss is : [1.4758815216755725, 0.8047619047619048]
# sequential_41 model is trained. best val loss is : [0.5019270146601463, 0.8047619047619048]
# sequential_41 model is trained. best val loss is : [0.6712433299848012, 0.6047619047619047]
# sequential_41 model is trained. best val loss is : [0.6869665446735563, 0.5952380952380952]
# sequential_41 model is trained. best val loss is : [0.6169383576938084, 0.6047619047619047]
# sequential_41 model is trained. best val loss is : [0.4947963868046091, 0.7857142857142857]
# sequential_41 model is trained. best val loss is : [0.4955185338766092, 0.7952380952380952]
# sequential_41 model is trained. best val loss is : [0.5503376836932841, 0.7571428571428571]
# sequential_41 model is trained. best val loss is : [0.6646482367429541, 0.7714285714285715]
# sequential_41 model is trained. best val loss is : [0.653605131341582, 0.8]
# sequential_41 model is trained. best val loss is : [0.7635794572319815, 0.8047619047619048]
# sequential_41 model is trained. best val loss is : [0.42588542004398605, 0.8095238095238095]
# sequential_41 model is trained. best val loss is : [1.5284481191908477, 0.7952380952380952]
# sequential_41 model is trained. best val loss is : [2.0427391039611336, 0.8047619047619048]
# sequential_41 model is trained. best val loss is : [0.5707201243423675, 0.7523809523809524]
# sequential_42 model is trained. best val loss is : [0.6975432983466557, 0.41904761904761906]
# sequential_42 model is trained. best val loss is : [0.6824427437214624, 0.6047619047619047]
# sequential_42 model is trained. best val loss is : [0.6814676557268415, 0.5904761904761905]
# sequential_42 model is trained. best val loss is : [0.6102486810513905, 0.6571428571428571]
# sequential_42 model is trained. best val loss is : [0.6843425009931837, 0.6095238095238096]
# sequential_42 model is trained. best val loss is : [0.6659745948655265, 0.6047619047619047]
# sequential_42 model is trained. best val loss is : [0.6332629328682309, 0.6047619047619047]
# sequential_42 model is trained. best val loss is : [0.4868247305176088, 0.8047619047619048]
# sequential_42 model is trained. best val loss is : [0.9061736654388224, 0.8]
# sequential_42 model is trained. best val loss is : [3.0636386981203114, 0.7857142857142857]
# sequential_42 model is trained. best val loss is : [0.6714411255859193, 0.6047619047619047]
# sequential_42 model is trained. best val loss is : [0.6724218053477151, 0.6047619047619047]
# sequential_42 model is trained. best val loss is : [0.6855602116811843, 0.6047619047619047]
# sequential_42 model is trained. best val loss is : [0.5774841373165448, 0.7285714285714285]
# sequential_42 model is trained. best val loss is : [0.5290836450333397, 0.7904761904761904]
# sequential_42 model is trained. best val loss is : [0.4914925406975228, 0.8]
# sequential_42 model is trained. best val loss is : [0.5113229228272325, 0.7761904761904762]
# sequential_42 model is trained. best val loss is : [0.5813608800066437, 0.780952380952381]
# sequential_42 model is trained. best val loss is : [0.8285494542439911, 0.7714285714285715]
# sequential_42 model is trained. best val loss is : [1.233156251805656, 0.8238095238095238]
# sequential_42 model is trained. best val loss is : [0.4357285455772875, 0.8238095238095238]
# sequential_42 model is trained. best val loss is : [0.7430002324957751, 0.7523809523809524]
# sequential_42 model is trained. best val loss is : [1.8680043959110277, 0.7857142857142857]
# sequential_42 model is trained. best val loss is : [1.7193291284221284, 0.7523809523809524]
# sequential_43 model is trained. best val loss is : [0.6940299993469602, 0.3952380952380952]
# sequential_43 model is trained. best val loss is : [0.6958880543708801, 0.3952380952380952]
# sequential_43 model is trained. best val loss is : [0.6805993923119136, 0.6047619047619047]
# sequential_43 model is trained. best val loss is : [0.5990976799811636, 0.6761904761904762]
# sequential_43 model is trained. best val loss is : [0.6806882631211054, 0.6047619047619047]
# sequential_43 model is trained. best val loss is : [0.6589817140783583, 0.6047619047619047]
# sequential_43 model is trained. best val loss is : [0.6478140728814261, 0.6047619047619047]
# sequential_43 model is trained. best val loss is : [0.49149623315426566, 0.8]
# sequential_43 model is trained. best val loss is : [0.9801973507883168, 0.7904761904761904]
# sequential_43 model is trained. best val loss is : [1.3066934087329685, 0.8]
# sequential_43 model is trained. best val loss is : [1.6723256734596676, 0.7714285714285715]
# sequential_43 model is trained. best val loss is : [0.6525909130062376, 0.6428571428571429]
# sequential_43 model is trained. best val loss is : [0.6777191567988623, 0.6047619047619047]
# sequential_43 model is trained. best val loss is : [0.617250318754287, 0.6047619047619047]
# sequential_43 model is trained. best val loss is : [0.4967781245708466, 0.7952380952380952]
# sequential_43 model is trained. best val loss is : [0.49507502411780435, 0.8095238095238095]
# sequential_43 model is trained. best val loss is : [0.4666254828595335, 0.7952380952380952]
# sequential_43 model is trained. best val loss is : [0.6386778824768137, 0.780952380952381]
# sequential_43 model is trained. best val loss is : [0.9208156004216569, 0.7714285714285715]
# sequential_43 model is trained. best val loss is : [1.2395806152398046, 0.7666666666666667]
# sequential_43 model is trained. best val loss is : [0.5466827824828215, 0.780952380952381]
# sequential_43 model is trained. best val loss is : [0.7782036037022155, 0.8333333333333334]
# sequential_43 model is trained. best val loss is : [0.9956197931955055, 0.7857142857142857]
# sequential_43 model is trained. best val loss is : [0.6960885724911487, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [0.6915834631238665, 0.6285714285714286]
# sequential_44 model is trained. best val loss is : [0.6847680545988537, 0.7095238095238096]
# sequential_44 model is trained. best val loss is : [0.6750704001812707, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [0.5708845242148354, 0.7619047619047619]
# sequential_44 model is trained. best val loss is : [0.685563581046604, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [0.6655714395500365, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [0.652022960072472, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [0.4992870064097501, 0.7857142857142857]
# sequential_44 model is trained. best val loss is : [0.7692005914904982, 0.8047619047619048]
# sequential_44 model is trained. best val loss is : [3.3408994654445987, 0.7761904761904762]
# sequential_44 model is trained. best val loss is : [0.8723464287294941, 0.7523809523809524]
# sequential_44 model is trained. best val loss is : [0.6676080341850008, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [0.6788736587479001, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [0.5941930699916113, 0.680952380952381]
# sequential_44 model is trained. best val loss is : [0.5125776412586371, 0.7666666666666667]
# sequential_44 model is trained. best val loss is : [0.48886762153401614, 0.7952380952380952]
# sequential_44 model is trained. best val loss is : [0.47424265527986875, 0.780952380952381]
# sequential_44 model is trained. best val loss is : [0.758321210469544, 0.7857142857142857]
# sequential_44 model is trained. best val loss is : [0.9433238486028426, 0.7619047619047619]
# sequential_44 model is trained. best val loss is : [1.813403323462654, 0.7619047619047619]
# sequential_44 model is trained. best val loss is : [0.6328901205150379, 0.7857142857142857]
# sequential_44 model is trained. best val loss is : [1.2843321337398244, 0.7857142857142857]
# sequential_44 model is trained. best val loss is : [7.163936908613337, 0.6047619047619047]
# sequential_44 model is trained. best val loss is : [1.024250598333395, 0.6714285714285714]

# %%
# same result
mlp_titanic1 = MLP(ds_titanic.trans_X_train, ds_titanic.trans_y_train, problem=ds_titanic.problem)
mlp_titanic1.build_structure(max_hidden_layers=1, units=[16], use_all=True)
mlp_titanic1.create_optimizer(optimizers=['adam'], lrs=[0.01], use_all=True)
mlp_titanic1.compile_model()

mlp_titanic1.train_models(mlp_titanic1.compiled_models,
                         ds_titanic.trans_X_train, ds_titanic.trans_y_train,
                         ds_titanic.trans_X_val, ds_titanic.trans_y_val,
                         batch_size=64, epochs=10)
# Out:
# sequential_45 model is trained. best val loss is : [0.6893095464933486, 0.6095238095238096]
# sequential_45 model is trained. best val loss is : [0.6872799440508797, 0.4714285714285714]
# sequential_45 model is trained. best val loss is : [0.7026587750230516, 0.3952380952380952]
# sequential_45 model is trained. best val loss is : [0.6371105954760596, 0.7476190476190476]
# sequential_45 model is trained. best val loss is : [0.7161075369233176, 0.4238095238095238]
# sequential_45 model is trained. best val loss is : [0.5872712013976914, 0.7]
# sequential_45 model is trained. best val loss is : [0.5753086182333175, 0.7428571428571429]
# sequential_45 model is trained. best val loss is : [0.47682202466364415, 0.7952380952380952]
# sequential_45 model is trained. best val loss is : [0.46156686373675865, 0.8]
# sequential_45 model is trained. best val loss is : [0.7684512538338785, 0.7904761904761904]
# sequential_45 model is trained. best val loss is : [0.7173159052500883, 0.7904761904761904]
# sequential_45 model is trained. best val loss is : [1.031233274847132, 0.7571428571428571]
# sequential_45 model is trained. best val loss is : [0.6889727544216883, 0.5952380952380952]
# sequential_45 model is trained. best val loss is : [0.5048527246784597, 0.8095238095238095]
# sequential_45 model is trained. best val loss is : [0.49242925867438314, 0.8]
# sequential_45 model is trained. best val loss is : [0.4739246557012112, 0.819047619047619]
# sequential_45 model is trained. best val loss is : [0.5689690281237875, 0.7619047619047619]
# sequential_45 model is trained. best val loss is : [0.4217826736573313, 0.819047619047619]
# sequential_45 model is trained. best val loss is : [0.4796252175371992, 0.8]
# sequential_45 model is trained. best val loss is : [0.7043928172273624, 0.8095238095238095]
# sequential_45 model is trained. best val loss is : [0.46508433316346437, 0.8]
# sequential_45 model is trained. best val loss is : [1.1081881371129596, 0.7952380952380952]
# sequential_45 model is trained. best val loss is : [1.7335029542197862, 0.8095238095238095]
# sequential_45 model is trained. best val loss is : [4.249131337255917, 0.7619047619047619]
# sequential_46 model is trained. best val loss is : [0.6972343461854117, 0.44285714285714284]
# sequential_46 model is trained. best val loss is : [0.6802120877163751, 0.6238095238095238]
# sequential_46 model is trained. best val loss is : [0.6709888472443535, 0.6047619047619047]
# sequential_46 model is trained. best val loss is : [0.6272472673938387, 0.6571428571428571]
# sequential_46 model is trained. best val loss is : [0.674912755262284, 0.638095238095238]
# sequential_46 model is trained. best val loss is : [0.6356592069069544, 0.719047619047619]
# sequential_46 model is trained. best val loss is : [0.5778930159551757, 0.7285714285714285]
# sequential_46 model is trained. best val loss is : [0.48446330256937514, 0.780952380952381]
# sequential_46 model is trained. best val loss is : [0.43344240116712174, 0.8142857142857143]
# sequential_46 model is trained. best val loss is : [0.7547194606394709, 0.7904761904761904]
# sequential_46 model is trained. best val loss is : [1.0012443776816708, 0.8095238095238095]
# sequential_46 model is trained. best val loss is : [1.2936880862030915, 0.7714285714285715]
# sequential_46 model is trained. best val loss is : [0.6626541171755109, 0.6523809523809524]
# sequential_46 model is trained. best val loss is : [0.5525433079117821, 0.7714285714285715]
# sequential_46 model is trained. best val loss is : [0.49358790341232506, 0.7857142857142857]
# sequential_46 model is trained. best val loss is : [0.4725226003931658, 0.8]
# sequential_46 model is trained. best val loss is : [0.5305401837541943, 0.780952380952381]
# sequential_46 model is trained. best val loss is : [0.4105562478960824, 0.8333333333333334]
# sequential_46 model is trained. best val loss is : [0.5798295342756232, 0.7857142857142857]
# sequential_46 model is trained. best val loss is : [0.9339970623033942, 0.819047619047619]
# sequential_46 model is trained. best val loss is : [0.45288583863349186, 0.7904761904761904]
# sequential_46 model is trained. best val loss is : [1.3880907994018696, 0.7857142857142857]
# sequential_46 model is trained. best val loss is : [1.9418594782694927, 0.7857142857142857]
# sequential_46 model is trained. best val loss is : [2.9868890311916023, 0.7666666666666667]
# sequential_47 model is trained. best val loss is : [0.6682801953383855, 0.6238095238095238]
# sequential_47 model is trained. best val loss is : [0.6828402022520701, 0.6571428571428571]
# sequential_47 model is trained. best val loss is : [0.6871347748097919, 0.6047619047619047]
# sequential_47 model is trained. best val loss is : [0.6348731841359819, 0.7333333333333333]
# sequential_47 model is trained. best val loss is : [0.7006323746272496, 0.41904761904761906]
# sequential_47 model is trained. best val loss is : [0.6283327607881455, 0.6238095238095238]
# sequential_47 model is trained. best val loss is : [0.5821279995498203, 0.7238095238095238]
# sequential_47 model is trained. best val loss is : [0.4904866457961145, 0.7571428571428571]
# sequential_47 model is trained. best val loss is : [0.45792714162740766, 0.7904761904761904]
# sequential_47 model is trained. best val loss is : [1.1670412581081753, 0.8]
# sequential_47 model is trained. best val loss is : [1.282852907961824, 0.780952380952381]
# sequential_47 model is trained. best val loss is : [0.8595652441977363, 0.7571428571428571]
# sequential_47 model is trained. best val loss is : [0.6795038407757169, 0.6333333333333333]
# sequential_47 model is trained. best val loss is : [0.5523348339256786, 0.7571428571428571]
# sequential_47 model is trained. best val loss is : [0.49755320332589603, 0.7904761904761904]
# sequential_47 model is trained. best val loss is : [0.4822918428695716, 0.8047619047619048]
# sequential_47 model is trained. best val loss is : [0.5666908469938097, 0.7761904761904762]
# sequential_47 model is trained. best val loss is : [0.43132877600465214, 0.780952380952381]
# sequential_47 model is trained. best val loss is : [0.6066008141127116, 0.7714285714285715]
# sequential_47 model is trained. best val loss is : [0.8423333314987714, 0.780952380952381]
# sequential_47 model is trained. best val loss is : [0.4589026821045471, 0.7857142857142857]
# sequential_47 model is trained. best val loss is : [1.5204391951423417, 0.8047619047619048]
# sequential_47 model is trained. best val loss is : [1.611994230261149, 0.7619047619047619]
# sequential_47 model is trained. best val loss is : [1.3075090129371414, 0.7857142857142857]
# sequential_48 model is trained. best val loss is : [0.6793563266595205, 0.6857142857142857]
# sequential_48 model is trained. best val loss is : [0.6917997118972596, 0.5380952380952381]
# sequential_48 model is trained. best val loss is : [0.6861179326261793, 0.5904761904761905]
# sequential_48 model is trained. best val loss is : [0.6149874109597433, 0.7666666666666667]
# sequential_48 model is trained. best val loss is : [0.6883494433902558, 0.6]
# sequential_48 model is trained. best val loss is : [0.6518855373064677, 0.6047619047619047]
# sequential_48 model is trained. best val loss is : [0.6060793497732707, 0.6857142857142857]
# sequential_48 model is trained. best val loss is : [0.492865520697974, 0.7761904761904762]
# sequential_48 model is trained. best val loss is : [0.5079340067857543, 0.7714285714285715]
# sequential_48 model is trained. best val loss is : [1.2275749093976163, 0.8]
# sequential_48 model is trained. best val loss is : [0.9595038086165514, 0.8047619047619048]
# sequential_48 model is trained. best val loss is : [1.9087706215820297, 0.5380952380952381]
# sequential_48 model is trained. best val loss is : [0.6765288398379371, 0.6142857142857143]
# sequential_48 model is trained. best val loss is : [0.5898509179552396, 0.7238095238095238]
# sequential_48 model is trained. best val loss is : [0.49481709954284486, 0.7761904761904762]
# sequential_48 model is trained. best val loss is : [0.47992070728824254, 0.8095238095238095]
# sequential_48 model is trained. best val loss is : [0.5113499126973606, 0.780952380952381]
# sequential_48 model is trained. best val loss is : [0.47643215550446516, 0.780952380952381]
# sequential_48 model is trained. best val loss is : [0.619505085181226, 0.780952380952381]
# sequential_48 model is trained. best val loss is : [0.9037808120640707, 0.8047619047619048]
# sequential_48 model is trained. best val loss is : [0.432694703412597, 0.8095238095238095]
# sequential_48 model is trained. best val loss is : [1.955632695809967, 0.780952380952381]
# sequential_48 model is trained. best val loss is : [3.2124871539815834, 0.780952380952381]
# sequential_48 model is trained. best val loss is : [2.192083913052677, 0.780952380952381]
# sequential_49 model is trained. best val loss is : [0.6951233460789635, 0.48095238095238096]
# sequential_49 model is trained. best val loss is : [0.6895413940861111, 0.6095238095238096]
# sequential_49 model is trained. best val loss is : [0.6758042122636523, 0.7047619047619048]
# sequential_49 model is trained. best val loss is : [0.6035779158274333, 0.7333333333333333]
# sequential_49 model is trained. best val loss is : [0.6916651802403586, 0.5714285714285714]
# sequential_49 model is trained. best val loss is : [0.6425466077668326, 0.6238095238095238]
# sequential_49 model is trained. best val loss is : [0.629129107225509, 0.6619047619047619]
# sequential_49 model is trained. best val loss is : [0.4885724238962645, 0.7714285714285715]
# sequential_49 model is trained. best val loss is : [0.5966161336117867, 0.7761904761904762]
# sequential_49 model is trained. best val loss is : [1.453646492755238, 0.7857142857142857]
# sequential_49 model is trained. best val loss is : [1.3836204103428946, 0.7666666666666667]
# sequential_49 model is trained. best val loss is : [0.7255730059706563, 0.4523809523809524]
# sequential_49 model is trained. best val loss is : [0.6834953373386746, 0.6238095238095238]
# sequential_49 model is trained. best val loss is : [0.5772551702601569, 0.7619047619047619]
# sequential_49 model is trained. best val loss is : [0.5103202623980386, 0.7761904761904762]
# sequential_49 model is trained. best val loss is : [0.47274467570019796, 0.8]
# sequential_49 model is trained. best val loss is : [0.5099795186448665, 0.7857142857142857]
# sequential_49 model is trained. best val loss is : [0.5203395335058238, 0.7904761904761904]
# sequential_49 model is trained. best val loss is : [0.7247812752601321, 0.7761904761904762]
# sequential_49 model is trained. best val loss is : [1.215732873202496, 0.7857142857142857]
# sequential_49 model is trained. best val loss is : [0.45198125446359405, 0.8047619047619048]
# sequential_49 model is trained. best val loss is : [1.0458766909264752, 0.7904761904761904]
# sequential_49 model is trained. best val loss is : [2.361911697588535, 0.7523809523809524]
# sequential_49 model is trained. best val loss is : [5.53184758611332, 0.7285714285714285]
# sequential_50 model is trained. best val loss is : [0.6872848243940444, 0.6190476190476191]
# sequential_50 model is trained. best val loss is : [0.7012804468472799, 0.4523809523809524]
# sequential_50 model is trained. best val loss is : [0.6882139688446408, 0.6095238095238096]
# sequential_50 model is trained. best val loss is : [0.6721345929872422, 0.6476190476190476]
# sequential_50 model is trained. best val loss is : [0.662388299192701, 0.6047619047619047]
# sequential_50 model is trained. best val loss is : [0.6320841217324847, 0.6428571428571429]
# sequential_50 model is trained. best val loss is : [0.6421422851937157, 0.6047619047619047]
# sequential_50 model is trained. best val loss is : [0.49052550157620795, 0.8142857142857143]
# sequential_50 model is trained. best val loss is : [0.5242511010892312, 0.7666666666666667]
# sequential_50 model is trained. best val loss is : [1.1568326368097885, 0.7904761904761904]
# sequential_50 model is trained. best val loss is : [1.0511121452256367, 0.8095238095238095]
# sequential_50 model is trained. best val loss is : [0.6669021856217158, 0.6047619047619047]
# sequential_50 model is trained. best val loss is : [0.6624989364828382, 0.6047619047619047]
# sequential_50 model is trained. best val loss is : [0.5846362179233915, 0.7095238095238096]
# sequential_50 model is trained. best val loss is : [0.48770357444882395, 0.7761904761904762]
# sequential_50 model is trained. best val loss is : [0.5010270765250815, 0.8]
# sequential_50 model is trained. best val loss is : [0.5837232044055348, 0.7619047619047619]
# sequential_50 model is trained. best val loss is : [0.4339197847973472, 0.8142857142857143]
# sequential_50 model is trained. best val loss is : [0.6287473825216559, 0.780952380952381]
# sequential_50 model is trained. best val loss is : [1.0400606065211473, 0.7952380952380952]
# sequential_50 model is trained. best val loss is : [0.45412338346331604, 0.8095238095238095]
# sequential_50 model is trained. best val loss is : [1.3733786661368201, 0.7904761904761904]
# sequential_50 model is trained. best val loss is : [1.1874011167478207, 0.8]
# sequential_50 model is trained. best val loss is : [1.1176328083250613, 0.7476190476190476]
# sequential_51 model is trained. best val loss is : [0.6894676736422948, 0.5761904761904761]
# sequential_51 model is trained. best val loss is : [0.6946535419850123, 0.5476190476190477]
# sequential_51 model is trained. best val loss is : [0.6732175557386307, 0.6285714285714286]
# sequential_51 model is trained. best val loss is : [0.6286678867680686, 0.680952380952381]
# sequential_51 model is trained. best val loss is : [0.6752895467338108, 0.580952380952381]
# sequential_51 model is trained. best val loss is : [0.6317695914279847, 0.7047619047619048]
# sequential_51 model is trained. best val loss is : [0.6395903997478031, 0.6047619047619047]
# sequential_51 model is trained. best val loss is : [0.47532980198129304, 0.7857142857142857]
# sequential_51 model is trained. best val loss is : [0.5887765944994431, 0.7857142857142857]
# sequential_51 model is trained. best val loss is : [1.4156702378173895, 0.8]
# sequential_51 model is trained. best val loss is : [1.1706561987401982, 0.7904761904761904]
# sequential_51 model is trained. best val loss is : [0.6719692494188036, 0.6047619047619047]
# sequential_51 model is trained. best val loss is : [0.6763556057498569, 0.6190476190476191]
# sequential_51 model is trained. best val loss is : [0.5612972655466625, 0.7666666666666667]
# sequential_51 model is trained. best val loss is : [0.4883235755066077, 0.7952380952380952]
# sequential_51 model is trained. best val loss is : [0.47976183837967085, 0.7952380952380952]
# sequential_51 model is trained. best val loss is : [0.5299353692503203, 0.7857142857142857]
# sequential_51 model is trained. best val loss is : [0.490450272637567, 0.7857142857142857]
# sequential_51 model is trained. best val loss is : [0.6749965754260976, 0.8142857142857143]
# sequential_51 model is trained. best val loss is : [1.08670984215316, 0.7857142857142857]
# sequential_51 model is trained. best val loss is : [0.44539676617964036, 0.8]
# sequential_51 model is trained. best val loss is : [2.3179234604140406, 0.7619047619047619]
# sequential_51 model is trained. best val loss is : [1.7423514969422937, 0.7952380952380952]
# sequential_51 model is trained. best val loss is : [4.637133208143865, 0.7619047619047619]
# sequential_52 model is trained. best val loss is : [0.6927383360408601, 0.46190476190476193]
# sequential_52 model is trained. best val loss is : [0.6845680231139774, 0.6095238095238096]
# sequential_52 model is trained. best val loss is : [0.6778286150523595, 0.7142857142857143]
# sequential_52 model is trained. best val loss is : [0.6004406905600003, 0.6047619047619047]
# sequential_52 model is trained. best val loss is : [0.6879700762884957, 0.5857142857142857]
# sequential_52 model is trained. best val loss is : [0.6621253349951335, 0.6047619047619047]
# sequential_52 model is trained. best val loss is : [0.6014643622296197, 0.7380952380952381]
# sequential_52 model is trained. best val loss is : [0.4781360386471663, 0.780952380952381]
# sequential_52 model is trained. best val loss is : [0.795356802200059, 0.7761904761904762]
# sequential_52 model is trained. best val loss is : [1.5701640860644872, 0.8095238095238095]
# sequential_52 model is trained. best val loss is : [1.6269128247784463, 0.7857142857142857]
# sequential_52 model is trained. best val loss is : [0.6680909329936617, 0.6047619047619047]
# sequential_52 model is trained. best val loss is : [0.6812665192853837, 0.6190476190476191]
# sequential_52 model is trained. best val loss is : [0.5688933527185803, 0.7476190476190476]
# sequential_52 model is trained. best val loss is : [0.4829908011215074, 0.7714285714285715]
# sequential_52 model is trained. best val loss is : [0.4962248034642211, 0.8095238095238095]
# sequential_52 model is trained. best val loss is : [0.5178866529659856, 0.7619047619047619]
# sequential_52 model is trained. best val loss is : [0.6376124966498489, 0.7857142857142857]
# sequential_52 model is trained. best val loss is : [0.7406275898058704, 0.8047619047619048]
# sequential_52 model is trained. best val loss is : [1.4124974971370439, 0.7714285714285715]
# sequential_52 model is trained. best val loss is : [0.44162277596658983, 0.8142857142857143]
# sequential_52 model is trained. best val loss is : [1.08939661558647, 0.7666666666666667]
# sequential_52 model is trained. best val loss is : [2.0588852045446977, 0.7952380952380952]
# sequential_52 model is trained. best val loss is : [1.8554222275220655, 0.7904761904761904]
# sequential_53 model is trained. best val loss is : [0.6887404512791406, 0.6047619047619047]
# sequential_53 model is trained. best val loss is : [0.6908774869782585, 0.5714285714285714]
# sequential_53 model is trained. best val loss is : [0.6819774971121834, 0.6857142857142857]
# sequential_53 model is trained. best val loss is : [0.5714865089172408, 0.7666666666666667]
# sequential_53 model is trained. best val loss is : [0.6902697699410575, 0.6238095238095238]
# sequential_53 model is trained. best val loss is : [0.6701684225173223, 0.6047619047619047]
# sequential_53 model is trained. best val loss is : [0.6256736961149034, 0.6047619047619047]
# sequential_53 model is trained. best val loss is : [0.49475814198986406, 0.7904761904761904]
# sequential_53 model is trained. best val loss is : [0.7959006143667482, 0.8]
# sequential_53 model is trained. best val loss is : [1.194718115774685, 0.780952380952381]
# sequential_53 model is trained. best val loss is : [1.0204961992356858, 0.7619047619047619]
# sequential_53 model is trained. best val loss is : [0.6722477532568432, 0.6047619047619047]
# sequential_53 model is trained. best val loss is : [0.6854636589686076, 0.638095238095238]
# sequential_53 model is trained. best val loss is : [0.5858536430767605, 0.7380952380952381]
# sequential_53 model is trained. best val loss is : [0.4944906850301084, 0.780952380952381]
# sequential_53 model is trained. best val loss is : [0.49218273564640963, 0.7857142857142857]
# sequential_53 model is trained. best val loss is : [0.4981275585258291, 0.7857142857142857]
# sequential_53 model is trained. best val loss is : [0.7699168874711156, 0.7761904761904762]
# sequential_53 model is trained. best val loss is : [0.7889727991774783, 0.8047619047619048]
# sequential_53 model is trained. best val loss is : [1.0989184481498488, 0.819047619047619]
# sequential_53 model is trained. best val loss is : [0.4405815841415287, 0.8238095238095238]
# sequential_53 model is trained. best val loss is : [1.7817882995662953, 0.7904761904761904]
# sequential_53 model is trained. best val loss is : [2.5343882840978096, 0.7857142857142857]
# sequential_53 model is trained. best val loss is : [0.6054561597588969, 0.8]
# sequential_54 model is trained. best val loss is : [0.6960592647393544, 0.38571428571428573]
# sequential_54 model is trained. best val loss is : [0.6745572342759087, 0.6047619047619047]
# sequential_54 model is trained. best val loss is : [0.6839812863440741, 0.6047619047619047]
# sequential_54 model is trained. best val loss is : [0.5776634568969409, 0.7380952380952381]
# sequential_54 model is trained. best val loss is : [0.6927470845835549, 0.5142857142857142]
# sequential_54 model is trained. best val loss is : [0.654761689049857, 0.6047619047619047]
# sequential_54 model is trained. best val loss is : [0.6324919626826332, 0.6047619047619047]
# sequential_54 model is trained. best val loss is : [0.48814681480150846, 0.7904761904761904]
# sequential_54 model is trained. best val loss is : [0.9323370965029889, 0.8]
# sequential_54 model is trained. best val loss is : [1.022532611846587, 0.7857142857142857]
# sequential_54 model is trained. best val loss is : [1.3893633381625878, 0.7952380952380952]
# sequential_54 model is trained. best val loss is : [0.6718129030295781, 0.6047619047619047]
# sequential_54 model is trained. best val loss is : [0.6866626969405583, 0.6142857142857143]
# sequential_54 model is trained. best val loss is : [0.577870622135344, 0.7238095238095238]
# sequential_54 model is trained. best val loss is : [0.5163569880028566, 0.780952380952381]
# sequential_54 model is trained. best val loss is : [0.48304703266670307, 0.7952380952380952]
# sequential_54 model is trained. best val loss is : [0.4605692789235729, 0.7952380952380952]
# sequential_54 model is trained. best val loss is : [0.6900805667170288, 0.8]
# sequential_54 model is trained. best val loss is : [0.9710149397513019, 0.780952380952381]
# sequential_54 model is trained. best val loss is : [1.5984719736168749, 0.7904761904761904]
# sequential_54 model is trained. best val loss is : [0.5112711289300239, 0.8095238095238095]
# sequential_54 model is trained. best val loss is : [1.968024819577099, 0.7857142857142857]
# sequential_54 model is trained. best val loss is : [1.2976829135347228, 0.7952380952380952]
# sequential_54 model is trained. best val loss is : [2.1700964756215932, 0.7333333333333333]
# sequential_55 model is trained. best val loss is : [0.6920946938650948, 0.5476190476190477]
# sequential_55 model is trained. best val loss is : [0.6966592748959859, 0.38571428571428573]
# sequential_55 model is trained. best val loss is : [0.6716132910478683, 0.6047619047619047]
# sequential_55 model is trained. best val loss is : [0.6580784928231013, 0.6142857142857143]
# sequential_55 model is trained. best val loss is : [0.6661019932656062, 0.6047619047619047]
# sequential_55 model is trained. best val loss is : [0.6654102123918988, 0.6047619047619047]
# sequential_55 model is trained. best val loss is : [0.6212379387446813, 0.6714285714285714]
# sequential_55 model is trained. best val loss is : [0.48548547927112806, 0.8047619047619048]
# sequential_55 model is trained. best val loss is : [0.7259110470039883, 0.7952380952380952]
# sequential_55 model is trained. best val loss is : [0.7698181054797986, 0.8238095238095238]
# sequential_55 model is trained. best val loss is : [1.0740951337398879, 0.8095238095238095]
# sequential_55 model is trained. best val loss is : [0.6712136613471168, 0.6047619047619047]
# sequential_55 model is trained. best val loss is : [0.6737023563612075, 0.6047619047619047]
# sequential_55 model is trained. best val loss is : [0.5763050334794181, 0.7619047619047619]
# sequential_55 model is trained. best val loss is : [0.5755503793912274, 0.6952380952380952]
# sequential_55 model is trained. best val loss is : [0.498749163365435, 0.7952380952380952]
# sequential_55 model is trained. best val loss is : [0.5585107215813228, 0.7619047619047619]
# sequential_55 model is trained. best val loss is : [0.5848310724250463, 0.7619047619047619]
# sequential_55 model is trained. best val loss is : [0.685427108290135, 0.7857142857142857]
# sequential_55 model is trained. best val loss is : [0.8933162118361033, 0.7714285714285715]
# sequential_55 model is trained. best val loss is : [0.45122065525501964, 0.8095238095238095]
# sequential_55 model is trained. best val loss is : [1.0189082156193434, 0.7952380952380952]
# sequential_55 model is trained. best val loss is : [1.3470512027060992, 0.8047619047619048]
# sequential_55 model is trained. best val loss is : [1.2573966723325614, 0.7857142857142857]
# sequential_56 model is trained. best val loss is : [0.6766764442125957, 0.6095238095238096]
# sequential_56 model is trained. best val loss is : [0.687997449579693, 0.5714285714285714]
# sequential_56 model is trained. best val loss is : [0.6894766177449908, 0.6523809523809524]
# sequential_56 model is trained. best val loss is : [0.622622131166004, 0.7047619047619048]
# sequential_56 model is trained. best val loss is : [0.679310203166235, 0.6095238095238096]
# sequential_56 model is trained. best val loss is : [0.657680708311853, 0.6095238095238096]
# sequential_56 model is trained. best val loss is : [0.6108693917592366, 0.6619047619047619]
# sequential_56 model is trained. best val loss is : [0.4900554784795358, 0.8047619047619048]
# sequential_56 model is trained. best val loss is : [0.6122938016667232, 0.8238095238095238]
# sequential_56 model is trained. best val loss is : [1.4758815216755725, 0.8047619047619048]
# sequential_56 model is trained. best val loss is : [0.5019270146601463, 0.8047619047619048]
# sequential_56 model is trained. best val loss is : [0.6712433299848012, 0.6047619047619047]
# sequential_56 model is trained. best val loss is : [0.6869665446735563, 0.5952380952380952]
# sequential_56 model is trained. best val loss is : [0.6169383576938084, 0.6047619047619047]
# sequential_56 model is trained. best val loss is : [0.4947963868046091, 0.7857142857142857]
# sequential_56 model is trained. best val loss is : [0.4955185338766092, 0.7952380952380952]
# sequential_56 model is trained. best val loss is : [0.5503376836932841, 0.7571428571428571]
# sequential_56 model is trained. best val loss is : [0.6646482367429541, 0.7714285714285715]
# sequential_56 model is trained. best val loss is : [0.653605131341582, 0.8]
# sequential_56 model is trained. best val loss is : [0.7635794572319815, 0.8047619047619048]
# sequential_56 model is trained. best val loss is : [0.42588542004398605, 0.8095238095238095]
# sequential_56 model is trained. best val loss is : [1.5284481191908477, 0.7952380952380952]
# sequential_56 model is trained. best val loss is : [2.0427391039611336, 0.8047619047619048]
# sequential_56 model is trained. best val loss is : [0.5707201243423675, 0.7523809523809524]
# sequential_57 model is trained. best val loss is : [0.6975432983466557, 0.41904761904761906]
# sequential_57 model is trained. best val loss is : [0.6824427437214624, 0.6047619047619047]
# sequential_57 model is trained. best val loss is : [0.6814676557268415, 0.5904761904761905]
# sequential_57 model is trained. best val loss is : [0.6102486810513905, 0.6571428571428571]
# sequential_57 model is trained. best val loss is : [0.6843425009931837, 0.6095238095238096]
# sequential_57 model is trained. best val loss is : [0.6659745948655265, 0.6047619047619047]
# sequential_57 model is trained. best val loss is : [0.6332629328682309, 0.6047619047619047]
# sequential_57 model is trained. best val loss is : [0.4868247305176088, 0.8047619047619048]
# sequential_57 model is trained. best val loss is : [0.9061736654388224, 0.8]
# sequential_57 model is trained. best val loss is : [3.0636386981203114, 0.7857142857142857]
# sequential_57 model is trained. best val loss is : [0.6714411255859193, 0.6047619047619047]
# sequential_57 model is trained. best val loss is : [0.6724218053477151, 0.6047619047619047]
# sequential_57 model is trained. best val loss is : [0.6855602116811843, 0.6047619047619047]
# sequential_57 model is trained. best val loss is : [0.5774841373165448, 0.7285714285714285]
# sequential_57 model is trained. best val loss is : [0.5290836450333397, 0.7904761904761904]
# sequential_57 model is trained. best val loss is : [0.4914925406975228, 0.8]
# sequential_57 model is trained. best val loss is : [0.5113229228272325, 0.7761904761904762]
# sequential_57 model is trained. best val loss is : [0.5813608800066437, 0.780952380952381]
# sequential_57 model is trained. best val loss is : [0.8285494542439911, 0.7714285714285715]
# sequential_57 model is trained. best val loss is : [1.233156251805656, 0.8238095238095238]
# sequential_57 model is trained. best val loss is : [0.4357285455772875, 0.8238095238095238]
# sequential_57 model is trained. best val loss is : [0.7430002324957751, 0.7523809523809524]
# sequential_57 model is trained. best val loss is : [1.8680043959110277, 0.7857142857142857]
# sequential_57 model is trained. best val loss is : [1.7193291284221284, 0.7523809523809524]
# sequential_58 model is trained. best val loss is : [0.6940299993469602, 0.3952380952380952]
# sequential_58 model is trained. best val loss is : [0.6958880543708801, 0.3952380952380952]
# sequential_58 model is trained. best val loss is : [0.6805993923119136, 0.6047619047619047]
# sequential_58 model is trained. best val loss is : [0.5990976799811636, 0.6761904761904762]
# sequential_58 model is trained. best val loss is : [0.6806882631211054, 0.6047619047619047]
# sequential_58 model is trained. best val loss is : [0.6589817140783583, 0.6047619047619047]
# sequential_58 model is trained. best val loss is : [0.6478140728814261, 0.6047619047619047]
# sequential_58 model is trained. best val loss is : [0.49149623315426566, 0.8]
# sequential_58 model is trained. best val loss is : [0.9801973507883168, 0.7904761904761904]
# sequential_58 model is trained. best val loss is : [1.3066934087329685, 0.8]
# sequential_58 model is trained. best val loss is : [1.6723256734596676, 0.7714285714285715]
# sequential_58 model is trained. best val loss is : [0.6525909130062376, 0.6428571428571429]
# sequential_58 model is trained. best val loss is : [0.6777191567988623, 0.6047619047619047]
# sequential_58 model is trained. best val loss is : [0.617250318754287, 0.6047619047619047]
# sequential_58 model is trained. best val loss is : [0.4967781245708466, 0.7952380952380952]
# sequential_58 model is trained. best val loss is : [0.49507502411780435, 0.8095238095238095]
# sequential_58 model is trained. best val loss is : [0.4666254828595335, 0.7952380952380952]
# sequential_58 model is trained. best val loss is : [0.6386778824768137, 0.780952380952381]
# sequential_58 model is trained. best val loss is : [0.9208156004216569, 0.7714285714285715]
# sequential_58 model is trained. best val loss is : [1.2395806152398046, 0.7666666666666667]
# sequential_58 model is trained. best val loss is : [0.5466827824828215, 0.780952380952381]
# sequential_58 model is trained. best val loss is : [0.7782036037022155, 0.8333333333333334]
# sequential_58 model is trained. best val loss is : [0.9956197931955055, 0.7857142857142857]
# sequential_58 model is trained. best val loss is : [0.6960885724911487, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [0.6915834631238665, 0.6285714285714286]
# sequential_59 model is trained. best val loss is : [0.6847680545988537, 0.7095238095238096]
# sequential_59 model is trained. best val loss is : [0.6750704001812707, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [0.5708845242148354, 0.7619047619047619]
# sequential_59 model is trained. best val loss is : [0.685563581046604, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [0.6655714395500365, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [0.652022960072472, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [0.4992870064097501, 0.7857142857142857]
# sequential_59 model is trained. best val loss is : [0.7692005914904982, 0.8047619047619048]
# sequential_59 model is trained. best val loss is : [3.3408994654445987, 0.7761904761904762]
# sequential_59 model is trained. best val loss is : [0.8723464287294941, 0.7523809523809524]
# sequential_59 model is trained. best val loss is : [0.6676080341850008, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [0.6788736587479001, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [0.5941930699916113, 0.680952380952381]
# sequential_59 model is trained. best val loss is : [0.5125776412586371, 0.7666666666666667]
# sequential_59 model is trained. best val loss is : [0.48886762153401614, 0.7952380952380952]
# sequential_59 model is trained. best val loss is : [0.47424265527986875, 0.780952380952381]
# sequential_59 model is trained. best val loss is : [0.758321210469544, 0.7857142857142857]
# sequential_59 model is trained. best val loss is : [0.9433238486028426, 0.7619047619047619]
# sequential_59 model is trained. best val loss is : [1.813403323462654, 0.7619047619047619]
# sequential_59 model is trained. best val loss is : [0.6328901205150379, 0.7857142857142857]
# sequential_59 model is trained. best val loss is : [1.2843321337398244, 0.7857142857142857]
# sequential_59 model is trained. best val loss is : [7.163936908613337, 0.6047619047619047]
# sequential_59 model is trained. best val loss is : [1.024250598333395, 0.6714285714285714]

# %%
best_model_titanic, best_model_info_titanic = select_best_model(mlp_titanic.trained_models, mlp_titanic.val_losses, mlp_titanic.compiled_models_info)
best_model_titanic.evaluate(ds_titanic.trans_X_val, ds_titanic.trans_y_val)
print(best_model_info_titanic)
# Out:
# 210/210 [==============================] - 0s 328us/sample - loss: 0.4106 - accuracy: 0.8333
# {'structure_info': {'hidden_layers': 1, 'units': 32}, 'optimizer_info': {'optimizer_name': 'adamax', 'lr': 0.01}}

# %% [markdown]
# ## Churn

# %%
filename="./data/Churn_Modelling.csv"
ds_churn = DataSource(filename)

ds_churn.data_load_split(target=['Exited'], 
                         ignore=["RowNumber", "CustomerId", "Surname"])
ds_churn.define_problem()
ds_churn.train_val_split(ratio=0.2, random_state=42)
ds_churn.data_preprocess(ds_churn.X_train, ds_churn.y_train, train_set=True)
ds_churn.data_preprocess(ds_churn.X_val, ds_churn.y_val, train_set=False)

# %%
mlp_churn = MLP(ds_churn.trans_X_train, ds_churn.trans_y_train, problem=ds_churn.problem)
mlp_churn.build_structure(max_hidden_layers=1, units=[16], use_all=True)
mlp_churn.create_optimizer(optimizers=['adam'], lrs=[0.01], use_all=True)
mlp_churn.compile_model()

mlp_churn.train_models(mlp_churn.compiled_models,
                       ds_churn.trans_X_train, ds_churn.trans_y_train,
                       ds_churn.trans_X_val, ds_churn.trans_y_val,
                       batch_size=64, epochs=10)
# Out:
# sequential_60 model is trained. best val loss is : [0.5694263844043016, 0.7425]
# sequential_60 model is trained. best val loss is : [0.6569567990303039, 0.6075]
# sequential_60 model is trained. best val loss is : [0.6116714963316917, 0.6905]
# sequential_60 model is trained. best val loss is : [0.42710661236662417, 0.8165]
# sequential_60 model is trained. best val loss is : [0.4788254123814404, 0.7965]
# sequential_60 model is trained. best val loss is : [0.395539220134262, 0.8315]
# sequential_60 model is trained. best val loss is : [0.37386749728466384, 0.845]
# sequential_60 model is trained. best val loss is : [0.33960293480632026, 0.8645]
# sequential_60 model is trained. best val loss is : [0.34092929778841063, 0.861]
# sequential_60 model is trained. best val loss is : [0.33904706904559134, 0.8615]
# sequential_60 model is trained. best val loss is : [0.33361949534030827, 0.8665]
# sequential_60 model is trained. best val loss is : [0.6603649490134684, 0.804]
# sequential_60 model is trained. best val loss is : [0.5470045333653688, 0.8]
# sequential_60 model is trained. best val loss is : [0.3759710131813772, 0.844]
# sequential_60 model is trained. best val loss is : [0.3412170312431408, 0.859]
# sequential_60 model is trained. best val loss is : [0.33886571883189937, 0.863]
# sequential_60 model is trained. best val loss is : [0.3946117630307563, 0.832]
# sequential_60 model is trained. best val loss is : [0.3374208772864827, 0.865]
# sequential_60 model is trained. best val loss is : [0.3398182699209756, 0.861]
# sequential_60 model is trained. best val loss is : [0.33525923495801824, 0.8635]
# sequential_60 model is trained. best val loss is : [0.3442574302023277, 0.8585]
# sequential_60 model is trained. best val loss is : [0.3431750063927561, 0.8585]
# sequential_60 model is trained. best val loss is : [0.3368569178095006, 0.865]
# sequential_60 model is trained. best val loss is : [0.3975549508293999, 0.8225]
# sequential_61 model is trained. best val loss is : [0.8160507712587715, 0.5025]
# sequential_61 model is trained. best val loss is : [0.5131118096038699, 0.8035]
# sequential_61 model is trained. best val loss is : [0.5009319034460932, 0.795]
# sequential_61 model is trained. best val loss is : [0.42061822512070646, 0.817]
# sequential_61 model is trained. best val loss is : [0.491241119094193, 0.805]
# sequential_61 model is trained. best val loss is : [0.383576455545146, 0.835]
# sequential_61 model is trained. best val loss is : [0.37553649172536097, 0.8465]
# sequential_61 model is trained. best val loss is : [0.33950062158749644, 0.86]
# sequential_61 model is trained. best val loss is : [0.3378996052624061, 0.8665]
# sequential_61 model is trained. best val loss is : [0.33069426561916004, 0.8635]
# sequential_61 model is trained. best val loss is : [0.37098799338261595, 0.839]
# sequential_61 model is trained. best val loss is : [0.49574811843037603, 0.8035]
# sequential_61 model is trained. best val loss is : [0.5179279257506132, 0.81]
# sequential_61 model is trained. best val loss is : [0.3712305498968344, 0.8475]
# sequential_61 model is trained. best val loss is : [0.3468322615009238, 0.8575]
# sequential_61 model is trained. best val loss is : [0.3381169433160248, 0.8645]
# sequential_61 model is trained. best val loss is : [0.36753952809609475, 0.8475]
# sequential_61 model is trained. best val loss is : [0.3388958772827182, 0.862]
# sequential_61 model is trained. best val loss is : [0.3331746149313258, 0.8655]
# sequential_61 model is trained. best val loss is : [0.34172195381334086, 0.8605]
# sequential_61 model is trained. best val loss is : [0.3413342816251916, 0.862]
# sequential_61 model is trained. best val loss is : [0.3376839556965255, 0.8635]
# sequential_61 model is trained. best val loss is : [0.34036383294267464, 0.8595]
# sequential_61 model is trained. best val loss is : [0.4008508771028009, 0.8225]
# sequential_62 model is trained. best val loss is : [0.5891210926100612, 0.7755]
# sequential_62 model is trained. best val loss is : [0.564909250870347, 0.7985]
# sequential_62 model is trained. best val loss is : [0.47045673887617884, 0.8115]
# sequential_62 model is trained. best val loss is : [0.4056331387257669, 0.827]
# sequential_62 model is trained. best val loss is : [0.5114072074368596, 0.8035]
# sequential_62 model is trained. best val loss is : [0.3987010811350774, 0.835]
# sequential_62 model is trained. best val loss is : [0.3727809431478381, 0.846]
# sequential_62 model is trained. best val loss is : [0.33902879094081073, 0.8655]
# sequential_62 model is trained. best val loss is : [0.33512607358528473, 0.8665]
# sequential_62 model is trained. best val loss is : [0.332360390218176, 0.862]
# sequential_62 model is trained. best val loss is : [0.3420482095791335, 0.8575]
# sequential_62 model is trained. best val loss is : [0.4957271860614419, 0.8035]
# sequential_62 model is trained. best val loss is : [0.4722871020026505, 0.8205]
# sequential_62 model is trained. best val loss is : [0.375390569701558, 0.844]
# sequential_62 model is trained. best val loss is : [0.3400451567990676, 0.861]
# sequential_62 model is trained. best val loss is : [0.3342329762406794, 0.867]
# sequential_62 model is trained. best val loss is : [0.34851221288274975, 0.855]
# sequential_62 model is trained. best val loss is : [0.3353742261520615, 0.8655]
# sequential_62 model is trained. best val loss is : [0.3363769563143906, 0.861]
# sequential_62 model is trained. best val loss is : [0.33756347170777146, 0.8605]
# sequential_62 model is trained. best val loss is : [0.3406481035186889, 0.862]
# sequential_62 model is trained. best val loss is : [0.33436009054322674, 0.868]
# sequential_62 model is trained. best val loss is : [0.3443672366360159, 0.858]
# sequential_62 model is trained. best val loss is : [0.406218726846583, 0.818]
# sequential_63 model is trained. best val loss is : [0.6653380942046643, 0.604]
# sequential_63 model is trained. best val loss is : [0.5374577339030803, 0.7915]
# sequential_63 model is trained. best val loss is : [0.47878755012340846, 0.8035]
# sequential_63 model is trained. best val loss is : [0.3972346245739609, 0.8345]
# sequential_63 model is trained. best val loss is : [0.5090474899858236, 0.805]
# sequential_63 model is trained. best val loss is : [0.3973892138074152, 0.828]
# sequential_63 model is trained. best val loss is : [0.37936718173278494, 0.839]
# sequential_63 model is trained. best val loss is : [0.34021592728236283, 0.8655]
# sequential_63 model is trained. best val loss is : [0.3342420738245098, 0.867]
# sequential_63 model is trained. best val loss is : [0.33576869232956974, 0.8605]
# sequential_63 model is trained. best val loss is : [0.3324966231772945, 0.865]
# sequential_63 model is trained. best val loss is : [0.4957098243162036, 0.8035]
# sequential_63 model is trained. best val loss is : [0.45593952539749444, 0.804]
# sequential_63 model is trained. best val loss is : [0.3605505760756787, 0.852]
# sequential_63 model is trained. best val loss is : [0.33972636911649895, 0.8655]
# sequential_63 model is trained. best val loss is : [0.33386705565508784, 0.867]
# sequential_63 model is trained. best val loss is : [0.34227122860666714, 0.8615]
# sequential_63 model is trained. best val loss is : [0.33124998086698654, 0.8665]
# sequential_63 model is trained. best val loss is : [0.3336282260094341, 0.864]
# sequential_63 model is trained. best val loss is : [0.3452113714768123, 0.8575]
# sequential_63 model is trained. best val loss is : [0.3379123307358195, 0.8635]
# sequential_63 model is trained. best val loss is : [0.3370066901574542, 0.863]
# sequential_63 model is trained. best val loss is : [0.3461496866231964, 0.8635]
# sequential_63 model is trained. best val loss is : [0.46474935864301575, 0.8175]
# sequential_64 model is trained. best val loss is : [0.6197908343672752, 0.73]
# sequential_64 model is trained. best val loss is : [0.5053014636598527, 0.806]
# sequential_64 model is trained. best val loss is : [0.4593942652568221, 0.8045]
# sequential_64 model is trained. best val loss is : [0.3895005179080181, 0.8335]
# sequential_64 model is trained. best val loss is : [0.4754567968342453, 0.8035]
# sequential_64 model is trained. best val loss is : [0.4104942791960202, 0.8195]
# sequential_64 model is trained. best val loss is : [0.37204496199358256, 0.85]
# sequential_64 model is trained. best val loss is : [0.34020677095283736, 0.863]
# sequential_64 model is trained. best val loss is : [0.33365734636838124, 0.8685]
# sequential_64 model is trained. best val loss is : [0.33217231273401426, 0.861]
# sequential_64 model is trained. best val loss is : [0.3514865696896075, 0.862]
# sequential_64 model is trained. best val loss is : [0.4957001551240683, 0.8035]
# sequential_64 model is trained. best val loss is : [0.4969482762105763, 0.8035]
# sequential_64 model is trained. best val loss is : [0.361149754550308, 0.848]
# sequential_64 model is trained. best val loss is : [0.3411594886587045, 0.866]
# sequential_64 model is trained. best val loss is : [0.33844227683753114, 0.862]
# sequential_64 model is trained. best val loss is : [0.34097258411523945, 0.8625]
# sequential_64 model is trained. best val loss is : [0.3348073110355458, 0.864]
# sequential_64 model is trained. best val loss is : [0.3345314507377498, 0.8615]
# sequential_64 model is trained. best val loss is : [0.33844168461790136, 0.86]
# sequential_64 model is trained. best val loss is : [0.3374891542494529, 0.87]
# sequential_64 model is trained. best val loss is : [0.33519534780806776, 0.866]
# sequential_64 model is trained. best val loss is : [0.35894740230111055, 0.86]
# sequential_64 model is trained. best val loss is : [0.41696726276582236, 0.8185]
# sequential_65 model is trained. best val loss is : [0.6510599248558283, 0.6545]
# sequential_65 model is trained. best val loss is : [0.5861929434686899, 0.6955]
# sequential_65 model is trained. best val loss is : [0.4617852746862918, 0.8095]
# sequential_65 model is trained. best val loss is : [0.4144952255967073, 0.822]
# sequential_65 model is trained. best val loss is : [0.49946154828369616, 0.8035]
# sequential_65 model is trained. best val loss is : [0.4191606611153111, 0.8035]
# sequential_65 model is trained. best val loss is : [0.37188888506963846, 0.8505]
# sequential_65 model is trained. best val loss is : [0.34079663712519687, 0.8625]
# sequential_65 model is trained. best val loss is : [0.33893152967621426, 0.8605]
# sequential_65 model is trained. best val loss is : [0.3327408914614025, 0.8625]
# sequential_65 model is trained. best val loss is : [0.3490754932924419, 0.857]
# sequential_65 model is trained. best val loss is : [0.49569582817703484, 0.8035]
# sequential_65 model is trained. best val loss is : [0.4762762637287378, 0.8035]
# sequential_65 model is trained. best val loss is : [0.34965530209522694, 0.862]
# sequential_65 model is trained. best val loss is : [0.33879032395465764, 0.864]
# sequential_65 model is trained. best val loss is : [0.33706479911874615, 0.8655]
# sequential_65 model is trained. best val loss is : [0.35253205316339153, 0.86]
# sequential_65 model is trained. best val loss is : [0.3379219905435057, 0.8635]
# sequential_65 model is trained. best val loss is : [0.3348151065854845, 0.861]
# sequential_65 model is trained. best val loss is : [0.3445747231276675, 0.86]
# sequential_65 model is trained. best val loss is : [0.33465710995708653, 0.865]
# sequential_65 model is trained. best val loss is : [0.34437876184527594, 0.858]
# sequential_65 model is trained. best val loss is : [0.34009371631202745, 0.8625]
# sequential_65 model is trained. best val loss is : [0.41375288805970306, 0.833]
# sequential_66 model is trained. best val loss is : [0.6521100228726864, 0.692]
# sequential_66 model is trained. best val loss is : [0.5208751625344157, 0.8035]
# sequential_66 model is trained. best val loss is : [0.4679894571304321, 0.8035]
# sequential_66 model is trained. best val loss is : [0.403584913819097, 0.8155]
# sequential_66 model is trained. best val loss is : [0.481378037343733, 0.8035]
# sequential_66 model is trained. best val loss is : [0.3982676048364956, 0.8305]
# sequential_66 model is trained. best val loss is : [0.35075003119255416, 0.86]
# sequential_66 model is trained. best val loss is : [0.33433770094096327, 0.864]
# sequential_66 model is trained. best val loss is : [0.33686758750558693, 0.8605]
# sequential_66 model is trained. best val loss is : [0.33659333082250303, 0.862]
# sequential_66 model is trained. best val loss is : [0.3407103202606668, 0.862]
# sequential_66 model is trained. best val loss is : [0.4956892686188221, 0.8035]
# sequential_66 model is trained. best val loss is : [0.4630936468411237, 0.8035]
# sequential_66 model is trained. best val loss is : [0.36741612434759735, 0.8455]
# sequential_66 model is trained. best val loss is : [0.3409366602107475, 0.862]
# sequential_66 model is trained. best val loss is : [0.3339263056741793, 0.8645]
# sequential_66 model is trained. best val loss is : [0.3434785284101963, 0.855]
# sequential_66 model is trained. best val loss is : [0.3364636237119112, 0.86]
# sequential_66 model is trained. best val loss is : [0.33422008453011265, 0.8635]
# sequential_66 model is trained. best val loss is : [0.3505008547952907, 0.858]
# sequential_66 model is trained. best val loss is : [0.33185039474008227, 0.867]
# sequential_66 model is trained. best val loss is : [0.33397422398369975, 0.865]
# sequential_66 model is trained. best val loss is : [0.34380038382173733, 0.861]
# sequential_66 model is trained. best val loss is : [0.482277939600251, 0.8115]
# sequential_67 model is trained. best val loss is : [0.6965655111372471, 0.524]
# sequential_67 model is trained. best val loss is : [0.49548771942406894, 0.8035]
# sequential_67 model is trained. best val loss is : [0.46733102000225335, 0.8035]
# sequential_67 model is trained. best val loss is : [0.36760672923375387, 0.8505]
# sequential_67 model is trained. best val loss is : [0.49448902874439954, 0.8035]
# sequential_67 model is trained. best val loss is : [0.40142931465106085, 0.8255]
# sequential_67 model is trained. best val loss is : [0.37834200318623334, 0.838]
# sequential_67 model is trained. best val loss is : [0.3355975958545787, 0.864]
# sequential_67 model is trained. best val loss is : [0.3349728887405536, 0.862]
# sequential_67 model is trained. best val loss is : [0.3314171690332823, 0.8615]
# sequential_67 model is trained. best val loss is : [0.3458406075306193, 0.8615]
# sequential_67 model is trained. best val loss is : [0.4957226884737611, 0.8035]
# sequential_67 model is trained. best val loss is : [0.4726654199305922, 0.8035]
# sequential_67 model is trained. best val loss is : [0.35745430018915797, 0.857]
# sequential_67 model is trained. best val loss is : [0.3331497992287659, 0.864]
# sequential_67 model is trained. best val loss is : [0.3343718130148891, 0.8615]
# sequential_67 model is trained. best val loss is : [0.346667876358144, 0.857]
# sequential_67 model is trained. best val loss is : [0.3342630569303558, 0.862]
# sequential_67 model is trained. best val loss is : [0.33632363704824714, 0.863]
# sequential_67 model is trained. best val loss is : [0.3438734652940755, 0.859]
# sequential_67 model is trained. best val loss is : [0.333501552577025, 0.8655]
# sequential_67 model is trained. best val loss is : [0.3406212638446912, 0.861]
# sequential_67 model is trained. best val loss is : [0.35803818029183665, 0.86]
# sequential_67 model is trained. best val loss is : [0.49552662068605424, 0.8035]
# sequential_68 model is trained. best val loss is : [0.5755963783040643, 0.8035]
# sequential_68 model is trained. best val loss is : [0.4572284745499492, 0.8035]
# sequential_68 model is trained. best val loss is : [0.42388522053789346, 0.82]
# sequential_68 model is trained. best val loss is : [0.3553252179354895, 0.8575]
# sequential_68 model is trained. best val loss is : [0.48853728818148373, 0.8035]
# sequential_68 model is trained. best val loss is : [0.37911878517456354, 0.8425]
# sequential_68 model is trained. best val loss is : [0.35142148881789764, 0.855]
# sequential_68 model is trained. best val loss is : [0.3371417955328689, 0.8645]
# sequential_68 model is trained. best val loss is : [0.3307736214997171, 0.864]
# sequential_68 model is trained. best val loss is : [0.33561148609023983, 0.865]
# sequential_68 model is trained. best val loss is : [0.49579248831421135, 0.8035]
# sequential_68 model is trained. best val loss is : [0.495689284786582, 0.8035]
# sequential_68 model is trained. best val loss is : [0.45290582574997096, 0.803]
# sequential_68 model is trained. best val loss is : [0.347516493154224, 0.858]
# sequential_68 model is trained. best val loss is : [0.3384862411950598, 0.8625]
# sequential_68 model is trained. best val loss is : [0.334540094781795, 0.864]
# sequential_68 model is trained. best val loss is : [0.3366910677822134, 0.859]
# sequential_68 model is trained. best val loss is : [0.33505660014173655, 0.8605]
# sequential_68 model is trained. best val loss is : [0.3303546088914209, 0.8605]
# sequential_68 model is trained. best val loss is : [0.34813983680206445, 0.8625]
# sequential_68 model is trained. best val loss is : [0.33550625515036947, 0.866]
# sequential_68 model is trained. best val loss is : [0.33444530883877804, 0.8645]
# sequential_68 model is trained. best val loss is : [0.34636359438244335, 0.8575]
# sequential_68 model is trained. best val loss is : [0.49552662068605424, 0.8035]
# sequential_69 model is trained. best val loss is : [0.6045400074422359, 0.8055]
# sequential_69 model is trained. best val loss is : [0.44411817643232643, 0.8045]
# sequential_69 model is trained. best val loss is : [0.4143204139326699, 0.822]
# sequential_69 model is trained. best val loss is : [0.3480079379180679, 0.86]
# sequential_69 model is trained. best val loss is : [0.5000591960251332, 0.8035]
# sequential_69 model is trained. best val loss is : [0.3928301458922215, 0.839]
# sequential_69 model is trained. best val loss is : [0.35311754866247064, 0.856]
# sequential_69 model is trained. best val loss is : [0.33654203132928795, 0.865]
# sequential_69 model is trained. best val loss is : [0.3381808031259395, 0.8625]
# sequential_69 model is trained. best val loss is : [0.34250646206267993, 0.8635]
# sequential_69 model is trained. best val loss is : [0.3429839250109378, 0.858]
# sequential_69 model is trained. best val loss is : [0.49574022537469864, 0.8035]
# sequential_69 model is trained. best val loss is : [0.43810435155034066, 0.804]
# sequential_69 model is trained. best val loss is : [0.34223055820085574, 0.861]
# sequential_69 model is trained. best val loss is : [0.33706683173524654, 0.8615]
# sequential_69 model is trained. best val loss is : [0.3378549091797195, 0.864]
# sequential_69 model is trained. best val loss is : [0.3398270105080642, 0.863]
# sequential_69 model is trained. best val loss is : [0.33841732215749, 0.864]
# sequential_69 model is trained. best val loss is : [0.34050778753879446, 0.8625]
# sequential_69 model is trained. best val loss is : [0.347957404637833, 0.8575]
# sequential_69 model is trained. best val loss is : [0.3322953540782637, 0.8615]
# sequential_69 model is trained. best val loss is : [0.3328176788295751, 0.8635]
# sequential_69 model is trained. best val loss is : [0.3537874697485169, 0.857]
# sequential_69 model is trained. best val loss is : [0.49552662068605424, 0.8035]
# sequential_70 model is trained. best val loss is : [0.5987605644613504, 0.78]
# sequential_70 model is trained. best val loss is : [0.6309435243755579, 0.7745]
# sequential_70 model is trained. best val loss is : [0.4703608836401254, 0.8035]
# sequential_70 model is trained. best val loss is : [0.4031013842858374, 0.819]
# sequential_70 model is trained. best val loss is : [0.5131001205816865, 0.8035]
# sequential_70 model is trained. best val loss is : [0.4218894703532569, 0.8035]
# sequential_70 model is trained. best val loss is : [0.3998289990434423, 0.827]
# sequential_70 model is trained. best val loss is : [0.338082956170314, 0.8645]
# sequential_70 model is trained. best val loss is : [0.3392507031239802, 0.864]
# sequential_70 model is trained. best val loss is : [0.33105212366640385, 0.865]
# sequential_70 model is trained. best val loss is : [0.3543547986264748, 0.853]
# sequential_70 model is trained. best val loss is : [0.49533139044046404, 0.8035]
# sequential_70 model is trained. best val loss is : [0.4697994974069297, 0.8035]
# sequential_70 model is trained. best val loss is : [0.40266543136467225, 0.823]
# sequential_70 model is trained. best val loss is : [0.34341032219992484, 0.8545]
# sequential_70 model is trained. best val loss is : [0.3355109060819668, 0.8655]
# sequential_70 model is trained. best val loss is : [0.3680564156176988, 0.8525]
# sequential_70 model is trained. best val loss is : [0.33529678148284436, 0.865]
# sequential_70 model is trained. best val loss is : [0.34003233842165265, 0.861]
# sequential_70 model is trained. best val loss is : [0.3430935681360133, 0.8585]
# sequential_70 model is trained. best val loss is : [0.33500679461807975, 0.8655]
# sequential_70 model is trained. best val loss is : [0.3381591607805674, 0.8625]
# sequential_70 model is trained. best val loss is : [0.34147344790364825, 0.8605]
# sequential_70 model is trained. best val loss is : [0.49552662068605424, 0.8035]
# sequential_71 model is trained. best val loss is : [0.5915315387696027, 0.8035]
# sequential_71 model is trained. best val loss is : [0.5600175872072577, 0.8035]
# sequential_71 model is trained. best val loss is : [0.47621958921290936, 0.8035]
# sequential_71 model is trained. best val loss is : [0.40054827442835084, 0.8285]
# sequential_71 model is trained. best val loss is : [0.48414894511178136, 0.8035]
# sequential_71 model is trained. best val loss is : [0.4097636818117462, 0.8155]
# sequential_71 model is trained. best val loss is : [0.35545238279597835, 0.853]
# sequential_71 model is trained. best val loss is : [0.3380156752901421, 0.863]
# sequential_71 model is trained. best val loss is : [0.3375817805875349, 0.855]
# sequential_71 model is trained. best val loss is : [0.33388025018909245, 0.862]
# sequential_71 model is trained. best val loss is : [0.3520084239466814, 0.8465]
# sequential_71 model is trained. best val loss is : [0.495691643409431, 0.8035]
# sequential_71 model is trained. best val loss is : [0.49277474777027963, 0.803]
# sequential_71 model is trained. best val loss is : [0.355630623573903, 0.859]
# sequential_71 model is trained. best val loss is : [0.3389468450090208, 0.8615]
# sequential_71 model is trained. best val loss is : [0.3370739582677743, 0.862]
# sequential_71 model is trained. best val loss is : [0.34379645541968057, 0.859]
# sequential_71 model is trained. best val loss is : [0.33327996652962977, 0.867]
# sequential_71 model is trained. best val loss is : [0.33439024639732995, 0.8615]
# sequential_71 model is trained. best val loss is : [0.3379538393029756, 0.863]
# sequential_71 model is trained. best val loss is : [0.33278087671394313, 0.868]
# sequential_71 model is trained. best val loss is : [0.3395738190300355, 0.86]
# sequential_71 model is trained. best val loss is : [0.33371679303346846, 0.865]
# sequential_71 model is trained. best val loss is : [0.49552662068605424, 0.8035]
# sequential_72 model is trained. best val loss is : [0.7268851848989725, 0.351]
# sequential_72 model is trained. best val loss is : [0.49570127817988396, 0.8035]
# sequential_72 model is trained. best val loss is : [0.45231137771345675, 0.8035]
# sequential_72 model is trained. best val loss is : [0.35458761755563317, 0.853]
# sequential_72 model is trained. best val loss is : [0.5186266138330102, 0.8035]
# sequential_72 model is trained. best val loss is : [0.4141260674656369, 0.819]
# sequential_72 model is trained. best val loss is : [0.36225407794234343, 0.853]
# sequential_72 model is trained. best val loss is : [0.33599766490692856, 0.867]
# sequential_72 model is trained. best val loss is : [0.3347494176358982, 0.8605]
# sequential_72 model is trained. best val loss is : [0.33972137267743296, 0.8595]
# sequential_72 model is trained. best val loss is : [0.4957938218712807, 0.8035]
# sequential_72 model is trained. best val loss is : [0.4957022584155202, 0.8035]
# sequential_72 model is trained. best val loss is : [0.4846998620312661, 0.8035]
# sequential_72 model is trained. best val loss is : [0.34608370292768814, 0.8615]
# sequential_72 model is trained. best val loss is : [0.3361808223981061, 0.8605]
# sequential_72 model is trained. best val loss is : [0.3339385879272304, 0.8595]
# sequential_72 model is trained. best val loss is : [0.34037398809023944, 0.8605]
# sequential_72 model is trained. best val loss is : [0.3348703144272895, 0.8635]
# sequential_72 model is trained. best val loss is : [0.3367550969523163, 0.862]
# sequential_72 model is trained. best val loss is : [0.34209561473589567, 0.859]
# sequential_72 model is trained. best val loss is : [0.3371002264598137, 0.8645]
# sequential_72 model is trained. best val loss is : [0.34526467564856583, 0.8645]
# sequential_72 model is trained. best val loss is : [0.33601191690570187, 0.859]
# sequential_72 model is trained. best val loss is : [0.49552662068605424, 0.8035]
# sequential_73 model is trained. best val loss is : [0.6247649135291576, 0.795]
# sequential_73 model is trained. best val loss is : [0.47773094971105456, 0.8035]
# sequential_73 model is trained. best val loss is : [0.425148346262984, 0.8085]
# sequential_73 model is trained. best val loss is : [0.34230771130672655, 0.859]
# sequential_73 model is trained. best val loss is : [0.4933860784024, 0.8035]
# sequential_73 model is trained. best val loss is : [0.3905322849117219, 0.834]
# sequential_73 model is trained. best val loss is : [0.3714944498820696, 0.8485]
# sequential_73 model is trained. best val loss is : [0.33666063143598146, 0.865]
# sequential_73 model is trained. best val loss is : [0.3423472934991851, 0.86]
# sequential_73 model is trained. best val loss is : [0.34235769674298355, 0.8635]
# sequential_73 model is trained. best val loss is : [0.4596895794868469, 0.8035]
# sequential_73 model is trained. best val loss is : [0.49574066454172133, 0.8035]
# sequential_73 model is trained. best val loss is : [0.4623308082325384, 0.8035]
# sequential_73 model is trained. best val loss is : [0.34235540248069446, 0.86]
# sequential_73 model is trained. best val loss is : [0.3368755962113646, 0.862]
# sequential_73 model is trained. best val loss is : [0.3349673004343331, 0.865]
# sequential_73 model is trained. best val loss is : [0.3418161320723739, 0.863]
# sequential_73 model is trained. best val loss is : [0.3405176393034685, 0.862]
# sequential_73 model is trained. best val loss is : [0.3348133545438503, 0.864]
# sequential_73 model is trained. best val loss is : [0.340355856125032, 0.863]
# sequential_73 model is trained. best val loss is : [0.34082821829841625, 0.867]
# sequential_73 model is trained. best val loss is : [0.33547627710680866, 0.861]
# sequential_73 model is trained. best val loss is : [0.3482629633199621, 0.8575]
# sequential_73 model is trained. best val loss is : [0.49552662068605424, 0.8035]
# sequential_74 model is trained. best val loss is : [0.5638978911414743, 0.8035]
# sequential_74 model is trained. best val loss is : [0.4551296152267605, 0.8035]
# sequential_74 model is trained. best val loss is : [0.40754631424834953, 0.83]
# sequential_74 model is trained. best val loss is : [0.3429862878987915, 0.862]
# sequential_74 model is trained. best val loss is : [0.49541497851908206, 0.8035]
# sequential_74 model is trained. best val loss is : [0.3860516707401257, 0.8315]
# sequential_74 model is trained. best val loss is : [0.3696092140832916, 0.847]
# sequential_74 model is trained. best val loss is : [0.3349380829165384, 0.868]
# sequential_74 model is trained. best val loss is : [0.34480712455492984, 0.8625]
# sequential_74 model is trained. best val loss is : [0.35388821114739405, 0.847]
# sequential_74 model is trained. best val loss is : [0.49565867640823125, 0.8035]
# sequential_74 model is trained. best val loss is : [0.4957874389886856, 0.8035]
# sequential_74 model is trained. best val loss is : [0.4650147001594305, 0.8035]
# sequential_74 model is trained. best val loss is : [0.3432132732910686, 0.861]
# sequential_74 model is trained. best val loss is : [0.3364109181517997, 0.8625]
# sequential_74 model is trained. best val loss is : [0.33515046780853297, 0.863]
# sequential_74 model is trained. best val loss is : [0.3363316945620591, 0.861]
# sequential_74 model is trained. best val loss is : [0.3385572357445859, 0.863]
# sequential_74 model is trained. best val loss is : [0.33582366842101585, 0.8645]
# sequential_74 model is trained. best val loss is : [0.3365599145788801, 0.862]
# sequential_74 model is trained. best val loss is : [0.3514359064399273, 0.859]
# sequential_74 model is trained. best val loss is : [0.342746573100869, 0.865]
# sequential_74 model is trained. best val loss is : [0.37081338224489324, 0.839]
# sequential_74 model is trained. best val loss is : [0.49552662068605424, 0.8035]

# %%
best_model_churn, best_model_info_churn = select_best_model(mlp_churn.trained_models, mlp_churn.val_losses, mlp_churn.compiled_models_info)
best_model_churn.evaluate(ds_churn.trans_X_val, ds_churn.trans_y_val)
print(best_model_info_churn)
# Out:
# 2000/2000 [==============================] - 0s 40us/sample - loss: 0.3304 - accuracy: 0.8605
# {'structure_info': {'hidden_layers': 2, 'units': 128}, 'optimizer_info': {'optimizer_name': 'adamax', 'lr': 0.02}}

# %% [markdown]
# ## House

# %%
filename="./data/sberbank_train_reduced_10k.csv"
ds_house = DataSource(filename)

ds_house.data_load_split(target=['price_doc'],)
ds_house.define_problem()
ds_house.train_val_split(ratio=0.2, random_state=42)
ds_house.data_preprocess(ds_house.X_train, ds_house.y_train, train_set=True)
ds_house.data_preprocess(ds_house.X_val, ds_house.y_val, train_set=False)

# %%
# when X transformer is Normalizer
mlp_house = MLP(ds_house.trans_X_train, ds_house.trans_y_train, problem=ds_house.problem)
mlp_house.build_structure(max_hidden_layers=1, units=[16], use_all=True)
mlp_house.create_optimizer(optimizers=['adam'], lrs=[0.01], use_all=True)
mlp_house.compile_model()

mlp_house.train_models(mlp_house.compiled_models,
                       ds_house.trans_X_train, ds_house.trans_y_train,
                       ds_house.trans_X_val, ds_house.trans_y_val,
                       batch_size=64, epochs=10)
# Out:
# sequential_30 model is trained. best val loss is : [2.190548397064209, 2.190548396233459, 1.3743321695724697]
# sequential_30 model is trained. best val loss is : [0.18139843638486433, 0.18139843644344225, 0.34768779140442435]
# sequential_30 model is trained. best val loss is : [0.10086381096488208, 0.10086381085853086, 0.2407387644456538]
# sequential_30 model is trained. best val loss is : [0.0062517400813343164, 0.0062517400828736615, 0.05865226686056064]
# sequential_30 model is trained. best val loss is : [0.030007667147842813, 0.030007667148125916, 0.13326024157557007]
# sequential_30 model is trained. best val loss is : [0.0046233553153293885, 0.004623355312962317, 0.048441574706130634]
# sequential_30 model is trained. best val loss is : [0.002295149809642683, 0.0022951498086621063, 0.0353033603825427]
# sequential_30 model is trained. best val loss is : [0.00030013533463802555, 0.00030013533566371783, 0.01260218445778718]
# sequential_30 model is trained. best val loss is : [0.0009932977473114321, 0.0009932977482739601, 0.02340155977866767]
# sequential_30 model is trained. best val loss is : [0.0002113776030845721, 0.00021137760347708144, 0.008902847309966965]
# sequential_30 model is trained. best val loss is : [0.00039908117127249426, 0.0003990811708614022, 0.015385745479766028]
# sequential_30 model is trained. best val loss is : [9.24730323009679e-05, 9.247303254274662e-05, 0.005718649954978744]
# sequential_30 model is trained. best val loss is : [0.06589222264025048, 0.06589222252299436, 0.1941932255175916]
# sequential_30 model is trained. best val loss is : [0.005573233573391031, 0.0055732335671232, 0.054100671427778094]
# sequential_30 model is trained. best val loss is : [0.0017484897756672169, 0.0017484897770236436, 0.030029467847317973]
# sequential_30 model is trained. best val loss is : [0.0009447184532785882, 0.0009447184538692786, 0.02081655729423006]
# sequential_30 model is trained. best val loss is : [0.0035197472040630288, 0.003519747201174217, 0.04445479835222865]
# sequential_30 model is trained. best val loss is : [0.0006664613714708291, 0.0006664613707759501, 0.018006236959824253]
# sequential_30 model is trained. best val loss is : [0.0012475099285767345, 0.0012475099291772089, 0.019177926266381387]
# sequential_30 model is trained. best val loss is : [0.002246878712401898, 0.0022468787033355217, 0.030778363057453566]
# sequential_30 model is trained. best val loss is : [0.0008591748613189469, 0.0008591748618557225, 0.021423393427487402]
# sequential_30 model is trained. best val loss is : [0.00041797266717912864, 0.0004179726673190187, 0.020175892787767644]
# sequential_30 model is trained. best val loss is : [9.999900066759437e-05, 9.999900360378099e-05, 0.009999950180064943]
# sequential_30 model is trained. best val loss is : [0.002466061618179083, 0.0024660616890917783, 0.049659457196910534]
# sequential_31 model is trained. best val loss is : [0.5995774615831027, 0.5995774610975234, 0.6537687058819376]
# sequential_31 model is trained. best val loss is : [0.5996039857081389, 0.5996039856648863, 0.7158741738601105]
# sequential_31 model is trained. best val loss is : [0.042105093186099944, 0.04210509311312397, 0.16098376186918148]
# sequential_31 model is trained. best val loss is : [0.006075747544897809, 0.006075747542742068, 0.05529340884206917]
# sequential_31 model is trained. best val loss is : [0.03181872784215477, 0.03181872784584499, 0.14289047606372055]
# sequential_31 model is trained. best val loss is : [0.004773585240147554, 0.004773585249163497, 0.05072443132200931]
# sequential_31 model is trained. best val loss is : [0.0022216221008296015, 0.002221622100674819, 0.03527759233336633]
# sequential_31 model is trained. best val loss is : [0.0005243530451975058, 0.00052435304491208, 0.01677747495524624]
# sequential_31 model is trained. best val loss is : [0.0006038984849265871, 0.0006038984840553409, 0.016697378938683047]
# sequential_31 model is trained. best val loss is : [0.00026598947604941463, 0.0002659894759431469, 0.011576426372800415]
# sequential_31 model is trained. best val loss is : [0.002249876907101402, 0.0022498769111622494, 0.03241339039484338]
# sequential_31 model is trained. best val loss is : [1.0973698588657441, 1.0973698558523812, 0.6559902711000333]
# sequential_31 model is trained. best val loss is : [0.027554913767639043, 0.027554913752715335, 0.12122208242980703]
# sequential_31 model is trained. best val loss is : [0.0035685618362119474, 0.003568561830575302, 0.04482247360487984]
# sequential_31 model is trained. best val loss is : [0.0013050556498619154, 0.0013050556495803809, 0.026160658241411915]
# sequential_31 model is trained. best val loss is : [0.0004782083168575666, 0.00047820831917246134, 0.015887749545130957]
# sequential_31 model is trained. best val loss is : [0.0036947395594065383, 0.0036947395481489328, 0.042460685223063524]
# sequential_31 model is trained. best val loss is : [0.0004403987656183519, 0.0004403987662806933, 0.0150544481804508]
# sequential_31 model is trained. best val loss is : [0.001107566131479866, 0.0011075661287329802, 0.01990354257263023]
# sequential_31 model is trained. best val loss is : [0.00013882786612283464, 0.00013882786571709128, 0.008306012937691391]
# sequential_31 model is trained. best val loss is : [0.0014339430004259197, 0.0014339430045583802, 0.0288547017211234]
# sequential_31 model is trained. best val loss is : [0.00023857174651402603, 0.00023857174622473655, 0.015243520421164771]
# sequential_31 model is trained. best val loss is : [9.997799186385237e-05, 9.997799084384314e-05, 0.009998758305721302]
# sequential_31 model is trained. best val loss is : [0.0005859537068317877, 0.0005859536835720316, 0.023600016317200476]
# sequential_32 model is trained. best val loss is : [1.528072506725788, 1.5280725069399133, 1.2054344125652252]
# sequential_32 model is trained. best val loss is : [0.22072067530210945, 0.2207206753178338, 0.4005822640203708]
# sequential_32 model is trained. best val loss is : [0.0679509892722804, 0.06795098935130334, 0.20546248099463]
# sequential_32 model is trained. best val loss is : [0.003277251225966931, 0.0032772512305155937, 0.042910642319262685]
# sequential_32 model is trained. best val loss is : [0.023406706818037214, 0.023406706852785637, 0.12127572257525578]
# sequential_32 model is trained. best val loss is : [0.003405679475721874, 0.0034056794818326432, 0.04324496176625268]
# sequential_32 model is trained. best val loss is : [0.0015465479965975017, 0.0015465479968434356, 0.02967290657554785]
# sequential_32 model is trained. best val loss is : [0.00043540816528861627, 0.0004354081646732433, 0.015132812406864992]
# sequential_32 model is trained. best val loss is : [0.00027652427380875746, 0.00027652427430504704, 0.011290545324765875]
# sequential_32 model is trained. best val loss is : [0.00022396092679617539, 0.00022396092634140844, 0.010961217028752773]
# sequential_32 model is trained. best val loss is : [0.0036444156155624953, 0.0036444156163711384, 0.04325684460098883]
# sequential_32 model is trained. best val loss is : [3.570355395304439, 3.5703553852087313, 1.2045775598824282]
# sequential_32 model is trained. best val loss is : [0.02558296401250274, 0.02558296401073617, 0.1215950968475728]
# sequential_32 model is trained. best val loss is : [0.0029063503291241128, 0.0029063503302302657, 0.0377832823395839]
# sequential_32 model is trained. best val loss is : [0.0013112662967228205, 0.0013112662954320488, 0.02595363944567751]
# sequential_32 model is trained. best val loss is : [0.001402040183927498, 0.0014020401839095159, 0.026635503541089397]
# sequential_32 model is trained. best val loss is : [0.0018716071450380508, 0.0018716071438406024, 0.030868175885890883]
# sequential_32 model is trained. best val loss is : [0.0003605012666791568, 0.00036050126524404607, 0.013404121084067008]
# sequential_32 model is trained. best val loss is : [0.0003917779285556378, 0.00039177792924259064, 0.013233702400531702]
# sequential_32 model is trained. best val loss is : [0.00013966804928307504, 0.00013966804948316848, 0.008509727086643198]
# sequential_32 model is trained. best val loss is : [0.00036176845661644127, 0.00036176845668746177, 0.014586508883327671]
# sequential_32 model is trained. best val loss is : [0.0004210280847196373, 0.0004210280849341065, 0.019740922030941865]
# sequential_32 model is trained. best val loss is : [9.874724583642092e-05, 9.874724243553424e-05, 0.009929349964380394]
# sequential_32 model is trained. best val loss is : [0.08678832032640275, 0.08678831921998324, 0.25822837923048136]
# sequential_33 model is trained. best val loss is : [1.1593027821145951, 1.159302782036458, 0.951377722493078]
# sequential_33 model is trained. best val loss is : [0.0869431710873368, 0.08694317093489906, 0.22806186016650218]
# sequential_33 model is trained. best val loss is : [0.046958043674842416, 0.04695804361516144, 0.1741584158460047]
# sequential_33 model is trained. best val loss is : [0.002652601409303892, 0.002652601406511681, 0.035786053316824495]
# sequential_33 model is trained. best val loss is : [0.020237187314596818, 0.02023718728567807, 0.10938367971116707]
# sequential_33 model is trained. best val loss is : [0.003060740574928475, 0.003060740591539465, 0.03957328821309806]
# sequential_33 model is trained. best val loss is : [0.0017463762935997333, 0.0017463762884418258, 0.029998763823509935]
# sequential_33 model is trained. best val loss is : [0.00031611902300873545, 0.0003161190225649547, 0.013472648404206934]
# sequential_33 model is trained. best val loss is : [0.0002744750141007971, 0.00027447501402948004, 0.011677978213694325]
# sequential_33 model is trained. best val loss is : [0.0010125948637806838, 0.0010125948635230971, 0.02197864243010766]
# sequential_33 model is trained. best val loss is : [0.015757591738576313, 0.015757591739634664, 0.08541245307718351]
# sequential_33 model is trained. best val loss is : [221.7483682139681, 221.74836781064784, 9.93629321966444]
# sequential_33 model is trained. best val loss is : [0.03785454434697911, 0.03785454438075157, 0.14496443068751885]
# sequential_33 model is trained. best val loss is : [0.002113635078937392, 0.0021136350772541193, 0.033896253699751105]
# sequential_33 model is trained. best val loss is : [0.0009504056357773626, 0.0009504056331636041, 0.022193771998627588]
# sequential_33 model is trained. best val loss is : [0.0013010377940687657, 0.0013010378007390902, 0.024712924752800455]
# sequential_33 model is trained. best val loss is : [0.002044762210728937, 0.002044762205815538, 0.031105250056312112]
# sequential_33 model is trained. best val loss is : [0.0007640123717195612, 0.0007640123728944446, 0.01545366663439492]
# sequential_33 model is trained. best val loss is : [0.0003347122504895461, 0.00033471224918268136, 0.011321617291620107]
# sequential_33 model is trained. best val loss is : [0.0001255983025590169, 0.00012559830254353657, 0.007668638700104172]
# sequential_33 model is trained. best val loss is : [0.0004437062944824061, 0.0004437062945967139, 0.01608715527804797]
# sequential_33 model is trained. best val loss is : [0.00022054688583739336, 0.00022054688580655572, 0.014716718549756319]
# sequential_33 model is trained. best val loss is : [0.000316226323559917, 0.00031622632632458835, 0.0107998211455966]
# sequential_33 model is trained. best val loss is : [0.002846100191352889, 0.0028461002394493088, 0.05298529678435614]
# sequential_34 model is trained. best val loss is : [0.9457437578253448, 0.9457437569934145, 0.9610974567591508]
# sequential_34 model is trained. best val loss is : [0.06325453781804809, 0.06325453778036505, 0.20003463540655173]
# sequential_34 model is trained. best val loss is : [0.013641183547705871, 0.013641183556645094, 0.09149308847805583]
# sequential_34 model is trained. best val loss is : [0.0013318911957055364, 0.0013318911931416658, 0.026437905205022424]
# sequential_34 model is trained. best val loss is : [0.013871830486391328, 0.013871830476364816, 0.09664113397829194]
# sequential_34 model is trained. best val loss is : [0.002434312226085046, 0.0024343122299719127, 0.036452206016436006]
# sequential_34 model is trained. best val loss is : [0.0015176149031673448, 0.0015176149054427124, 0.028115391973169937]
# sequential_34 model is trained. best val loss is : [0.0002444915049327961, 0.00024449150481973495, 0.011643077369220104]
# sequential_34 model is trained. best val loss is : [0.00013507251285262495, 0.0001350725127743626, 0.008105884788598564]
# sequential_34 model is trained. best val loss is : [0.00018320768877988673, 0.0001832076886177508, 0.009461706296894884]
# sequential_34 model is trained. best val loss is : [0.06546403276711438, 0.0654640330109519, 0.15597085015827422]
# sequential_34 model is trained. best val loss is : [362.70015942635274, 362.7001591834026, 12.270408526622878]
# sequential_34 model is trained. best val loss is : [0.02015937553485999, 0.020159375541475844, 0.11044783143554911]
# sequential_34 model is trained. best val loss is : [0.0015378479450779661, 0.0015378479441904695, 0.028004885117023388]
# sequential_34 model is trained. best val loss is : [0.0006450589553429815, 0.0006450589564979633, 0.01799474489198174]
# sequential_34 model is trained. best val loss is : [0.0011976406434749771, 0.0011976406440754735, 0.0253019948127603]
# sequential_34 model is trained. best val loss is : [0.0013485810584956924, 0.0013485810650009417, 0.024245546906326035]
# sequential_34 model is trained. best val loss is : [0.00016016038016839596, 0.00016016038000039702, 0.009074485004670521]
# sequential_34 model is trained. best val loss is : [8.572205468333858e-05, 8.572205458775011e-05, 0.00675030617766031]
# sequential_34 model is trained. best val loss is : [0.00046085506467198075, 0.000460855064627116, 0.013562451729334644]
# sequential_34 model is trained. best val loss is : [0.00048450990408679316, 0.00048450990501176805, 0.018656449954006893]
# sequential_34 model is trained. best val loss is : [8.023239721804149e-05, 8.023239725228996e-05, 0.008513014977457569]
# sequential_34 model is trained. best val loss is : [4.828495682592759e-05, 4.828495608012219e-05, 0.006935864927712135]
# sequential_34 model is trained. best val loss is : [0.002553220372647047, 0.0025532204258615914, 0.05052940159809527]
# sequential_35 model is trained. best val loss is : [1.2994802096635103, 1.2994802099754676, 1.1080154754719083]
# sequential_35 model is trained. best val loss is : [0.2398499170466776, 0.23984991734209826, 0.41611760554037536]
# sequential_35 model is trained. best val loss is : [0.09348187737459815, 0.09348187727985864, 0.2461199140807629]
# sequential_35 model is trained. best val loss is : [0.006259922792373894, 0.006259922805712472, 0.05786792201781195]
# sequential_35 model is trained. best val loss is : [0.013660076539765038, 0.013660076538923531, 0.09229545602881006]
# sequential_35 model is trained. best val loss is : [0.0034137614931549053, 0.003413761495379387, 0.04392788015136336]
# sequential_35 model is trained. best val loss is : [0.0017894239642725197, 0.0017894239576951314, 0.03120249603866251]
# sequential_35 model is trained. best val loss is : [0.0004891402370263362, 0.0004891402361684328, 0.015283798013481186]
# sequential_35 model is trained. best val loss is : [0.0003576722930559369, 0.00035767229241154654, 0.013440897531758913]
# sequential_35 model is trained. best val loss is : [0.00014871516831176608, 0.00014871516833703534, 0.007822391721907442]
# sequential_35 model is trained. best val loss is : [6.138323918750998e-33, 6.138323918750998e-33, 1.98729921407903e-17]
# sequential_35 model is trained. best val loss is : [1.232595164407831e-32, 1.232595164407831e-32, 1.1102230246251565e-16]
# sequential_35 model is trained. best val loss is : [0.20367045874070405, 0.20367045884790222, 0.4168690985534027]
# sequential_35 model is trained. best val loss is : [0.003272900035087432, 0.003272900033267481, 0.04161681577752689]
# sequential_35 model is trained. best val loss is : [0.0015523055682680838, 0.001552305571475751, 0.028408136485776423]
# sequential_35 model is trained. best val loss is : [0.0002244201344217753, 0.00022442013421152248, 0.010617687339427348]
# sequential_35 model is trained. best val loss is : [0.0019441910376254772, 0.0019441910344671599, 0.03196954698647929]
# sequential_35 model is trained. best val loss is : [0.0005869662952479809, 0.0005869662953976105, 0.01639979268866051]
# sequential_35 model is trained. best val loss is : [0.00089823797659997, 0.0008982379734558921, 0.01624892670503367]
# sequential_35 model is trained. best val loss is : [5.885839516430845e-05, 5.885839500644758e-05, 0.005529944194182704]
# sequential_35 model is trained. best val loss is : [0.0018880751907533661, 0.0018880751944431288, 0.03215552655766206]
# sequential_35 model is trained. best val loss is : [0.0005648117516248021, 0.0005648117796151372, 0.023765750680914008]
# sequential_35 model is trained. best val loss is : [0.00039269530680030584, 0.00039269529864402377, 0.019816541036316693]
# sequential_35 model is trained. best val loss is : [0.002499995054677129, 0.002499995074508239, 0.049999950745058225]
# sequential_36 model is trained. best val loss is : [0.9863342386223958, 0.9863342386832592, 0.9773002977223016]
# sequential_36 model is trained. best val loss is : [0.2505722540679462, 0.25057225412834533, 0.45067567531472336]
# sequential_36 model is trained. best val loss is : [0.0470336052901569, 0.047033605299477595, 0.17209495302234393]
# sequential_36 model is trained. best val loss is : [0.0033113570621348424, 0.0033113570620821927, 0.041822798822963865]
# sequential_36 model is trained. best val loss is : [0.021709674561026886, 0.021709674570814207, 0.11212012446228657]
# sequential_36 model is trained. best val loss is : [0.0034994441540641603, 0.0034994441508331637, 0.04499920281145957]
# sequential_36 model is trained. best val loss is : [0.0015260591176463818, 0.0015260591187540207, 0.02918506079636747]
# sequential_36 model is trained. best val loss is : [0.000533419131135443, 0.0005334191320690089, 0.016406380767391298]
# sequential_36 model is trained. best val loss is : [0.00035481498050535926, 0.00035481498027495405, 0.013472345305323907]
# sequential_36 model is trained. best val loss is : [5.609111563255914e-05, 5.609111562675386e-05, 0.0053678922579352495]
# sequential_36 model is trained. best val loss is : [4.930380657631324e-32, 4.930380657631324e-32, 2.220446049250313e-16]
# sequential_36 model is trained. best val loss is : [3.696287840794931e-24, 3.696287754513269e-24, 1.9225732117433836e-12]
# sequential_36 model is trained. best val loss is : [0.03511627022320215, 0.03511627022937948, 0.1464414855587135]
# sequential_36 model is trained. best val loss is : [0.002883314630771558, 0.002883314627380364, 0.03951671655650018]
# sequential_36 model is trained. best val loss is : [0.0009575825039217161, 0.0009575825051824054, 0.022450883549137476]
# sequential_36 model is trained. best val loss is : [0.00021335075410732146, 0.0002133507543717966, 0.010602005725757042]
# sequential_36 model is trained. best val loss is : [0.0016598321441873146, 0.001659832146482285, 0.02980341354082671]
# sequential_36 model is trained. best val loss is : [0.0002666159284078957, 0.0002666159286060585, 0.011469799473840626]
# sequential_36 model is trained. best val loss is : [0.0011308332507790166, 0.0011308332511397146, 0.018811400181396796]
# sequential_36 model is trained. best val loss is : [0.00013769352339380135, 0.00013769352350543546, 0.008378341491677885]
# sequential_36 model is trained. best val loss is : [0.0005944523890544909, 0.000594452389192983, 0.021211581925636644]
# sequential_36 model is trained. best val loss is : [0.0005202960455790162, 0.0005202960411282359, 0.022809998709518494]
# sequential_36 model is trained. best val loss is : [0.00010001106460185838, 0.00010001106364111994, 0.010000553166756285]
# sequential_36 model is trained. best val loss is : [0.002499995054677129, 0.002499995074508209, 0.04999995074505788]
# sequential_37 model is trained. best val loss is : [0.5207026782734993, 0.5207026780193159, 0.6916083463315548]
# sequential_37 model is trained. best val loss is : [0.09139440116531361, 0.09139440117042434, 0.23687487690920866]
# sequential_37 model is trained. best val loss is : [0.03388384340490282, 0.03388384333599782, 0.1333278290912886]
# sequential_37 model is trained. best val loss is : [0.0024832977199968917, 0.002483297718184118, 0.035636299525248376]
# sequential_37 model is trained. best val loss is : [0.014744832588192576, 0.014744832581546108, 0.09459714808487674]
# sequential_37 model is trained. best val loss is : [0.002506728773649774, 0.002506728771892699, 0.03749142725001495]
# sequential_37 model is trained. best val loss is : [0.0016160145079480016, 0.0016160145034329393, 0.029264836095277576]
# sequential_37 model is trained. best val loss is : [0.00046485821378806165, 0.0004648582127815604, 0.015468746810972973]
# sequential_37 model is trained. best val loss is : [0.00020398502468264076, 0.0002039850248960267, 0.01002468146589361]
# sequential_37 model is trained. best val loss is : [7.208320145411603e-08, 7.208320041081692e-08, 6.091892699786838e-05]
# sequential_37 model is trained. best val loss is : [4.437342591868191e-31, 4.437342591868191e-31, 6.661338147750939e-16]
# sequential_37 model is trained. best val loss is : [0.0018238717457279563, 0.001823871780269225, 0.042706811871986265]
# sequential_37 model is trained. best val loss is : [0.02246874873674959, 0.02246874870462296, 0.11439881168267185]
# sequential_37 model is trained. best val loss is : [0.001561338232007447, 0.0015613382288879904, 0.028478253157633294]
# sequential_37 model is trained. best val loss is : [0.000984488968859073, 0.000984488968340348, 0.022286297696342734]
# sequential_37 model is trained. best val loss is : [0.00017922896074626572, 0.00017922896047220055, 0.00958011497640544]
# sequential_37 model is trained. best val loss is : [0.001428520328600634, 0.0014285203254049425, 0.027936417353466685]
# sequential_37 model is trained. best val loss is : [0.0006551981068359533, 0.0006551981043431568, 0.015634722977222692]
# sequential_37 model is trained. best val loss is : [0.001190224560799913, 0.0011902245589934057, 0.01886942574355522]
# sequential_37 model is trained. best val loss is : [0.00017193416304670767, 0.00017193416335323542, 0.009317132324002948]
# sequential_37 model is trained. best val loss is : [0.0009917424684862234, 0.0009917424675660346, 0.0278630131505411]
# sequential_37 model is trained. best val loss is : [1.0333457068692931e-05, 1.0333457068981783e-05, 0.0008942617832877909]
# sequential_37 model is trained. best val loss is : [8.369386858976213e-05, 8.36938687289586e-05, 0.009148417909774668]
# sequential_37 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_38 model is trained. best val loss is : [0.9986464117616415, 0.9986464123507534, 0.9919662918000021]
# sequential_38 model is trained. best val loss is : [0.029345914195090105, 0.02934591425045031, 0.13139704799712193]
# sequential_38 model is trained. best val loss is : [0.014442196583795842, 0.014442196642844275, 0.0852690747492465]
# sequential_38 model is trained. best val loss is : [0.0011707078927758019, 0.001170707895239283, 0.024515910792449816]
# sequential_38 model is trained. best val loss is : [0.014990844454493998, 0.014990844455092744, 0.09708357106486365]
# sequential_38 model is trained. best val loss is : [0.002310925834792165, 0.0023109258341480776, 0.03519046978696831]
# sequential_38 model is trained. best val loss is : [0.0011754812456990593, 0.0011754812450299218, 0.02517147244917662]
# sequential_38 model is trained. best val loss is : [0.00024286878350745976, 0.0002428687836142694, 0.011535155311298707]
# sequential_38 model is trained. best val loss is : [0.00018941162373498657, 0.0001894116239539615, 0.009582597171252696]
# sequential_38 model is trained. best val loss is : [2.0074103205181904e-19, 2.0074104124575296e-19, 2.956030680789645e-10]
# sequential_38 model is trained. best val loss is : [4.930380657631324e-32, 4.930380657631324e-32, 2.220446049250313e-16]
# sequential_38 model is trained. best val loss is : [0.6782627105712891, 0.6782627364218292, 0.8235670807055301]
# sequential_38 model is trained. best val loss is : [0.014910917847777348, 0.014910917843646426, 0.09238824317180909]
# sequential_38 model is trained. best val loss is : [0.0011926229149871474, 0.0011926229130802483, 0.024736755484974997]
# sequential_38 model is trained. best val loss is : [0.0005190432198723019, 0.000519043219668802, 0.016786819876084942]
# sequential_38 model is trained. best val loss is : [0.00016906447109134691, 0.00016906447112404556, 0.00902670817607786]
# sequential_38 model is trained. best val loss is : [0.0008610778053451968, 0.0008610778043583685, 0.020224870437881688]
# sequential_38 model is trained. best val loss is : [0.00020132600323437803, 0.0002013260030130192, 0.009793485000896314]
# sequential_38 model is trained. best val loss is : [0.00017365291506347123, 0.0001736529145984323, 0.00853489368780238]
# sequential_38 model is trained. best val loss is : [0.001795043017475921, 0.0017950430155636134, 0.039918743727151894]
# sequential_38 model is trained. best val loss is : [0.0012008995216100788, 0.0012008995225639713, 0.031900021580749435]
# sequential_38 model is trained. best val loss is : [0.006873856997365692, 0.006873857001373155, 0.05572743684265493]
# sequential_38 model is trained. best val loss is : [0.00010632852383787395, 0.00010632852367647885, 0.01007244985018122]
# sequential_38 model is trained. best val loss is : [0.002499995054677129, 0.002499995074508229, 0.04999995074505796]
# sequential_39 model is trained. best val loss is : [0.33734049716626396, 0.337340497483152, 0.5576280765098407]
# sequential_39 model is trained. best val loss is : [0.023371967421885784, 0.023371967368449976, 0.11013106351882951]
# sequential_39 model is trained. best val loss is : [0.009247836924871383, 0.009247836895188741, 0.06737609745169944]
# sequential_39 model is trained. best val loss is : [0.001096392495366739, 0.0010963924928609275, 0.024026022506658834]
# sequential_39 model is trained. best val loss is : [0.01703780755185001, 0.017037807530168442, 0.10394767746168662]
# sequential_39 model is trained. best val loss is : [0.001498249466787803, 0.0014982494652812002, 0.029380533785385046]
# sequential_39 model is trained. best val loss is : [0.0008209007199982247, 0.000820900717701242, 0.020714176358954034]
# sequential_39 model is trained. best val loss is : [0.00020038673392975515, 0.00020038673431750886, 0.010218384266809098]
# sequential_39 model is trained. best val loss is : [0.0002194719327320371, 0.0002194719330813522, 0.009048705173437485]
# sequential_39 model is trained. best val loss is : [2.0923629785707908e-14, 2.0923630330607614e-14, 1.446500270674278e-07]
# sequential_39 model is trained. best val loss is : [5.6428281237095104e-14, 5.642828022994041e-14, 2.375463749038076e-07]
# sequential_39 model is trained. best val loss is : [4.769009113311768, 4.769008949961153, 2.1838060696776997]
# sequential_39 model is trained. best val loss is : [0.012833592209856625, 0.01283359221946279, 0.08598157953769002]
# sequential_39 model is trained. best val loss is : [0.000638874723403709, 0.0006388747241893994, 0.018638067578368254]
# sequential_39 model is trained. best val loss is : [0.00037294114542237424, 0.0003729411461773524, 0.014078479927640752]
# sequential_39 model is trained. best val loss is : [8.441580798380376e-05, 8.441580774452296e-05, 0.006497452051873027]
# sequential_39 model is trained. best val loss is : [0.0006821472238340654, 0.0006821472226999688, 0.017296375791472113]
# sequential_39 model is trained. best val loss is : [0.0001552542183538337, 0.00015525421853001926, 0.00916857022729028]
# sequential_39 model is trained. best val loss is : [0.00011945617640759955, 0.00011945617583051576, 0.006068175747564333]
# sequential_39 model is trained. best val loss is : [0.00010629852108063082, 0.00010629852113972251, 0.007427569075415001]
# sequential_39 model is trained. best val loss is : [0.0013933147493566632, 0.0013933147495616084, 0.03473252322459907]
# sequential_39 model is trained. best val loss is : [5.311522489689078e-05, 5.3115224290655366e-05, 0.005435962876563559]
# sequential_39 model is trained. best val loss is : [9.999899339163676e-05, 9.999899693104516e-05, 0.009999949846426492]
# sequential_39 model is trained. best val loss is : [0.002499995054677129, 0.0024999950745083293, 0.04999995074505911]
# sequential_40 model is trained. best val loss is : [1.7069571449160577, 1.7069571418926817, 1.255168878501165]
# sequential_40 model is trained. best val loss is : [0.234121553845851, 0.2341215536826278, 0.4308292150217508]
# sequential_40 model is trained. best val loss is : [0.2581038402298996, 0.2581038402495709, 0.471264226227185]
# sequential_40 model is trained. best val loss is : [0.002661908234358632, 0.0026619082274124814, 0.03576974290042568]
# sequential_40 model is trained. best val loss is : [0.010154098710180177, 0.010154098697357162, 0.07999799183153022]
# sequential_40 model is trained. best val loss is : [0.001626436100320641, 0.0016264360988420311, 0.030902760167702464]
# sequential_40 model is trained. best val loss is : [0.0010288444833237715, 0.001028844481966615, 0.024934352084017113]
# sequential_40 model is trained. best val loss is : [0.00026632147357627366, 0.00026632147338271923, 0.012106745769850215]
# sequential_40 model is trained. best val loss is : [0.0001933654122373113, 0.00019336541187387767, 0.0102642507320037]
# sequential_40 model is trained. best val loss is : [2.2504176406409648e-06, 2.2504176532780344e-06, 0.0007378608515404534]
# sequential_40 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_40 model is trained. best val loss is : [8.664940764901985e-09, 8.664940589229588e-09, 9.30856626405463e-05]
# sequential_40 model is trained. best val loss is : [0.21179189163637785, 0.21179189153229705, 0.41030150353170597]
# sequential_40 model is trained. best val loss is : [0.002432144068772625, 0.0024321440687036823, 0.03609515977785044]
# sequential_40 model is trained. best val loss is : [0.00041602518386226806, 0.0004160251840219477, 0.014779636237782114]
# sequential_40 model is trained. best val loss is : [0.00018362114029587577, 0.00018362114007503878, 0.009957940327185572]
# sequential_40 model is trained. best val loss is : [0.001693626539749793, 0.0016936265393262765, 0.02920843719089759]
# sequential_40 model is trained. best val loss is : [0.0002936050938920662, 0.0002936050929787204, 0.011707039022633491]
# sequential_40 model is trained. best val loss is : [6.878310593262957e-05, 6.878310580145796e-05, 0.005758789849446475]
# sequential_40 model is trained. best val loss is : [6.58595501070011e-05, 6.585954976968278e-05, 0.004993373589631223]
# sequential_40 model is trained. best val loss is : [0.000650107584174986, 0.0006501075833723884, 0.02285871774875775]
# sequential_40 model is trained. best val loss is : [0.0006124898532580119, 0.0006124898604942291, 0.02474703755687563]
# sequential_40 model is trained. best val loss is : [0.0004679255224473309, 0.00046792551496538105, 0.021631022865123875]
# sequential_40 model is trained. best val loss is : [0.002499995054677129, 0.0024999950745081736, 0.049999950745057475]
# sequential_41 model is trained. best val loss is : [1.2763830974400043, 1.2763830966345746, 1.1041785301530014]
# sequential_41 model is trained. best val loss is : [0.06224146000080747, 0.06224145995574861, 0.19508712096415068]
# sequential_41 model is trained. best val loss is : [0.0349159297487821, 0.03491592985931129, 0.14127132832971398]
# sequential_41 model is trained. best val loss is : [0.0022426385082891616, 0.002242638506418786, 0.03395445279278245]
# sequential_41 model is trained. best val loss is : [0.011387496787648917, 0.011387496805709192, 0.078991336160099]
# sequential_41 model is trained. best val loss is : [0.002017342003309279, 0.002017342001509959, 0.03397133313568827]
# sequential_41 model is trained. best val loss is : [0.0015109129933508676, 0.0015109129971595514, 0.028063763221592656]
# sequential_41 model is trained. best val loss is : [0.00024911454442427637, 0.00024911454493042016, 0.011485621687511707]
# sequential_41 model is trained. best val loss is : [0.00015026120651058077, 0.00015026120631534047, 0.008467814677986345]
# sequential_41 model is trained. best val loss is : [1.3268409538457074e-05, 1.3268409524856176e-05, 0.0024447339765247]
# sequential_41 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_41 model is trained. best val loss is : [4.437342591868191e-31, 4.437342591868191e-31, 6.661338147750939e-16]
# sequential_41 model is trained. best val loss is : [0.021153791204264093, 0.021153791194957524, 0.1106130444013144]
# sequential_41 model is trained. best val loss is : [0.0015155118326136319, 0.0015155118328151385, 0.028471525683106316]
# sequential_41 model is trained. best val loss is : [0.0008583708505158251, 0.0008583708506178466, 0.021118804226636968]
# sequential_41 model is trained. best val loss is : [0.000152451571054239, 0.00015245157086933095, 0.008687157832114639]
# sequential_41 model is trained. best val loss is : [0.0013517211683496102, 0.0013517211672326374, 0.02551736221046065]
# sequential_41 model is trained. best val loss is : [0.00021766556318117959, 0.00021766556400164278, 0.009194796650229195]
# sequential_41 model is trained. best val loss is : [0.00014311318478014054, 0.00014311318477771906, 0.008580192336540216]
# sequential_41 model is trained. best val loss is : [2.0938692275581347e-05, 2.093869231230134e-05, 0.002855231246814872]
# sequential_41 model is trained. best val loss is : [0.00044711770058182153, 0.00044711770032043974, 0.01726897860938339]
# sequential_41 model is trained. best val loss is : [0.0005089303595013916, 0.0005089303546885715, 0.02255948480547754]
# sequential_41 model is trained. best val loss is : [0.0006312387413345277, 0.000631238758086139, 0.025124465329358525]
# sequential_41 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_42 model is trained. best val loss is : [0.5103735620548614, 0.5103735620989683, 0.6944884162970304]
# sequential_42 model is trained. best val loss is : [0.049328160435756205, 0.049328160419724494, 0.175451615806813]
# sequential_42 model is trained. best val loss is : [0.014142663069775711, 0.01414266305726977, 0.08763041663737825]
# sequential_42 model is trained. best val loss is : [0.0015580162477168674, 0.0015580162460518774, 0.02646815787285954]
# sequential_42 model is trained. best val loss is : [0.012376493398012738, 0.012376493397949653, 0.08423080313182875]
# sequential_42 model is trained. best val loss is : [0.0016459905364043241, 0.0016459905372684252, 0.030489045110902304]
# sequential_42 model is trained. best val loss is : [0.000809589928160984, 0.0008095899255853488, 0.020571039993203765]
# sequential_42 model is trained. best val loss is : [0.00030778907121065244, 0.0003077890708488217, 0.012199461113971155]
# sequential_42 model is trained. best val loss is : [0.0001184934633137097, 0.00011849346414357205, 0.0068377107386389715]
# sequential_42 model is trained. best val loss is : [1.3195217486744459e-08, 1.3195217338710464e-08, 1.0683743355013541e-05]
# sequential_42 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_42 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_42 model is trained. best val loss is : [0.019517155961130978, 0.019517155952736932, 0.10342416629605389]
# sequential_42 model is trained. best val loss is : [0.001305778407029914, 0.0013057784062612244, 0.02713899265707024]
# sequential_42 model is trained. best val loss is : [0.0006011559407766735, 0.0006011559410888549, 0.01808051112857704]
# sequential_42 model is trained. best val loss is : [0.00011586051316299087, 0.00011586051339916101, 0.007579797133724334]
# sequential_42 model is trained. best val loss is : [0.000912083605714378, 0.0009120836054347655, 0.022142811815440255]
# sequential_42 model is trained. best val loss is : [0.00010322253515235519, 0.00010322253496674595, 0.007383338282970805]
# sequential_42 model is trained. best val loss is : [0.0002099429969095744, 0.0002099429964969043, 0.010568187217901594]
# sequential_42 model is trained. best val loss is : [3.015686892480754e-05, 3.0156868916534913e-05, 0.004587739501193781]
# sequential_42 model is trained. best val loss is : [0.000247368733767573, 0.0002473687340829315, 0.01252307837413775]
# sequential_42 model is trained. best val loss is : [0.0006857223343104124, 0.0006857223310371678, 0.026186300445789693]
# sequential_42 model is trained. best val loss is : [0.0005829719011671841, 0.0005829719018903757, 0.024144811075889058]
# sequential_42 model is trained. best val loss is : [4.6541729534510523e-07, 4.654172899977349e-07, 2.1499652235930977e-05]
# sequential_43 model is trained. best val loss is : [0.47079271042682014, 0.47079270998068645, 0.6654326498451013]
# sequential_43 model is trained. best val loss is : [0.021785842467606054, 0.021785842552747802, 0.1054897158899847]
# sequential_43 model is trained. best val loss is : [0.007824965568647957, 0.007824965557694574, 0.06641603875801402]
# sequential_43 model is trained. best val loss is : [0.000842637474390785, 0.0008426374799084077, 0.02004854371873356]
# sequential_43 model is trained. best val loss is : [0.011451846496320745, 0.011451846516730705, 0.08400959006298978]
# sequential_43 model is trained. best val loss is : [0.0010194660380604458, 0.0010194660371440581, 0.02435055473080207]
# sequential_43 model is trained. best val loss is : [0.0007838384267793257, 0.0007838384343119214, 0.018975984693348758]
# sequential_43 model is trained. best val loss is : [0.00017136279238517705, 0.00017136279262218248, 0.00944409728734307]
# sequential_43 model is trained. best val loss is : [9.476281700384015e-05, 9.476281693906354e-05, 0.006596812637000583]
# sequential_43 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_43 model is trained. best val loss is : [6.179004463349216e-08, 6.179004602179807e-08, 1.2136645925399092e-05]
# sequential_43 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_43 model is trained. best val loss is : [0.013114077945975766, 0.01311407795673289, 0.08527819853678921]
# sequential_43 model is trained. best val loss is : [0.0006686244299990228, 0.0006686244298872022, 0.019031593592922624]
# sequential_43 model is trained. best val loss is : [0.0004214554321245421, 0.00042145543237299477, 0.014605106567727053]
# sequential_43 model is trained. best val loss is : [8.222498698003992e-05, 8.222498698090794e-05, 0.006555511281365548]
# sequential_43 model is trained. best val loss is : [0.000593906045807519, 0.0005939060455900262, 0.017303590967342342]
# sequential_43 model is trained. best val loss is : [9.439032062670689e-05, 9.439032055047395e-05, 0.006891153716180358]
# sequential_43 model is trained. best val loss is : [7.382300213798265e-05, 7.382300217792357e-05, 0.007067001760268346]
# sequential_43 model is trained. best val loss is : [2.1952404887956346e-05, 2.1952404960540937e-05, 0.0033785370231334995]
# sequential_43 model is trained. best val loss is : [0.000855077384533633, 0.0008550773846237386, 0.026960076573372852]
# sequential_43 model is trained. best val loss is : [0.0005503405700437725, 0.0005503405779960424, 0.023459338822653168]
# sequential_43 model is trained. best val loss is : [0.0009301353129558265, 0.0009301353151281876, 0.030498119862184758]
# sequential_43 model is trained. best val loss is : [0.0024997596007306127, 0.00249975962075119, 0.04999747346670331]
# sequential_44 model is trained. best val loss is : [0.2906988977153417, 0.2906988980588487, 0.5041562336112445]
# sequential_44 model is trained. best val loss is : [0.014802017111240968, 0.014802017122170085, 0.0907638871189034]
# sequential_44 model is trained. best val loss is : [0.004656230734950526, 0.004656230733231906, 0.0497529490892352]
# sequential_44 model is trained. best val loss is : [0.0006306439720390995, 0.0006306439740901289, 0.017504760079869418]
# sequential_44 model is trained. best val loss is : [0.011051816693244178, 0.011051816707457628, 0.08334682118376448]
# sequential_44 model is trained. best val loss is : [0.0009308923070423283, 0.0009308923064119237, 0.022421897636257224]
# sequential_44 model is trained. best val loss is : [0.000492504437217705, 0.0004925044370184275, 0.01658650863109318]
# sequential_44 model is trained. best val loss is : [0.00010800043980920973, 0.00010800043990631404, 0.007669176517278421]
# sequential_44 model is trained. best val loss is : [5.2514635273876654e-05, 5.251463528007652e-05, 0.005195921841395914]
# sequential_44 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_44 model is trained. best val loss is : [0.0, 0.0, 0.0]
# sequential_44 model is trained. best val loss is : [14.81049919128418, 14.81049886524158, 3.8484410954621073]
# sequential_44 model is trained. best val loss is : [0.010685979311187909, 0.010685979305332011, 0.07880507167355949]
# sequential_44 model is trained. best val loss is : [0.0003392110188867324, 0.00033921101836788714, 0.013609103255397183]
# sequential_44 model is trained. best val loss is : [0.00029585474496800755, 0.000295854745254455, 0.012123485922383832]
# sequential_44 model is trained. best val loss is : [3.506552129430493e-05, 3.5065521359310694e-05, 0.004102507926768689]
# sequential_44 model is trained. best val loss is : [0.0003473577225577237, 0.00034735772292743153, 0.012955781618882663]
# sequential_44 model is trained. best val loss is : [0.00018916464935491494, 0.0001891646489943671, 0.009747167145537772]
# sequential_44 model is trained. best val loss is : [3.035092290178621e-05, 3.0350922879070486e-05, 0.004336786555941809]
# sequential_44 model is trained. best val loss is : [4.0006696436631576e-07, 4.0006696431880637e-07, 0.00014792121667865044]
# sequential_44 model is trained. best val loss is : [0.00021589177906025726, 0.00021589177910890547, 0.014639754235072298]
# sequential_44 model is trained. best val loss is : [0.0012600678019225597, 0.0012600678248299584, 0.03549743405980157]
# sequential_44 model is trained. best val loss is : [0.0004996791249141097, 0.0004996791086079969, 0.02235350327371521]
# sequential_44 model is trained. best val loss is : [0.002499995054677129, 0.0024999950748238456, 0.049999950748214096]

# %%
best_model_house, best_model_info_house = select_best_model(mlp_house.trained_models, mlp_house.val_losses, mlp_house.compiled_models_info)
best_model_house.evaluate(ds_house.trans_X_val, ds_house.trans_y_val)
print(best_model_info_house)
# Out:
# 2000/2000 [==============================] - 0s 70us/sample - loss: 0.0000e+00 - MSE: 0.0000e+00 - MAE: 0.0000e+00
# {'structure_info': {'hidden_layers': 2, 'units': 64}, 'optimizer_info': {'optimizer_name': 'rmsprop', 'lr': 0.1}}

# %%
import matplotlib.pyplot as plt
plt.plot(sorted(mlp_house.val_losses)[:], '.')

# %%
# when X transformer is nothing
mlp_house = MLP(ds_house.trans_X_train, ds_house.trans_y_train, problem=ds_house.problem)
mlp_house.build_structure(max_hidden_layers=1, units=[16], use_all=True)
mlp_house.create_optimizer(optimizers=['adam'], lrs=[0.01], use_all=True)
mlp_house.compile_model()

mlp_house.train_models(mlp_house.compiled_models,
                       ds_house.trans_X_train, ds_house.trans_y_train,
                       ds_house.trans_X_val, ds_house.trans_y_val,
                       batch_size=64, epochs=10)
# Out:
# sequential_15 model is trained. best val loss is : [73460344263139.33, 73460344332869.83, 7172668.843420654]
# sequential_15 model is trained. best val loss is : [73460321250938.88, 73460321295314.16, 7172667.215030917]
# sequential_15 model is trained. best val loss is : [73460281044922.38, 73460281227180.5, 7172664.601587093]
# sequential_15 model is trained. best val loss is : [11240505948908.465, 11240505922187.945, 1879298.7633353595]
# sequential_15 model is trained. best val loss is : [nan, nan, nan]
# sequential_15 model is trained. best val loss is : [nan, nan, nan]
# sequential_15 model is trained. best val loss is : [nan, nan, nan]
# sequential_15 model is trained. best val loss is : [nan, nan, nan]
# sequential_15 model is trained. best val loss is : [73121239853740.03, 73121239994520.36, 7149637.168543462]
# sequential_15 model is trained. best val loss is : [40403446663042.47, 40403446607518.07, 4372924.195691681]
# sequential_15 model is trained. best val loss is : [36322317218388.93, 36322317147758.4, 4089565.2799269506]
# sequential_15 model is trained. best val loss is : [11957321184816.879, 11957321213796.18, 2153427.715540297]
# sequential_15 model is trained. best val loss is : [73460259629010.94, 73460259505453.78, 7172663.682966125]
# sequential_15 model is trained. best val loss is : [73428446166335.48, 73428446062792.75, 7170453.387064677]
# sequential_15 model is trained. best val loss is : [73105361873559.55, 73105361951199.3, 7150625.231712609]
# sequential_15 model is trained. best val loss is : [51014623897677.2, 51014623921363.305, 5451293.222137103]
# sequential_15 model is trained. best val loss is : [73448911552274.44, 73448911612066.84, 7171853.643243417]
# sequential_15 model is trained. best val loss is : [62587493573223.42, 62587493557244.84, 6296233.543983791]
# sequential_15 model is trained. best val loss is : [46423736602606.38, 46423736501119.78, 4843818.692784338]
# sequential_15 model is trained. best val loss is : [20474214242161.547, 20474214297871.387, 2538152.161459443]
# sequential_15 model is trained. best val loss is : [73416878085758.97, 73416878010869.05, 7169948.239102902]
# sequential_15 model is trained. best val loss is : [44081506256783.234, 44081506405318.38, 4708257.090375489]
# sequential_15 model is trained. best val loss is : [36521754207098.14, 36521754090124.484, 4001539.955891009]
# sequential_15 model is trained. best val loss is : [12020888317398.729, 12020888365080.895, 1991981.0234640802]
# sequential_16 model is trained. best val loss is : [73460330823258.11, 73460330878323.38, 7172667.952032688]
# sequential_16 model is trained. best val loss is : [73460332238512.12, 73460332126917.03, 7172668.065211861]
# sequential_16 model is trained. best val loss is : [73460276747227.14, 73460276715884.19, 7172664.081710427]
# sequential_16 model is trained. best val loss is : [11394004708683.748, 11394004668766.385, 1871603.0613129782]
# sequential_16 model is trained. best val loss is : [nan, nan, nan]
# sequential_16 model is trained. best val loss is : [nan, nan, nan]
# sequential_16 model is trained. best val loss is : [nan, nan, nan]
# sequential_16 model is trained. best val loss is : [nan, nan, nan]
# sequential_16 model is trained. best val loss is : [71438233868295.94, 71438233955062.84, 7025651.364425293]
# sequential_16 model is trained. best val loss is : [27529428345558.19, 27529428366853.266, 3186362.627573916]
# sequential_16 model is trained. best val loss is : [19729484580149.1, 19729484480220.04, 2424136.418947944]
# sequential_16 model is trained. best val loss is : [10918933910767.219, 10918933925636.559, 1817914.0115844253]
# sequential_16 model is trained. best val loss is : [73460214104727.55, 73460214145866.25, 7172660.387338189]
# sequential_16 model is trained. best val loss is : [73387968946135.05, 73387968941703.83, 7167848.322540291]
# sequential_16 model is trained. best val loss is : [72732426290528.25, 72732426417821.4, 7127579.516564862]
# sequential_16 model is trained. best val loss is : [42422785515559.03, 42422785588328.05, 4567925.125092535]
# sequential_16 model is trained. best val loss is : [73440866308026.38, 73440866294997.52, 7171258.139847491]
# sequential_16 model is trained. best val loss is : [58123012063505.055, 58123012169838.555, 5953328.711292675]
# sequential_16 model is trained. best val loss is : [41494639001709.44, 41494639071133.13, 4350400.82555267]
# sequential_16 model is trained. best val loss is : [19267094329342.26, 19267094194028.21, 2442738.2683614925]
# sequential_16 model is trained. best val loss is : [73330100669718.53, 73330100923881.84, 7164018.261162225]
# sequential_16 model is trained. best val loss is : [41383290890892.484, 41383290942197.2, 4432396.092771833]
# sequential_16 model is trained. best val loss is : [27200509194623.523, 27200509192676.598, 3167022.9368921835]
# sequential_16 model is trained. best val loss is : [11099254789795.371, 11099254842005.494, 1862140.0565782206]
# sequential_17 model is trained. best val loss is : [73460341931876.36, 73460342054541.61, 7172668.6756376885]
# sequential_17 model is trained. best val loss is : [73460327291670.53, 73460327203826.42, 7172667.6910517095]
# sequential_17 model is trained. best val loss is : [73460266719444.98, 73460266831970.0, 7172663.635927749]
# sequential_17 model is trained. best val loss is : [11293224813831.865, 11293224845016.105, 1891872.2145841378]
# sequential_17 model is trained. best val loss is : [nan, nan, nan]
# sequential_17 model is trained. best val loss is : [nan, nan, nan]
# sequential_17 model is trained. best val loss is : [nan, nan, nan]
# sequential_17 model is trained. best val loss is : [nan, nan, nan]
# sequential_17 model is trained. best val loss is : [68534017964538.2, 68534018029834.44, 6821119.390243939]
# sequential_17 model is trained. best val loss is : [25680333836496.625, 25680333853077.023, 3063596.6704808855]
# sequential_17 model is trained. best val loss is : [16657864090218.943, 16657864058858.377, 2228038.936454585]
# sequential_17 model is trained. best val loss is : [10862120351862.572, 10862120365001.447, 1796459.3366023966]
# sequential_17 model is trained. best val loss is : [73460089085939.72, 73460089408023.77, 7172652.959156434]
# sequential_17 model is trained. best val loss is : [73276416683995.14, 73276416713382.7, 7160279.413138797]
# sequential_17 model is trained. best val loss is : [71862796336445.95, 71862796288321.58, 7062349.020077055]
# sequential_17 model is trained. best val loss is : [40437642853192.21, 40437642901783.2, 4334136.107481044]
# sequential_17 model is trained. best val loss is : [73426568947003.39, 73426568960788.72, 7170255.108693808]
# sequential_17 model is trained. best val loss is : [43098349042000.914, 43098348846620.27, 4558362.860564482]
# sequential_17 model is trained. best val loss is : [35521342962188.35, 35521342988425.2, 3875250.0439235647]
# sequential_17 model is trained. best val loss is : [17597207655084.555, 17597207648752.855, 2259679.8017103425]
# sequential_17 model is trained. best val loss is : [73216236636766.2, 73216236586655.11, 7155978.941545021]
# sequential_17 model is trained. best val loss is : [37645606365988.4, 37645606228033.84, 4082651.511228606]
# sequential_17 model is trained. best val loss is : [23790506143003.145, 23790506171479.027, 2870270.4783694437]
# sequential_17 model is trained. best val loss is : [11123969368728.793, 11123969367061.81, 1806866.0420721327]
# sequential_18 model is trained. best val loss is : [73460338974957.56, 73460338930561.98, 7172668.4147328315]
# sequential_18 model is trained. best val loss is : [73460300921638.9, 73460301112167.95, 7172665.754169899]
# sequential_18 model is trained. best val loss is : [73459823259648.0, 73459823288931.27, 7172628.860565747]
# sequential_18 model is trained. best val loss is : [11278645378604.664, 11278645327856.664, 1889295.278920084]
# sequential_18 model is trained. best val loss is : [nan, nan, nan]
# sequential_18 model is trained. best val loss is : [nan, nan, nan]
# sequential_18 model is trained. best val loss is : [nan, nan, nan]
# sequential_18 model is trained. best val loss is : [nan, nan, nan]
# sequential_18 model is trained. best val loss is : [63215991893870.16, 63215991936159.766, 6441726.018980532]
# sequential_18 model is trained. best val loss is : [20907217440263.34, 20907217371470.695, 2578912.580408046]
# sequential_18 model is trained. best val loss is : [11697859714408.414, 11697859669105.182, 1947643.531784815]
# sequential_18 model is trained. best val loss is : [10824999932097.648, 10824999974957.092, 1800682.4130252409]
# sequential_18 model is trained. best val loss is : [73460091661049.86, 73460091657499.55, 7172651.559685717]
# sequential_18 model is trained. best val loss is : [73129814549704.7, 73129814803894.14, 7149131.77765901]
# sequential_18 model is trained. best val loss is : [70520722220373.83, 70520722329485.19, 6958360.474376395]
# sequential_18 model is trained. best val loss is : [38236028076202.16, 38236028066972.62, 4158872.0761151374]
# sequential_18 model is trained. best val loss is : [73380211083706.38, 73380211089925.42, 7166965.195233963]
# sequential_18 model is trained. best val loss is : [39958533976791.54, 39958534007134.51, 4273907.367527599]
# sequential_18 model is trained. best val loss is : [31802276751557.246, 31802276654078.984, 3506599.441496627]
# sequential_18 model is trained. best val loss is : [17042671117305.818, 17042671167135.254, 2208461.455400487]
# sequential_18 model is trained. best val loss is : [72927655875782.66, 72927656058136.12, 7136341.39296572]
# sequential_18 model is trained. best val loss is : [33577387099454.047, 33577387093326.72, 3695161.182224996]
# sequential_18 model is trained. best val loss is : [21580184048167.22, 21580184002427.035, 2690110.2448447254]
# sequential_18 model is trained. best val loss is : [11023450337760.316, 11023450441179.512, 1760229.6603232957]
# sequential_19 model is trained. best val loss is : [73460338577932.28, 73460338579672.56, 7172668.435338729]
# sequential_19 model is trained. best val loss is : [73460276712873.98, 73460276692926.67, 7172664.150327815]
# sequential_19 model is trained. best val loss is : [14772664516870.914, 14772664481850.31, 2224262.0984191285]
# sequential_19 model is trained. best val loss is : [11259911624423.596, 11259911589902.8, 1883748.5972806823]
# sequential_19 model is trained. best val loss is : [nan, nan, nan]
# sequential_19 model is trained. best val loss is : [nan, nan, nan]
# sequential_19 model is trained. best val loss is : [nan, nan, nan]
# sequential_19 model is trained. best val loss is : [nan, nan, nan]
# sequential_19 model is trained. best val loss is : [55534465639491.42, 55534465702195.03, 5832912.34022571]
# sequential_19 model is trained. best val loss is : [18922812075584.527, 18922812117659.97, 2381981.5839493843]
# sequential_19 model is trained. best val loss is : [12345159319674.055, 12345159361617.352, 1995246.196954587]
# sequential_19 model is trained. best val loss is : [10828519931204.234, 10828519961652.727, 1763544.9606728249]
# sequential_19 model is trained. best val loss is : [73459723135750.14, 73459722938872.3, 7172628.46513571]
# sequential_19 model is trained. best val loss is : [72675162830632.95, 72675162821953.39, 7120528.523011533]
# sequential_19 model is trained. best val loss is : [67338528343215.03, 67338528174911.555, 6723410.058101785]
# sequential_19 model is trained. best val loss is : [36346636372031.44, 36346636454880.36, 3996243.7415497797]
# sequential_19 model is trained. best val loss is : [73317003780042.75, 73317003906319.9, 7162040.918638815]
# sequential_19 model is trained. best val loss is : [38062958240321.52, 38062958284613.13, 4100919.928147932]
# sequential_19 model is trained. best val loss is : [29979050033508.293, 29979050009052.15, 3375518.319743273]
# sequential_19 model is trained. best val loss is : [13689614571403.553, 13689614554935.775, 2064692.6836634993]
# sequential_19 model is trained. best val loss is : [72396083726388.22, 72396083752640.78, 7099532.816919107]
# sequential_19 model is trained. best val loss is : [31260260275698.27, 31260260177902.03, 3499715.968902151]
# sequential_19 model is trained. best val loss is : [19010613075768.832, 19010613037907.062, 2405323.378966689]
# sequential_19 model is trained. best val loss is : [10905878609156.879, 10905878690887.838, 1750759.7987424736]
# sequential_20 model is trained. best val loss is : [73460341161078.78, 73460341079893.48, 7172668.579873432]
# sequential_20 model is trained. best val loss is : [73460319790620.67, 73460319900988.86, 7172667.337483348]
# sequential_20 model is trained. best val loss is : [73460306105204.73, 73460305953771.72, 7172666.089811408]
# sequential_20 model is trained. best val loss is : [11303255690802.281, 11303255649596.17, 1809582.6475165174]
# sequential_20 model is trained. best val loss is : [1.974463024323527e+22, 1.974463021381753e+22, 140515587006.5824]
# sequential_20 model is trained. best val loss is : [27511411416612.69, 27511411397606.105, 3117816.470295847]
# sequential_20 model is trained. best val loss is : [22013184603087.305, 22013184646219.758, 2864901.3609973555]
# sequential_20 model is trained. best val loss is : [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential_20 model is trained. best val loss is : [46325001659136.95, 46325001667256.375, 4959552.027634772]
# sequential_20 model is trained. best val loss is : [11632345120581.027, 11632345089744.314, 1937360.8239572367]
# sequential_20 model is trained. best val loss is : [11326485951048.363, 11326485894995.768, 1898604.9442251578]
# sequential_20 model is trained. best val loss is : [11551922710334.715, 11551922658509.984, 1817753.4083047777]
# sequential_20 model is trained. best val loss is : [73460299318595.58, 73460299453122.89, 7172665.928833256]
# sequential_20 model is trained. best val loss is : [72528692594475.02, 72528692625794.0, 7108504.523365275]
# sequential_20 model is trained. best val loss is : [64740959580490.36, 64740959590885.82, 6601084.08319345]
# sequential_20 model is trained. best val loss is : [32565849841416.51, 32565849697406.484, 3684566.880616915]
# sequential_20 model is trained. best val loss is : [73367295068958.72, 73367295205479.75, 7166040.010833536]
# sequential_20 model is trained. best val loss is : [33313650792157.254, 33313650751422.938, 3654599.2029672405]
# sequential_20 model is trained. best val loss is : [36694534146252.29, 36694534223545.23, 4190772.648578141]
# sequential_20 model is trained. best val loss is : [13155831212512.75, 13155831185016.695, 2041664.441956249]
# sequential_20 model is trained. best val loss is : [72346371926257.66, 72346371837947.31, 7098680.569852494]
# sequential_20 model is trained. best val loss is : [23031787578164.855, 23031787531023.023, 2834516.86350858]
# sequential_20 model is trained. best val loss is : [12859089909651.078, 12859089922604.283, 2056661.6246591085]
# sequential_20 model is trained. best val loss is : [11030622102017.01, 11030621887034.805, 1740568.7839602486]
# sequential_21 model is trained. best val loss is : [73460338775019.52, 73460338684171.12, 7172668.451557074]
# sequential_21 model is trained. best val loss is : [73460323853438.97, 73460323911300.08, 7172667.3595176665]
# sequential_21 model is trained. best val loss is : [12676279877954.281, 12676279778656.754, 2009007.3522456253]
# sequential_21 model is trained. best val loss is : [11048513569594.836, 11048513600099.072, 1785478.3744669785]
# sequential_21 model is trained. best val loss is : [5.263396071769408e+23, 5.263396074850736e+23, 725492665340.6356]
# sequential_21 model is trained. best val loss is : [173163202208595.97, 173163202562741.8, 12294309.108615728]
# sequential_21 model is trained. best val loss is : [22013184602809.438, 22013184646223.18, 2864901.360893725]
# sequential_21 model is trained. best val loss is : [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential_21 model is trained. best val loss is : [41903206091901.36, 41903206032618.6, 4488392.979542564]
# sequential_21 model is trained. best val loss is : [11202187036137.758, 11202186976719.408, 1872839.5391557286]
# sequential_21 model is trained. best val loss is : [10861569459463.795, 10861569497404.88, 1830291.732292437]
# sequential_21 model is trained. best val loss is : [11827127293560.89, 11827127194876.559, 1855780.4755454396]
# sequential_21 model is trained. best val loss is : [73459930446028.8, 73459930263729.73, 7172642.286896198]
# sequential_21 model is trained. best val loss is : [70018966233776.125, 70018965948384.586, 6930381.628615386]
# sequential_21 model is trained. best val loss is : [47859956075997.42, 47859956131145.01, 5127771.014041001]
# sequential_21 model is trained. best val loss is : [20760254955435.613, 20760255046924.42, 2643034.4802891705]
# sequential_21 model is trained. best val loss is : [73101118694936.58, 73101118455602.3, 7147498.009335474]
# sequential_21 model is trained. best val loss is : [32750458715507.22, 32750458548627.98, 3619133.3083876814]
# sequential_21 model is trained. best val loss is : [20543970664171.32, 20543970759040.71, 2566499.269486265]
# sequential_21 model is trained. best val loss is : [11026541954730.055, 11026541929925.645, 1854268.5766216503]
# sequential_21 model is trained. best val loss is : [69750823738153.22, 69750823761815.12, 6915268.3490318265]
# sequential_21 model is trained. best val loss is : [18317870022822.008, 18317870028329.156, 2608225.246298782]
# sequential_21 model is trained. best val loss is : [11315887659685.543, 11315887729783.828, 1898173.693202689]
# sequential_21 model is trained. best val loss is : [10991862867735.008, 10991862803319.16, 1737927.8582403094]
# sequential_22 model is trained. best val loss is : [73460333513981.95, 73460333426234.27, 7172668.12321479]
# sequential_22 model is trained. best val loss is : [11263585587810.6, 11263585626339.88, 1901079.6763176427]
# sequential_22 model is trained. best val loss is : [11217184025516.22, 11217184036960.56, 1839811.4888065148]
# sequential_22 model is trained. best val loss is : [11247050150388.662, 11247050172027.469, 1777812.0283231877]
# sequential_22 model is trained. best val loss is : [inf, 4.055734476221459e+156, 2.013885417848161e+78]
# sequential_22 model is trained. best val loss is : [57007425195153.01, 57007425324657.016, 5931861.914602149]
# sequential_22 model is trained. best val loss is : [22013184603585.99, 22013184646215.188, 2864901.361135825]
# sequential_22 model is trained. best val loss is : [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential_22 model is trained. best val loss is : [41056990322635.99, 41056990276639.88, 4450180.457890865]
# sequential_22 model is trained. best val loss is : [11490744677578.607, 11490744756727.629, 1868020.5361667098]
# sequential_22 model is trained. best val loss is : [10734775322825.262, 10734775251673.238, 1771518.884517791]
# sequential_22 model is trained. best val loss is : [11381439658527.7, 11381439717569.26, 1777844.7033061238]
# sequential_22 model is trained. best val loss is : [73458724903911.42, 73458724927584.34, 7172564.436348256]
# sequential_22 model is trained. best val loss is : [61091523264232.32, 61091523323909.516, 6238955.857300763]
# sequential_22 model is trained. best val loss is : [42063105245550.555, 42063105144268.46, 4504500.673212634]
# sequential_22 model is trained. best val loss is : [17923635200462.53, 17923635195188.094, 2398950.0137538007]
# sequential_22 model is trained. best val loss is : [72123590679230.47, 72123590963617.97, 7077453.810146347]
# sequential_22 model is trained. best val loss is : [25306483282179.754, 25306483322428.3, 3047106.6777225216]
# sequential_22 model is trained. best val loss is : [17511706885864.512, 17511706960743.635, 2278344.281301712]
# sequential_22 model is trained. best val loss is : [11002542348922.326, 11002542355384.578, 1860513.3056590129]
# sequential_22 model is trained. best val loss is : [61162206452186.65, 61162206483099.33, 6297866.456226401]
# sequential_22 model is trained. best val loss is : [12551832716127.152, 12551832674991.838, 1991000.5735326891]
# sequential_22 model is trained. best val loss is : [11123170524985.887, 11123170470720.855, 1806739.3198187083]
# sequential_22 model is trained. best val loss is : [11160106629811.914, 11160106531705.264, 1731946.9781992002]
# sequential_23 model is trained. best val loss is : [73460339020857.34, 73460339078212.14, 7172668.464866793]
# sequential_23 model is trained. best val loss is : [11467164147552.08, 11467164190561.611, 1855152.217399936]
# sequential_23 model is trained. best val loss is : [11056290815096.404, 11056290736964.219, 1774248.838352955]
# sequential_23 model is trained. best val loss is : [11186406568243.94, 11186406542833.516, 1795241.1829307254]
# sequential_23 model is trained. best val loss is : [3.4396892944454516e+22, 3.439689294144252e+22, 185463993592.90558]
# sequential_23 model is trained. best val loss is : [nan, nan, nan]
# sequential_23 model is trained. best val loss is : [nan, nan, nan]
# sequential_23 model is trained. best val loss is : [nan, nan, nan]
# sequential_23 model is trained. best val loss is : [34673972310413.88, 34673972262216.895, 3855814.2538139354]
# sequential_23 model is trained. best val loss is : [11067141483294.525, 11067141433195.67, 1843772.8295472357]
# sequential_23 model is trained. best val loss is : [10888833978179.543, 10888833947805.457, 1799506.10167428]
# sequential_23 model is trained. best val loss is : [12082726399867.564, 12082726516348.568, 1853246.3554104224]
# sequential_23 model is trained. best val loss is : [73452546006966.27, 73452546112323.12, 7172145.932987179]
# sequential_23 model is trained. best val loss is : [54766091586976.7, 54766091553985.375, 5771708.278496568]
# sequential_23 model is trained. best val loss is : [41220561543377.92, 41220561547864.086, 4436164.544103414]
# sequential_23 model is trained. best val loss is : [11764626905290.078, 11764626976016.385, 1966663.9731178966]
# sequential_23 model is trained. best val loss is : [66513265517134.11, 66513265565388.09, 6645036.291661175]
# sequential_23 model is trained. best val loss is : [19909728134203.16, 19909728170936.254, 2599893.2810526015]
# sequential_23 model is trained. best val loss is : [13561756594241.184, 13561756496416.871, 2067050.262529448]
# sequential_23 model is trained. best val loss is : [10936154178518.31, 10936154202260.965, 1848074.6022356744]
# sequential_23 model is trained. best val loss is : [49747317372337.86, 49747317410804.56, 5318055.82482976]
# sequential_23 model is trained. best val loss is : [11315506586691.0, 11315506534640.166, 1860203.8325679884]
# sequential_23 model is trained. best val loss is : [11086052899534.14, 11086052938239.434, 1777758.2884240318]
# sequential_23 model is trained. best val loss is : [11134067382019.684, 11134067242029.488, 1687120.834186665]
# sequential_24 model is trained. best val loss is : [73460330682138.62, 73460330734972.6, 7172667.901853686]
# sequential_24 model is trained. best val loss is : [11036896874683.72, 11036896936025.266, 1733970.5336491081]
# sequential_24 model is trained. best val loss is : [11074097143543.15, 11074097085623.717, 1767497.7841070523]
# sequential_24 model is trained. best val loss is : [11359445280586.893, 11359445272631.656, 1789921.1960635295]
# sequential_24 model is trained. best val loss is : [1.4209078938284658e+23, 1.420907894370139e+23, 376949319425.04016]
# sequential_24 model is trained. best val loss is : [32360006884677.984, 32360006779632.13, 3646947.0145750996]
# sequential_24 model is trained. best val loss is : [inf, 1.1214489609401173e+81, 3.3488042058921852e+40]
# sequential_24 model is trained. best val loss is : [22014009205012.04, 22014009314595.723, 2873676.208922309]
# sequential_24 model is trained. best val loss is : [29806425517245.176, 29806425633747.543, 3425123.1529139834]
# sequential_24 model is trained. best val loss is : [10840802784425.54, 10840802776519.207, 1789095.0579345557]
# sequential_24 model is trained. best val loss is : [11177064054547.28, 11177064066428.271, 1761729.3796299489]
# sequential_24 model is trained. best val loss is : [10104735349014.768, 10104735272668.277, 1753615.2535690342]
# sequential_24 model is trained. best val loss is : [73429842806255.61, 73429842884913.89, 7170569.178163125]
# sequential_24 model is trained. best val loss is : [44801157941138.81, 44801157906603.6, 4805769.44483078]
# sequential_24 model is trained. best val loss is : [37564682038692.75, 37564682089670.086, 4114328.647615619]
# sequential_24 model is trained. best val loss is : [11427234521069.229, 11427234449570.102, 1836078.7440307674]
# sequential_24 model is trained. best val loss is : [52371007470377.06, 52371007633586.516, 5472873.188087456]
# sequential_24 model is trained. best val loss is : [17616907399460.473, 17616907462437.082, 2281134.322793611]
# sequential_24 model is trained. best val loss is : [11689740015671.969, 11689740063810.768, 1920073.6562669831]
# sequential_24 model is trained. best val loss is : [11076864908202.352, 11076864966889.717, 1820347.676364743]
# sequential_24 model is trained. best val loss is : [41985792860639.23, 41985793008433.1, 4496418.715214799]
# sequential_24 model is trained. best val loss is : [11034358080693.234, 11034358100033.4, 1776928.1630057946]
# sequential_24 model is trained. best val loss is : [10986673303510.795, 10986673310720.184, 1751547.6596704521]
# sequential_24 model is trained. best val loss is : [11138090268639.41, 11138090287825.02, 1670741.6796251775]
# sequential_25 model is trained. best val loss is : [73460343029776.39, 73460343126952.4, 7172668.725153773]
# sequential_25 model is trained. best val loss is : [73460319089098.75, 73460319049316.17, 7172667.088814387]
# sequential_25 model is trained. best val loss is : [73401466368905.22, 73401466230212.7, 7168944.724492645]
# sequential_25 model is trained. best val loss is : [11179615347745.47, 11179615419571.37, 1787129.0256018087]
# sequential_25 model is trained. best val loss is : [2.4869089836988396e+26, 2.4869089843393824e+26, 15769936538677.506]
# sequential_25 model is trained. best val loss is : [2.703146428349187e+19, 2.703146427978176e+19, 5199177075.904964]
# sequential_25 model is trained. best val loss is : [nan, nan, nan]
# sequential_25 model is trained. best val loss is : [inf, 7.57690614046696e+304, 7.000495039918428e+150]
# sequential_25 model is trained. best val loss is : [29898665044478.19, 29898665007739.773, 3803522.2110764263]
# sequential_25 model is trained. best val loss is : [10955826065585.08, 10955826143379.1, 1839907.9423585958]
# sequential_25 model is trained. best val loss is : [10941763323392.402, 10941763345598.871, 1763603.6689506203]
# sequential_25 model is trained. best val loss is : [11428160140273.762, 11428160045352.676, 1739523.5666520866]
# sequential_25 model is trained. best val loss is : [73460240045461.5, 73460240166881.95, 7172661.006280913]
# sequential_25 model is trained. best val loss is : [55330005963984.234, 55330005952109.75, 5887574.156872677]
# sequential_25 model is trained. best val loss is : [39697392452623.37, 39697392468257.26, 4278209.922688319]
# sequential_25 model is trained. best val loss is : [13584532477144.104, 13584532468038.617, 2025463.6120933243]
# sequential_25 model is trained. best val loss is : [72534186714157.06, 72534186683602.42, 7105745.01848453]
# sequential_25 model is trained. best val loss is : [21697110390258.195, 21697110409534.93, 2661682.903499598]
# sequential_25 model is trained. best val loss is : [13592516149400.742, 13592516187539.389, 2093704.4578369982]
# sequential_25 model is trained. best val loss is : [11280963636156.031, 11280963583663.195, 1832620.5835400228]
# sequential_25 model is trained. best val loss is : [59886980782667.74, 59886980849520.445, 6281257.952058886]
# sequential_25 model is trained. best val loss is : [11863681216786.229, 11863681239664.145, 1970799.1159124265]
# sequential_25 model is trained. best val loss is : [10991223141145.9, 10991223097685.635, 1774773.3557377495]
# sequential_25 model is trained. best val loss is : [11275287902015.559, 11275287889288.191, 1715909.5222757757]
# sequential_26 model is trained. best val loss is : [73460340743151.61, 73460340769509.28, 7172668.57316301]
# sequential_26 model is trained. best val loss is : [18560356386991.2, 18560356466933.883, 2656360.4934086357]
# sequential_26 model is trained. best val loss is : [11337061732316.672, 11337061770594.455, 1853629.336126733]
# sequential_26 model is trained. best val loss is : [11280154441590.896, 11280154381512.047, 1811680.0596416828]
# sequential_26 model is trained. best val loss is : [3.444685656134241e+29, 3.4446856378412634e+29, 586914443325538.1]
# sequential_26 model is trained. best val loss is : [nan, nan, nan]
# sequential_26 model is trained. best val loss is : [22013184886267.133, 22013184902283.266, 2864893.656844292]
# sequential_26 model is trained. best val loss is : [nan, nan, nan]
# sequential_26 model is trained. best val loss is : [25503101327120.17, 25503101388398.508, 3083025.8590491745]
# sequential_26 model is trained. best val loss is : [10840519267814.004, 10840519242138.611, 1780740.3609533096]
# sequential_26 model is trained. best val loss is : [11320142688140.51, 11320142643721.28, 1794001.036640162]
# sequential_26 model is trained. best val loss is : [11842328620740.31, 11842328648707.17, 1759507.965702224]
# sequential_26 model is trained. best val loss is : [73457536061497.34, 73457536001536.67, 7172482.579138795]
# sequential_26 model is trained. best val loss is : [45355167027339.78, 45355166960512.88, 4819887.296371621]
# sequential_26 model is trained. best val loss is : [35452157994752.53, 35452158130103.37, 3907614.1990420455]
# sequential_26 model is trained. best val loss is : [11638067916720.168, 11638067915820.992, 1935747.9586451964]
# sequential_26 model is trained. best val loss is : [62424889809142.21, 62424889717671.57, 6285252.9773064]
# sequential_26 model is trained. best val loss is : [17675929258600.48, 17675929347212.09, 2421777.7231628844]
# sequential_26 model is trained. best val loss is : [11398289474973.87, 11398289478569.148, 1906956.1747686234]
# sequential_26 model is trained. best val loss is : [11167105697873.922, 11167105706404.85, 1812063.9496672486]
# sequential_26 model is trained. best val loss is : [51146294056171.01, 51146294114297.91, 5345704.194152225]
# sequential_26 model is trained. best val loss is : [11110827199012.514, 11110827200695.201, 1808502.453810231]
# sequential_26 model is trained. best val loss is : [11050266861569.059, 11050266843224.846, 1848195.2727969394]
# sequential_26 model is trained. best val loss is : [11097627835470.186, 11097627838742.533, 1679534.9807864479]
# sequential_27 model is trained. best val loss is : [73460335015579.64, 73460334933312.19, 7172668.167141611]
# sequential_27 model is trained. best val loss is : [11506273174842.65, 11506273239027.865, 1915126.5086636161]
# sequential_27 model is trained. best val loss is : [11605152421826.533, 11605152434986.516, 1779251.0515234354]
# sequential_27 model is trained. best val loss is : [11086461952246.371, 11086461914056.36, 1790066.0948205013]
# sequential_27 model is trained. best val loss is : [nan, nan, nan]
# sequential_27 model is trained. best val loss is : [inf, 3.8307333249060077e+86, 1.9572259258721308e+43]
# sequential_27 model is trained. best val loss is : [nan, nan, nan]
# sequential_27 model is trained. best val loss is : [nan, nan, nan]
# sequential_27 model is trained. best val loss is : [13505801654819.363, 13505801667159.16, 1989716.1603199823]
# sequential_27 model is trained. best val loss is : [10862953660983.318, 10862953617594.295, 1709581.6233071354]
# sequential_27 model is trained. best val loss is : [11952639695771.742, 11952639674361.074, 1866326.8232450637]
# sequential_27 model is trained. best val loss is : [11017672962860.87, 11017672989496.504, 1877523.3649661588]
# sequential_27 model is trained. best val loss is : [73438617763741.7, 73438617759701.92, 7171237.293924884]
# sequential_27 model is trained. best val loss is : [37867610412895.39, 37867610544982.92, 4123398.3762077815]
# sequential_27 model is trained. best val loss is : [35032224969235.684, 35032224927757.586, 3975716.6755891773]
# sequential_27 model is trained. best val loss is : [11012404407133.238, 11012404461511.104, 1762275.315440068]
# sequential_27 model is trained. best val loss is : [39816490188882.016, 39816490257296.11, 4233648.781254843]
# sequential_27 model is trained. best val loss is : [11866627110033.996, 11866627147983.98, 1951789.6268067344]
# sequential_27 model is trained. best val loss is : [11004312712599.305, 11004312725692.871, 1852403.0660602872]
# sequential_27 model is trained. best val loss is : [11854416095321.012, 11854416096042.836, 1878084.7749377885]
# sequential_27 model is trained. best val loss is : [36579750713390.58, 36579750706844.97, 3991211.033254643]
# sequential_27 model is trained. best val loss is : [11008927642251.098, 11008927744572.906, 1772895.5853272083]
# sequential_27 model is trained. best val loss is : [11064658834151.805, 11064658848317.154, 1734936.0910144148]
# sequential_27 model is trained. best val loss is : [11344106408312.807, 11344106303243.184, 1697548.7209733329]
# sequential_28 model is trained. best val loss is : [73460334037331.97, 73460333888737.69, 7172668.107657376]
# sequential_28 model is trained. best val loss is : [11130292188842.475, 11130292210279.514, 1759462.0403009315]
# sequential_28 model is trained. best val loss is : [11071790904100.271, 11071790996534.768, 1735908.6737529547]
# sequential_28 model is trained. best val loss is : [11085293132965.344, 11085293205411.57, 1773658.9832809283]
# sequential_28 model is trained. best val loss is : [nan, nan, nan]
# sequential_28 model is trained. best val loss is : [nan, nan, nan]
# sequential_28 model is trained. best val loss is : [nan, nan, nan]
# sequential_28 model is trained. best val loss is : [nan, nan, nan]
# sequential_28 model is trained. best val loss is : [12316794984885.309, 12316795033540.4, 1923207.775643449]
# sequential_28 model is trained. best val loss is : [11237830237053.436, 11237830303284.982, 1764350.0699172576]
# sequential_28 model is trained. best val loss is : [11931076071152.08, 11931076134712.238, 1824854.2544414615]
# sequential_28 model is trained. best val loss is : [11846207313520.54, 11846207458615.97, 1839516.2497583358]
# sequential_28 model is trained. best val loss is : [73276402235482.11, 73276402317934.66, 7160122.078346589]
# sequential_28 model is trained. best val loss is : [36992863152279.2, 36992863224848.805, 4068208.667529219]
# sequential_28 model is trained. best val loss is : [19487271340408.23, 19487271407523.574, 2607377.1222521393]
# sequential_28 model is trained. best val loss is : [10975167485053.824, 10975167393197.6, 1774982.7873341704]
# sequential_28 model is trained. best val loss is : [42565800979990.47, 42565801068394.42, 4473659.381492332]
# sequential_28 model is trained. best val loss is : [11560350847253.008, 11560350824084.514, 1857312.1844907808]
# sequential_28 model is trained. best val loss is : [10893953418295.12, 10893953390470.59, 1839694.128151088]
# sequential_28 model is trained. best val loss is : [12013844534479.271, 12013844477712.04, 1891569.2073276592]
# sequential_28 model is trained. best val loss is : [29652731890000.227, 29652731889226.95, 3380053.280802875]
# sequential_28 model is trained. best val loss is : [11047120863103.455, 11047120917542.395, 1742221.059989612]
# sequential_28 model is trained. best val loss is : [11161285558883.363, 11161285614855.953, 1718226.6970289878]
# sequential_28 model is trained. best val loss is : [10703666843025.68, 10703666874039.299, 1681707.233870369]
# sequential_29 model is trained. best val loss is : [73460326645063.69, 73460326528982.16, 7172667.59325178]
# sequential_29 model is trained. best val loss is : [11070425844113.676, 11070425828410.016, 1748168.3858411084]
# sequential_29 model is trained. best val loss is : [11051947550258.809, 11051947477874.826, 1746772.304704738]
# sequential_29 model is trained. best val loss is : [11042794388793.016, 11042794398013.639, 1743167.525766142]
# sequential_29 model is trained. best val loss is : [nan, nan, nan]
# sequential_29 model is trained. best val loss is : [nan, nan, nan]
# sequential_29 model is trained. best val loss is : [nan, nan, nan]
# sequential_29 model is trained. best val loss is : [nan, nan, nan]
# sequential_29 model is trained. best val loss is : [11110000370384.48, 11110000343693.05, 1878415.139285149]
# sequential_29 model is trained. best val loss is : [12014332993251.045, 12014332884584.12, 1860991.9815389463]
# sequential_29 model is trained. best val loss is : [11372242938970.508, 11372242879829.592, 1784884.5435086049]
# sequential_29 model is trained. best val loss is : [11362574817233.684, 11362574863193.43, 1835431.9963847287]
# sequential_29 model is trained. best val loss is : [72206160197844.98, 72206160221659.11, 7088059.909359081]
# sequential_29 model is trained. best val loss is : [28517248106377.2, 28517248108032.832, 3315196.343039895]
# sequential_29 model is trained. best val loss is : [12049316251986.436, 12049316337700.635, 1909811.7835903405]
# sequential_29 model is trained. best val loss is : [10863703025075.91, 10863703054931.104, 1771204.648695183]
# sequential_29 model is trained. best val loss is : [32826096355610.797, 32826096341581.4, 3580917.9111633534]
# sequential_29 model is trained. best val loss is : [10955881201066.229, 10955881180816.059, 1847575.8754474507]
# sequential_29 model is trained. best val loss is : [11020420133545.781, 11020420203717.096, 1849839.5996090749]
# sequential_29 model is trained. best val loss is : [12036961262920.494, 12036961307067.521, 2077796.8937734056]
# sequential_29 model is trained. best val loss is : [17338660518753.408, 17338660539721.648, 2340260.180573774]
# sequential_29 model is trained. best val loss is : [11091561049897.812, 11091560981277.889, 1732661.412759781]
# sequential_29 model is trained. best val loss is : [11061812546603.268, 11061812640621.428, 1708376.5598472366]
# sequential_29 model is trained. best val loss is : [11307468898180.324, 11307469021557.146, 1688617.9679494463]

# %%
best_model_house, best_model_info_house = select_best_model(mlp_house.trained_models, mlp_house.val_losses, mlp_house.compiled_models_info)
best_model_house.evaluate(ds_house.trans_X_val, ds_house.trans_y_val)
print(best_model_info_house)
# Out:
# 2000/2000 [==============================] - 0s 48us/sample - loss: 10104735349014.7676 - MSE: 10104735272668.2773 - MAE: 1753615.2536
# {'structure_info': {'hidden_layers': 2, 'units': 256}, 'optimizer_info': {'optimizer_name': 'adam', 'lr': 0.1}}

# %%
import matplotlib.pyplot as plt
plt.plot(sorted(mlp_house.val_losses)[:10], '.')
