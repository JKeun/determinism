# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename = "./data/marketing.csv"
ds = DataSource(filename)
ds.data_load_split(target=['insurance_subscribe'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)

# %%
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.21242680515215273, 0.90478826]
# sequential model is trained. best val loss is: [0.21009428379784298, 0.90556234]
# sequential model is trained. best val loss is: [0.21144239450732283, 0.9068893]
# sequential model is trained. best val loss is: [0.2446262197303097, 0.8793542]
# sequential model is trained. best val loss is: [0.882838157924366, 0.23432489]
# sequential model is trained. best val loss is: [0.3366114530239856, 0.87968594]
# sequential model is trained. best val loss is: [0.2942232133691506, 0.8827823]
# sequential model is trained. best val loss is: [0.24234370459672375, 0.8952781]
# sequential model is trained. best val loss is: [0.2236219558959169, 0.9010284]
# sequential model is trained. best val loss is: [0.20942312111886718, 0.90655756]
# sequential model is trained. best val loss is: [0.21098227153161347, 0.9046776]
# sequential model is trained. best val loss is: [0.21297971119425088, 0.9009178]
# sequential model is trained. best val loss is: [0.33283859109385516, 0.88211876]
# sequential model is trained. best val loss is: [0.2338704295809865, 0.897158]
# sequential model is trained. best val loss is: [0.22478030864398563, 0.899812]
# sequential model is trained. best val loss is: [0.21338529729756134, 0.90257657]
# sequential model is trained. best val loss is: [0.28982119063657164, 0.8830034]
# sequential model is trained. best val loss is: [0.23773564492708338, 0.8952781]
# sequential model is trained. best val loss is: [0.22997264372396822, 0.89837444]
# sequential model is trained. best val loss is: [0.2191810391519524, 0.9022448]
# sequential model is trained. best val loss is: [0.21537050872754435, 0.90511996]
# sequential model is trained. best val loss is: [0.21104330329337137, 0.90556234]
# sequential model is trained. best val loss is: [0.21434451913024213, 0.90478826]
# sequential model is trained. best val loss is: [0.2491543838721546, 0.88665265]
# sequential model is trained. best val loss is: [0.21018746403298993, 0.9052306]
# sequential model is trained. best val loss is: [0.21630948550943963, 0.90456706]
# sequential model is trained. best val loss is: [0.21047232536751256, 0.90589404]
# sequential model is trained. best val loss is: [0.23205318740810768, 0.8790224]
# sequential model is trained. best val loss is: [0.5787608592196216, 0.7858012]
# sequential model is trained. best val loss is: [0.3229117590044632, 0.8795754]
# sequential model is trained. best val loss is: [0.2808284707648372, 0.88410926]
# sequential model is trained. best val loss is: [0.23604012412280356, 0.8985956]
# sequential model is trained. best val loss is: [0.2223865365106738, 0.9031295]
# sequential model is trained. best val loss is: [0.2093065888411332, 0.90534115]
# sequential model is trained. best val loss is: [0.20923644087093932, 0.9054517]
# sequential model is trained. best val loss is: [0.21838425806266576, 0.9014708]
# sequential model is trained. best val loss is: [0.305817791005883, 0.88145524]
# sequential model is trained. best val loss is: [0.23155998368976682, 0.90080726]
# sequential model is trained. best val loss is: [0.22341459129719585, 0.90213424]
# sequential model is trained. best val loss is: [0.21038675445655033, 0.9069999]
# sequential model is trained. best val loss is: [0.2994651760225023, 0.8832246]
# sequential model is trained. best val loss is: [0.23966386718493204, 0.8980427]
# sequential model is trained. best val loss is: [0.22929710867551792, 0.90025437]
# sequential model is trained. best val loss is: [0.21650698304795907, 0.90456706]
# sequential model is trained. best val loss is: [0.21547925946170166, 0.90235543]
# sequential model is trained. best val loss is: [0.21505273509958894, 0.9009178]
# sequential model is trained. best val loss is: [0.22890046178918885, 0.90478826]
# sequential model is trained. best val loss is: [0.32448623144928496, 0.88267165]
# sequential model is trained. best val loss is: [0.2085935598576898, 0.90589404]
# sequential model is trained. best val loss is: [0.21858312671563931, 0.9044565]
# sequential model is trained. best val loss is: [0.21405720469844325, 0.9075528]
# sequential model is trained. best val loss is: [0.2308936462483548, 0.8793542]
# sequential model is trained. best val loss is: [0.6169439334264571, 0.75572264]
# sequential model is trained. best val loss is: [0.29448762467829487, 0.8795754]
# sequential model is trained. best val loss is: [0.26099133327064505, 0.88886434]
# sequential model is trained. best val loss is: [0.22986610776408115, 0.899812]
# sequential model is trained. best val loss is: [0.21803657632940285, 0.90655756]
# sequential model is trained. best val loss is: [0.20921746189320337, 0.90733165]
# sequential model is trained. best val loss is: [0.21308774791512095, 0.90390354]
# sequential model is trained. best val loss is: [0.21424681456113012, 0.90235543]
# sequential model is trained. best val loss is: [0.28705188964539813, 0.88156587]
# sequential model is trained. best val loss is: [0.22691554645449005, 0.8999226]
# sequential model is trained. best val loss is: [0.22022071032546256, 0.9029083]
# sequential model is trained. best val loss is: [0.21002565278991667, 0.90611523]
# sequential model is trained. best val loss is: [0.28840394141623155, 0.8825611]
# sequential model is trained. best val loss is: [0.23488577066645822, 0.8967157]
# sequential model is trained. best val loss is: [0.22636462859277978, 0.89903796]
# sequential model is trained. best val loss is: [0.2152724388023268, 0.9044565]
# sequential model is trained. best val loss is: [0.2103473370770998, 0.90810573]
# sequential model is trained. best val loss is: [0.2256834393421343, 0.9048988]
# sequential model is trained. best val loss is: [0.22789010797390089, 0.9034612]
# sequential model is trained. best val loss is: [0.28645183141221253, 0.88665265]
# sequential model is trained. best val loss is: [0.20748589475321239, 0.9057835]
# sequential model is trained. best val loss is: [0.2132120081133433, 0.9082163]
# sequential model is trained. best val loss is: [0.2144227140207912, 0.90412474]
# sequential model is trained. best val loss is: [0.23566063165822862, 0.8818976]
# sequential model is trained. best val loss is: [0.48163676667263533, 0.87316155]
# sequential model is trained. best val loss is: [0.2751255791152748, 0.8832246]
# sequential model is trained. best val loss is: [0.2508766849714874, 0.8920712]
# sequential model is trained. best val loss is: [0.22551174832763995, 0.90158135]
# sequential model is trained. best val loss is: [0.21435584848820602, 0.9043459]
# sequential model is trained. best val loss is: [0.2089718011124767, 0.9056729]
# sequential model is trained. best val loss is: [0.21313666949675011, 0.90478826]
# sequential model is trained. best val loss is: [0.22478838429228995, 0.9018025]
# sequential model is trained. best val loss is: [0.2748334727481866, 0.8842198]
# sequential model is trained. best val loss is: [0.22470945094151926, 0.9010284]
# sequential model is trained. best val loss is: [0.21824640865467243, 0.90412474]
# sequential model is trained. best val loss is: [0.20807840453567303, 0.9066681]
# sequential model is trained. best val loss is: [0.2869920041179362, 0.8822293]
# sequential model is trained. best val loss is: [0.23352354585986004, 0.89837444]
# sequential model is trained. best val loss is: [0.22519221964180897, 0.9010284]
# sequential model is trained. best val loss is: [0.21219600704632988, 0.9057835]
# sequential model is trained. best val loss is: [0.20940468558613395, 0.90733165]
# sequential model is trained. best val loss is: [0.22388438564228508, 0.90589404]
# sequential model is trained. best val loss is: [0.2400849495500402, 0.90611523]
# sequential model is trained. best val loss is: [0.28702163939176506, 0.884441]
# sequential model is trained. best val loss is: [0.20795749623032253, 0.90611523]
# sequential model is trained. best val loss is: [0.21716417551343847, 0.9050094]
# sequential model is trained. best val loss is: [0.21430250483580585, 0.90534115]
# sequential model is trained. best val loss is: [0.2352788882828729, 0.8793542]
# sequential model is trained. best val loss is: [0.42543803803836117, 0.8793542]
# sequential model is trained. best val loss is: [0.26143973240886104, 0.8865421]
# sequential model is trained. best val loss is: [0.24390114492696693, 0.89439344]
# sequential model is trained. best val loss is: [0.2211990952162198, 0.903793]
# sequential model is trained. best val loss is: [0.210789367643906, 0.90655756]
# sequential model is trained. best val loss is: [0.21080467179722456, 0.90456706]
# sequential model is trained. best val loss is: [0.21332212317626614, 0.90456706]
# sequential model is trained. best val loss is: [0.2158190036135069, 0.90335065]
# sequential model is trained. best val loss is: [0.26643475074163253, 0.8864315]
# sequential model is trained. best val loss is: [0.22188732641652584, 0.9019131]
# sequential model is trained. best val loss is: [0.21624910186497917, 0.9046776]
# sequential model is trained. best val loss is: [0.2073225354569604, 0.9082163]
# sequential model is trained. best val loss is: [0.28076452202703606, 0.8833352]
# sequential model is trained. best val loss is: [0.2312852760325171, 0.8985956]
# sequential model is trained. best val loss is: [0.2233510488306647, 0.9004755]
# sequential model is trained. best val loss is: [0.2113828896375458, 0.9054517]
# sequential model is trained. best val loss is: [0.2095553558128249, 0.9062258]
# sequential model is trained. best val loss is: [0.23283796531627046, 0.903793]
# sequential model is trained. best val loss is: [0.2492927442270083, 0.90711045]
# sequential model is trained. best val loss is: [0.36983914433571796, 0.8818976]
# sequential model is trained. best val loss is: [0.2119671014357652, 0.9034612]
# sequential model is trained. best val loss is: [0.21203118592358974, 0.90456706]
# sequential model is trained. best val loss is: [0.21255104841416644, 0.90534115]
# sequential model is trained. best val loss is: [0.23467085946915253, 0.89439344]
# sequential model is trained. best val loss is: [0.5757752187244399, 0.8782484]
# sequential model is trained. best val loss is: [0.3417669644888874, 0.8793542]
# sequential model is trained. best val loss is: [0.29089740109525397, 0.88156587]
# sequential model is trained. best val loss is: [0.23329047389583066, 0.8949464]
# sequential model is trained. best val loss is: [0.22343580926873838, 0.9019131]
# sequential model is trained. best val loss is: [0.20996086150292445, 0.90511996]
# sequential model is trained. best val loss is: [0.20911928988275547, 0.9075528]
# sequential model is trained. best val loss is: [0.21021165830838817, 0.9068893]
# sequential model is trained. best val loss is: [0.31546937109661305, 0.8794648]
# sequential model is trained. best val loss is: [0.22810547033875414, 0.8980427]
# sequential model is trained. best val loss is: [0.2226421820910436, 0.90235543]
# sequential model is trained. best val loss is: [0.21119231708042127, 0.90478826]
# sequential model is trained. best val loss is: [0.3077215675322682, 0.87913305]
# sequential model is trained. best val loss is: [0.23618786441835565, 0.8927347]
# sequential model is trained. best val loss is: [0.2281996377680031, 0.8967157]
# sequential model is trained. best val loss is: [0.21728826086236144, 0.9029083]
# sequential model is trained. best val loss is: [0.21516815103433123, 0.90401417]
# sequential model is trained. best val loss is: [0.2132372692215829, 0.9066681]
# sequential model is trained. best val loss is: [0.21368681074810228, 0.90412474]
# sequential model is trained. best val loss is: [0.24463002701571832, 0.87437797]
# sequential model is trained. best val loss is: [0.20708354340643134, 0.90788454]
# sequential model is trained. best val loss is: [0.20827079332403464, 0.9056729]
# sequential model is trained. best val loss is: [0.20633550775099893, 0.9068893]
# sequential model is trained. best val loss is: [0.23323875491655757, 0.8793542]
# sequential model is trained. best val loss is: [0.472080536948808, 0.8795754]
# sequential model is trained. best val loss is: [0.2919411902391817, 0.88156587]
# sequential model is trained. best val loss is: [0.2577769979299018, 0.88665265]
# sequential model is trained. best val loss is: [0.22633703859601415, 0.89815325]
# sequential model is trained. best val loss is: [0.21546804990953514, 0.90412474]
# sequential model is trained. best val loss is: [0.20728279812191225, 0.9086586]
# sequential model is trained. best val loss is: [0.20773417510304001, 0.9087692]
# sequential model is trained. best val loss is: [0.21209962187674963, 0.90456706]
# sequential model is trained. best val loss is: [0.2761621209229962, 0.88388807]
# sequential model is trained. best val loss is: [0.22293032299927823, 0.9009178]
# sequential model is trained. best val loss is: [0.2177140603290384, 0.902466]
# sequential model is trained. best val loss is: [0.20575801412391936, 0.9087692]
# sequential model is trained. best val loss is: [0.286706882412687, 0.8825611]
# sequential model is trained. best val loss is: [0.2311141261330197, 0.8959416]
# sequential model is trained. best val loss is: [0.2232630063438658, 0.9009178]
# sequential model is trained. best val loss is: [0.21115602211958537, 0.90611523]
# sequential model is trained. best val loss is: [0.2096389681084367, 0.90677875]
# sequential model is trained. best val loss is: [0.21213295545960822, 0.9079951]
# sequential model is trained. best val loss is: [0.22024200312742997, 0.90478826]
# sequential model is trained. best val loss is: [0.25443889504049544, 0.8793542]
# sequential model is trained. best val loss is: [0.20923837246876908, 0.90534115]
# sequential model is trained. best val loss is: [0.21136605543174353, 0.90456706]
# sequential model is trained. best val loss is: [0.21340559106425191, 0.90036494]
# sequential model is trained. best val loss is: [0.24608409334228298, 0.8793542]
# sequential model is trained. best val loss is: [0.4189307055588806, 0.8793542]
# sequential model is trained. best val loss is: [0.2742965454306735, 0.88344574]
# sequential model is trained. best val loss is: [0.2483796189247369, 0.89240295]
# sequential model is trained. best val loss is: [0.22268327548284256, 0.90268713]
# sequential model is trained. best val loss is: [0.21093637929360293, 0.9066681]
# sequential model is trained. best val loss is: [0.21222152080365045, 0.9054517]
# sequential model is trained. best val loss is: [0.21196137382685445, 0.90534115]
# sequential model is trained. best val loss is: [0.2146131720912545, 0.9052306]
# sequential model is trained. best val loss is: [0.2721703641811172, 0.8845516]
# sequential model is trained. best val loss is: [0.22153058183426536, 0.9019131]
# sequential model is trained. best val loss is: [0.2147986136165114, 0.9046776]
# sequential model is trained. best val loss is: [0.20705784459985702, 0.9068893]
# sequential model is trained. best val loss is: [0.2985164200845683, 0.88145524]
# sequential model is trained. best val loss is: [0.23306293529996458, 0.89660513]
# sequential model is trained. best val loss is: [0.22313472931790798, 0.90136015]
# sequential model is trained. best val loss is: [0.2095597456293297, 0.9054517]
# sequential model is trained. best val loss is: [0.20670705419732027, 0.907774]
# sequential model is trained. best val loss is: [0.22331142165841986, 0.9068893]
# sequential model is trained. best val loss is: [0.21830763563597794, 0.90279776]
# sequential model is trained. best val loss is: [0.2449520970061858, 0.88864315]
# sequential model is trained. best val loss is: [0.21205940295884557, 0.9052306]
# sequential model is trained. best val loss is: [0.22024428816768668, 0.9032401]
# sequential model is trained. best val loss is: [0.2090407724594313, 0.9072211]
# sequential model is trained. best val loss is: [0.2363396955086148, 0.8793542]
# sequential model is trained. best val loss is: [0.3751373079436603, 0.8793542]
# sequential model is trained. best val loss is: [0.2502044177610342, 0.89306647]
# sequential model is trained. best val loss is: [0.23610787561123553, 0.8992591]
# sequential model is trained. best val loss is: [0.2172391876490997, 0.903793]
# sequential model is trained. best val loss is: [0.20735842030712504, 0.90832686]
# sequential model is trained. best val loss is: [0.21698344140720885, 0.90534115]
# sequential model is trained. best val loss is: [0.2141784776513402, 0.90390354]
# sequential model is trained. best val loss is: [0.21779307754683333, 0.90401417]
# sequential model is trained. best val loss is: [0.25447553930445527, 0.89107597]
# sequential model is trained. best val loss is: [0.21623279333417822, 0.9052306]
# sequential model is trained. best val loss is: [0.20996482698155178, 0.9072211]
# sequential model is trained. best val loss is: [0.20530846863606064, 0.90854806]
# sequential model is trained. best val loss is: [0.27966652544451986, 0.8839987]
# sequential model is trained. best val loss is: [0.22541488673944568, 0.9000332]
# sequential model is trained. best val loss is: [0.2178095501436539, 0.90357184]
# sequential model is trained. best val loss is: [0.20882444754844348, 0.9074422]
# sequential model is trained. best val loss is: [0.21045268539647857, 0.9052306]
# sequential model is trained. best val loss is: [0.24526211538963924, 0.9092115]
# sequential model is trained. best val loss is: [0.22203813378399326, 0.8987062]
# sequential model is trained. best val loss is: [0.2840045144715352, 0.8824505]
# sequential model is trained. best val loss is: [0.22138197908066126, 0.90534115]
# sequential model is trained. best val loss is: [0.21476460820104937, 0.9056729]
# sequential model is trained. best val loss is: [0.21281631414663288, 0.9034612]
# sequential model is trained. best val loss is: [0.24817177916632993, 0.8788013]
# sequential model is trained. best val loss is: [0.32391365781223747, 0.8793542]
# sequential model is trained. best val loss is: [0.24179866638091843, 0.8957204]
# sequential model is trained. best val loss is: [0.2296612222585137, 0.898485]
# sequential model is trained. best val loss is: [0.21388562675349207, 0.90556234]
# sequential model is trained. best val loss is: [0.2056709699770208, 0.9084375]
# sequential model is trained. best val loss is: [0.22863744852962872, 0.90058607]
# sequential model is trained. best val loss is: [0.22778998323079036, 0.9009178]
# sequential model is trained. best val loss is: [0.21930117521035017, 0.9036824]
# sequential model is trained. best val loss is: [0.2500309241064536, 0.889749]
# sequential model is trained. best val loss is: [0.21542595537655598, 0.90589404]
# sequential model is trained. best val loss is: [0.20998179751411156, 0.9066681]
# sequential model is trained. best val loss is: [0.2051363642086804, 0.9084375]
# sequential model is trained. best val loss is: [0.27293595060315606, 0.88466215]
# sequential model is trained. best val loss is: [0.22518233758981654, 0.8997014]
# sequential model is trained. best val loss is: [0.21781362843147015, 0.90589404]
# sequential model is trained. best val loss is: [0.20778144472048476, 0.9072211]
# sequential model is trained. best val loss is: [0.2230685868121401, 0.90711045]
# sequential model is trained. best val loss is: [0.23622234182640947, 0.90733165]
# sequential model is trained. best val loss is: [0.2442265737245242, 0.9012496]
# sequential model is trained. best val loss is: [0.4253840712527845, 0.8793542]
# sequential model is trained. best val loss is: [0.21040896994408737, 0.90711045]
# sequential model is trained. best val loss is: [0.2087608089782384, 0.90854806]
# sequential model is trained. best val loss is: [0.211200465463134, 0.9075528]
# sequential model is trained. best val loss is: [0.22270254064592312, 0.9010284]
# sequential model is trained. best val loss is: [0.6503306958813273, 0.8086918]
# sequential model is trained. best val loss is: [0.3162489120285028, 0.8793542]
# sequential model is trained. best val loss is: [0.2724703344790714, 0.88211876]
# sequential model is trained. best val loss is: [0.23076410366346467, 0.89638394]
# sequential model is trained. best val loss is: [0.22039783309086833, 0.9018025]
# sequential model is trained. best val loss is: [0.2108308950231677, 0.90589404]
# sequential model is trained. best val loss is: [0.21178843527719218, 0.90556234]
# sequential model is trained. best val loss is: [0.21521966526640948, 0.9050094]
# sequential model is trained. best val loss is: [0.3156244308432027, 0.8793542]
# sequential model is trained. best val loss is: [0.2261634512897035, 0.89881676]
# sequential model is trained. best val loss is: [0.21956946702047245, 0.90257657]
# sequential model is trained. best val loss is: [0.21026010286171298, 0.90511996]
# sequential model is trained. best val loss is: [0.32598208100424264, 0.8793542]
# sequential model is trained. best val loss is: [0.23402684339706606, 0.89361936]
# sequential model is trained. best val loss is: [0.22516289727423922, 0.89881676]
# sequential model is trained. best val loss is: [0.21367317463501911, 0.90556234]
# sequential model is trained. best val loss is: [0.21141054404397513, 0.907774]
# sequential model is trained. best val loss is: [0.21283598511300492, 0.9082163]
# sequential model is trained. best val loss is: [0.21439030012778051, 0.90788454]
# sequential model is trained. best val loss is: [0.27886905784392324, 0.8793542]
# sequential model is trained. best val loss is: [0.20526491801427368, 0.9087692]
# sequential model is trained. best val loss is: [0.2054706267467922, 0.90456706]
# sequential model is trained. best val loss is: [0.20658665241939916, 0.90832686]
# sequential model is trained. best val loss is: [0.23409044706332371, 0.8793542]
# sequential model is trained. best val loss is: [0.5215973005705566, 0.8793542]
# sequential model is trained. best val loss is: [0.2926466449506908, 0.8795754]
# sequential model is trained. best val loss is: [0.25342593536919544, 0.88731617]
# sequential model is trained. best val loss is: [0.2251993196306932, 0.8992591]
# sequential model is trained. best val loss is: [0.2157409043158101, 0.9042353]
# sequential model is trained. best val loss is: [0.206642145464197, 0.9092115]
# sequential model is trained. best val loss is: [0.20531569556906254, 0.90910095]
# sequential model is trained. best val loss is: [0.2146180956768117, 0.90268713]
# sequential model is trained. best val loss is: [0.28082175427776096, 0.88145524]
# sequential model is trained. best val loss is: [0.22227757151156127, 0.901139]
# sequential model is trained. best val loss is: [0.21684342177518237, 0.9032401]
# sequential model is trained. best val loss is: [0.20677307149246837, 0.9062258]
# sequential model is trained. best val loss is: [0.308300717457277, 0.8797965]
# sequential model is trained. best val loss is: [0.2292644267659344, 0.90058607]
# sequential model is trained. best val loss is: [0.22240863830909047, 0.9012496]
# sequential model is trained. best val loss is: [0.21267729254471812, 0.90534115]
# sequential model is trained. best val loss is: [0.21052458383704029, 0.9087692]
# sequential model is trained. best val loss is: [0.21453198475159072, 0.9086586]
# sequential model is trained. best val loss is: [0.22396850261648157, 0.9062258]
# sequential model is trained. best val loss is: [0.4208789589288263, 0.8793542]
# sequential model is trained. best val loss is: [0.2057171727813979, 0.90810573]
# sequential model is trained. best val loss is: [0.2084792857411081, 0.90633637]
# sequential model is trained. best val loss is: [0.21287589652617658, 0.9062258]
# sequential model is trained. best val loss is: [0.3038566522164299, 0.8793542]
# sequential model is trained. best val loss is: [0.3936769592146371, 0.8793542]
# sequential model is trained. best val loss is: [0.25728263102787385, 0.8875373]
# sequential model is trained. best val loss is: [0.23865826259365416, 0.8962734]
# sequential model is trained. best val loss is: [0.21876538563760708, 0.9044565]
# sequential model is trained. best val loss is: [0.20912499482107283, 0.90788454]
# sequential model is trained. best val loss is: [0.21389148888645426, 0.90456706]
# sequential model is trained. best val loss is: [0.21043606342552748, 0.90633637]
# sequential model is trained. best val loss is: [0.21411927710601902, 0.90390354]
# sequential model is trained. best val loss is: [0.25815812789087444, 0.8877585]
# sequential model is trained. best val loss is: [0.21757011033654752, 0.9048988]
# sequential model is trained. best val loss is: [0.2111562600339341, 0.90611523]
# sequential model is trained. best val loss is: [0.2066887612760983, 0.9068893]
# sequential model is trained. best val loss is: [0.2878407646066568, 0.88112354]
# sequential model is trained. best val loss is: [0.22566939627888272, 0.8972686]
# sequential model is trained. best val loss is: [0.21792382919378386, 0.9036824]
# sequential model is trained. best val loss is: [0.2094415422826824, 0.9057835]
# sequential model is trained. best val loss is: [0.2104431866386698, 0.9062258]
# sequential model is trained. best val loss is: [0.21377270690084202, 0.9075528]
# sequential model is trained. best val loss is: [0.21717451633268603, 0.90357184]
# sequential model is trained. best val loss is: [0.35469345446380646, 0.8952781]
# sequential model is trained. best val loss is: [0.21734022533262143, 0.90456706]
# sequential model is trained. best val loss is: [0.2151216072350968, 0.90600467]
# sequential model is trained. best val loss is: [0.21113797966574166, 0.903793]
# sequential model is trained. best val loss is: [0.36890673110749517, 0.8793542]
# sequential model is trained. best val loss is: [0.3645258963134428, 0.8793542]
# sequential model is trained. best val loss is: [0.24134832704988687, 0.8960522]
# sequential model is trained. best val loss is: [0.2290079644180354, 0.898485]
# sequential model is trained. best val loss is: [0.21239463498367483, 0.9072211]
# sequential model is trained. best val loss is: [0.20580757296706254, 0.91053855]
# sequential model is trained. best val loss is: [0.21677382457286637, 0.90589404]
# sequential model is trained. best val loss is: [0.2217188247877136, 0.906447]
# sequential model is trained. best val loss is: [0.21923960134490827, 0.90268713]
# sequential model is trained. best val loss is: [0.24576610985562086, 0.89306647]
# sequential model is trained. best val loss is: [0.21291432135284152, 0.9057835]
# sequential model is trained. best val loss is: [0.20846468591523964, 0.90611523]
# sequential model is trained. best val loss is: [0.2067681238422691, 0.90511996]
# sequential model is trained. best val loss is: [0.2754770421710252, 0.88466215]
# sequential model is trained. best val loss is: [0.22060428203028887, 0.9034612]
# sequential model is trained. best val loss is: [0.21451170673138878, 0.90456706]
# sequential model is trained. best val loss is: [0.20716403686577117, 0.90534115]
# sequential model is trained. best val loss is: [0.21252863563743032, 0.90677875]
# sequential model is trained. best val loss is: [0.2330041085936835, 0.9082163]
# sequential model is trained. best val loss is: [0.23100709088289223, 0.9046776]
# sequential model is trained. best val loss is: [0.3733580406492795, 0.8793542]
# sequential model is trained. best val loss is: [0.2386349135171282, 0.90080726]
# sequential model is trained. best val loss is: [0.20905520239920924, 0.906447]
# sequential model is trained. best val loss is: [0.21519210715150458, 0.906447]
# sequential model is trained. best val loss is: [0.36853096551182235, 0.8793542]
# sequential model is trained. best val loss is: [0.3261445944424977, 0.8793542]
# sequential model is trained. best val loss is: [0.23418880104820877, 0.89583105]
# sequential model is trained. best val loss is: [0.22389889988740513, 0.90025437]
# sequential model is trained. best val loss is: [0.20969968834150607, 0.90633637]
# sequential model is trained. best val loss is: [0.20958930064154635, 0.9052306]
# sequential model is trained. best val loss is: [0.23387288589149557, 0.903793]
# sequential model is trained. best val loss is: [0.21595959354657113, 0.9057835]
# sequential model is trained. best val loss is: [0.21736380930470509, 0.90412474]
# sequential model is trained. best val loss is: [0.24308617607320976, 0.8925136]
# sequential model is trained. best val loss is: [0.21153792528653717, 0.90611523]
# sequential model is trained. best val loss is: [0.2072290840974677, 0.9074422]
# sequential model is trained. best val loss is: [0.20679623168033928, 0.9066681]
# sequential model is trained. best val loss is: [0.27200484650859813, 0.88410926]
# sequential model is trained. best val loss is: [0.22101830221720004, 0.9006967]
# sequential model is trained. best val loss is: [0.21426334801493235, 0.9032401]
# sequential model is trained. best val loss is: [0.2067829327227122, 0.9074422]
# sequential model is trained. best val loss is: [0.23817209003180723, 0.907774]
# sequential model is trained. best val loss is: [0.24627513853135025, 0.907774]
# sequential model is trained. best val loss is: [0.2517835505370161, 0.9050094]
# sequential model is trained. best val loss is: [0.3733580406492795, 0.8793542]
# ==== 78.46580744981766 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 2, 'unit': 256, 'optimizer': 'adagrad', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info['hidden_layer']], units=[best_model_info['unit']],
         optimizers=[best_model_info['optimizer']], lrs=[best_model_info['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.2051363642086804, 0.9084375]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x163101fd0>],
#  [{'hidden_layer': 2, 'unit': 256, 'optimizer': 'adagrad', 'lr': 0.1}],
#  [0.2051363642086804])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.21242680515215273, 0.90478826]
# sequential model is trained. best val loss is: [0.21009428379784298, 0.90556234]
# sequential model is trained. best val loss is: [0.21144239450732283, 0.9068893]
# sequential model is trained. best val loss is: [0.2446262197303097, 0.8793542]
# sequential model is trained. best val loss is: [0.882838157924366, 0.23432489]
# sequential model is trained. best val loss is: [0.3366114530239856, 0.87968594]
# sequential model is trained. best val loss is: [0.2942232133691506, 0.8827823]
# sequential model is trained. best val loss is: [0.24234370459672375, 0.8952781]
# sequential model is trained. best val loss is: [0.2236219558959169, 0.9010284]
# sequential model is trained. best val loss is: [0.20942312111886718, 0.90655756]
# sequential model is trained. best val loss is: [0.21098227153161347, 0.9046776]
# sequential model is trained. best val loss is: [0.21297971119425088, 0.9009178]
# sequential model is trained. best val loss is: [0.33283859109385516, 0.88211876]
# sequential model is trained. best val loss is: [0.2338704295809865, 0.897158]
# sequential model is trained. best val loss is: [0.22478030864398563, 0.899812]
# sequential model is trained. best val loss is: [0.21338529729756134, 0.90257657]
# sequential model is trained. best val loss is: [0.28982119063657164, 0.8830034]
# sequential model is trained. best val loss is: [0.23773564492708338, 0.8952781]
# sequential model is trained. best val loss is: [0.22997264372396822, 0.89837444]
# sequential model is trained. best val loss is: [0.2191810391519524, 0.9022448]
# sequential model is trained. best val loss is: [0.21537050872754435, 0.90511996]
# sequential model is trained. best val loss is: [0.21104330329337137, 0.90556234]
# sequential model is trained. best val loss is: [0.21434451913024213, 0.90478826]
# sequential model is trained. best val loss is: [0.2491543838721546, 0.88665265]
# sequential model is trained. best val loss is: [0.21018746403298993, 0.9052306]
# sequential model is trained. best val loss is: [0.21630948550943963, 0.90456706]
# sequential model is trained. best val loss is: [0.21047232536751256, 0.90589404]
# sequential model is trained. best val loss is: [0.23205318740810768, 0.8790224]
# sequential model is trained. best val loss is: [0.5787608592196216, 0.7858012]
# sequential model is trained. best val loss is: [0.3229117590044632, 0.8795754]
# sequential model is trained. best val loss is: [0.2808284707648372, 0.88410926]
# sequential model is trained. best val loss is: [0.23604012412280356, 0.8985956]
# sequential model is trained. best val loss is: [0.2223865365106738, 0.9031295]
# sequential model is trained. best val loss is: [0.2093065888411332, 0.90534115]
# sequential model is trained. best val loss is: [0.20923644087093932, 0.9054517]
# sequential model is trained. best val loss is: [0.21838425806266576, 0.9014708]
# sequential model is trained. best val loss is: [0.305817791005883, 0.88145524]
# sequential model is trained. best val loss is: [0.23155998368976682, 0.90080726]
# sequential model is trained. best val loss is: [0.22341459129719585, 0.90213424]
# sequential model is trained. best val loss is: [0.21038675445655033, 0.9069999]
# sequential model is trained. best val loss is: [0.2994651760225023, 0.8832246]
# sequential model is trained. best val loss is: [0.23966386718493204, 0.8980427]
# sequential model is trained. best val loss is: [0.22929710867551792, 0.90025437]
# sequential model is trained. best val loss is: [0.21650698304795907, 0.90456706]
# sequential model is trained. best val loss is: [0.21547925946170166, 0.90235543]
# sequential model is trained. best val loss is: [0.21505273509958894, 0.9009178]
# sequential model is trained. best val loss is: [0.22890046178918885, 0.90478826]
# sequential model is trained. best val loss is: [0.32448623144928496, 0.88267165]
# sequential model is trained. best val loss is: [0.2085935598576898, 0.90589404]
# sequential model is trained. best val loss is: [0.21858312671563931, 0.9044565]
# sequential model is trained. best val loss is: [0.21405720469844325, 0.9075528]
# sequential model is trained. best val loss is: [0.2308936462483548, 0.8793542]
# sequential model is trained. best val loss is: [0.6169439334264571, 0.75572264]
# sequential model is trained. best val loss is: [0.29448762467829487, 0.8795754]
# sequential model is trained. best val loss is: [0.26099133327064505, 0.88886434]
# sequential model is trained. best val loss is: [0.22986610776408115, 0.899812]
# sequential model is trained. best val loss is: [0.21803657632940285, 0.90655756]
# sequential model is trained. best val loss is: [0.20921746189320337, 0.90733165]
# sequential model is trained. best val loss is: [0.21308774791512095, 0.90390354]
# sequential model is trained. best val loss is: [0.21424681456113012, 0.90235543]
# sequential model is trained. best val loss is: [0.28705188964539813, 0.88156587]
# sequential model is trained. best val loss is: [0.22691554645449005, 0.8999226]
# sequential model is trained. best val loss is: [0.22022071032546256, 0.9029083]
# sequential model is trained. best val loss is: [0.21002565278991667, 0.90611523]
# sequential model is trained. best val loss is: [0.28840394141623155, 0.8825611]
# sequential model is trained. best val loss is: [0.23488577066645822, 0.8967157]
# sequential model is trained. best val loss is: [0.22636462859277978, 0.89903796]
# sequential model is trained. best val loss is: [0.2152724388023268, 0.9044565]
# sequential model is trained. best val loss is: [0.2103473370770998, 0.90810573]
# sequential model is trained. best val loss is: [0.2256834393421343, 0.9048988]
# sequential model is trained. best val loss is: [0.22789010797390089, 0.9034612]
# sequential model is trained. best val loss is: [0.28645183141221253, 0.88665265]
# sequential model is trained. best val loss is: [0.20748589475321239, 0.9057835]
# sequential model is trained. best val loss is: [0.2132120081133433, 0.9082163]
# sequential model is trained. best val loss is: [0.2144227140207912, 0.90412474]
# sequential model is trained. best val loss is: [0.23566063165822862, 0.8818976]
# sequential model is trained. best val loss is: [0.48163676667263533, 0.87316155]
# sequential model is trained. best val loss is: [0.2751255791152748, 0.8832246]
# sequential model is trained. best val loss is: [0.2508766849714874, 0.8920712]
# sequential model is trained. best val loss is: [0.22551174832763995, 0.90158135]
# sequential model is trained. best val loss is: [0.21435584848820602, 0.9043459]
# sequential model is trained. best val loss is: [0.2089718011124767, 0.9056729]
# sequential model is trained. best val loss is: [0.21313666949675011, 0.90478826]
# sequential model is trained. best val loss is: [0.22478838429228995, 0.9018025]
# sequential model is trained. best val loss is: [0.2748334727481866, 0.8842198]
# sequential model is trained. best val loss is: [0.22470945094151926, 0.9010284]
# sequential model is trained. best val loss is: [0.21824640865467243, 0.90412474]
# sequential model is trained. best val loss is: [0.20807840453567303, 0.9066681]
# sequential model is trained. best val loss is: [0.2869920041179362, 0.8822293]
# sequential model is trained. best val loss is: [0.23352354585986004, 0.89837444]
# sequential model is trained. best val loss is: [0.22519221964180897, 0.9010284]
# sequential model is trained. best val loss is: [0.21219600704632988, 0.9057835]
# sequential model is trained. best val loss is: [0.20940468558613395, 0.90733165]
# sequential model is trained. best val loss is: [0.22388438564228508, 0.90589404]
# sequential model is trained. best val loss is: [0.2400849495500402, 0.90611523]
# sequential model is trained. best val loss is: [0.28702163939176506, 0.884441]
# sequential model is trained. best val loss is: [0.20795749623032253, 0.90611523]
# sequential model is trained. best val loss is: [0.21716417551343847, 0.9050094]
# sequential model is trained. best val loss is: [0.21430250483580585, 0.90534115]
# sequential model is trained. best val loss is: [0.2352788882828729, 0.8793542]
# sequential model is trained. best val loss is: [0.42543803803836117, 0.8793542]
# sequential model is trained. best val loss is: [0.26143973240886104, 0.8865421]
# sequential model is trained. best val loss is: [0.24390114492696693, 0.89439344]
# sequential model is trained. best val loss is: [0.2211990952162198, 0.903793]
# sequential model is trained. best val loss is: [0.210789367643906, 0.90655756]
# sequential model is trained. best val loss is: [0.21080467179722456, 0.90456706]
# sequential model is trained. best val loss is: [0.21332212317626614, 0.90456706]
# sequential model is trained. best val loss is: [0.2158190036135069, 0.90335065]
# sequential model is trained. best val loss is: [0.26643475074163253, 0.8864315]
# sequential model is trained. best val loss is: [0.22188732641652584, 0.9019131]
# sequential model is trained. best val loss is: [0.21624910186497917, 0.9046776]
# sequential model is trained. best val loss is: [0.2073225354569604, 0.9082163]
# sequential model is trained. best val loss is: [0.28076452202703606, 0.8833352]
# sequential model is trained. best val loss is: [0.2312852760325171, 0.8985956]
# sequential model is trained. best val loss is: [0.2233510488306647, 0.9004755]
# sequential model is trained. best val loss is: [0.2113828896375458, 0.9054517]
# sequential model is trained. best val loss is: [0.2095553558128249, 0.9062258]
# sequential model is trained. best val loss is: [0.23283796531627046, 0.903793]
# sequential model is trained. best val loss is: [0.2492927442270083, 0.90711045]
# sequential model is trained. best val loss is: [0.36983914433571796, 0.8818976]
# sequential model is trained. best val loss is: [0.2119671014357652, 0.9034612]
# sequential model is trained. best val loss is: [0.21203118592358974, 0.90456706]
# sequential model is trained. best val loss is: [0.21255104841416644, 0.90534115]
# sequential model is trained. best val loss is: [0.23467085946915253, 0.89439344]
# sequential model is trained. best val loss is: [0.5757752187244399, 0.8782484]
# sequential model is trained. best val loss is: [0.3417669644888874, 0.8793542]
# sequential model is trained. best val loss is: [0.29089740109525397, 0.88156587]
# sequential model is trained. best val loss is: [0.23329047389583066, 0.8949464]
# sequential model is trained. best val loss is: [0.22343580926873838, 0.9019131]
# sequential model is trained. best val loss is: [0.20996086150292445, 0.90511996]
# sequential model is trained. best val loss is: [0.20911928988275547, 0.9075528]
# sequential model is trained. best val loss is: [0.21021165830838817, 0.9068893]
# sequential model is trained. best val loss is: [0.31546937109661305, 0.8794648]
# sequential model is trained. best val loss is: [0.22810547033875414, 0.8980427]
# sequential model is trained. best val loss is: [0.2226421820910436, 0.90235543]
# sequential model is trained. best val loss is: [0.21119231708042127, 0.90478826]
# sequential model is trained. best val loss is: [0.3077215675322682, 0.87913305]
# sequential model is trained. best val loss is: [0.23618786441835565, 0.8927347]
# sequential model is trained. best val loss is: [0.2281996377680031, 0.8967157]
# sequential model is trained. best val loss is: [0.21728826086236144, 0.9029083]
# sequential model is trained. best val loss is: [0.21516815103433123, 0.90401417]
# sequential model is trained. best val loss is: [0.2132372692215829, 0.9066681]
# sequential model is trained. best val loss is: [0.21368681074810228, 0.90412474]
# sequential model is trained. best val loss is: [0.24463002701571832, 0.87437797]
# sequential model is trained. best val loss is: [0.20708354340643134, 0.90788454]
# sequential model is trained. best val loss is: [0.20827079332403464, 0.9056729]
# sequential model is trained. best val loss is: [0.20633550775099893, 0.9068893]
# sequential model is trained. best val loss is: [0.23323875491655757, 0.8793542]
# sequential model is trained. best val loss is: [0.472080536948808, 0.8795754]
# sequential model is trained. best val loss is: [0.2919411902391817, 0.88156587]
# sequential model is trained. best val loss is: [0.2577769979299018, 0.88665265]
# sequential model is trained. best val loss is: [0.22633703859601415, 0.89815325]
# sequential model is trained. best val loss is: [0.21546804990953514, 0.90412474]
# sequential model is trained. best val loss is: [0.20728279812191225, 0.9086586]
# sequential model is trained. best val loss is: [0.20773417510304001, 0.9087692]
# sequential model is trained. best val loss is: [0.21209962187674963, 0.90456706]
# sequential model is trained. best val loss is: [0.2761621209229962, 0.88388807]
# sequential model is trained. best val loss is: [0.22293032299927823, 0.9009178]
# sequential model is trained. best val loss is: [0.2177140603290384, 0.902466]
# sequential model is trained. best val loss is: [0.20575801412391936, 0.9087692]
# sequential model is trained. best val loss is: [0.286706882412687, 0.8825611]
# sequential model is trained. best val loss is: [0.2311141261330197, 0.8959416]
# sequential model is trained. best val loss is: [0.2232630063438658, 0.9009178]
# sequential model is trained. best val loss is: [0.21115602211958537, 0.90611523]
# sequential model is trained. best val loss is: [0.2096389681084367, 0.90677875]
# sequential model is trained. best val loss is: [0.21213295545960822, 0.9079951]
# sequential model is trained. best val loss is: [0.22024200312742997, 0.90478826]
# sequential model is trained. best val loss is: [0.25443889504049544, 0.8793542]
# sequential model is trained. best val loss is: [0.20923837246876908, 0.90534115]
# sequential model is trained. best val loss is: [0.21136605543174353, 0.90456706]
# sequential model is trained. best val loss is: [0.21340559106425191, 0.90036494]
# sequential model is trained. best val loss is: [0.24608409334228298, 0.8793542]
# sequential model is trained. best val loss is: [0.4189307055588806, 0.8793542]
# sequential model is trained. best val loss is: [0.2742965454306735, 0.88344574]
# sequential model is trained. best val loss is: [0.2483796189247369, 0.89240295]
# sequential model is trained. best val loss is: [0.22268327548284256, 0.90268713]
# sequential model is trained. best val loss is: [0.21093637929360293, 0.9066681]
# sequential model is trained. best val loss is: [0.21222152080365045, 0.9054517]
# sequential model is trained. best val loss is: [0.21196137382685445, 0.90534115]
# sequential model is trained. best val loss is: [0.2146131720912545, 0.9052306]
# sequential model is trained. best val loss is: [0.2721703641811172, 0.8845516]
# sequential model is trained. best val loss is: [0.22153058183426536, 0.9019131]
# sequential model is trained. best val loss is: [0.2147986136165114, 0.9046776]
# sequential model is trained. best val loss is: [0.20705784459985702, 0.9068893]
# sequential model is trained. best val loss is: [0.2985164200845683, 0.88145524]
# sequential model is trained. best val loss is: [0.23306293529996458, 0.89660513]
# sequential model is trained. best val loss is: [0.22313472931790798, 0.90136015]
# sequential model is trained. best val loss is: [0.2095597456293297, 0.9054517]
# sequential model is trained. best val loss is: [0.20670705419732027, 0.907774]
# sequential model is trained. best val loss is: [0.22331142165841986, 0.9068893]
# sequential model is trained. best val loss is: [0.21830763563597794, 0.90279776]
# sequential model is trained. best val loss is: [0.2449520970061858, 0.88864315]
# sequential model is trained. best val loss is: [0.21205940295884557, 0.9052306]
# sequential model is trained. best val loss is: [0.22024428816768668, 0.9032401]
# sequential model is trained. best val loss is: [0.2090407724594313, 0.9072211]
# sequential model is trained. best val loss is: [0.2363396955086148, 0.8793542]
# sequential model is trained. best val loss is: [0.3751373079436603, 0.8793542]
# sequential model is trained. best val loss is: [0.2502044177610342, 0.89306647]
# sequential model is trained. best val loss is: [0.23610787561123553, 0.8992591]
# sequential model is trained. best val loss is: [0.2172391876490997, 0.903793]
# sequential model is trained. best val loss is: [0.20735842030712504, 0.90832686]
# sequential model is trained. best val loss is: [0.21698344140720885, 0.90534115]
# sequential model is trained. best val loss is: [0.2141784776513402, 0.90390354]
# sequential model is trained. best val loss is: [0.21779307754683333, 0.90401417]
# sequential model is trained. best val loss is: [0.25447553930445527, 0.89107597]
# sequential model is trained. best val loss is: [0.21623279333417822, 0.9052306]
# sequential model is trained. best val loss is: [0.20996482698155178, 0.9072211]
# sequential model is trained. best val loss is: [0.20530846863606064, 0.90854806]
# sequential model is trained. best val loss is: [0.27966652544451986, 0.8839987]
# sequential model is trained. best val loss is: [0.22541488673944568, 0.9000332]
# sequential model is trained. best val loss is: [0.2178095501436539, 0.90357184]
# sequential model is trained. best val loss is: [0.20882444754844348, 0.9074422]
# sequential model is trained. best val loss is: [0.21045268539647857, 0.9052306]
# sequential model is trained. best val loss is: [0.24526211538963924, 0.9092115]
# sequential model is trained. best val loss is: [0.22203813378399326, 0.8987062]
# sequential model is trained. best val loss is: [0.2840045144715352, 0.8824505]
# sequential model is trained. best val loss is: [0.22138197908066126, 0.90534115]
# sequential model is trained. best val loss is: [0.21476460820104937, 0.9056729]
# sequential model is trained. best val loss is: [0.21281631414663288, 0.9034612]
# sequential model is trained. best val loss is: [0.24817177916632993, 0.8788013]
# sequential model is trained. best val loss is: [0.32391365781223747, 0.8793542]
# sequential model is trained. best val loss is: [0.24179866638091843, 0.8957204]
# sequential model is trained. best val loss is: [0.2296612222585137, 0.898485]
# sequential model is trained. best val loss is: [0.21388562675349207, 0.90556234]
# sequential model is trained. best val loss is: [0.2056709699770208, 0.9084375]
# sequential model is trained. best val loss is: [0.22863744852962872, 0.90058607]
# sequential model is trained. best val loss is: [0.22778998323079036, 0.9009178]
# sequential model is trained. best val loss is: [0.21930117521035017, 0.9036824]
# sequential model is trained. best val loss is: [0.2500309241064536, 0.889749]
# sequential model is trained. best val loss is: [0.21542595537655598, 0.90589404]
# sequential model is trained. best val loss is: [0.20998179751411156, 0.9066681]
# sequential model is trained. best val loss is: [0.2051363642086804, 0.9084375]
# sequential model is trained. best val loss is: [0.27293595060315606, 0.88466215]
# sequential model is trained. best val loss is: [0.22518233758981654, 0.8997014]
# sequential model is trained. best val loss is: [0.21781362843147015, 0.90589404]
# sequential model is trained. best val loss is: [0.20778144472048476, 0.9072211]
# sequential model is trained. best val loss is: [0.2230685868121401, 0.90711045]
# sequential model is trained. best val loss is: [0.23622234182640947, 0.90733165]
# sequential model is trained. best val loss is: [0.2442265737245242, 0.9012496]
# sequential model is trained. best val loss is: [0.4253840712527845, 0.8793542]
# sequential model is trained. best val loss is: [0.21040896994408737, 0.90711045]
# sequential model is trained. best val loss is: [0.2087608089782384, 0.90854806]
# sequential model is trained. best val loss is: [0.211200465463134, 0.9075528]
# sequential model is trained. best val loss is: [0.22270254064592312, 0.9010284]
# sequential model is trained. best val loss is: [0.6503306958813273, 0.8086918]
# sequential model is trained. best val loss is: [0.3162489120285028, 0.8793542]
# sequential model is trained. best val loss is: [0.2724703344790714, 0.88211876]
# sequential model is trained. best val loss is: [0.23076410366346467, 0.89638394]
# sequential model is trained. best val loss is: [0.22039783309086833, 0.9018025]
# sequential model is trained. best val loss is: [0.2108308950231677, 0.90589404]
# sequential model is trained. best val loss is: [0.21178843527719218, 0.90556234]
# sequential model is trained. best val loss is: [0.21521966526640948, 0.9050094]
# sequential model is trained. best val loss is: [0.3156244308432027, 0.8793542]
# sequential model is trained. best val loss is: [0.2261634512897035, 0.89881676]
# sequential model is trained. best val loss is: [0.21956946702047245, 0.90257657]
# sequential model is trained. best val loss is: [0.21026010286171298, 0.90511996]
# sequential model is trained. best val loss is: [0.32598208100424264, 0.8793542]
# sequential model is trained. best val loss is: [0.23402684339706606, 0.89361936]
# sequential model is trained. best val loss is: [0.22516289727423922, 0.89881676]
# sequential model is trained. best val loss is: [0.21367317463501911, 0.90556234]
# sequential model is trained. best val loss is: [0.21141054404397513, 0.907774]
# sequential model is trained. best val loss is: [0.21283598511300492, 0.9082163]
# sequential model is trained. best val loss is: [0.21439030012778051, 0.90788454]
# sequential model is trained. best val loss is: [0.27886905784392324, 0.8793542]
# sequential model is trained. best val loss is: [0.20526491801427368, 0.9087692]
# sequential model is trained. best val loss is: [0.2054706267467922, 0.90456706]
# sequential model is trained. best val loss is: [0.20658665241939916, 0.90832686]
# sequential model is trained. best val loss is: [0.23409044706332371, 0.8793542]
# sequential model is trained. best val loss is: [0.5215973005705566, 0.8793542]
# sequential model is trained. best val loss is: [0.2926466449506908, 0.8795754]
# sequential model is trained. best val loss is: [0.25342593536919544, 0.88731617]
# sequential model is trained. best val loss is: [0.2251993196306932, 0.8992591]
# sequential model is trained. best val loss is: [0.2157409043158101, 0.9042353]
# sequential model is trained. best val loss is: [0.206642145464197, 0.9092115]
# sequential model is trained. best val loss is: [0.20531569556906254, 0.90910095]
# sequential model is trained. best val loss is: [0.2146180956768117, 0.90268713]
# sequential model is trained. best val loss is: [0.28082175427776096, 0.88145524]
# sequential model is trained. best val loss is: [0.22227757151156127, 0.901139]
# sequential model is trained. best val loss is: [0.21684342177518237, 0.9032401]
# sequential model is trained. best val loss is: [0.20677307149246837, 0.9062258]
# sequential model is trained. best val loss is: [0.308300717457277, 0.8797965]
# sequential model is trained. best val loss is: [0.2292644267659344, 0.90058607]
# sequential model is trained. best val loss is: [0.22240863830909047, 0.9012496]
# sequential model is trained. best val loss is: [0.21267729254471812, 0.90534115]
# sequential model is trained. best val loss is: [0.21052458383704029, 0.9087692]
# sequential model is trained. best val loss is: [0.21453198475159072, 0.9086586]
# sequential model is trained. best val loss is: [0.22396850261648157, 0.9062258]
# sequential model is trained. best val loss is: [0.4208789589288263, 0.8793542]
# sequential model is trained. best val loss is: [0.2057171727813979, 0.90810573]
# sequential model is trained. best val loss is: [0.2084792857411081, 0.90633637]
# sequential model is trained. best val loss is: [0.21287589652617658, 0.9062258]
# sequential model is trained. best val loss is: [0.3038566522164299, 0.8793542]
# sequential model is trained. best val loss is: [0.3936769592146371, 0.8793542]
# sequential model is trained. best val loss is: [0.25728263102787385, 0.8875373]
# sequential model is trained. best val loss is: [0.23865826259365416, 0.8962734]
# sequential model is trained. best val loss is: [0.21876538563760708, 0.9044565]
# sequential model is trained. best val loss is: [0.20912499482107283, 0.90788454]
# sequential model is trained. best val loss is: [0.21389148888645426, 0.90456706]
# sequential model is trained. best val loss is: [0.21043606342552748, 0.90633637]
# sequential model is trained. best val loss is: [0.21411927710601902, 0.90390354]
# sequential model is trained. best val loss is: [0.25815812789087444, 0.8877585]
# sequential model is trained. best val loss is: [0.21757011033654752, 0.9048988]
# sequential model is trained. best val loss is: [0.2111562600339341, 0.90611523]
# sequential model is trained. best val loss is: [0.2066887612760983, 0.9068893]
# sequential model is trained. best val loss is: [0.2878407646066568, 0.88112354]
# sequential model is trained. best val loss is: [0.22566939627888272, 0.8972686]
# sequential model is trained. best val loss is: [0.21792382919378386, 0.9036824]
# sequential model is trained. best val loss is: [0.2094415422826824, 0.9057835]
# sequential model is trained. best val loss is: [0.2104431866386698, 0.9062258]
# sequential model is trained. best val loss is: [0.21377270690084202, 0.9075528]
# sequential model is trained. best val loss is: [0.21717451633268603, 0.90357184]
# sequential model is trained. best val loss is: [0.35469345446380646, 0.8952781]
# sequential model is trained. best val loss is: [0.21734022533262143, 0.90456706]
# sequential model is trained. best val loss is: [0.2151216072350968, 0.90600467]
# sequential model is trained. best val loss is: [0.21113797966574166, 0.903793]
# sequential model is trained. best val loss is: [0.36890673110749517, 0.8793542]
# sequential model is trained. best val loss is: [0.3645258963134428, 0.8793542]
# sequential model is trained. best val loss is: [0.24134832704988687, 0.8960522]
# sequential model is trained. best val loss is: [0.2290079644180354, 0.898485]
# sequential model is trained. best val loss is: [0.21239463498367483, 0.9072211]
# sequential model is trained. best val loss is: [0.20580757296706254, 0.91053855]
# sequential model is trained. best val loss is: [0.21677382457286637, 0.90589404]
# sequential model is trained. best val loss is: [0.2217188247877136, 0.906447]
# sequential model is trained. best val loss is: [0.21923960134490827, 0.90268713]
# sequential model is trained. best val loss is: [0.24576610985562086, 0.89306647]
# sequential model is trained. best val loss is: [0.21291432135284152, 0.9057835]
# sequential model is trained. best val loss is: [0.20846468591523964, 0.90611523]
# sequential model is trained. best val loss is: [0.2067681238422691, 0.90511996]
# sequential model is trained. best val loss is: [0.2754770421710252, 0.88466215]
# sequential model is trained. best val loss is: [0.22060428203028887, 0.9034612]
# sequential model is trained. best val loss is: [0.21451170673138878, 0.90456706]
# sequential model is trained. best val loss is: [0.20716403686577117, 0.90534115]
# sequential model is trained. best val loss is: [0.21252863563743032, 0.90677875]
# sequential model is trained. best val loss is: [0.2330041085936835, 0.9082163]
# sequential model is trained. best val loss is: [0.23100709088289223, 0.9046776]
# sequential model is trained. best val loss is: [0.3733580406492795, 0.8793542]
# sequential model is trained. best val loss is: [0.2386349135171282, 0.90080726]
# sequential model is trained. best val loss is: [0.20905520239920924, 0.906447]
# sequential model is trained. best val loss is: [0.21519210715150458, 0.906447]
# sequential model is trained. best val loss is: [0.36853096551182235, 0.8793542]
# sequential model is trained. best val loss is: [0.3261445944424977, 0.8793542]
# sequential model is trained. best val loss is: [0.23418880104820877, 0.89583105]
# sequential model is trained. best val loss is: [0.22389889988740513, 0.90025437]
# sequential model is trained. best val loss is: [0.20969968834150607, 0.90633637]
# sequential model is trained. best val loss is: [0.20958930064154635, 0.9052306]
# sequential model is trained. best val loss is: [0.23387288589149557, 0.903793]
# sequential model is trained. best val loss is: [0.21595959354657113, 0.9057835]
# sequential model is trained. best val loss is: [0.21736380930470509, 0.90412474]
# sequential model is trained. best val loss is: [0.24308617607320976, 0.8925136]
# sequential model is trained. best val loss is: [0.21153792528653717, 0.90611523]
# sequential model is trained. best val loss is: [0.2072290840974677, 0.9074422]
# sequential model is trained. best val loss is: [0.20679623168033928, 0.9066681]
# sequential model is trained. best val loss is: [0.27200484650859813, 0.88410926]
# sequential model is trained. best val loss is: [0.22101830221720004, 0.9006967]
# sequential model is trained. best val loss is: [0.21426334801493235, 0.9032401]
# sequential model is trained. best val loss is: [0.2067829327227122, 0.9074422]
# sequential model is trained. best val loss is: [0.23817209003180723, 0.907774]
# sequential model is trained. best val loss is: [0.24627513853135025, 0.907774]
# sequential model is trained. best val loss is: [0.2517835505370161, 0.9050094]
# sequential model is trained. best val loss is: [0.3733580406492795, 0.8793542]
# ==== 67.46812404791514 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 2, 'unit': 256, 'optimizer': 'adagrad', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info_2nd['hidden_layer']], units=[best_model_info_2nd['unit']],
         optimizers=[best_model_info_2nd['optimizer']], lrs=[best_model_info_2nd['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.2051363642086804, 0.9084375]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x1632cec50>],
#  [{'hidden_layer': 2, 'unit': 256, 'optimizer': 'adagrad', 'lr': 0.1}],
#  [0.2051363642086804])
