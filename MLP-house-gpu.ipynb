# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename="./data/sberbank_train_reduced_10k.csv"
ds = DataSource(filename)
ds.data_load_split(target=['price_doc'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [73454359412736.0, 73454359412736.0, 7172281.5]
# sequential model is trained. best val loss is: [72852912996352.0, 72852912996352.0, 7131515.0]
# sequential model is trained. best val loss is: [70723573907456.0, 70723573907456.0, 6983923.5]
# sequential model is trained. best val loss is: [37366504882176.0, 37366504882176.0, 4255566.0]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [73460306935808.0, 73460306935808.0, 7172667.0]
# sequential model is trained. best val loss is: [73452312592384.0, 73452312592384.0, 7172151.0]
# sequential model is trained. best val loss is: [73459157696512.0, 73459157696512.0, 7172586.0]
# sequential model is trained. best val loss is: [73359987572736.0, 73359987572736.0, 7165418.0]
# sequential model is trained. best val loss is: [73063970373632.0, 73063970373632.0, 7143971.0]
# sequential model is trained. best val loss is: [61065215868928.0, 61065215868928.0, 6180375.5]
# sequential model is trained. best val loss is: [73460298547200.0, 73460298547200.0, 7172666.0]
# sequential model is trained. best val loss is: [73458654380032.0, 73458654380032.0, 7172562.0]
# sequential model is trained. best val loss is: [73454132920320.0, 73454132920320.0, 7172255.5]
# sequential model is trained. best val loss is: [73302466887680.0, 73302466887680.0, 7161994.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73457186373632.0, 73457186373632.0, 7172465.5]
# sequential model is trained. best val loss is: [73191921811456.0, 73191921811456.0, 7154939.0]
# sequential model is trained. best val loss is: [72391204012032.0, 72391204012032.0, 7099970.0]
# sequential model is trained. best val loss is: [50436350410752.0, 50436350410752.0, 5551210.0]
# sequential model is trained. best val loss is: [73449032646656.0, 73449032646656.0, 7171939.0]
# sequential model is trained. best val loss is: [72228892835840.0, 72228892835840.0, 7092387.0]
# sequential model is trained. best val loss is: [68013122387968.0, 68013122387968.0, 6797090.5]
# sequential model is trained. best val loss is: [27313643192320.0, 27313643192320.0, 3368900.5]
# sequential model is trained. best val loss is: [73460340490240.0, 73460340490240.0, 7172668.0]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [73460273381376.0, 73460273381376.0, 7172665.5]
# sequential model is trained. best val loss is: [45759701450752.0, 45759701450752.0, 4545708.0]
# sequential model is trained. best val loss is: [73458226561024.0, 73458226561024.0, 7172524.0]
# sequential model is trained. best val loss is: [73275958886400.0, 73275958886400.0, 7159746.0]
# sequential model is trained. best val loss is: [72613065916416.0, 72613065916416.0, 7112083.5]
# sequential model is trained. best val loss is: [52961476608000.0, 52961476608000.0, 5536452.0]
# sequential model is trained. best val loss is: [73460264992768.0, 73460264992768.0, 7172664.5]
# sequential model is trained. best val loss is: [73457211539456.0, 73457211539456.0, 7172470.0]
# sequential model is trained. best val loss is: [73448487387136.0, 73448487387136.0, 7171893.0]
# sequential model is trained. best val loss is: [73093313724416.0, 73093313724416.0, 7148075.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73454543962112.0, 73454543962112.0, 7172295.0]
# sequential model is trained. best val loss is: [72888975622144.0, 72888975622144.0, 7134575.0]
# sequential model is trained. best val loss is: [71044303945728.0, 71044303945728.0, 7009206.0]
# sequential model is trained. best val loss is: [36568026841088.0, 36568026841088.0, 4214929.0]
# sequential model is trained. best val loss is: [73437330538496.0, 73437330538496.0, 7171176.5]
# sequential model is trained. best val loss is: [70839538024448.0, 70839538024448.0, 6997982.0]
# sequential model is trained. best val loss is: [63021737050112.0, 63021737050112.0, 6406367.5]
# sequential model is trained. best val loss is: [20720019046400.0, 20720019046400.0, 2730716.75]
# sequential model is trained. best val loss is: [73460340490240.0, 73460340490240.0, 7172668.5]
# sequential model is trained. best val loss is: [73460306935808.0, 73460306935808.0, 7172667.0]
# sequential model is trained. best val loss is: [73460264992768.0, 73460264992768.0, 7172664.5]
# sequential model is trained. best val loss is: [42386218549248.0, 42386218549248.0, 4200482.0]
# sequential model is trained. best val loss is: [73456506896384.0, 73456506896384.0, 7172399.5]
# sequential model is trained. best val loss is: [73050003341312.0, 73050003341312.0, 7143214.0]
# sequential model is trained. best val loss is: [71645305765888.0, 71645305765888.0, 7040434.5]
# sequential model is trained. best val loss is: [39680963772416.0, 39680963772416.0, 4213774.5]
# sequential model is trained. best val loss is: [73460239826944.0, 73460239826944.0, 7172662.5]
# sequential model is trained. best val loss is: [73454233583616.0, 73454233583616.0, 7172268.0]
# sequential model is trained. best val loss is: [73436625895424.0, 73436625895424.0, 7171091.5]
# sequential model is trained. best val loss is: [72700424880128.0, 72700424880128.0, 7121409.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73449292693504.0, 73449292693504.0, 7171938.5]
# sequential model is trained. best val loss is: [72293057298432.0, 72293057298432.0, 7093150.5]
# sequential model is trained. best val loss is: [68682197762048.0, 68682197762048.0, 6836829.0]
# sequential model is trained. best val loss is: [24925324705792.0, 24925324705792.0, 3078965.5]
# sequential model is trained. best val loss is: [73413683052544.0, 73413683052544.0, 7169674.0]
# sequential model is trained. best val loss is: [67844129685504.0, 67844129685504.0, 6787965.0]
# sequential model is trained. best val loss is: [55448489164800.0, 55448489164800.0, 5881834.5]
# sequential model is trained. best val loss is: [16283162640384.0, 16283162640384.0, 2381728.25]
# sequential model is trained. best val loss is: [73460340490240.0, 73460340490240.0, 7172668.0]
# sequential model is trained. best val loss is: [73460281769984.0, 73460281769984.0, 7172665.5]
# sequential model is trained. best val loss is: [73457689690112.0, 73457689690112.0, 7172462.5]
# sequential model is trained. best val loss is: [37293033259008.0, 37293033259008.0, 3676859.0]
# sequential model is trained. best val loss is: [73452866240512.0, 73452866240512.0, 7172152.0]
# sequential model is trained. best val loss is: [72612285775872.0, 72612285775872.0, 7111810.0]
# sequential model is trained. best val loss is: [69731981721600.0, 69731981721600.0, 6897324.0]
# sequential model is trained. best val loss is: [30438565347328.0, 30438565347328.0, 3430280.0]
# sequential model is trained. best val loss is: [73460155940864.0, 73460155940864.0, 7172657.5]
# sequential model is trained. best val loss is: [73448009236480.0, 73448009236480.0, 7171872.5]
# sequential model is trained. best val loss is: [73411015475200.0, 73411015475200.0, 7169416.5]
# sequential model is trained. best val loss is: [71926928113664.0, 71926928113664.0, 7067953.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73437070491648.0, 73437070491648.0, 7171147.5]
# sequential model is trained. best val loss is: [71028281704448.0, 71028281704448.0, 7005409.0]
# sequential model is trained. best val loss is: [63938653847552.0, 63938653847552.0, 6487765.5]
# sequential model is trained. best val loss is: [17753943572480.0, 17753943572480.0, 2523561.25]
# sequential model is trained. best val loss is: [73358637006848.0, 73358637006848.0, 7166040.5]
# sequential model is trained. best val loss is: [63062270803968.0, 63062270803968.0, 6430002.5]
# sequential model is trained. best val loss is: [45473410842624.0, 45473410842624.0, 5086481.0]
# sequential model is trained. best val loss is: [13796742529024.0, 13796742529024.0, 2112703.75]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [73459459686400.0, 73459459686400.0, 7172602.0]
# sequential model is trained. best val loss is: [72476239331328.0, 72476239331328.0, 7096102.5]
# sequential model is trained. best val loss is: [24713478799360.0, 24713478799360.0, 2899480.75]
# sequential model is trained. best val loss is: [73444855119872.0, 73444855119872.0, 7171576.0]
# sequential model is trained. best val loss is: [71609436078080.0, 71609436078080.0, 7038663.5]
# sequential model is trained. best val loss is: [65889667907584.0, 65889667907584.0, 6601138.0]
# sequential model is trained. best val loss is: [24969658499072.0, 24969658499072.0, 3013468.5]
# sequential model is trained. best val loss is: [73460055277568.0, 73460055277568.0, 7172648.5]
# sequential model is trained. best val loss is: [73434360971264.0, 73434360971264.0, 7170953.0]
# sequential model is trained. best val loss is: [73355180900352.0, 73355180900352.0, 7165739.5]
# sequential model is trained. best val loss is: [70441775398912.0, 70441775398912.0, 6969506.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73410956754944.0, 73410956754944.0, 7169395.5]
# sequential model is trained. best val loss is: [68486109855744.0, 68486109855744.0, 6824293.0]
# sequential model is trained. best val loss is: [56165840977920.0, 56165840977920.0, 5935501.5]
# sequential model is trained. best val loss is: [14370503393280.0, 14370503393280.0, 2190465.0]
# sequential model is trained. best val loss is: [73220392747008.0, 73220392747008.0, 7156679.0]
# sequential model is trained. best val loss is: [27464547958784.0, 27464547958784.0, 3287070.5]
# sequential model is trained. best val loss is: [15951112175616.0, 15951112175616.0, 2362236.75]
# sequential model is trained. best val loss is: [11486024957952.0, 11486024957952.0, 1786403.75]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460281769984.0, 73460281769984.0, 7172665.5]
# sequential model is trained. best val loss is: [11529091022848.0, 11529091022848.0, 1776878.625]
# sequential model is trained. best val loss is: [73448831320064.0, 73448831320064.0, 7171831.0]
# sequential model is trained. best val loss is: [65063759118336.0, 65063759118336.0, 6543440.0]
# sequential model is trained. best val loss is: [34080416595968.0, 34080416595968.0, 3727722.25]
# sequential model is trained. best val loss is: [13473196015616.0, 13473196015616.0, 2031569.5]
# sequential model is trained. best val loss is: [73460298547200.0, 73460298547200.0, 7172666.0]
# sequential model is trained. best val loss is: [73430669983744.0, 73430669983744.0, 7170602.0]
# sequential model is trained. best val loss is: [73236263993344.0, 73236263993344.0, 7157133.5]
# sequential model is trained. best val loss is: [51438210252800.0, 51438210252800.0, 5594640.5]
# sequential model is trained. best val loss is: [2.0910031100706816e+16, 2.0910031100706816e+16, 144526864.0]
# sequential model is trained. best val loss is: [22013324296192.0, 22013324296192.0, 2862760.0]
# sequential model is trained. best val loss is: [22013680812032.0, 22013680812032.0, 2871997.75]
# sequential model is trained. best val loss is: [22024479047680.0, 22024479047680.0, 2895539.5]
# sequential model is trained. best val loss is: [73418288398336.0, 73418288398336.0, 7169862.5]
# sequential model is trained. best val loss is: [45812369326080.0, 45812369326080.0, 5067978.0]
# sequential model is trained. best val loss is: [19194158514176.0, 19194158514176.0, 2624437.25]
# sequential model is trained. best val loss is: [11628428918784.0, 11628428918784.0, 1734562.5]
# sequential model is trained. best val loss is: [72584745975808.0, 72584745975808.0, 7115735.5]
# sequential model is trained. best val loss is: [17666825781248.0, 17666825781248.0, 2499735.0]
# sequential model is trained. best val loss is: [12969067937792.0, 12969067937792.0, 1947394.25]
# sequential model is trained. best val loss is: [11372361416704.0, 11372361416704.0, 1772418.375]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460306935808.0, 73460306935808.0, 7172667.0]
# sequential model is trained. best val loss is: [40549344083968.0, 40549344083968.0, 4016483.5]
# sequential model is trained. best val loss is: [11065206243328.0, 11065206243328.0, 1731451.125]
# sequential model is trained. best val loss is: [73420955975680.0, 73420955975680.0, 7169948.5]
# sequential model is trained. best val loss is: [44941942194176.0, 44941942194176.0, 4813560.5]
# sequential model is trained. best val loss is: [25437426155520.0, 25437426155520.0, 3046459.5]
# sequential model is trained. best val loss is: [12325748736000.0, 12325748736000.0, 1823547.625]
# sequential model is trained. best val loss is: [73460181106688.0, 73460181106688.0, 7172658.0]
# sequential model is trained. best val loss is: [73343621398528.0, 73343621398528.0, 7165148.5]
# sequential model is trained. best val loss is: [72558187642880.0, 72558187642880.0, 7113622.5]
# sequential model is trained. best val loss is: [33521762566144.0, 33521762566144.0, 3872864.25]
# sequential model is trained. best val loss is: [6.196541302977331e+16, 6.196541302977331e+16, 248884336.0]
# sequential model is trained. best val loss is: [22013326393344.0, 22013326393344.0, 2862723.25]
# sequential model is trained. best val loss is: [22013680812032.0, 22013680812032.0, 2871997.75]
# sequential model is trained. best val loss is: [22024479047680.0, 22024479047680.0, 2895539.5]
# sequential model is trained. best val loss is: [73302005514240.0, 73302005514240.0, 7162440.5]
# sequential model is trained. best val loss is: [25996503810048.0, 25996503810048.0, 3149085.25]
# sequential model is trained. best val loss is: [13842638700544.0, 13842638700544.0, 2095846.875]
# sequential model is trained. best val loss is: [11266351431680.0, 11266351431680.0, 1693700.0]
# sequential model is trained. best val loss is: [70158898954240.0, 70158898954240.0, 6947919.5]
# sequential model is trained. best val loss is: [14001102651392.0, 14001102651392.0, 2124614.25]
# sequential model is trained. best val loss is: [12025872777216.0, 12025872777216.0, 1802156.125]
# sequential model is trained. best val loss is: [11560733900800.0, 11560733900800.0, 1786528.75]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460214661120.0, 73460214661120.0, 7172660.5]
# sequential model is trained. best val loss is: [11119505702912.0, 11119505702912.0, 1765166.0]
# sequential model is trained. best val loss is: [10864735289344.0, 10864735289344.0, 1703448.125]
# sequential model is trained. best val loss is: [73299262439424.0, 73299262439424.0, 7161124.0]
# sequential model is trained. best val loss is: [29081865289728.0, 29081865289728.0, 3338873.0]
# sequential model is trained. best val loss is: [19319979245568.0, 19319979245568.0, 2632413.0]
# sequential model is trained. best val loss is: [11637972008960.0, 11637972008960.0, 1747722.375]
# sequential model is trained. best val loss is: [73459736510464.0, 73459736510464.0, 7172628.5]
# sequential model is trained. best val loss is: [73021750509568.0, 73021750509568.0, 7143762.5]
# sequential model is trained. best val loss is: [70050446835712.0, 70050446835712.0, 6938985.0]
# sequential model is trained. best val loss is: [22407221870592.0, 22407221870592.0, 2872056.75]
# sequential model is trained. best val loss is: [4.2838280187944804e+22, 4.2838280187944804e+22, 206974173184.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72840229421056.0, 72840229421056.0, 7131835.5]
# sequential model is trained. best val loss is: [16545614921728.0, 16545614921728.0, 2412024.5]
# sequential model is trained. best val loss is: [12346823016448.0, 12346823016448.0, 1838289.5]
# sequential model is trained. best val loss is: [11063631282176.0, 11063631282176.0, 1665250.75]
# sequential model is trained. best val loss is: [61691761000448.0, 61691761000448.0, 6379486.0]
# sequential model is trained. best val loss is: [12169269739520.0, 12169269739520.0, 1841784.25]
# sequential model is trained. best val loss is: [11466172268544.0, 11466172268544.0, 1755249.125]
# sequential model is trained. best val loss is: [11919977086976.0, 11919977086976.0, 1809710.625]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [11139593273344.0, 11139593273344.0, 1749937.25]
# sequential model is trained. best val loss is: [10877859266560.0, 10877859266560.0, 1708041.125]
# sequential model is trained. best val loss is: [10869435006976.0, 10869435006976.0, 1683691.375]
# sequential model is trained. best val loss is: [72816061841408.0, 72816061841408.0, 7127666.0]
# sequential model is trained. best val loss is: [21532973727744.0, 21532973727744.0, 2780937.5]
# sequential model is trained. best val loss is: [14225755865088.0, 14225755865088.0, 2153776.25]
# sequential model is trained. best val loss is: [11439537389568.0, 11439537389568.0, 1752480.5]
# sequential model is trained. best val loss is: [73457656135680.0, 73457656135680.0, 7172496.0]
# sequential model is trained. best val loss is: [71568793272320.0, 71568793272320.0, 7048149.5]
# sequential model is trained. best val loss is: [61376185761792.0, 61376185761792.0, 6338619.5]
# sequential model is trained. best val loss is: [15174206488576.0, 15174206488576.0, 2279456.0]
# sequential model is trained. best val loss is: [2.0328771969708615e+20, 2.0328771969708615e+20, 14257898496.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [70887764131840.0, 70887764131840.0, 7004590.5]
# sequential model is trained. best val loss is: [12619552391168.0, 12619552391168.0, 1905644.0]
# sequential model is trained. best val loss is: [11716573265920.0, 11716573265920.0, 1743336.375]
# sequential model is trained. best val loss is: [11029365915648.0, 11029365915648.0, 1643648.625]
# sequential model is trained. best val loss is: [45254719832064.0, 45254719832064.0, 5093600.5]
# sequential model is trained. best val loss is: [11605399044096.0, 11605399044096.0, 1764387.625]
# sequential model is trained. best val loss is: [11315150061568.0, 11315150061568.0, 1772015.5]
# sequential model is trained. best val loss is: [12476989046784.0, 12476989046784.0, 1865203.75]
# sequential model is trained. best val loss is: [73460323713024.0, 73460323713024.0, 7172668.0]
# sequential model is trained. best val loss is: [10882038890496.0, 10882038890496.0, 1724404.25]
# sequential model is trained. best val loss is: [10741119713280.0, 10741119713280.0, 1686104.25]
# sequential model is trained. best val loss is: [10847288033280.0, 10847288033280.0, 1675831.625]
# sequential model is trained. best val loss is: [70958530428928.0, 70958530428928.0, 6993644.5]
# sequential model is trained. best val loss is: [16073521889280.0, 16073521889280.0, 2377800.5]
# sequential model is trained. best val loss is: [12376881496064.0, 12376881496064.0, 1878881.875]
# sequential model is trained. best val loss is: [11452575383552.0, 11452575383552.0, 1773531.125]
# sequential model is trained. best val loss is: [73451163353088.0, 73451163353088.0, 7172065.0]
# sequential model is trained. best val loss is: [66765254033408.0, 66765254033408.0, 6709309.0]
# sequential model is trained. best val loss is: [46945720598528.0, 46945720598528.0, 5266084.5]
# sequential model is trained. best val loss is: [12609058242560.0, 12609058242560.0, 1949188.25]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [64400278945792.0, 64400278945792.0, 6537945.0]
# sequential model is trained. best val loss is: [11856341106688.0, 11856341106688.0, 1773130.75]
# sequential model is trained. best val loss is: [11367632338944.0, 11367632338944.0, 1705400.625]
# sequential model is trained. best val loss is: [11134473076736.0, 11134473076736.0, 1647449.125]
# sequential model is trained. best val loss is: [62257996234752.0, 62257996234752.0, 6349382.0]
# sequential model is trained. best val loss is: [12247515529216.0, 12247515529216.0, 1817135.125]
# sequential model is trained. best val loss is: [11358174183424.0, 11358174183424.0, 1758397.25]
# sequential model is trained. best val loss is: [12339430555648.0, 12339430555648.0, 1839536.625]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172667.0]
# sequential model is trained. best val loss is: [11697746083840.0, 11697746083840.0, 1847632.875]
# sequential model is trained. best val loss is: [10837578219520.0, 10837578219520.0, 1701961.75]
# sequential model is trained. best val loss is: [73302223618048.0, 73302223618048.0, 7161111.0]
# sequential model is trained. best val loss is: [21498685292544.0, 21498685292544.0, 2776424.5]
# sequential model is trained. best val loss is: [13767487258624.0, 13767487258624.0, 2065512.75]
# sequential model is trained. best val loss is: [11411368443904.0, 11411368443904.0, 1757829.0]
# sequential model is trained. best val loss is: [73460231438336.0, 73460231438336.0, 7172661.0]
# sequential model is trained. best val loss is: [72579226271744.0, 72579226271744.0, 7113505.5]
# sequential model is trained. best val loss is: [61879749705728.0, 61879749705728.0, 6352922.0]
# sequential model is trained. best val loss is: [14363525120000.0, 14363525120000.0, 2186190.25]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72653264125952.0, 72653264125952.0, 7117107.5]
# sequential model is trained. best val loss is: [12660945977344.0, 12660945977344.0, 1873549.625]
# sequential model is trained. best val loss is: [11747797762048.0, 11747797762048.0, 1737219.5]
# sequential model is trained. best val loss is: [11067370504192.0, 11067370504192.0, 1669413.125]
# sequential model is trained. best val loss is: [34675884032000.0, 34675884032000.0, 3937321.25]
# sequential model is trained. best val loss is: [11601273946112.0, 11601273946112.0, 1746185.625]
# sequential model is trained. best val loss is: [11417539313664.0, 11417539313664.0, 1759520.75]
# sequential model is trained. best val loss is: [12358769442816.0, 12358769442816.0, 1859148.25]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460273381376.0, 73460273381376.0, 7172665.5]
# sequential model is trained. best val loss is: [11214449016832.0, 11214449016832.0, 1800340.875]
# sequential model is trained. best val loss is: [11197415948288.0, 11197415948288.0, 1718794.375]
# sequential model is trained. best val loss is: [72251558854656.0, 72251558854656.0, 7085824.0]
# sequential model is trained. best val loss is: [14552049647616.0, 14552049647616.0, 2183703.25]
# sequential model is trained. best val loss is: [12090947403776.0, 12090947403776.0, 1809095.625]
# sequential model is trained. best val loss is: [11563493752832.0, 11563493752832.0, 1778317.0]
# sequential model is trained. best val loss is: [73459635847168.0, 73459635847168.0, 7172622.5]
# sequential model is trained. best val loss is: [65524566327296.0, 65524566327296.0, 6599087.5]
# sequential model is trained. best val loss is: [33797139595264.0, 33797139595264.0, 3872921.75]
# sequential model is trained. best val loss is: [12029756702720.0, 12029756702720.0, 1867621.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [66619531329536.0, 66619531329536.0, 6688107.5]
# sequential model is trained. best val loss is: [11760005283840.0, 11760005283840.0, 1742709.375]
# sequential model is trained. best val loss is: [11323083587584.0, 11323083587584.0, 1694072.125]
# sequential model is trained. best val loss is: [11114684350464.0, 11114684350464.0, 1681695.375]
# sequential model is trained. best val loss is: [21382521946112.0, 21382521946112.0, 2768727.75]
# sequential model is trained. best val loss is: [11367321960448.0, 11367321960448.0, 1749504.75]
# sequential model is trained. best val loss is: [11781818810368.0, 11781818810368.0, 1782503.875]
# sequential model is trained. best val loss is: [11121545183232.0, 11121545183232.0, 1758979.75]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [11091144867840.0, 11091144867840.0, 1738424.125]
# sequential model is trained. best val loss is: [10977563115520.0, 10977563115520.0, 1675817.5]
# sequential model is trained. best val loss is: [10973741056000.0, 10973741056000.0, 1695600.75]
# sequential model is trained. best val loss is: [63822899445760.0, 63822899445760.0, 6431282.5]
# sequential model is trained. best val loss is: [12547156606976.0, 12547156606976.0, 1869179.0]
# sequential model is trained. best val loss is: [11727891595264.0, 11727891595264.0, 1745961.375]
# sequential model is trained. best val loss is: [11827570278400.0, 11827570278400.0, 1789806.875]
# sequential model is trained. best val loss is: [73453554106368.0, 73453554106368.0, 7172215.0]
# sequential model is trained. best val loss is: [43049807773696.0, 43049807773696.0, 4826247.5]
# sequential model is trained. best val loss is: [20717596835840.0, 20717596835840.0, 2742279.25]
# sequential model is trained. best val loss is: [11816948203520.0, 11816948203520.0, 1783754.875]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [41116309127168.0, 41116309127168.0, 4612505.5]
# sequential model is trained. best val loss is: [11408165044224.0, 11408165044224.0, 1699782.625]
# sequential model is trained. best val loss is: [11191608934400.0, 11191608934400.0, 1671381.25]
# sequential model is trained. best val loss is: [11153021337600.0, 11153021337600.0, 1738328.125]
# sequential model is trained. best val loss is: [14618770538496.0, 14618770538496.0, 2228909.75]
# sequential model is trained. best val loss is: [11570675449856.0, 11570675449856.0, 1763175.0]
# sequential model is trained. best val loss is: [12382469357568.0, 12382469357568.0, 1834263.0]
# sequential model is trained. best val loss is: [11336557789184.0, 11336557789184.0, 1921346.75]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [11031454679040.0, 11031454679040.0, 1684665.625]
# sequential model is trained. best val loss is: [11134050500608.0, 11134050500608.0, 1686485.125]
# sequential model is trained. best val loss is: [11018123083776.0, 11018123083776.0, 1680899.75]
# sequential model is trained. best val loss is: [39193761808384.0, 39193761808384.0, 4350768.0]
# sequential model is trained. best val loss is: [11806503337984.0, 11806503337984.0, 1754403.0]
# sequential model is trained. best val loss is: [11400317501440.0, 11400317501440.0, 1742592.5]
# sequential model is trained. best val loss is: [12367345745920.0, 12367345745920.0, 1818859.875]
# sequential model is trained. best val loss is: [73406485626880.0, 73406485626880.0, 7169218.5]
# sequential model is trained. best val loss is: [24304328638464.0, 24304328638464.0, 3018875.75]
# sequential model is trained. best val loss is: [14716186394624.0, 14716186394624.0, 2229781.25]
# sequential model is trained. best val loss is: [11401395437568.0, 11401395437568.0, 1716194.375]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [20702340055040.0, 20702340055040.0, 2749576.0]
# sequential model is trained. best val loss is: [11217230888960.0, 11217230888960.0, 1679869.5]
# sequential model is trained. best val loss is: [11091205685248.0, 11091205685248.0, 1658047.25]
# sequential model is trained. best val loss is: [10771307167744.0, 10771307167744.0, 1751918.875]
# sequential model is trained. best val loss is: [12264221442048.0, 12264221442048.0, 1861419.625]
# sequential model is trained. best val loss is: [12170261692416.0, 12170261692416.0, 1810102.125]
# sequential model is trained. best val loss is: [12373948628992.0, 12373948628992.0, 1845901.625]
# sequential model is trained. best val loss is: [12699280867328.0, 12699280867328.0, 2257760.25]
# sequential model is trained. best val loss is: [73460323713024.0, 73460323713024.0, 7172667.0]
# sequential model is trained. best val loss is: [11069760208896.0, 11069760208896.0, 1690580.5]
# sequential model is trained. best val loss is: [10971446771712.0, 10971446771712.0, 1681979.875]
# sequential model is trained. best val loss is: [11005454188544.0, 11005454188544.0, 1681781.0]
# sequential model is trained. best val loss is: [24519137820672.0, 24519137820672.0, 2992807.75]
# sequential model is trained. best val loss is: [11407669067776.0, 11407669067776.0, 1731579.25]
# sequential model is trained. best val loss is: [11417736445952.0, 11417736445952.0, 1758484.0]
# sequential model is trained. best val loss is: [12275693912064.0, 12275693912064.0, 1824852.25]
# sequential model is trained. best val loss is: [73021440131072.0, 73021440131072.0, 7143548.5]
# sequential model is trained. best val loss is: [16122030063616.0, 16122030063616.0, 2386962.5]
# sequential model is trained. best val loss is: [12351720914944.0, 12351720914944.0, 1894055.875]
# sequential model is trained. best val loss is: [11004604841984.0, 11004604841984.0, 1673034.375]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [13300069826560.0, 13300069826560.0, 2022677.25]
# sequential model is trained. best val loss is: [11090668814336.0, 11090668814336.0, 1653768.5]
# sequential model is trained. best val loss is: [11062100361216.0, 11062100361216.0, 1657736.625]
# sequential model is trained. best val loss is: [9813832499200.0, 9813832499200.0, 1673983.5]
# ==== 10.23136138121287 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info['hidden_layer']], units=[best_model_info['unit']],
         optimizers=[best_model_info['optimizer']], lrs=[best_model_info['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [9912329437184.0, 9912329437184.0, 1669315.0]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7fb21fd92e10>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}],
#  [9912329437184.0])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [73454359412736.0, 73454359412736.0, 7172281.5]
# sequential model is trained. best val loss is: [72852912996352.0, 72852912996352.0, 7131515.0]
# sequential model is trained. best val loss is: [70723573907456.0, 70723573907456.0, 6983923.5]
# sequential model is trained. best val loss is: [37366504882176.0, 37366504882176.0, 4255566.0]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [73460306935808.0, 73460306935808.0, 7172667.0]
# sequential model is trained. best val loss is: [73452312592384.0, 73452312592384.0, 7172151.0]
# sequential model is trained. best val loss is: [73459157696512.0, 73459157696512.0, 7172586.0]
# sequential model is trained. best val loss is: [73359987572736.0, 73359987572736.0, 7165418.0]
# sequential model is trained. best val loss is: [73063970373632.0, 73063970373632.0, 7143971.0]
# sequential model is trained. best val loss is: [61065215868928.0, 61065215868928.0, 6180375.5]
# sequential model is trained. best val loss is: [73460298547200.0, 73460298547200.0, 7172666.0]
# sequential model is trained. best val loss is: [73458654380032.0, 73458654380032.0, 7172562.0]
# sequential model is trained. best val loss is: [73454132920320.0, 73454132920320.0, 7172255.5]
# sequential model is trained. best val loss is: [73302466887680.0, 73302466887680.0, 7161994.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73457186373632.0, 73457186373632.0, 7172465.5]
# sequential model is trained. best val loss is: [73191921811456.0, 73191921811456.0, 7154939.0]
# sequential model is trained. best val loss is: [72391204012032.0, 72391204012032.0, 7099970.0]
# sequential model is trained. best val loss is: [50436350410752.0, 50436350410752.0, 5551210.0]
# sequential model is trained. best val loss is: [73449032646656.0, 73449032646656.0, 7171939.0]
# sequential model is trained. best val loss is: [72228892835840.0, 72228892835840.0, 7092387.0]
# sequential model is trained. best val loss is: [68013122387968.0, 68013122387968.0, 6797090.5]
# sequential model is trained. best val loss is: [27313643192320.0, 27313643192320.0, 3368900.5]
# sequential model is trained. best val loss is: [73460340490240.0, 73460340490240.0, 7172668.0]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [73460273381376.0, 73460273381376.0, 7172665.5]
# sequential model is trained. best val loss is: [45759701450752.0, 45759701450752.0, 4545708.0]
# sequential model is trained. best val loss is: [73458226561024.0, 73458226561024.0, 7172524.0]
# sequential model is trained. best val loss is: [73275958886400.0, 73275958886400.0, 7159746.0]
# sequential model is trained. best val loss is: [72613065916416.0, 72613065916416.0, 7112083.5]
# sequential model is trained. best val loss is: [52961476608000.0, 52961476608000.0, 5536452.0]
# sequential model is trained. best val loss is: [73460264992768.0, 73460264992768.0, 7172664.5]
# sequential model is trained. best val loss is: [73457211539456.0, 73457211539456.0, 7172470.0]
# sequential model is trained. best val loss is: [73448487387136.0, 73448487387136.0, 7171893.0]
# sequential model is trained. best val loss is: [73093313724416.0, 73093313724416.0, 7148075.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73454543962112.0, 73454543962112.0, 7172295.0]
# sequential model is trained. best val loss is: [72888975622144.0, 72888975622144.0, 7134575.0]
# sequential model is trained. best val loss is: [71044303945728.0, 71044303945728.0, 7009206.0]
# sequential model is trained. best val loss is: [36568026841088.0, 36568026841088.0, 4214929.0]
# sequential model is trained. best val loss is: [73437330538496.0, 73437330538496.0, 7171176.5]
# sequential model is trained. best val loss is: [70839538024448.0, 70839538024448.0, 6997982.0]
# sequential model is trained. best val loss is: [63021737050112.0, 63021737050112.0, 6406367.5]
# sequential model is trained. best val loss is: [20720019046400.0, 20720019046400.0, 2730716.75]
# sequential model is trained. best val loss is: [73460340490240.0, 73460340490240.0, 7172668.5]
# sequential model is trained. best val loss is: [73460306935808.0, 73460306935808.0, 7172667.0]
# sequential model is trained. best val loss is: [73460264992768.0, 73460264992768.0, 7172664.5]
# sequential model is trained. best val loss is: [42386214354944.0, 42386214354944.0, 4200481.5]
# sequential model is trained. best val loss is: [73456506896384.0, 73456506896384.0, 7172399.5]
# sequential model is trained. best val loss is: [73050003341312.0, 73050003341312.0, 7143214.0]
# sequential model is trained. best val loss is: [71645305765888.0, 71645305765888.0, 7040434.5]
# sequential model is trained. best val loss is: [39680963772416.0, 39680963772416.0, 4213774.5]
# sequential model is trained. best val loss is: [73460239826944.0, 73460239826944.0, 7172662.5]
# sequential model is trained. best val loss is: [73454233583616.0, 73454233583616.0, 7172268.0]
# sequential model is trained. best val loss is: [73436625895424.0, 73436625895424.0, 7171091.5]
# sequential model is trained. best val loss is: [72700424880128.0, 72700424880128.0, 7121409.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73449292693504.0, 73449292693504.0, 7171938.5]
# sequential model is trained. best val loss is: [72293057298432.0, 72293057298432.0, 7093150.5]
# sequential model is trained. best val loss is: [68682197762048.0, 68682197762048.0, 6836829.0]
# sequential model is trained. best val loss is: [24925322608640.0, 24925322608640.0, 3078965.5]
# sequential model is trained. best val loss is: [73413683052544.0, 73413683052544.0, 7169674.0]
# sequential model is trained. best val loss is: [67844129685504.0, 67844129685504.0, 6787965.0]
# sequential model is trained. best val loss is: [55448489164800.0, 55448489164800.0, 5881834.5]
# sequential model is trained. best val loss is: [16283162640384.0, 16283162640384.0, 2381728.0]
# sequential model is trained. best val loss is: [73460340490240.0, 73460340490240.0, 7172668.0]
# sequential model is trained. best val loss is: [73460281769984.0, 73460281769984.0, 7172665.5]
# sequential model is trained. best val loss is: [73457689690112.0, 73457689690112.0, 7172462.5]
# sequential model is trained. best val loss is: [37293029064704.0, 37293029064704.0, 3676858.25]
# sequential model is trained. best val loss is: [73452866240512.0, 73452866240512.0, 7172152.0]
# sequential model is trained. best val loss is: [72612285775872.0, 72612285775872.0, 7111810.0]
# sequential model is trained. best val loss is: [69731981721600.0, 69731981721600.0, 6897324.0]
# sequential model is trained. best val loss is: [30438565347328.0, 30438565347328.0, 3430280.0]
# sequential model is trained. best val loss is: [73460155940864.0, 73460155940864.0, 7172657.5]
# sequential model is trained. best val loss is: [73448009236480.0, 73448009236480.0, 7171872.5]
# sequential model is trained. best val loss is: [73411015475200.0, 73411015475200.0, 7169416.5]
# sequential model is trained. best val loss is: [71926928113664.0, 71926928113664.0, 7067953.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73437070491648.0, 73437070491648.0, 7171147.5]
# sequential model is trained. best val loss is: [71028281704448.0, 71028281704448.0, 7005409.0]
# sequential model is trained. best val loss is: [63938653847552.0, 63938653847552.0, 6487765.5]
# sequential model is trained. best val loss is: [17753941475328.0, 17753941475328.0, 2523561.25]
# sequential model is trained. best val loss is: [73358637006848.0, 73358637006848.0, 7166040.5]
# sequential model is trained. best val loss is: [63062270803968.0, 63062270803968.0, 6430002.5]
# sequential model is trained. best val loss is: [45473410842624.0, 45473410842624.0, 5086481.0]
# sequential model is trained. best val loss is: [13796742529024.0, 13796742529024.0, 2112703.75]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [73459459686400.0, 73459459686400.0, 7172602.0]
# sequential model is trained. best val loss is: [72476239331328.0, 72476239331328.0, 7096102.5]
# sequential model is trained. best val loss is: [24713478799360.0, 24713478799360.0, 2899480.75]
# sequential model is trained. best val loss is: [73444855119872.0, 73444855119872.0, 7171576.0]
# sequential model is trained. best val loss is: [71609436078080.0, 71609436078080.0, 7038663.5]
# sequential model is trained. best val loss is: [65889667907584.0, 65889667907584.0, 6601138.0]
# sequential model is trained. best val loss is: [24969658499072.0, 24969658499072.0, 3013468.5]
# sequential model is trained. best val loss is: [73460055277568.0, 73460055277568.0, 7172648.5]
# sequential model is trained. best val loss is: [73434360971264.0, 73434360971264.0, 7170953.0]
# sequential model is trained. best val loss is: [73355180900352.0, 73355180900352.0, 7165739.5]
# sequential model is trained. best val loss is: [70441775398912.0, 70441775398912.0, 6969506.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73410956754944.0, 73410956754944.0, 7169395.5]
# sequential model is trained. best val loss is: [68486109855744.0, 68486109855744.0, 6824293.0]
# sequential model is trained. best val loss is: [56165840977920.0, 56165840977920.0, 5935501.5]
# sequential model is trained. best val loss is: [14370503393280.0, 14370503393280.0, 2190465.0]
# sequential model is trained. best val loss is: [73220392747008.0, 73220392747008.0, 7156679.0]
# sequential model is trained. best val loss is: [27464547958784.0, 27464547958784.0, 3287070.5]
# sequential model is trained. best val loss is: [15951112175616.0, 15951112175616.0, 2362236.75]
# sequential model is trained. best val loss is: [11486024957952.0, 11486024957952.0, 1786403.75]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460281769984.0, 73460281769984.0, 7172665.5]
# sequential model is trained. best val loss is: [11529091022848.0, 11529091022848.0, 1776878.625]
# sequential model is trained. best val loss is: [73448831320064.0, 73448831320064.0, 7171831.0]
# sequential model is trained. best val loss is: [65063759118336.0, 65063759118336.0, 6543440.0]
# sequential model is trained. best val loss is: [34080416595968.0, 34080416595968.0, 3727722.25]
# sequential model is trained. best val loss is: [13473196015616.0, 13473196015616.0, 2031569.5]
# sequential model is trained. best val loss is: [73460298547200.0, 73460298547200.0, 7172666.0]
# sequential model is trained. best val loss is: [73430669983744.0, 73430669983744.0, 7170602.0]
# sequential model is trained. best val loss is: [73236263993344.0, 73236263993344.0, 7157133.5]
# sequential model is trained. best val loss is: [51438210252800.0, 51438210252800.0, 5594640.5]
# sequential model is trained. best val loss is: [2.0910031100706816e+16, 2.0910031100706816e+16, 144526864.0]
# sequential model is trained. best val loss is: [22013324296192.0, 22013324296192.0, 2862760.0]
# sequential model is trained. best val loss is: [22013680812032.0, 22013680812032.0, 2871997.75]
# sequential model is trained. best val loss is: [22024479047680.0, 22024479047680.0, 2895539.5]
# sequential model is trained. best val loss is: [73418288398336.0, 73418288398336.0, 7169862.5]
# sequential model is trained. best val loss is: [45812369326080.0, 45812369326080.0, 5067978.0]
# sequential model is trained. best val loss is: [19194158514176.0, 19194158514176.0, 2624437.25]
# sequential model is trained. best val loss is: [11628428918784.0, 11628428918784.0, 1734562.5]
# sequential model is trained. best val loss is: [72584745975808.0, 72584745975808.0, 7115735.5]
# sequential model is trained. best val loss is: [17666825781248.0, 17666825781248.0, 2499735.0]
# sequential model is trained. best val loss is: [12969067937792.0, 12969067937792.0, 1947394.25]
# sequential model is trained. best val loss is: [11372359319552.0, 11372359319552.0, 1772418.25]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460306935808.0, 73460306935808.0, 7172667.0]
# sequential model is trained. best val loss is: [40549360861184.0, 40549360861184.0, 4016485.0]
# sequential model is trained. best val loss is: [11065204146176.0, 11065204146176.0, 1731451.125]
# sequential model is trained. best val loss is: [73420955975680.0, 73420955975680.0, 7169948.5]
# sequential model is trained. best val loss is: [44941942194176.0, 44941942194176.0, 4813560.5]
# sequential model is trained. best val loss is: [25437426155520.0, 25437426155520.0, 3046459.5]
# sequential model is trained. best val loss is: [12325748736000.0, 12325748736000.0, 1823547.625]
# sequential model is trained. best val loss is: [73460181106688.0, 73460181106688.0, 7172658.0]
# sequential model is trained. best val loss is: [73343621398528.0, 73343621398528.0, 7165148.5]
# sequential model is trained. best val loss is: [72558187642880.0, 72558187642880.0, 7113622.5]
# sequential model is trained. best val loss is: [33521762566144.0, 33521762566144.0, 3872864.25]
# sequential model is trained. best val loss is: [6.196541302977331e+16, 6.196541302977331e+16, 248884336.0]
# sequential model is trained. best val loss is: [22013326393344.0, 22013326393344.0, 2862723.25]
# sequential model is trained. best val loss is: [22013680812032.0, 22013680812032.0, 2871997.75]
# sequential model is trained. best val loss is: [22024479047680.0, 22024479047680.0, 2895539.5]
# sequential model is trained. best val loss is: [73302005514240.0, 73302005514240.0, 7162440.5]
# sequential model is trained. best val loss is: [25996503810048.0, 25996503810048.0, 3149085.25]
# sequential model is trained. best val loss is: [13842638700544.0, 13842638700544.0, 2095846.875]
# sequential model is trained. best val loss is: [11266351431680.0, 11266351431680.0, 1693699.875]
# sequential model is trained. best val loss is: [70158898954240.0, 70158898954240.0, 6947919.5]
# sequential model is trained. best val loss is: [14001102651392.0, 14001102651392.0, 2124614.5]
# sequential model is trained. best val loss is: [12025874874368.0, 12025874874368.0, 1802156.125]
# sequential model is trained. best val loss is: [11560733900800.0, 11560733900800.0, 1786528.75]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460214661120.0, 73460214661120.0, 7172660.5]
# sequential model is trained. best val loss is: [11118981414912.0, 11118981414912.0, 1765139.5]
# sequential model is trained. best val loss is: [10864681811968.0, 10864681811968.0, 1703445.625]
# sequential model is trained. best val loss is: [73299262439424.0, 73299262439424.0, 7161124.0]
# sequential model is trained. best val loss is: [29081867386880.0, 29081867386880.0, 3338873.0]
# sequential model is trained. best val loss is: [19319979245568.0, 19319979245568.0, 2632413.0]
# sequential model is trained. best val loss is: [11637970960384.0, 11637970960384.0, 1747722.25]
# sequential model is trained. best val loss is: [73459736510464.0, 73459736510464.0, 7172628.5]
# sequential model is trained. best val loss is: [73021750509568.0, 73021750509568.0, 7143762.5]
# sequential model is trained. best val loss is: [70050446835712.0, 70050446835712.0, 6938985.0]
# sequential model is trained. best val loss is: [22407221870592.0, 22407221870592.0, 2872057.0]
# sequential model is trained. best val loss is: [4.2838280187944804e+22, 4.2838280187944804e+22, 206974173184.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72840229421056.0, 72840229421056.0, 7131835.5]
# sequential model is trained. best val loss is: [16545612824576.0, 16545612824576.0, 2412024.5]
# sequential model is trained. best val loss is: [12346823016448.0, 12346823016448.0, 1838289.5]
# sequential model is trained. best val loss is: [11063635476480.0, 11063635476480.0, 1665250.5]
# sequential model is trained. best val loss is: [61691761000448.0, 61691761000448.0, 6379486.0]
# sequential model is trained. best val loss is: [12169269739520.0, 12169269739520.0, 1841784.25]
# sequential model is trained. best val loss is: [11466172268544.0, 11466172268544.0, 1755249.125]
# sequential model is trained. best val loss is: [11919978135552.0, 11919978135552.0, 1809710.625]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172668.0]
# sequential model is trained. best val loss is: [11139593273344.0, 11139593273344.0, 1749937.25]
# sequential model is trained. best val loss is: [10877859266560.0, 10877859266560.0, 1708041.125]
# sequential model is trained. best val loss is: [10868510162944.0, 10868510162944.0, 1683788.375]
# sequential model is trained. best val loss is: [72816061841408.0, 72816061841408.0, 7127666.0]
# sequential model is trained. best val loss is: [21532971630592.0, 21532971630592.0, 2780937.25]
# sequential model is trained. best val loss is: [14225754816512.0, 14225754816512.0, 2153776.25]
# sequential model is trained. best val loss is: [11439537389568.0, 11439537389568.0, 1752480.5]
# sequential model is trained. best val loss is: [73457656135680.0, 73457656135680.0, 7172496.0]
# sequential model is trained. best val loss is: [71568793272320.0, 71568793272320.0, 7048149.5]
# sequential model is trained. best val loss is: [61376185761792.0, 61376185761792.0, 6338619.5]
# sequential model is trained. best val loss is: [15174206488576.0, 15174206488576.0, 2279456.0]
# sequential model is trained. best val loss is: [2.0328771969708615e+20, 2.0328771969708615e+20, 14257898496.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [70887764131840.0, 70887764131840.0, 7004590.5]
# sequential model is trained. best val loss is: [12619552391168.0, 12619552391168.0, 1905644.0]
# sequential model is trained. best val loss is: [11716613111808.0, 11716613111808.0, 1743330.0]
# sequential model is trained. best val loss is: [11029439315968.0, 11029439315968.0, 1643628.0]
# sequential model is trained. best val loss is: [45254719832064.0, 45254719832064.0, 5093600.5]
# sequential model is trained. best val loss is: [11605399044096.0, 11605399044096.0, 1764387.5]
# sequential model is trained. best val loss is: [11315284279296.0, 11315284279296.0, 1772044.125]
# sequential model is trained. best val loss is: [12476989046784.0, 12476989046784.0, 1865203.75]
# sequential model is trained. best val loss is: [73460323713024.0, 73460323713024.0, 7172668.0]
# sequential model is trained. best val loss is: [10882060910592.0, 10882060910592.0, 1724418.25]
# sequential model is trained. best val loss is: [10741120761856.0, 10741120761856.0, 1686105.25]
# sequential model is trained. best val loss is: [10847277547520.0, 10847277547520.0, 1675820.5]
# sequential model is trained. best val loss is: [70958530428928.0, 70958530428928.0, 6993644.5]
# sequential model is trained. best val loss is: [16073521889280.0, 16073521889280.0, 2377800.5]
# sequential model is trained. best val loss is: [12376881496064.0, 12376881496064.0, 1878881.875]
# sequential model is trained. best val loss is: [11452187410432.0, 11452187410432.0, 1773507.625]
# sequential model is trained. best val loss is: [73451163353088.0, 73451163353088.0, 7172065.0]
# sequential model is trained. best val loss is: [66765254033408.0, 66765254033408.0, 6709309.0]
# sequential model is trained. best val loss is: [46945720598528.0, 46945720598528.0, 5266084.5]
# sequential model is trained. best val loss is: [12609058242560.0, 12609058242560.0, 1949188.25]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [64400274751488.0, 64400274751488.0, 6537945.0]
# sequential model is trained. best val loss is: [11856341106688.0, 11856341106688.0, 1773130.75]
# sequential model is trained. best val loss is: [11367631290368.0, 11367631290368.0, 1705400.75]
# sequential model is trained. best val loss is: [11134470979584.0, 11134470979584.0, 1647449.125]
# sequential model is trained. best val loss is: [62257996234752.0, 62257996234752.0, 6349382.0]
# sequential model is trained. best val loss is: [12247515529216.0, 12247515529216.0, 1817135.125]
# sequential model is trained. best val loss is: [11358174183424.0, 11358174183424.0, 1758397.25]
# sequential model is trained. best val loss is: [12339430555648.0, 12339430555648.0, 1839536.625]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460332101632.0, 73460332101632.0, 7172667.0]
# sequential model is trained. best val loss is: [11697746083840.0, 11697746083840.0, 1847632.875]
# sequential model is trained. best val loss is: [10837578219520.0, 10837578219520.0, 1701961.75]
# sequential model is trained. best val loss is: [73302223618048.0, 73302223618048.0, 7161111.0]
# sequential model is trained. best val loss is: [21498685292544.0, 21498685292544.0, 2776424.5]
# sequential model is trained. best val loss is: [13767487258624.0, 13767487258624.0, 2065512.75]
# sequential model is trained. best val loss is: [11411368443904.0, 11411368443904.0, 1757829.0]
# sequential model is trained. best val loss is: [73460231438336.0, 73460231438336.0, 7172661.0]
# sequential model is trained. best val loss is: [72579226271744.0, 72579226271744.0, 7113505.5]
# sequential model is trained. best val loss is: [61879749705728.0, 61879749705728.0, 6352922.0]
# sequential model is trained. best val loss is: [14363525120000.0, 14363525120000.0, 2186190.25]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72653264125952.0, 72653264125952.0, 7117107.5]
# sequential model is trained. best val loss is: [12660945977344.0, 12660945977344.0, 1873549.625]
# sequential model is trained. best val loss is: [11747797762048.0, 11747797762048.0, 1737219.5]
# sequential model is trained. best val loss is: [11067370504192.0, 11067370504192.0, 1669413.125]
# sequential model is trained. best val loss is: [34675881934848.0, 34675881934848.0, 3937321.25]
# sequential model is trained. best val loss is: [11601273946112.0, 11601273946112.0, 1746185.625]
# sequential model is trained. best val loss is: [11417539313664.0, 11417539313664.0, 1759520.875]
# sequential model is trained. best val loss is: [12358769442816.0, 12358769442816.0, 1859148.125]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [73460273381376.0, 73460273381376.0, 7172665.5]
# sequential model is trained. best val loss is: [11207747567616.0, 11207747567616.0, 1797797.375]
# sequential model is trained. best val loss is: [11197414899712.0, 11197414899712.0, 1718794.5]
# sequential model is trained. best val loss is: [72251558854656.0, 72251558854656.0, 7085824.0]
# sequential model is trained. best val loss is: [14552048599040.0, 14552048599040.0, 2183703.25]
# sequential model is trained. best val loss is: [12090947403776.0, 12090947403776.0, 1809095.875]
# sequential model is trained. best val loss is: [11563512627200.0, 11563512627200.0, 1778320.625]
# sequential model is trained. best val loss is: [73459635847168.0, 73459635847168.0, 7172622.5]
# sequential model is trained. best val loss is: [65524566327296.0, 65524566327296.0, 6599087.5]
# sequential model is trained. best val loss is: [33797139595264.0, 33797139595264.0, 3872921.75]
# sequential model is trained. best val loss is: [12029756702720.0, 12029756702720.0, 1867620.875]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [66619531329536.0, 66619531329536.0, 6688107.5]
# sequential model is trained. best val loss is: [11760004235264.0, 11760004235264.0, 1742709.5]
# sequential model is trained. best val loss is: [11323082539008.0, 11323082539008.0, 1694072.125]
# sequential model is trained. best val loss is: [11114684350464.0, 11114684350464.0, 1681695.5]
# sequential model is trained. best val loss is: [21382521946112.0, 21382521946112.0, 2768727.75]
# sequential model is trained. best val loss is: [11367321960448.0, 11367321960448.0, 1749504.875]
# sequential model is trained. best val loss is: [11781818810368.0, 11781818810368.0, 1782503.75]
# sequential model is trained. best val loss is: [11121545183232.0, 11121545183232.0, 1758979.625]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [11090504187904.0, 11090504187904.0, 1738277.75]
# sequential model is trained. best val loss is: [10982365593600.0, 10982365593600.0, 1676136.25]
# sequential model is trained. best val loss is: [10973755736064.0, 10973755736064.0, 1695598.25]
# sequential model is trained. best val loss is: [63822899445760.0, 63822899445760.0, 6431282.5]
# sequential model is trained. best val loss is: [12547156606976.0, 12547156606976.0, 1869179.0]
# sequential model is trained. best val loss is: [11727891595264.0, 11727891595264.0, 1745961.375]
# sequential model is trained. best val loss is: [11827569229824.0, 11827569229824.0, 1789806.75]
# sequential model is trained. best val loss is: [73453554106368.0, 73453554106368.0, 7172215.0]
# sequential model is trained. best val loss is: [43049807773696.0, 43049807773696.0, 4826247.5]
# sequential model is trained. best val loss is: [20717596835840.0, 20717596835840.0, 2742279.25]
# sequential model is trained. best val loss is: [11816948203520.0, 11816948203520.0, 1783754.875]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [41116309127168.0, 41116309127168.0, 4612505.5]
# sequential model is trained. best val loss is: [11408166092800.0, 11408166092800.0, 1699782.625]
# sequential model is trained. best val loss is: [11192595644416.0, 11192595644416.0, 1671446.25]
# sequential model is trained. best val loss is: [11150394654720.0, 11150394654720.0, 1737643.0]
# sequential model is trained. best val loss is: [14618769489920.0, 14618769489920.0, 2228909.75]
# sequential model is trained. best val loss is: [11570668109824.0, 11570668109824.0, 1763171.5]
# sequential model is trained. best val loss is: [12382470406144.0, 12382470406144.0, 1834263.0]
# sequential model is trained. best val loss is: [11336557789184.0, 11336557789184.0, 1921346.75]
# sequential model is trained. best val loss is: [73460348878848.0, 73460348878848.0, 7172668.5]
# sequential model is trained. best val loss is: [11032611258368.0, 11032611258368.0, 1684369.75]
# sequential model is trained. best val loss is: [11134381850624.0, 11134381850624.0, 1686490.875]
# sequential model is trained. best val loss is: [11018051780608.0, 11018051780608.0, 1680903.0]
# sequential model is trained. best val loss is: [39193761808384.0, 39193761808384.0, 4350768.0]
# sequential model is trained. best val loss is: [11806502289408.0, 11806502289408.0, 1754403.0]
# sequential model is trained. best val loss is: [11400319598592.0, 11400319598592.0, 1742592.5]
# sequential model is trained. best val loss is: [12367345745920.0, 12367345745920.0, 1818860.0]
# sequential model is trained. best val loss is: [73406485626880.0, 73406485626880.0, 7169218.5]
# sequential model is trained. best val loss is: [24304328638464.0, 24304328638464.0, 3018875.25]
# sequential model is trained. best val loss is: [14716187443200.0, 14716187443200.0, 2229781.25]
# sequential model is trained. best val loss is: [11401394388992.0, 11401394388992.0, 1716194.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [20702342152192.0, 20702342152192.0, 2749576.0]
# sequential model is trained. best val loss is: [11217229840384.0, 11217229840384.0, 1679869.5]
# sequential model is trained. best val loss is: [11091206733824.0, 11091206733824.0, 1658047.375]
# sequential model is trained. best val loss is: [10807562731520.0, 10807562731520.0, 1754390.25]
# sequential model is trained. best val loss is: [12264221442048.0, 12264221442048.0, 1861419.625]
# sequential model is trained. best val loss is: [12170261692416.0, 12170261692416.0, 1810102.0]
# sequential model is trained. best val loss is: [12373948628992.0, 12373948628992.0, 1845901.875]
# sequential model is trained. best val loss is: [12696963514368.0, 12696963514368.0, 2256825.25]
# sequential model is trained. best val loss is: [73460323713024.0, 73460323713024.0, 7172667.0]
# sequential model is trained. best val loss is: [11069211803648.0, 11069211803648.0, 1690501.875]
# sequential model is trained. best val loss is: [10971472986112.0, 10971472986112.0, 1681973.125]
# sequential model is trained. best val loss is: [11005509763072.0, 11005509763072.0, 1681785.0]
# sequential model is trained. best val loss is: [24519137820672.0, 24519137820672.0, 2992807.75]
# sequential model is trained. best val loss is: [11407670116352.0, 11407670116352.0, 1731579.375]
# sequential model is trained. best val loss is: [11417735397376.0, 11417735397376.0, 1758483.75]
# sequential model is trained. best val loss is: [12275690766336.0, 12275690766336.0, 1824852.375]
# sequential model is trained. best val loss is: [73021440131072.0, 73021440131072.0, 7143548.5]
# sequential model is trained. best val loss is: [16122030063616.0, 16122030063616.0, 2386962.5]
# sequential model is trained. best val loss is: [12351720914944.0, 12351720914944.0, 1894055.75]
# sequential model is trained. best val loss is: [11004605890560.0, 11004605890560.0, 1673034.375]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [13300070875136.0, 13300070875136.0, 2022677.25]
# sequential model is trained. best val loss is: [11090092097536.0, 11090092097536.0, 1653831.5]
# sequential model is trained. best val loss is: [11058735480832.0, 11058735480832.0, 1657725.25]
# sequential model is trained. best val loss is: [9896875524096.0, 9896875524096.0, 1668267.0]
# ==== 10.364548814296722 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}

# %% [markdown]
# ### The more the number of parameters, the worse the reproducibility.

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[3], units=[256],
         optimizers=['rmsprop'], lrs=[0.1],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [10136130158592.0, 10136130158592.0, 1674162.5]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7f03727be4e0>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}],
#  [10136130158592.0])

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[3], units=[256],
         optimizers=['rmsprop'], lrs=[0.1],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [9745228365824.0, 9745228365824.0, 1667644.375]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7f031814dc50>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}],
#  [9745228365824.0])

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[1], units=[64],
         optimizers=['adam'], lrs=[0.01],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [70839538024448.0, 70839538024448.0, 6997982.0]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7f0239877080>],
#  [{'hidden_layer': 1, 'unit': 64, 'optimizer': 'adam', 'lr': 0.01}],
#  [70839538024448.0])

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[1], units=[64],
         optimizers=['adam'], lrs=[0.01],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [70839538024448.0, 70839538024448.0, 6997982.0]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7f02396ecfd0>],
#  [{'hidden_layer': 1, 'unit': 64, 'optimizer': 'adam', 'lr': 0.01}],
#  [70839538024448.0])
