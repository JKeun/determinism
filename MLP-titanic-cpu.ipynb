# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename = "./data/titanic_train.csv"
ds = DataSource(filename)
ds.data_load_split(target=['Survived'],
                   ignore=['Name', 'Cabin', 'Ticket'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)
# Out:
# sequential model is trained. best val loss is: [0.5056127123889469, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4312516643097167, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4220164467493305, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4533856413903691, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.7052238515445164, 0.44761904761904764]
# sequential model is trained. best val loss is: [0.7016924877961477, 0.4666666666666667]
# sequential model is trained. best val loss is: [0.6978459798154377, 0.4857142857142857]
# sequential model is trained. best val loss is: [0.6697037509509496, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.6075572357291267, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4326189149880693, 0.8]
# sequential model is trained. best val loss is: [0.4089024210675797, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.4346194577968639, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6840250968933106, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.5652462427105223, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.5050124091761453, 0.780952380952381]
# sequential model is trained. best val loss is: [0.4657730593290623, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.693413343883696, 0.6238095238095238]
# sequential model is trained. best val loss is: [0.6208891339245297, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5730396120321183, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.47973595195937724, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.5075222512086233, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4697333046249003, 0.780952380952381]
# sequential model is trained. best val loss is: [0.42243496363946526, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.5264778377299774, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.481188426024857, 0.8]
# sequential model is trained. best val loss is: [0.46391779949503653, 0.8]
# sequential model is trained. best val loss is: [0.4272609110379736, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4541941259014796, 0.8]
# sequential model is trained. best val loss is: [0.7002769044467381, 0.5142857142857142]
# sequential model is trained. best val loss is: [0.6954896031391054, 0.5571428571428572]
# sequential model is trained. best val loss is: [0.6903333424102692, 0.5952380952380952]
# sequential model is trained. best val loss is: [0.6505980768374034, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5732000631945474, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.43233248307037037, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.41546125729232913, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.43323585160919936, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6791725090571812, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5603075531976563, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.5076866808391752, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4687587578592467, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.6908405651648839, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6254977011964434, 0.6952380952380952]
# sequential model is trained. best val loss is: [0.5825395389681771, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.48389840331815537, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.48117033111907187, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.418117548935836, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.45101160000771673, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.5084854228126163, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.45488514661611545, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4256822546103476, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4370750507040482, 0.819047619047619]
# sequential model is trained. best val loss is: [0.4656358282159556, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6906886302289509, 0.580952380952381]
# sequential model is trained. best val loss is: [0.6829614554132734, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.674720632746106, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.6170558554785592, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.5252950279485612, 0.780952380952381]
# sequential model is trained. best val loss is: [0.4170729868913657, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.41380418662461343, 0.8333333333333334]
# sequential model is trained. best val loss is: [0.45273635998111245, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.6601423706327166, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5358255572262265, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.49371256430943805, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4656185878507261, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6775767139026097, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.5995975968383608, 0.7333333333333333]
# sequential model is trained. best val loss is: [0.5591198753033365, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.478618012608162, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.45410968666186646, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4273559937678718, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.7772114978578392, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.5642575586097026, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.444769456239772, 0.8]
# sequential model is trained. best val loss is: [0.43078587896015963, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.44346152880791034, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.48300011334495124, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6842894051756178, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6738390218643915, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.663086107798985, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5982665280501048, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.503926631701844, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4128362318551808, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.43271120413730085, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.4470583539028699, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6531000676609221, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5376004228279704, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4936251262468951, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4664635476462233, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6719010821410588, 0.6714285714285714]
# sequential model is trained. best val loss is: [0.602117641766866, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5638298600912094, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.4779352947404342, 0.780952380952381]
# sequential model is trained. best val loss is: [0.44417189569655985, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.44992749654751, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.4886693023918017, 0.8]
# sequential model is trained. best val loss is: [2.4958902076257607, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4305877543170936, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4317794338682818, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4295266213719558, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.5184486689721026, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6709938023771559, 0.6619047619047619]
# sequential model is trained. best val loss is: [0.6567230376459303, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.6427907926695687, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5711960545607976, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4791726532081763, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.4147759841058186, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.42724495431317727, 0.819047619047619]
# sequential model is trained. best val loss is: [0.4764690330821923, 0.8]
# sequential model is trained. best val loss is: [0.6380643952460516, 0.719047619047619]
# sequential model is trained. best val loss is: [0.528088444684233, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.4893624773692517, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.46541398715815463, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6583613250936781, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.5910201864583152, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5545972952530498, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.47704161766561726, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4281045636871741, 0.819047619047619]
# sequential model is trained. best val loss is: [0.47896524030496096, 0.7952380952380952]
# sequential model is trained. best val loss is: [1.721497311931461, 0.780952380952381]
# sequential model is trained. best val loss is: [0.679439489652083, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.47972607676471984, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.43155305505746844, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.45328171298994374, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.48561513930603506, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6885807741255987, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6861700208414169, 0.6]
# sequential model is trained. best val loss is: [0.6836212484609513, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.6636287903501874, 0.7]
# sequential model is trained. best val loss is: [0.6055984814961751, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.41696039801019996, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4440592119638625, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4539595522841583, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6774893320742108, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5848342623029437, 0.7333333333333333]
# sequential model is trained. best val loss is: [0.5061875302876745, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4650271961687221, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6827258740152632, 0.6190476190476191]
# sequential model is trained. best val loss is: [0.6441257439908528, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.6090569772890636, 0.6952380952380952]
# sequential model is trained. best val loss is: [0.48364669355075984, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.48823977872019725, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.42916825804609937, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.4770908834339934, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.5673193822148495, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.4551114236603358, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4621947898241203, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.47364387365800903, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.5096148377632448, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.6958698116597675, 0.47619047619047616]
# sequential model is trained. best val loss is: [0.6920846663770222, 0.6]
# sequential model is trained. best val loss is: [0.6877509520167396, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6467930954127085, 0.7]
# sequential model is trained. best val loss is: [0.5597920392240797, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.43209662279165234, 0.819047619047619]
# sequential model is trained. best val loss is: [0.4647136824082173, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4468375974979516, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6837447379316602, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.590048724483876, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5163814365154221, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.47495338596026637, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6907316185179211, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6487432492630822, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6159410594474701, 0.638095238095238]
# sequential model is trained. best val loss is: [0.48815685252525975, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.45660182982904923, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.5100093094325746, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.5388167486026703, 0.8]
# sequential model is trained. best val loss is: [0.5153372930116131, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.43370960868446023, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4565413439493741, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4563161270757735, 0.819047619047619]
# sequential model is trained. best val loss is: [0.48529253792010074, 0.8]
# sequential model is trained. best val loss is: [0.7006251116593679, 0.3952380952380952]
# sequential model is trained. best val loss is: [0.6941998036134811, 0.5285714285714286]
# sequential model is trained. best val loss is: [0.6873284288815089, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6168740224270594, 0.719047619047619]
# sequential model is trained. best val loss is: [0.4953321901992673, 0.8]
# sequential model is trained. best val loss is: [0.45392724149514124, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.44872992249888305, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.47559407149789684, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6847851395606994, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5832649446669079, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5072844066080593, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.48701941767039464, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6936229297092983, 0.5333333333333333]
# sequential model is trained. best val loss is: [0.6496150228239241, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6178677114702407, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.4821361077084605, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.43534831358798937, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5014888744984222, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.5285966327529292, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4756108817523538, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.41400912369241444, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.44109376212533485, 0.8333333333333334]
# sequential model is trained. best val loss is: [0.45724716368752394, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.4930834313925684, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.7005706829684121, 0.4142857142857143]
# sequential model is trained. best val loss is: [0.6878820924531845, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6748046142714365, 0.6476190476190476]
# sequential model is trained. best val loss is: [0.5791272501150767, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.46486015698118577, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.44307645052068284, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.446456267840186, 0.819047619047619]
# sequential model is trained. best val loss is: [0.460052793336896, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.6785476837839399, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.5593139094965799, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.4906451287368933, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.47874912069777825, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6917616449651264, 0.5523809523809524]
# sequential model is trained. best val loss is: [0.6377277489219393, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.5981358484143302, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.47447179924430594, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.42103864962283255, 0.8476190476190476]
# sequential model is trained. best val loss is: [0.5210561153690962, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.5695336133259494, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6275440188031223, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4411342995948828, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.45310956690653775, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.456676248378963, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.5264051312646768, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.6834070381664095, 0.6571428571428571]
# sequential model is trained. best val loss is: [0.66202265166101, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.6418683703456606, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.531513501774697, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4460442071722355, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.44766400427096026, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4374713662039669, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4577067515688265, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6577600694838024, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.5380335934105374, 0.780952380952381]
# sequential model is trained. best val loss is: [0.481068615136402, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4887992623026505, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6744953166870844, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.616271802357265, 0.6428571428571429]
# sequential model is trained. best val loss is: [0.5758305639028549, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.47128906252882663, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.5730122473409361, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.5219420293957269, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.48318757677804913, 0.8285714285714286]
# sequential model is trained. best val loss is: [1.239464801016679, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4529867312560479, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4519408338997025, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4514443687462647, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.49025889245704524, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.6965196958609989, 0.4238095238095238]
# sequential model is trained. best val loss is: [0.6947088332403274, 0.48095238095238096]
# sequential model is trained. best val loss is: [0.6928139116082873, 0.5333333333333333]
# sequential model is trained. best val loss is: [0.6756916775589897, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.5892243183794476, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4324733919403072, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.4520934282699489, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4623719205281564, 0.8]
# sequential model is trained. best val loss is: [0.6898031413555146, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6122197978553318, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5039185406906265, 0.780952380952381]
# sequential model is trained. best val loss is: [0.47358290987488416, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6925778156235105, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6687783340613047, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6446659566391082, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.4878197803649874, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4575229064517078, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.4515701957767652, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5183197826113818, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.827101477967459, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.44372366249029127, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4624864287745108, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4609713635666984, 0.780952380952381]
# sequential model is trained. best val loss is: [0.4916433273704007, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6983671963214875, 0.4]
# sequential model is trained. best val loss is: [0.6952714866115933, 0.4238095238095238]
# sequential model is trained. best val loss is: [0.6919111070178804, 0.5]
# sequential model is trained. best val loss is: [0.6543645620346069, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.5372816803199905, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.44920890003751907, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.4522575603047569, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.45004488095707657, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6881990009830111, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6264084631488437, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.5181105339810962, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.48120665680062735, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6924639511676062, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6648783167203267, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6490112409705208, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.48044645569863775, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4497578365905654, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.5071780198020861, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.5286658882138519, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.5593988194340874, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.44831949171854096, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.45492273313700154, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.45482521498107376, 0.8]
# sequential model is trained. best val loss is: [0.4992589845255071, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6954374463785262, 0.4666666666666667]
# sequential model is trained. best val loss is: [0.6886496504147848, 0.6]
# sequential model is trained. best val loss is: [0.6813848739578611, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5900549965245383, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.47047525406593366, 0.8]
# sequential model is trained. best val loss is: [0.4613408603133437, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4626206033534843, 0.8]
# sequential model is trained. best val loss is: [0.4480144418016304, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.6803212004048483, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5741677446024759, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.49304457325488327, 0.780952380952381]
# sequential model is trained. best val loss is: [0.48767170007839533, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6885980770701454, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6512420738027209, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6195341061978114, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.49034787595183366, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.47564671666796565, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.5210617743867694, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.5349338907396443, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.5540227856096905, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.503704689071047, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.4660762837953024, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.47624713493804866, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4680132566807348, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6960174024105072, 0.4380952380952381]
# sequential model is trained. best val loss is: [0.6829702371642703, 0.6476190476190476]
# sequential model is trained. best val loss is: [0.6676786277975355, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5395672573929742, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4579912679325346, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4594116894849798, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4558532794148467, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.4535956446859602, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6758358807790847, 0.6761904761904762]
# sequential model is trained. best val loss is: [0.5522195796881403, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4812493701243684, 0.8]
# sequential model is trained. best val loss is: [0.48111015350621616, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6883814218498412, 0.6190476190476191]
# sequential model is trained. best val loss is: [0.63789666110561, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5985794511579332, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.4752399626431898, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.5716221031949357, 0.8]
# sequential model is trained. best val loss is: [1.5545391013937222, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.5328846854268617, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.9175668356308279, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.4409314830102847, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4657039687539536, 0.8]
# sequential model is trained. best val loss is: [0.45655537255119694, 0.8476190476190476]
# sequential model is trained. best val loss is: [0.5708317004221799, 0.780952380952381]
# sequential model is trained. best val loss is: [0.6854716547897883, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6658768555947713, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.644956287032082, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5094327965662593, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.43686421640978507, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4448748534171803, 0.819047619047619]
# sequential model is trained. best val loss is: [0.43378340249307384, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.47132450251296926, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.6682432325113388, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.5558056436124302, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4890490015170404, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4923735595815482, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6800181672686623, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6365114677520025, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.5994851666547003, 0.6285714285714286]
# sequential model is trained. best val loss is: [0.48440045092498796, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.128660648336656, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.509704748437201, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.5789736001470925, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.8905381338204327, 0.6761904761904762]

# %%
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
# Out:
# sequential model is trained. best val loss is: [0.5056127123889469, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4312516643097167, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4832674425983853, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.8929854804329067, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.7052238515445164, 0.44761904761904764]
# sequential model is trained. best val loss is: [0.7016924877961477, 0.4666666666666667]
# sequential model is trained. best val loss is: [0.6978459798154377, 0.4857142857142857]
# sequential model is trained. best val loss is: [0.6697037509509496, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.6075572357291267, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4326189149880693, 0.8]
# sequential model is trained. best val loss is: [0.4089024210675797, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.46065812883415547, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6840250968933106, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.5652462427105223, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.5050124091761453, 0.780952380952381]
# sequential model is trained. best val loss is: [0.4657730593290623, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.693413343883696, 0.6238095238095238]
# sequential model is trained. best val loss is: [0.6208891339245297, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5730396120321183, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.47973595195937724, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.5075222512086233, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4697333046249003, 0.780952380952381]
# sequential model is trained. best val loss is: [0.8075384750285328, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.5764921187052471, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.481188426024857, 0.8]
# sequential model is trained. best val loss is: [0.46391779949503653, 0.8]
# sequential model is trained. best val loss is: [0.5516829994120296, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.6935542208954935, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.7002769044467381, 0.5142857142857142]
# sequential model is trained. best val loss is: [0.6954896031391054, 0.5571428571428572]
# sequential model is trained. best val loss is: [0.6903333424102692, 0.5952380952380952]
# sequential model is trained. best val loss is: [0.6505980768374034, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5732000631945474, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.43233248307037037, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.41546125729232913, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.502373878803296, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6791725090571812, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5603075531976563, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.5076866808391752, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4687587578592467, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.6908405651648839, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6254977011964434, 0.6952380952380952]
# sequential model is trained. best val loss is: [0.5825395389681771, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.48389840331815537, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.48117033111907187, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.5940653206705249, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.836792944061644, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6875952034450407, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.45488514661611545, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.47292523966248373, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5500168898288892, 0.7857142857142857]
# sequential model is trained. best val loss is: [1.0553713955796586, 0.6571428571428571]
# sequential model is trained. best val loss is: [0.6906886302289509, 0.580952380952381]
# sequential model is trained. best val loss is: [0.6829614554132734, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.674720632746106, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.6170558554785592, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.5252950279485612, 0.780952380952381]
# sequential model is trained. best val loss is: [0.4170729868913657, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.41380418662461343, 0.8333333333333334]
# sequential model is trained. best val loss is: [0.5480832566682022, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6601423706327166, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5358255572262265, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.49371256430943805, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4656185878507261, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6775767139026097, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.5995975968383608, 0.7333333333333333]
# sequential model is trained. best val loss is: [0.5591198753033365, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.478618012608162, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.45410968666186646, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6371388995533628, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.7772114978578392, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.7592396131145093, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.444769456239772, 0.8]
# sequential model is trained. best val loss is: [0.533352964754935, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.5378910083571719, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6753737256482719, 0.8476190476190476]
# sequential model is trained. best val loss is: [0.6842894051756178, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6738390218643915, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.663086107798985, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5982665280501048, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.503926631701844, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4128362318551808, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.43271120413730085, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.504217337997729, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6531000676609221, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5376004228279704, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4936251262468951, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4664635476462233, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6719010821410588, 0.6714285714285714]
# sequential model is trained. best val loss is: [0.602117641766866, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5638298600912094, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.4779352947404342, 0.780952380952381]
# sequential model is trained. best val loss is: [0.44417189569655985, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.8692396074077449, 0.7904761904761904]
# sequential model is trained. best val loss is: [1.3862832418504984, 0.780952380952381]
# sequential model is trained. best val loss is: [2.4958902076257607, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4305877543170936, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.5560523310351994, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.610713395581902, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.7443376286994668, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.6709938023771559, 0.6619047619047619]
# sequential model is trained. best val loss is: [0.6567230376459303, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.6427907926695687, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5711960545607976, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4791726532081763, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.4147759841058186, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.4474124598756031, 0.8333333333333334]
# sequential model is trained. best val loss is: [0.5570989639697039, 0.8]
# sequential model is trained. best val loss is: [0.6380643952460516, 0.719047619047619]
# sequential model is trained. best val loss is: [0.528088444684233, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.4893624773692517, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.46541398715815463, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6583613250936781, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.5910201864583152, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5545972952530498, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.47704161766561726, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4281045636871741, 0.819047619047619]
# sequential model is trained. best val loss is: [1.1364211223195464, 0.7857142857142857]
# sequential model is trained. best val loss is: [1.721497311931461, 0.780952380952381]
# sequential model is trained. best val loss is: [2.799130327581554, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.47972607676471984, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.5731397478872867, 0.780952380952381]
# sequential model is trained. best val loss is: [0.6665528700754443, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.9340088577299498, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6885807741255987, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6861700208414169, 0.6]
# sequential model is trained. best val loss is: [0.6836212484609513, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.6636287903501874, 0.7]
# sequential model is trained. best val loss is: [0.6055984814961751, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.41696039801019996, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4440592119638625, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.7531262631630231, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.6774893320742108, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5848342623029437, 0.7333333333333333]
# sequential model is trained. best val loss is: [0.5061875302876745, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4650271961687221, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6827258740152632, 0.6190476190476191]
# sequential model is trained. best val loss is: [0.6441257439908528, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.6090569772890636, 0.6952380952380952]
# sequential model is trained. best val loss is: [0.48364669355075984, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.48823977872019725, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.0024041475509256, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.7227864961404876, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.8146860188246772, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4551114236603358, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6243431067796456, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.7736334614891509, 0.8]
# sequential model is trained. best val loss is: [0.9738289707924579, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.6958698116597675, 0.47619047619047616]
# sequential model is trained. best val loss is: [0.6920846663770222, 0.6]
# sequential model is trained. best val loss is: [0.6877509520167396, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6467930954127085, 0.7]
# sequential model is trained. best val loss is: [0.5597920392240797, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.43209662279165234, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5199624398686117, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6245196960376592, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.6837447379316602, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.590048724483876, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5163814365154221, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.47495338596026637, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6907316185179211, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6487432492630822, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6159410594474701, 0.638095238095238]
# sequential model is trained. best val loss is: [0.48815685252525975, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.45660182982904923, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6983940288980846, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.7059340664424341, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.6019252977037707, 0.819047619047619]
# sequential model is trained. best val loss is: [0.43370960868446023, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.7547910889154495, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.897508528037455, 0.7714285714285715]
# sequential model is trained. best val loss is: [1.3997814215378885, 0.6761904761904762]
# sequential model is trained. best val loss is: [0.7006251116593679, 0.3952380952380952]
# sequential model is trained. best val loss is: [0.6941998036134811, 0.5285714285714286]
# sequential model is trained. best val loss is: [0.6873284288815089, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6168740224270594, 0.719047619047619]
# sequential model is trained. best val loss is: [0.4953321901992673, 0.8]
# sequential model is trained. best val loss is: [0.45392724149514124, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.516036893373707, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.7940605743368621, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.6847851395606994, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5832649446669079, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5072844066080593, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.48701941767039464, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6936229297092983, 0.5333333333333333]
# sequential model is trained. best val loss is: [0.6496150228239241, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6178677114702407, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.4821361077084605, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.43534831358798937, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5594471426419487, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6467958082894107, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.9101828697782115, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.41400912369241444, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.7318134923380494, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.8955611057844082, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6196909401349028, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.7005706829684121, 0.4142857142857143]
# sequential model is trained. best val loss is: [0.6878820924531845, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6748046142714365, 0.6476190476190476]
# sequential model is trained. best val loss is: [0.5791272501150767, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.46486015698118577, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4932193775570554, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6890069043024577, 0.7476190476190476]
# sequential model is trained. best val loss is: [0.646416336973879, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6785476837839399, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.5593139094965799, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.4906451287368933, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.47874912069777825, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6917616449651264, 0.5523809523809524]
# sequential model is trained. best val loss is: [0.6377277489219393, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.5981358484143302, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.47447179924430594, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.42103864962283255, 0.8476190476190476]
# sequential model is trained. best val loss is: [0.8210755357030464, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.5491227996842336, 0.7714285714285715]
# sequential model is trained. best val loss is: [3.8804435044317995, 0.4857142857142857]
# sequential model is trained. best val loss is: [0.4411342995948828, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.7197679189676736, 0.7952380952380952]
# sequential model is trained. best val loss is: [1.31255206665564, 0.6571428571428571]
# sequential model is trained. best val loss is: [0.7157126900193451, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.6834070381664095, 0.6571428571428571]
# sequential model is trained. best val loss is: [0.66202265166101, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.6418683703456606, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.531513501774697, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4460442071722355, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.5301544880739179, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6390665348241891, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.8024658742134075, 0.780952380952381]
# sequential model is trained. best val loss is: [0.6577600694838024, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.5380335934105374, 0.780952380952381]
# sequential model is trained. best val loss is: [0.481068615136402, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4887992623026505, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6744953166870844, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.616271802357265, 0.6428571428571429]
# sequential model is trained. best val loss is: [0.5758305639028549, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.47128906252882663, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.5730122473409361, 0.7952380952380952]
# sequential model is trained. best val loss is: [1.3583906563261372, 0.7857142857142857]
# sequential model is trained. best val loss is: [1.1252002483119508, 0.7714285714285715]
# sequential model is trained. best val loss is: [1.239464801016679, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4529867312560479, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.7208411761711055, 0.8]
# sequential model is trained. best val loss is: [1.0752844408809639, 0.6761904761904762]
# sequential model is trained. best val loss is: [0.6955700614573328, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.6965196958609989, 0.4238095238095238]
# sequential model is trained. best val loss is: [0.6947088332403274, 0.48095238095238096]
# sequential model is trained. best val loss is: [0.6928139116082873, 0.5333333333333333]
# sequential model is trained. best val loss is: [0.6756916775589897, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.5892243183794476, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4324733919403072, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.558557424232782, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.7930425654346119, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.6898031413555146, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6122197978553318, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5039185406906265, 0.780952380952381]
# sequential model is trained. best val loss is: [0.47358290987488416, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6925778156235105, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6687783340613047, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6446659566391082, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.4878197803649874, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4575229064517078, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.7097529855542981, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.5381015593794723, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.827101477967459, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.44372366249029127, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.8609282703411643, 0.819047619047619]
# sequential model is trained. best val loss is: [1.385367704941648, 0.6285714285714286]
# sequential model is trained. best val loss is: [1.0801548574709021, 0.7476190476190476]
# sequential model is trained. best val loss is: [0.6983671963214875, 0.4]
# sequential model is trained. best val loss is: [0.6952714866115933, 0.4238095238095238]
# sequential model is trained. best val loss is: [0.6919111070178804, 0.5]
# sequential model is trained. best val loss is: [0.6543645620346069, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.5372816803199905, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.44920890003751907, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6493854838305451, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.6967211397893774, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.6881990009830111, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6264084631488437, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.5181105339810962, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.48120665680062735, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6924639511676062, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6648783167203267, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6490112409705208, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.48044645569863775, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4497578365905654, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.613589383625574, 0.7952380952380952]
# sequential model is trained. best val loss is: [1.0421551773729456, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.5593988194340874, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.44831949171854096, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.7025070450947414, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.9482687541754257, 0.7]
# sequential model is trained. best val loss is: [0.6557972143253182, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6954374463785262, 0.4666666666666667]
# sequential model is trained. best val loss is: [0.6886496504147848, 0.6]
# sequential model is trained. best val loss is: [0.6813848739578611, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5900549965245383, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.47047525406593366, 0.8]
# sequential model is trained. best val loss is: [0.536513193041126, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.9399769710842268, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.9823610389265502, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.6803212004048483, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5741677446024759, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.49304457325488327, 0.780952380952381]
# sequential model is trained. best val loss is: [0.48767170007839533, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6885980770701454, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6512420738027209, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6195341061978114, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.49034787595183366, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.47564671666796565, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.7604376372208642, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.7329492394393132, 0.780952380952381]
# sequential model is trained. best val loss is: [1.4808272070694488, 0.580952380952381]
# sequential model is trained. best val loss is: [0.503704689071047, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.7907009973034926, 0.7476190476190476]
# sequential model is trained. best val loss is: [1.0943852047176672, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6682467455483274, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6960174024105072, 0.4380952380952381]
# sequential model is trained. best val loss is: [0.6829702371642703, 0.6476190476190476]
# sequential model is trained. best val loss is: [0.6676786277975355, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5395672573929742, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4579912679325346, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.670333191513225, 0.7714285714285715]
# sequential model is trained. best val loss is: [1.1351517848268282, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.7802146157915507, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6758358807790847, 0.6761904761904762]
# sequential model is trained. best val loss is: [0.5522195796881403, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4812493701243684, 0.8]
# sequential model is trained. best val loss is: [0.48111015350621616, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6883814218498412, 0.6190476190476191]
# sequential model is trained. best val loss is: [0.63789666110561, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5985794511579332, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.4752399626431898, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.5716221031949357, 0.8]
# sequential model is trained. best val loss is: [1.5545391013937222, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.8523658102244462, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.9175668356308279, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.4973844688523797, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.9280763184200945, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.7322880306511218, 0.8]
# sequential model is trained. best val loss is: [1.1435902018637396, 0.780952380952381]
# sequential model is trained. best val loss is: [0.6854716547897883, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6658768555947713, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.644956287032082, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5094327965662593, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.43686421640978507, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.628753923260527, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.7957185587824657, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.792418107816643, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6682432325113388, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.5558056436124302, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4890490015170404, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4923735595815482, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6800181672686623, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6365114677520025, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.5994851666547003, 0.6285714285714286]
# sequential model is trained. best val loss is: [0.48440045092498796, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.128660648336656, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.6679142121206998, 0.8095238095238095]
# sequential model is trained. best val loss is: [1.0355957057157927, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.8905381338204327, 0.6761904761904762]

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 1, 'unit': 16, 'optimizer': 'adamax', 'lr': 0.02}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[1], units=[16],
         optimizers=['adamax'], lrs=[0.02],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.4089024210675797, 0.8238095238095238]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x15d462e90>],
#  [{'hidden_layer': 1, 'unit': 16, 'optimizer': 'adamax', 'lr': 0.02}],
#  [0.4089024210675797])

# %%
# 2nd trial
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
# Out:
# sequential model is trained. best val loss is: [0.5056127123889469, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4312516643097167, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4832674425983853, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.8929854804329067, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.7052238515445164, 0.44761904761904764]
# sequential model is trained. best val loss is: [0.7016924877961477, 0.4666666666666667]
# sequential model is trained. best val loss is: [0.6978459798154377, 0.4857142857142857]
# sequential model is trained. best val loss is: [0.6697037509509496, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.6075572357291267, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4326189149880693, 0.8]
# sequential model is trained. best val loss is: [0.4089024210675797, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.46065812883415547, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6840250968933106, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.5652462427105223, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.5050124091761453, 0.780952380952381]
# sequential model is trained. best val loss is: [0.4657730593290623, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.693413343883696, 0.6238095238095238]
# sequential model is trained. best val loss is: [0.6208891339245297, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5730396120321183, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.47973595195937724, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.5075222512086233, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4697333046249003, 0.780952380952381]
# sequential model is trained. best val loss is: [0.8075384750285328, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.5764921187052471, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.481188426024857, 0.8]
# sequential model is trained. best val loss is: [0.46391779949503653, 0.8]
# sequential model is trained. best val loss is: [0.5516829994120296, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.6935542208954935, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.7002769044467381, 0.5142857142857142]
# sequential model is trained. best val loss is: [0.6954896031391054, 0.5571428571428572]
# sequential model is trained. best val loss is: [0.6903333424102692, 0.5952380952380952]
# sequential model is trained. best val loss is: [0.6505980768374034, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5732000631945474, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.43233248307037037, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.41546125729232913, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.502373878803296, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6791725090571812, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5603075531976563, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.5076866808391752, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4687587578592467, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.6908405651648839, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6254977011964434, 0.6952380952380952]
# sequential model is trained. best val loss is: [0.5825395389681771, 0.7523809523809524]
# sequential model is trained. best val loss is: [0.48389840331815537, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.48117033111907187, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.5940653206705249, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.836792944061644, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6875952034450407, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.45488514661611545, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.47292523966248373, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5500168898288892, 0.7857142857142857]
# sequential model is trained. best val loss is: [1.0553713955796586, 0.6571428571428571]
# sequential model is trained. best val loss is: [0.6906886302289509, 0.580952380952381]
# sequential model is trained. best val loss is: [0.6829614554132734, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.674720632746106, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.6170558554785592, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.5252950279485612, 0.780952380952381]
# sequential model is trained. best val loss is: [0.4170729868913657, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.41380418662461343, 0.8333333333333334]
# sequential model is trained. best val loss is: [0.5480832566682022, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6601423706327166, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5358255572262265, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.49371256430943805, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4656185878507261, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6775767139026097, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.5995975968383608, 0.7333333333333333]
# sequential model is trained. best val loss is: [0.5591198753033365, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.478618012608162, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.45410968666186646, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6371388995533628, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.7772114978578392, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.7592396131145093, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.444769456239772, 0.8]
# sequential model is trained. best val loss is: [0.533352964754935, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.5378910083571719, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6753737256482719, 0.8476190476190476]
# sequential model is trained. best val loss is: [0.6842894051756178, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6738390218643915, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.663086107798985, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5982665280501048, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.503926631701844, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4128362318551808, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.43271120413730085, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.504217337997729, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6531000676609221, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5376004228279704, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4936251262468951, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4664635476462233, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6719010821410588, 0.6714285714285714]
# sequential model is trained. best val loss is: [0.602117641766866, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5638298600912094, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.4779352947404342, 0.780952380952381]
# sequential model is trained. best val loss is: [0.44417189569655985, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.8692396074077449, 0.7904761904761904]
# sequential model is trained. best val loss is: [1.3862832418504984, 0.780952380952381]
# sequential model is trained. best val loss is: [2.4958902076257607, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4305877543170936, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.5560523310351994, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.610713395581902, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.7443376286994668, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.6709938023771559, 0.6619047619047619]
# sequential model is trained. best val loss is: [0.6567230376459303, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.6427907926695687, 0.719047619047619]
# sequential model is trained. best val loss is: [0.5711960545607976, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4791726532081763, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.4147759841058186, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.4474124598756031, 0.8333333333333334]
# sequential model is trained. best val loss is: [0.5570989639697039, 0.8]
# sequential model is trained. best val loss is: [0.6380643952460516, 0.719047619047619]
# sequential model is trained. best val loss is: [0.528088444684233, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.4893624773692517, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.46541398715815463, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6583613250936781, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.5910201864583152, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5545972952530498, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.47704161766561726, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4281045636871741, 0.819047619047619]
# sequential model is trained. best val loss is: [1.1364211223195464, 0.7857142857142857]
# sequential model is trained. best val loss is: [1.721497311931461, 0.780952380952381]
# sequential model is trained. best val loss is: [2.799130327581554, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.47972607676471984, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.5731397478872867, 0.780952380952381]
# sequential model is trained. best val loss is: [0.6665528700754443, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.9340088577299498, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6885807741255987, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6861700208414169, 0.6]
# sequential model is trained. best val loss is: [0.6836212484609513, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.6636287903501874, 0.7]
# sequential model is trained. best val loss is: [0.6055984814961751, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.41696039801019996, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4440592119638625, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.7531262631630231, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.6774893320742108, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5848342623029437, 0.7333333333333333]
# sequential model is trained. best val loss is: [0.5061875302876745, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4650271961687221, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6827258740152632, 0.6190476190476191]
# sequential model is trained. best val loss is: [0.6441257439908528, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.6090569772890636, 0.6952380952380952]
# sequential model is trained. best val loss is: [0.48364669355075984, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.48823977872019725, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.0024041475509256, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.7227864961404876, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.8146860188246772, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.4551114236603358, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6243431067796456, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.7736334614891509, 0.8]
# sequential model is trained. best val loss is: [0.9738289707924579, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.6958698116597675, 0.47619047619047616]
# sequential model is trained. best val loss is: [0.6920846663770222, 0.6]
# sequential model is trained. best val loss is: [0.6877509520167396, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6467930954127085, 0.7]
# sequential model is trained. best val loss is: [0.5597920392240797, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.43209662279165234, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5199624398686117, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.6245196960376592, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.6837447379316602, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.590048724483876, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5163814365154221, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.47495338596026637, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6907316185179211, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6487432492630822, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6159410594474701, 0.638095238095238]
# sequential model is trained. best val loss is: [0.48815685252525975, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.45660182982904923, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6983940288980846, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.7059340664424341, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.6019252977037707, 0.819047619047619]
# sequential model is trained. best val loss is: [0.43370960868446023, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.7547910889154495, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.897508528037455, 0.7714285714285715]
# sequential model is trained. best val loss is: [1.3997814215378885, 0.6761904761904762]
# sequential model is trained. best val loss is: [0.7006251116593679, 0.3952380952380952]
# sequential model is trained. best val loss is: [0.6941998036134811, 0.5285714285714286]
# sequential model is trained. best val loss is: [0.6873284288815089, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6168740224270594, 0.719047619047619]
# sequential model is trained. best val loss is: [0.4953321901992673, 0.8]
# sequential model is trained. best val loss is: [0.45392724149514124, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.516036893373707, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.7940605743368621, 0.7142857142857143]
# sequential model is trained. best val loss is: [0.6847851395606994, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5832649446669079, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.5072844066080593, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.48701941767039464, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6936229297092983, 0.5333333333333333]
# sequential model is trained. best val loss is: [0.6496150228239241, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6178677114702407, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.4821361077084605, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.43534831358798937, 0.819047619047619]
# sequential model is trained. best val loss is: [0.5594471426419487, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6467958082894107, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.9101828697782115, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.41400912369241444, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.7318134923380494, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.8955611057844082, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.6196909401349028, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.7005706829684121, 0.4142857142857143]
# sequential model is trained. best val loss is: [0.6878820924531845, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6748046142714365, 0.6476190476190476]
# sequential model is trained. best val loss is: [0.5791272501150767, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.46486015698118577, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4932193775570554, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6890069043024577, 0.7476190476190476]
# sequential model is trained. best val loss is: [0.646416336973879, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6785476837839399, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.5593139094965799, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.4906451287368933, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.47874912069777825, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6917616449651264, 0.5523809523809524]
# sequential model is trained. best val loss is: [0.6377277489219393, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.5981358484143302, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.47447179924430594, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.42103864962283255, 0.8476190476190476]
# sequential model is trained. best val loss is: [0.8210755357030464, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.5491227996842336, 0.7714285714285715]
# sequential model is trained. best val loss is: [3.8804435044317995, 0.4857142857142857]
# sequential model is trained. best val loss is: [0.4411342995948828, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.7197679189676736, 0.7952380952380952]
# sequential model is trained. best val loss is: [1.31255206665564, 0.6571428571428571]
# sequential model is trained. best val loss is: [0.7157126900193451, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.6834070381664095, 0.6571428571428571]
# sequential model is trained. best val loss is: [0.66202265166101, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.6418683703456606, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.531513501774697, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4460442071722355, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.5301544880739179, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6390665348241891, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.8024658742134075, 0.780952380952381]
# sequential model is trained. best val loss is: [0.6577600694838024, 0.6666666666666666]
# sequential model is trained. best val loss is: [0.5380335934105374, 0.780952380952381]
# sequential model is trained. best val loss is: [0.481068615136402, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.4887992623026505, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.6744953166870844, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.616271802357265, 0.6428571428571429]
# sequential model is trained. best val loss is: [0.5758305639028549, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.47128906252882663, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.5730122473409361, 0.7952380952380952]
# sequential model is trained. best val loss is: [1.3583906563261372, 0.7857142857142857]
# sequential model is trained. best val loss is: [1.1252002483119508, 0.7714285714285715]
# sequential model is trained. best val loss is: [1.239464801016679, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.4529867312560479, 0.7857142857142857]
# sequential model is trained. best val loss is: [0.7208411761711055, 0.8]
# sequential model is trained. best val loss is: [1.0752844408809639, 0.6761904761904762]
# sequential model is trained. best val loss is: [0.6955700614573328, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.6965196958609989, 0.4238095238095238]
# sequential model is trained. best val loss is: [0.6947088332403274, 0.48095238095238096]
# sequential model is trained. best val loss is: [0.6928139116082873, 0.5333333333333333]
# sequential model is trained. best val loss is: [0.6756916775589897, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.5892243183794476, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4324733919403072, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.558557424232782, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.7930425654346119, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.6898031413555146, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6122197978553318, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5039185406906265, 0.780952380952381]
# sequential model is trained. best val loss is: [0.47358290987488416, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6925778156235105, 0.5761904761904761]
# sequential model is trained. best val loss is: [0.6687783340613047, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6446659566391082, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.4878197803649874, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.4575229064517078, 0.8238095238095238]
# sequential model is trained. best val loss is: [0.7097529855542981, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.5381015593794723, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.827101477967459, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.44372366249029127, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.8609282703411643, 0.819047619047619]
# sequential model is trained. best val loss is: [1.385367704941648, 0.6285714285714286]
# sequential model is trained. best val loss is: [1.0801548574709021, 0.7476190476190476]
# sequential model is trained. best val loss is: [0.6983671963214875, 0.4]
# sequential model is trained. best val loss is: [0.6952714866115933, 0.4238095238095238]
# sequential model is trained. best val loss is: [0.6919111070178804, 0.5]
# sequential model is trained. best val loss is: [0.6543645620346069, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.5372816803199905, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.44920890003751907, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6493854838305451, 0.7428571428571429]
# sequential model is trained. best val loss is: [0.6967211397893774, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.6881990009830111, 0.638095238095238]
# sequential model is trained. best val loss is: [0.6264084631488437, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.5181105339810962, 0.7714285714285715]
# sequential model is trained. best val loss is: [0.48120665680062735, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.6924639511676062, 0.5857142857142857]
# sequential model is trained. best val loss is: [0.6648783167203267, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6490112409705208, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.48044645569863775, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.4497578365905654, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.613589383625574, 0.7952380952380952]
# sequential model is trained. best val loss is: [1.0421551773729456, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.5593988194340874, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.44831949171854096, 0.8428571428571429]
# sequential model is trained. best val loss is: [0.7025070450947414, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.9482687541754257, 0.7]
# sequential model is trained. best val loss is: [0.6557972143253182, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6954374463785262, 0.4666666666666667]
# sequential model is trained. best val loss is: [0.6886496504147848, 0.6]
# sequential model is trained. best val loss is: [0.6813848739578611, 0.7047619047619048]
# sequential model is trained. best val loss is: [0.5900549965245383, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.47047525406593366, 0.8]
# sequential model is trained. best val loss is: [0.536513193041126, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.9399769710842268, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.9823610389265502, 0.6904761904761905]
# sequential model is trained. best val loss is: [0.6803212004048483, 0.6523809523809524]
# sequential model is trained. best val loss is: [0.5741677446024759, 0.7238095238095238]
# sequential model is trained. best val loss is: [0.49304457325488327, 0.780952380952381]
# sequential model is trained. best val loss is: [0.48767170007839533, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6885980770701454, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6512420738027209, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6195341061978114, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.49034787595183366, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.47564671666796565, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.7604376372208642, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.7329492394393132, 0.780952380952381]
# sequential model is trained. best val loss is: [1.4808272070694488, 0.580952380952381]
# sequential model is trained. best val loss is: [0.503704689071047, 0.8380952380952381]
# sequential model is trained. best val loss is: [0.7907009973034926, 0.7476190476190476]
# sequential model is trained. best val loss is: [1.0943852047176672, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6682467455483274, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6960174024105072, 0.4380952380952381]
# sequential model is trained. best val loss is: [0.6829702371642703, 0.6476190476190476]
# sequential model is trained. best val loss is: [0.6676786277975355, 0.7285714285714285]
# sequential model is trained. best val loss is: [0.5395672573929742, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.4579912679325346, 0.8047619047619048]
# sequential model is trained. best val loss is: [0.670333191513225, 0.7714285714285715]
# sequential model is trained. best val loss is: [1.1351517848268282, 0.6333333333333333]
# sequential model is trained. best val loss is: [0.7802146157915507, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6758358807790847, 0.6761904761904762]
# sequential model is trained. best val loss is: [0.5522195796881403, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4812493701243684, 0.8]
# sequential model is trained. best val loss is: [0.48111015350621616, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.6883814218498412, 0.6190476190476191]
# sequential model is trained. best val loss is: [0.63789666110561, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5985794511579332, 0.6857142857142857]
# sequential model is trained. best val loss is: [0.4752399626431898, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.5716221031949357, 0.8]
# sequential model is trained. best val loss is: [1.5545391013937222, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.8523658102244462, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.9175668356308279, 0.7571428571428571]
# sequential model is trained. best val loss is: [0.4973844688523797, 0.8285714285714286]
# sequential model is trained. best val loss is: [0.9280763184200945, 0.7619047619047619]
# sequential model is trained. best val loss is: [0.7322880306511218, 0.8]
# sequential model is trained. best val loss is: [1.1435902018637396, 0.780952380952381]
# sequential model is trained. best val loss is: [0.6854716547897883, 0.6142857142857143]
# sequential model is trained. best val loss is: [0.6658768555947713, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.644956287032082, 0.6095238095238096]
# sequential model is trained. best val loss is: [0.5094327965662593, 0.7952380952380952]
# sequential model is trained. best val loss is: [0.43686421640978507, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.628753923260527, 0.8142857142857143]
# sequential model is trained. best val loss is: [0.7957185587824657, 0.7380952380952381]
# sequential model is trained. best val loss is: [0.792418107816643, 0.819047619047619]
# sequential model is trained. best val loss is: [0.6682432325113388, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.5558056436124302, 0.7666666666666667]
# sequential model is trained. best val loss is: [0.4890490015170404, 0.7904761904761904]
# sequential model is trained. best val loss is: [0.4923735595815482, 0.8095238095238095]
# sequential model is trained. best val loss is: [0.6800181672686623, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.6365114677520025, 0.6047619047619047]
# sequential model is trained. best val loss is: [0.5994851666547003, 0.6285714285714286]
# sequential model is trained. best val loss is: [0.48440045092498796, 0.8047619047619048]
# sequential model is trained. best val loss is: [1.128660648336656, 0.7761904761904762]
# sequential model is trained. best val loss is: [0.6679142121206998, 0.8095238095238095]
# sequential model is trained. best val loss is: [1.0355957057157927, 0.7095238095238096]
# sequential model is trained. best val loss is: [0.8905381338204327, 0.6761904761904762]

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 1, 'unit': 16, 'optimizer': 'adamax', 'lr': 0.02}
