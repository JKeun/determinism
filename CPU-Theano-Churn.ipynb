# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename="./data/Churn_Modelling.csv"
ds = DataSource(filename)
ds.data_load_split(target=['Exited'], 
                   ignore=["RowNumber", "CustomerId", "Surname"])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)

# %%
# tensorflow
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.3680907416343689, 0.8475]
# sequential model is trained. best val loss is: [0.33560698556900026, 0.867]
# sequential model is trained. best val loss is: [0.3342642140388489, 0.8645]
# sequential model is trained. best val loss is: [0.3371084995269775, 0.8615]
# sequential model is trained. best val loss is: [0.9540332164764405, 0.31]
# sequential model is trained. best val loss is: [0.8262920985221863, 0.4]
# sequential model is trained. best val loss is: [0.7237344064712524, 0.5285]
# sequential model is trained. best val loss is: [0.4625368161201477, 0.796]
# sequential model is trained. best val loss is: [0.40608916139602663, 0.8255]
# sequential model is trained. best val loss is: [0.3394242453575134, 0.865]
# sequential model is trained. best val loss is: [0.33640674948692323, 0.8675]
# sequential model is trained. best val loss is: [0.3331810290813446, 0.8645]
# sequential model is trained. best val loss is: [0.6710990009307861, 0.5995]
# sequential model is trained. best val loss is: [0.4105424561500549, 0.822]
# sequential model is trained. best val loss is: [0.39234609627723693, 0.833]
# sequential model is trained. best val loss is: [0.34130953097343447, 0.8625]
# sequential model is trained. best val loss is: [0.5497275447845459, 0.7515]
# sequential model is trained. best val loss is: [0.4200468456745148, 0.8155]
# sequential model is trained. best val loss is: [0.40531679868698123, 0.8245]
# sequential model is trained. best val loss is: [0.3419898045063019, 0.8635]
# sequential model is trained. best val loss is: [0.3626509914398193, 0.8515]
# sequential model is trained. best val loss is: [0.3430259909629822, 0.8585]
# sequential model is trained. best val loss is: [0.3431369614601135, 0.8625]
# sequential model is trained. best val loss is: [0.3455528571605682, 0.854]
# sequential model is trained. best val loss is: [0.34438513922691344, 0.8585]
# sequential model is trained. best val loss is: [0.3291589298248291, 0.87]
# sequential model is trained. best val loss is: [0.32955014729499815, 0.868]
# sequential model is trained. best val loss is: [0.34178899335861207, 0.8585]
# sequential model is trained. best val loss is: [0.9236068787574768, 0.2645]
# sequential model is trained. best val loss is: [0.7658793306350709, 0.426]
# sequential model is trained. best val loss is: [0.6545568752288818, 0.624]
# sequential model is trained. best val loss is: [0.43645852279663083, 0.8095]
# sequential model is trained. best val loss is: [0.38130101990699766, 0.8455]
# sequential model is trained. best val loss is: [0.33971895813941955, 0.8645]
# sequential model is trained. best val loss is: [0.33405305743217467, 0.8645]
# sequential model is trained. best val loss is: [0.3360329964160919, 0.8615]
# sequential model is trained. best val loss is: [0.6117919921875, 0.697]
# sequential model is trained. best val loss is: [0.390545948266983, 0.8395]
# sequential model is trained. best val loss is: [0.35784452366828917, 0.853]
# sequential model is trained. best val loss is: [0.338549236536026, 0.866]
# sequential model is trained. best val loss is: [0.561681335926056, 0.7595]
# sequential model is trained. best val loss is: [0.4135090184211731, 0.8245]
# sequential model is trained. best val loss is: [0.38807475328445434, 0.8415]
# sequential model is trained. best val loss is: [0.34049587082862853, 0.864]
# sequential model is trained. best val loss is: [0.34415051794052126, 0.859]
# sequential model is trained. best val loss is: [0.3376833114624023, 0.86]
# sequential model is trained. best val loss is: [0.3372365021705627, 0.861]
# sequential model is trained. best val loss is: [0.3486001834869385, 0.8555]
# sequential model is trained. best val loss is: [0.3420356740951538, 0.862]
# sequential model is trained. best val loss is: [0.33268283343315125, 0.8625]
# sequential model is trained. best val loss is: [0.33387691926956176, 0.865]
# sequential model is trained. best val loss is: [0.345213570356369, 0.8585]
# sequential model is trained. best val loss is: [0.83416805934906, 0.2595]
# sequential model is trained. best val loss is: [0.6412912564277649, 0.675]
# sequential model is trained. best val loss is: [0.5387863612174988, 0.8015]
# sequential model is trained. best val loss is: [0.4128926010131836, 0.8215]
# sequential model is trained. best val loss is: [0.3654522562026978, 0.849]
# sequential model is trained. best val loss is: [0.339689514875412, 0.8645]
# sequential model is trained. best val loss is: [0.33533379769325256, 0.8675]
# sequential model is trained. best val loss is: [0.3386562216281891, 0.8625]
# sequential model is trained. best val loss is: [0.5172266130447387, 0.8035]
# sequential model is trained. best val loss is: [0.3822697947025299, 0.8395]
# sequential model is trained. best val loss is: [0.3536314854621887, 0.8565]
# sequential model is trained. best val loss is: [0.3382499253749847, 0.865]
# sequential model is trained. best val loss is: [0.5144284257888794, 0.8045]
# sequential model is trained. best val loss is: [0.40653773045539854, 0.82]
# sequential model is trained. best val loss is: [0.38297106003761294, 0.841]
# sequential model is trained. best val loss is: [0.34091029596328737, 0.8655]
# sequential model is trained. best val loss is: [0.3421248028278351, 0.8625]
# sequential model is trained. best val loss is: [0.33769053101539614, 0.866]
# sequential model is trained. best val loss is: [0.3343866534233093, 0.865]
# sequential model is trained. best val loss is: [0.3488343036174774, 0.857]
# sequential model is trained. best val loss is: [0.34042253756523133, 0.8625]
# sequential model is trained. best val loss is: [0.33265263986587523, 0.8705]
# sequential model is trained. best val loss is: [0.33328101205825805, 0.866]
# sequential model is trained. best val loss is: [0.3426813592910767, 0.8595]
# sequential model is trained. best val loss is: [0.7722467870712281, 0.3365]
# sequential model is trained. best val loss is: [0.5642143859863281, 0.8075]
# sequential model is trained. best val loss is: [0.480773313999176, 0.8065]
# sequential model is trained. best val loss is: [0.3991285138130188, 0.8255]
# sequential model is trained. best val loss is: [0.35522856879234316, 0.856]
# sequential model is trained. best val loss is: [0.3370194549560547, 0.8635]
# sequential model is trained. best val loss is: [0.33483668804168704, 0.865]
# sequential model is trained. best val loss is: [0.3420656008720398, 0.859]
# sequential model is trained. best val loss is: [0.4788394999504089, 0.8055]
# sequential model is trained. best val loss is: [0.3767532243728638, 0.84]
# sequential model is trained. best val loss is: [0.3490360035896301, 0.8575]
# sequential model is trained. best val loss is: [0.33848569488525393, 0.8635]
# sequential model is trained. best val loss is: [0.4952613458633423, 0.8045]
# sequential model is trained. best val loss is: [0.4039436626434326, 0.823]
# sequential model is trained. best val loss is: [0.38291550397872925, 0.8335]
# sequential model is trained. best val loss is: [0.34003576469421387, 0.86]
# sequential model is trained. best val loss is: [0.3403584702014923, 0.863]
# sequential model is trained. best val loss is: [0.33902127408981325, 0.8635]
# sequential model is trained. best val loss is: [0.33624407839775083, 0.8645]
# sequential model is trained. best val loss is: [0.35914995408058165, 0.8585]
# sequential model is trained. best val loss is: [0.3394235646724701, 0.8665]
# sequential model is trained. best val loss is: [0.33233061170578004, 0.8665]
# sequential model is trained. best val loss is: [0.33296736526489257, 0.869]
# sequential model is trained. best val loss is: [0.3437041923999786, 0.861]
# sequential model is trained. best val loss is: [0.7806270685195923, 0.246]
# sequential model is trained. best val loss is: [0.530572509765625, 0.803]
# sequential model is trained. best val loss is: [0.46146501874923707, 0.8035]
# sequential model is trained. best val loss is: [0.3910767865180969, 0.8295]
# sequential model is trained. best val loss is: [0.3456966269016266, 0.861]
# sequential model is trained. best val loss is: [0.33387121868133546, 0.8665]
# sequential model is trained. best val loss is: [0.3317445991039276, 0.867]
# sequential model is trained. best val loss is: [0.3404604799747467, 0.863]
# sequential model is trained. best val loss is: [0.4718801140785217, 0.8035]
# sequential model is trained. best val loss is: [0.37451449704170225, 0.843]
# sequential model is trained. best val loss is: [0.34668738079071043, 0.86]
# sequential model is trained. best val loss is: [0.33719590997695925, 0.8685]
# sequential model is trained. best val loss is: [0.49994821166992187, 0.8035]
# sequential model is trained. best val loss is: [0.40751695942878724, 0.823]
# sequential model is trained. best val loss is: [0.3856778969764709, 0.836]
# sequential model is trained. best val loss is: [0.3400794560909271, 0.8645]
# sequential model is trained. best val loss is: [0.34007838439941407, 0.867]
# sequential model is trained. best val loss is: [0.3399532597064972, 0.865]
# sequential model is trained. best val loss is: [0.3415278143882751, 0.8615]
# sequential model is trained. best val loss is: [0.3459976489543915, 0.864]
# sequential model is trained. best val loss is: [0.345151517868042, 0.858]
# sequential model is trained. best val loss is: [0.34289483332633974, 0.8585]
# sequential model is trained. best val loss is: [0.335587530374527, 0.865]
# sequential model is trained. best val loss is: [0.34779822182655334, 0.862]
# sequential model is trained. best val loss is: [0.6236725506782532, 0.7415]
# sequential model is trained. best val loss is: [0.5574537835121155, 0.798]
# sequential model is trained. best val loss is: [0.5206601400375366, 0.8025]
# sequential model is trained. best val loss is: [0.4416211242675781, 0.806]
# sequential model is trained. best val loss is: [0.3960553216934204, 0.8305]
# sequential model is trained. best val loss is: [0.3371204264163971, 0.8605]
# sequential model is trained. best val loss is: [0.33508101844787597, 0.865]
# sequential model is trained. best val loss is: [0.3396379699707031, 0.8655]
# sequential model is trained. best val loss is: [0.5066859197616577, 0.803]
# sequential model is trained. best val loss is: [0.4033739838600159, 0.83]
# sequential model is trained. best val loss is: [0.3654479465484619, 0.8545]
# sequential model is trained. best val loss is: [0.33573648500442504, 0.866]
# sequential model is trained. best val loss is: [0.5110522050857544, 0.803]
# sequential model is trained. best val loss is: [0.42702665901184084, 0.8105]
# sequential model is trained. best val loss is: [0.40442782974243163, 0.8285]
# sequential model is trained. best val loss is: [0.340451399564743, 0.8635]
# sequential model is trained. best val loss is: [0.34750171422958376, 0.858]
# sequential model is trained. best val loss is: [0.3382431290149689, 0.864]
# sequential model is trained. best val loss is: [0.335009006023407, 0.8625]
# sequential model is trained. best val loss is: [0.34872388911247254, 0.8675]
# sequential model is trained. best val loss is: [0.33644364261627197, 0.862]
# sequential model is trained. best val loss is: [0.34045472550392153, 0.86]
# sequential model is trained. best val loss is: [0.3369125692844391, 0.8645]
# sequential model is trained. best val loss is: [0.34512218594551086, 0.8625]
# sequential model is trained. best val loss is: [0.667766676902771, 0.616]
# sequential model is trained. best val loss is: [0.5427258458137513, 0.8035]
# sequential model is trained. best val loss is: [0.49675138330459595, 0.8035]
# sequential model is trained. best val loss is: [0.4117119433879852, 0.8175]
# sequential model is trained. best val loss is: [0.3698853986263275, 0.841]
# sequential model is trained. best val loss is: [0.3331892077922821, 0.8645]
# sequential model is trained. best val loss is: [0.3423943445682526, 0.8585]
# sequential model is trained. best val loss is: [0.3446065809726715, 0.8635]
# sequential model is trained. best val loss is: [0.492370602607727, 0.804]
# sequential model is trained. best val loss is: [0.3845930631160736, 0.8365]
# sequential model is trained. best val loss is: [0.34902119493484496, 0.8535]
# sequential model is trained. best val loss is: [0.33285996270179746, 0.8655]
# sequential model is trained. best val loss is: [0.5104807868003846, 0.8035]
# sequential model is trained. best val loss is: [0.4149537961483002, 0.816]
# sequential model is trained. best val loss is: [0.39035025095939635, 0.8335]
# sequential model is trained. best val loss is: [0.33536855268478394, 0.8645]
# sequential model is trained. best val loss is: [0.3378807961940765, 0.8625]
# sequential model is trained. best val loss is: [0.3473028376102448, 0.8575]
# sequential model is trained. best val loss is: [0.35396488547325133, 0.8575]
# sequential model is trained. best val loss is: [0.34259930896759033, 0.8625]
# sequential model is trained. best val loss is: [0.3402776048183441, 0.8625]
# sequential model is trained. best val loss is: [0.3379396414756775, 0.8635]
# sequential model is trained. best val loss is: [0.33593207120895385, 0.8615]
# sequential model is trained. best val loss is: [0.3592202961444855, 0.85]
# sequential model is trained. best val loss is: [0.6200923089981079, 0.768]
# sequential model is trained. best val loss is: [0.49695782852172854, 0.8035]
# sequential model is trained. best val loss is: [0.45720166063308715, 0.8045]
# sequential model is trained. best val loss is: [0.38111649942398074, 0.839]
# sequential model is trained. best val loss is: [0.34473815822601317, 0.857]
# sequential model is trained. best val loss is: [0.3395554296970367, 0.864]
# sequential model is trained. best val loss is: [0.3414430503845215, 0.861]
# sequential model is trained. best val loss is: [0.33880638527870177, 0.8595]
# sequential model is trained. best val loss is: [0.46954252195358276, 0.8035]
# sequential model is trained. best val loss is: [0.35604823207855224, 0.857]
# sequential model is trained. best val loss is: [0.3415765378475189, 0.86]
# sequential model is trained. best val loss is: [0.3361461617946625, 0.8655]
# sequential model is trained. best val loss is: [0.5040331926345826, 0.8035]
# sequential model is trained. best val loss is: [0.39611687898635867, 0.8285]
# sequential model is trained. best val loss is: [0.36478206849098205, 0.853]
# sequential model is trained. best val loss is: [0.33853730535507204, 0.861]
# sequential model is trained. best val loss is: [0.339894385099411, 0.862]
# sequential model is trained. best val loss is: [0.34549207735061643, 0.861]
# sequential model is trained. best val loss is: [0.3401134641170502, 0.865]
# sequential model is trained. best val loss is: [0.3560570275783539, 0.8575]
# sequential model is trained. best val loss is: [0.33381259179115297, 0.859]
# sequential model is trained. best val loss is: [0.3492285623550415, 0.8595]
# sequential model is trained. best val loss is: [0.3370769267082214, 0.8675]
# sequential model is trained. best val loss is: [0.3559045302867889, 0.8535]
# sequential model is trained. best val loss is: [0.6861554226875305, 0.552]
# sequential model is trained. best val loss is: [0.4702427930831909, 0.8035]
# sequential model is trained. best val loss is: [0.434543231010437, 0.809]
# sequential model is trained. best val loss is: [0.36561774373054506, 0.849]
# sequential model is trained. best val loss is: [0.3383485298156738, 0.8625]
# sequential model is trained. best val loss is: [0.3409957897663116, 0.858]
# sequential model is trained. best val loss is: [0.33786102652549743, 0.859]
# sequential model is trained. best val loss is: [0.3370995397567749, 0.858]
# sequential model is trained. best val loss is: [0.46124924516677857, 0.8035]
# sequential model is trained. best val loss is: [0.3546276483535767, 0.854]
# sequential model is trained. best val loss is: [0.34116697335243223, 0.862]
# sequential model is trained. best val loss is: [0.33527755331993103, 0.8665]
# sequential model is trained. best val loss is: [0.5003662648200988, 0.8035]
# sequential model is trained. best val loss is: [0.3999433624744415, 0.8275]
# sequential model is trained. best val loss is: [0.3688262813091278, 0.8455]
# sequential model is trained. best val loss is: [0.339722341299057, 0.8645]
# sequential model is trained. best val loss is: [0.3360039014816284, 0.8645]
# sequential model is trained. best val loss is: [0.35655968165397645, 0.858]
# sequential model is trained. best val loss is: [0.3645406928062439, 0.8555]
# sequential model is trained. best val loss is: [0.3611733469963074, 0.8655]
# sequential model is trained. best val loss is: [0.3364314787387848, 0.8635]
# sequential model is trained. best val loss is: [0.33469959926605225, 0.8645]
# sequential model is trained. best val loss is: [0.34087975311279295, 0.8655]
# sequential model is trained. best val loss is: [0.3537864151000977, 0.854]
# sequential model is trained. best val loss is: [0.5826225085258484, 0.8035]
# sequential model is trained. best val loss is: [0.44294626379013063, 0.8045]
# sequential model is trained. best val loss is: [0.4124683184623718, 0.8235]
# sequential model is trained. best val loss is: [0.3498211660385132, 0.8605]
# sequential model is trained. best val loss is: [0.3377109375, 0.868]
# sequential model is trained. best val loss is: [0.34196380162239076, 0.8635]
# sequential model is trained. best val loss is: [0.33961841177940366, 0.868]
# sequential model is trained. best val loss is: [0.35404199731349945, 0.8595]
# sequential model is trained. best val loss is: [0.44952448225021363, 0.8035]
# sequential model is trained. best val loss is: [0.348703444480896, 0.858]
# sequential model is trained. best val loss is: [0.338985319852829, 0.8645]
# sequential model is trained. best val loss is: [0.3362452290058136, 0.866]
# sequential model is trained. best val loss is: [0.486974102973938, 0.8035]
# sequential model is trained. best val loss is: [0.394911509513855, 0.8325]
# sequential model is trained. best val loss is: [0.364342761516571, 0.851]
# sequential model is trained. best val loss is: [0.33683900237083436, 0.869]
# sequential model is trained. best val loss is: [0.34172933459281923, 0.864]
# sequential model is trained. best val loss is: [0.3370696997642517, 0.8615]
# sequential model is trained. best val loss is: [0.3431547198295593, 0.8645]
# sequential model is trained. best val loss is: [0.37255677723884584, 0.8545]
# sequential model is trained. best val loss is: [0.34168018484115603, 0.8625]
# sequential model is trained. best val loss is: [0.33630736875534056, 0.8625]
# sequential model is trained. best val loss is: [0.3294893183708191, 0.865]
# sequential model is trained. best val loss is: [0.34438669395446775, 0.8615]
# sequential model is trained. best val loss is: [0.7286284413337708, 0.3065]
# sequential model is trained. best val loss is: [0.6285824313163757, 0.7805]
# sequential model is trained. best val loss is: [0.5395589423179626, 0.803]
# sequential model is trained. best val loss is: [0.41757405328750613, 0.8225]
# sequential model is trained. best val loss is: [0.38724125051498415, 0.835]
# sequential model is trained. best val loss is: [0.3363655550479889, 0.86]
# sequential model is trained. best val loss is: [0.3355809075832367, 0.8615]
# sequential model is trained. best val loss is: [0.3467286956310272, 0.86]
# sequential model is trained. best val loss is: [0.5517920227050781, 0.8025]
# sequential model is trained. best val loss is: [0.3983908171653748, 0.8285]
# sequential model is trained. best val loss is: [0.36585642099380494, 0.852]
# sequential model is trained. best val loss is: [0.3337524435520172, 0.862]
# sequential model is trained. best val loss is: [0.5391926221847534, 0.8035]
# sequential model is trained. best val loss is: [0.42197178268432617, 0.823]
# sequential model is trained. best val loss is: [0.39861790418624876, 0.828]
# sequential model is trained. best val loss is: [0.33586956071853635, 0.8665]
# sequential model is trained. best val loss is: [0.34367840814590456, 0.86]
# sequential model is trained. best val loss is: [0.34278009247779845, 0.8585]
# sequential model is trained. best val loss is: [0.3530842580795288, 0.861]
# sequential model is trained. best val loss is: [0.37209467029571536, 0.85]
# sequential model is trained. best val loss is: [0.34076971650123594, 0.8565]
# sequential model is trained. best val loss is: [0.3376878345012665, 0.8665]
# sequential model is trained. best val loss is: [0.33900523209571837, 0.861]
# sequential model is trained. best val loss is: [0.42272825503349304, 0.8035]
# sequential model is trained. best val loss is: [0.6873775420188903, 0.5715]
# sequential model is trained. best val loss is: [0.5491091666221619, 0.8035]
# sequential model is trained. best val loss is: [0.48689995670318603, 0.8035]
# sequential model is trained. best val loss is: [0.40494096422195436, 0.8215]
# sequential model is trained. best val loss is: [0.35416459608078005, 0.853]
# sequential model is trained. best val loss is: [0.3384857120513916, 0.859]
# sequential model is trained. best val loss is: [0.34029663395881654, 0.8575]
# sequential model is trained. best val loss is: [0.34120143628120425, 0.863]
# sequential model is trained. best val loss is: [0.5058920497894287, 0.8035]
# sequential model is trained. best val loss is: [0.37701179122924805, 0.841]
# sequential model is trained. best val loss is: [0.34651364374160765, 0.8565]
# sequential model is trained. best val loss is: [0.34280750584602354, 0.8605]
# sequential model is trained. best val loss is: [0.52804891872406, 0.8035]
# sequential model is trained. best val loss is: [0.4299490466117859, 0.8085]
# sequential model is trained. best val loss is: [0.3926476924419403, 0.829]
# sequential model is trained. best val loss is: [0.340139963388443, 0.8595]
# sequential model is trained. best val loss is: [0.3400753011703491, 0.8585]
# sequential model is trained. best val loss is: [0.36037680435180663, 0.8565]
# sequential model is trained. best val loss is: [0.34611203575134275, 0.8625]
# sequential model is trained. best val loss is: [0.3668763692378998, 0.8575]
# sequential model is trained. best val loss is: [0.33809093189239503, 0.8625]
# sequential model is trained. best val loss is: [0.3405708465576172, 0.8625]
# sequential model is trained. best val loss is: [0.34201200485229494, 0.86]
# sequential model is trained. best val loss is: [0.38479546546936033, 0.8565]
# sequential model is trained. best val loss is: [0.6854655599594116, 0.5485]
# sequential model is trained. best val loss is: [0.5032217602729797, 0.8035]
# sequential model is trained. best val loss is: [0.45226026248931883, 0.8035]
# sequential model is trained. best val loss is: [0.3655004167556763, 0.8475]
# sequential model is trained. best val loss is: [0.341049480676651, 0.8625]
# sequential model is trained. best val loss is: [0.342458785533905, 0.859]
# sequential model is trained. best val loss is: [0.34166471266746523, 0.8635]
# sequential model is trained. best val loss is: [0.3389019021987915, 0.863]
# sequential model is trained. best val loss is: [0.48864016246795655, 0.8035]
# sequential model is trained. best val loss is: [0.3505604462623596, 0.8555]
# sequential model is trained. best val loss is: [0.33928171229362486, 0.8635]
# sequential model is trained. best val loss is: [0.3400972282886505, 0.864]
# sequential model is trained. best val loss is: [0.5292774529457093, 0.8035]
# sequential model is trained. best val loss is: [0.40058211660385135, 0.822]
# sequential model is trained. best val loss is: [0.36194312930107114, 0.8485]
# sequential model is trained. best val loss is: [0.3372562265396118, 0.865]
# sequential model is trained. best val loss is: [0.3376403415203095, 0.8675]
# sequential model is trained. best val loss is: [0.3430478720664978, 0.8565]
# sequential model is trained. best val loss is: [0.3786679146289825, 0.8645]
# sequential model is trained. best val loss is: [0.3670633263587952, 0.8455]
# sequential model is trained. best val loss is: [0.344237566947937, 0.866]
# sequential model is trained. best val loss is: [0.3418402042388916, 0.8645]
# sequential model is trained. best val loss is: [0.3401305208206177, 0.8605]
# sequential model is trained. best val loss is: [0.3989076013565063, 0.8035]
# sequential model is trained. best val loss is: [0.6356420826911926, 0.796]
# sequential model is trained. best val loss is: [0.4638538074493408, 0.8035]
# sequential model is trained. best val loss is: [0.4225048336982727, 0.814]
# sequential model is trained. best val loss is: [0.3469461815357208, 0.862]
# sequential model is trained. best val loss is: [0.3396451804637909, 0.863]
# sequential model is trained. best val loss is: [0.3423334345817566, 0.8615]
# sequential model is trained. best val loss is: [0.34730140161514284, 0.861]
# sequential model is trained. best val loss is: [0.34013481211662294, 0.86]
# sequential model is trained. best val loss is: [0.4699295196533203, 0.8035]
# sequential model is trained. best val loss is: [0.34431348013877866, 0.865]
# sequential model is trained. best val loss is: [0.3381347680091858, 0.8655]
# sequential model is trained. best val loss is: [0.3427526230812073, 0.8635]
# sequential model is trained. best val loss is: [0.5120488276481628, 0.8035]
# sequential model is trained. best val loss is: [0.39739963483810425, 0.833]
# sequential model is trained. best val loss is: [0.35847645497322084, 0.856]
# sequential model is trained. best val loss is: [0.3363306658267975, 0.863]
# sequential model is trained. best val loss is: [0.3449959456920624, 0.863]
# sequential model is trained. best val loss is: [0.3421877088546753, 0.8635]
# sequential model is trained. best val loss is: [0.34552208304405213, 0.8595]
# sequential model is trained. best val loss is: [0.49553321266174316, 0.8035]
# sequential model is trained. best val loss is: [0.3432727949619293, 0.861]
# sequential model is trained. best val loss is: [0.33961699771881104, 0.861]
# sequential model is trained. best val loss is: [0.33240885066986087, 0.87]
# sequential model is trained. best val loss is: [0.4962010521888733, 0.8035]
# sequential model is trained. best val loss is: [0.5706160955429077, 0.8035]
# sequential model is trained. best val loss is: [0.43493961000442505, 0.804]
# sequential model is trained. best val loss is: [0.4012244100570679, 0.8285]
# sequential model is trained. best val loss is: [0.34128023862838747, 0.8595]
# sequential model is trained. best val loss is: [0.3418869032859802, 0.863]
# sequential model is trained. best val loss is: [0.34094539713859556, 0.8625]
# sequential model is trained. best val loss is: [0.33861157751083376, 0.8615]
# sequential model is trained. best val loss is: [0.34714808106422423, 0.862]
# sequential model is trained. best val loss is: [0.4539008722305298, 0.8035]
# sequential model is trained. best val loss is: [0.3419352521896362, 0.862]
# sequential model is trained. best val loss is: [0.3378216640949249, 0.8635]
# sequential model is trained. best val loss is: [0.34162600207328797, 0.8615]
# sequential model is trained. best val loss is: [0.4938482656478882, 0.8035]
# sequential model is trained. best val loss is: [0.3911454372406006, 0.835]
# sequential model is trained. best val loss is: [0.3538832519054413, 0.8575]
# sequential model is trained. best val loss is: [0.3375136570930481, 0.865]
# sequential model is trained. best val loss is: [0.3657088048458099, 0.855]
# sequential model is trained. best val loss is: [0.345409969329834, 0.8645]
# sequential model is trained. best val loss is: [0.3538643620014191, 0.863]
# sequential model is trained. best val loss is: [0.49553321266174316, 0.8035]
# ==== 19.940938667456308 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adam', 'lr': 0.01}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info['hidden_layer']], units=[best_model_info['unit']],
         optimizers=[best_model_info['optimizer']], lrs=[best_model_info['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.3291589298248291, 0.87]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x1591c7150>],
#  [{'hidden_layer': 1, 'unit': 32, 'optimizer': 'adam', 'lr': 0.01}],
#  [0.3291589298248291])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.3680907416343689, 0.8475]
# sequential model is trained. best val loss is: [0.33560698556900026, 0.867]
# sequential model is trained. best val loss is: [0.3342642140388489, 0.8645]
# sequential model is trained. best val loss is: [0.3371084995269775, 0.8615]
# sequential model is trained. best val loss is: [0.9540332164764405, 0.31]
# sequential model is trained. best val loss is: [0.8262920985221863, 0.4]
# sequential model is trained. best val loss is: [0.7237344064712524, 0.5285]
# sequential model is trained. best val loss is: [0.4625368161201477, 0.796]
# sequential model is trained. best val loss is: [0.40608916139602663, 0.8255]
# sequential model is trained. best val loss is: [0.3394242453575134, 0.865]
# sequential model is trained. best val loss is: [0.33640674948692323, 0.8675]
# sequential model is trained. best val loss is: [0.3331810290813446, 0.8645]
# sequential model is trained. best val loss is: [0.6710990009307861, 0.5995]
# sequential model is trained. best val loss is: [0.4105424561500549, 0.822]
# sequential model is trained. best val loss is: [0.39234609627723693, 0.833]
# sequential model is trained. best val loss is: [0.34130953097343447, 0.8625]
# sequential model is trained. best val loss is: [0.5497275447845459, 0.7515]
# sequential model is trained. best val loss is: [0.4200468456745148, 0.8155]
# sequential model is trained. best val loss is: [0.40531679868698123, 0.8245]
# sequential model is trained. best val loss is: [0.3419898045063019, 0.8635]
# sequential model is trained. best val loss is: [0.3626509914398193, 0.8515]
# sequential model is trained. best val loss is: [0.3430259909629822, 0.8585]
# sequential model is trained. best val loss is: [0.3431369614601135, 0.8625]
# sequential model is trained. best val loss is: [0.3455528571605682, 0.854]
# sequential model is trained. best val loss is: [0.34438513922691344, 0.8585]
# sequential model is trained. best val loss is: [0.3291589298248291, 0.87]
# sequential model is trained. best val loss is: [0.32955014729499815, 0.868]
# sequential model is trained. best val loss is: [0.34178899335861207, 0.8585]
# sequential model is trained. best val loss is: [0.9236068787574768, 0.2645]
# sequential model is trained. best val loss is: [0.7658793306350709, 0.426]
# sequential model is trained. best val loss is: [0.6545568752288818, 0.624]
# sequential model is trained. best val loss is: [0.43645852279663083, 0.8095]
# sequential model is trained. best val loss is: [0.38130101990699766, 0.8455]
# sequential model is trained. best val loss is: [0.33971895813941955, 0.8645]
# sequential model is trained. best val loss is: [0.33405305743217467, 0.8645]
# sequential model is trained. best val loss is: [0.3360329964160919, 0.8615]
# sequential model is trained. best val loss is: [0.6117919921875, 0.697]
# sequential model is trained. best val loss is: [0.390545948266983, 0.8395]
# sequential model is trained. best val loss is: [0.35784452366828917, 0.853]
# sequential model is trained. best val loss is: [0.338549236536026, 0.866]
# sequential model is trained. best val loss is: [0.561681335926056, 0.7595]
# sequential model is trained. best val loss is: [0.4135090184211731, 0.8245]
# sequential model is trained. best val loss is: [0.38807475328445434, 0.8415]
# sequential model is trained. best val loss is: [0.34049587082862853, 0.864]
# sequential model is trained. best val loss is: [0.34415051794052126, 0.859]
# sequential model is trained. best val loss is: [0.3376833114624023, 0.86]
# sequential model is trained. best val loss is: [0.3372365021705627, 0.861]
# sequential model is trained. best val loss is: [0.3486001834869385, 0.8555]
# sequential model is trained. best val loss is: [0.3420356740951538, 0.862]
# sequential model is trained. best val loss is: [0.33268283343315125, 0.8625]
# sequential model is trained. best val loss is: [0.33387691926956176, 0.865]
# sequential model is trained. best val loss is: [0.345213570356369, 0.8585]
# sequential model is trained. best val loss is: [0.83416805934906, 0.2595]
# sequential model is trained. best val loss is: [0.6412912564277649, 0.675]
# sequential model is trained. best val loss is: [0.5387863612174988, 0.8015]
# sequential model is trained. best val loss is: [0.4128926010131836, 0.8215]
# sequential model is trained. best val loss is: [0.3654522562026978, 0.849]
# sequential model is trained. best val loss is: [0.339689514875412, 0.8645]
# sequential model is trained. best val loss is: [0.33533379769325256, 0.8675]
# sequential model is trained. best val loss is: [0.3386562216281891, 0.8625]
# sequential model is trained. best val loss is: [0.5172266130447387, 0.8035]
# sequential model is trained. best val loss is: [0.3822697947025299, 0.8395]
# sequential model is trained. best val loss is: [0.3536314854621887, 0.8565]
# sequential model is trained. best val loss is: [0.3382499253749847, 0.865]
# sequential model is trained. best val loss is: [0.5144284257888794, 0.8045]
# sequential model is trained. best val loss is: [0.40653773045539854, 0.82]
# sequential model is trained. best val loss is: [0.38297106003761294, 0.841]
# sequential model is trained. best val loss is: [0.34091029596328737, 0.8655]
# sequential model is trained. best val loss is: [0.3421248028278351, 0.8625]
# sequential model is trained. best val loss is: [0.33769053101539614, 0.866]
# sequential model is trained. best val loss is: [0.3343866534233093, 0.865]
# sequential model is trained. best val loss is: [0.3488343036174774, 0.857]
# sequential model is trained. best val loss is: [0.34042253756523133, 0.8625]
# sequential model is trained. best val loss is: [0.33265263986587523, 0.8705]
# sequential model is trained. best val loss is: [0.33328101205825805, 0.866]
# sequential model is trained. best val loss is: [0.3426813592910767, 0.8595]
# sequential model is trained. best val loss is: [0.7722467870712281, 0.3365]
# sequential model is trained. best val loss is: [0.5642143859863281, 0.8075]
# sequential model is trained. best val loss is: [0.480773313999176, 0.8065]
# sequential model is trained. best val loss is: [0.3991285138130188, 0.8255]
# sequential model is trained. best val loss is: [0.35522856879234316, 0.856]
# sequential model is trained. best val loss is: [0.3370194549560547, 0.8635]
# sequential model is trained. best val loss is: [0.33483668804168704, 0.865]
# sequential model is trained. best val loss is: [0.3420656008720398, 0.859]
# sequential model is trained. best val loss is: [0.4788394999504089, 0.8055]
# sequential model is trained. best val loss is: [0.3767532243728638, 0.84]
# sequential model is trained. best val loss is: [0.3490360035896301, 0.8575]
# sequential model is trained. best val loss is: [0.33848569488525393, 0.8635]
# sequential model is trained. best val loss is: [0.4952613458633423, 0.8045]
# sequential model is trained. best val loss is: [0.4039436626434326, 0.823]
# sequential model is trained. best val loss is: [0.38291550397872925, 0.8335]
# sequential model is trained. best val loss is: [0.34003576469421387, 0.86]
# sequential model is trained. best val loss is: [0.3403584702014923, 0.863]
# sequential model is trained. best val loss is: [0.33902127408981325, 0.8635]
# sequential model is trained. best val loss is: [0.33624407839775083, 0.8645]
# sequential model is trained. best val loss is: [0.35914995408058165, 0.8585]
# sequential model is trained. best val loss is: [0.3394235646724701, 0.8665]
# sequential model is trained. best val loss is: [0.33233061170578004, 0.8665]
# sequential model is trained. best val loss is: [0.33296736526489257, 0.869]
# sequential model is trained. best val loss is: [0.3437041923999786, 0.861]
# sequential model is trained. best val loss is: [0.7806270685195923, 0.246]
# sequential model is trained. best val loss is: [0.530572509765625, 0.803]
# sequential model is trained. best val loss is: [0.46146501874923707, 0.8035]
# sequential model is trained. best val loss is: [0.3910767865180969, 0.8295]
# sequential model is trained. best val loss is: [0.3456966269016266, 0.861]
# sequential model is trained. best val loss is: [0.33387121868133546, 0.8665]
# sequential model is trained. best val loss is: [0.3317445991039276, 0.867]
# sequential model is trained. best val loss is: [0.3404604799747467, 0.863]
# sequential model is trained. best val loss is: [0.4718801140785217, 0.8035]
# sequential model is trained. best val loss is: [0.37451449704170225, 0.843]
# sequential model is trained. best val loss is: [0.34668738079071043, 0.86]
# sequential model is trained. best val loss is: [0.33719590997695925, 0.8685]
# sequential model is trained. best val loss is: [0.49994821166992187, 0.8035]
# sequential model is trained. best val loss is: [0.40751695942878724, 0.823]
# sequential model is trained. best val loss is: [0.3856778969764709, 0.836]
# sequential model is trained. best val loss is: [0.3400794560909271, 0.8645]
# sequential model is trained. best val loss is: [0.34007838439941407, 0.867]
# sequential model is trained. best val loss is: [0.3399532597064972, 0.865]
# sequential model is trained. best val loss is: [0.3415278143882751, 0.8615]
# sequential model is trained. best val loss is: [0.3459976489543915, 0.864]
# sequential model is trained. best val loss is: [0.345151517868042, 0.858]
# sequential model is trained. best val loss is: [0.34289483332633974, 0.8585]
# sequential model is trained. best val loss is: [0.335587530374527, 0.865]
# sequential model is trained. best val loss is: [0.34779822182655334, 0.862]
# sequential model is trained. best val loss is: [0.6236725506782532, 0.7415]
# sequential model is trained. best val loss is: [0.5574537835121155, 0.798]
# sequential model is trained. best val loss is: [0.5206601400375366, 0.8025]
# sequential model is trained. best val loss is: [0.4416211242675781, 0.806]
# sequential model is trained. best val loss is: [0.3960553216934204, 0.8305]
# sequential model is trained. best val loss is: [0.3371204264163971, 0.8605]
# sequential model is trained. best val loss is: [0.33508101844787597, 0.865]
# sequential model is trained. best val loss is: [0.3396379699707031, 0.8655]
# sequential model is trained. best val loss is: [0.5066859197616577, 0.803]
# sequential model is trained. best val loss is: [0.4033739838600159, 0.83]
# sequential model is trained. best val loss is: [0.3654479465484619, 0.8545]
# sequential model is trained. best val loss is: [0.33573648500442504, 0.866]
# sequential model is trained. best val loss is: [0.5110522050857544, 0.803]
# sequential model is trained. best val loss is: [0.42702665901184084, 0.8105]
# sequential model is trained. best val loss is: [0.40442782974243163, 0.8285]
# sequential model is trained. best val loss is: [0.340451399564743, 0.8635]
# sequential model is trained. best val loss is: [0.34750171422958376, 0.858]
# sequential model is trained. best val loss is: [0.3382431290149689, 0.864]
# sequential model is trained. best val loss is: [0.335009006023407, 0.8625]
# sequential model is trained. best val loss is: [0.34872388911247254, 0.8675]
# sequential model is trained. best val loss is: [0.33644364261627197, 0.862]
# sequential model is trained. best val loss is: [0.34045472550392153, 0.86]
# sequential model is trained. best val loss is: [0.3369125692844391, 0.8645]
# sequential model is trained. best val loss is: [0.34512218594551086, 0.8625]
# sequential model is trained. best val loss is: [0.667766676902771, 0.616]
# sequential model is trained. best val loss is: [0.5427258458137513, 0.8035]
# sequential model is trained. best val loss is: [0.49675138330459595, 0.8035]
# sequential model is trained. best val loss is: [0.4117119433879852, 0.8175]
# sequential model is trained. best val loss is: [0.3698853986263275, 0.841]
# sequential model is trained. best val loss is: [0.3331892077922821, 0.8645]
# sequential model is trained. best val loss is: [0.3423943445682526, 0.8585]
# sequential model is trained. best val loss is: [0.3446065809726715, 0.8635]
# sequential model is trained. best val loss is: [0.492370602607727, 0.804]
# sequential model is trained. best val loss is: [0.3845930631160736, 0.8365]
# sequential model is trained. best val loss is: [0.34902119493484496, 0.8535]
# sequential model is trained. best val loss is: [0.33285996270179746, 0.8655]
# sequential model is trained. best val loss is: [0.5104807868003846, 0.8035]
# sequential model is trained. best val loss is: [0.4149537961483002, 0.816]
# sequential model is trained. best val loss is: [0.39035025095939635, 0.8335]
# sequential model is trained. best val loss is: [0.33536855268478394, 0.8645]
# sequential model is trained. best val loss is: [0.3378807961940765, 0.8625]
# sequential model is trained. best val loss is: [0.3473028376102448, 0.8575]
# sequential model is trained. best val loss is: [0.35396488547325133, 0.8575]
# sequential model is trained. best val loss is: [0.34259930896759033, 0.8625]
# sequential model is trained. best val loss is: [0.3402776048183441, 0.8625]
# sequential model is trained. best val loss is: [0.3379396414756775, 0.8635]
# sequential model is trained. best val loss is: [0.33593207120895385, 0.8615]
# sequential model is trained. best val loss is: [0.3592202961444855, 0.85]
# sequential model is trained. best val loss is: [0.6200923089981079, 0.768]
# sequential model is trained. best val loss is: [0.49695782852172854, 0.8035]
# sequential model is trained. best val loss is: [0.45720166063308715, 0.8045]
# sequential model is trained. best val loss is: [0.38111649942398074, 0.839]
# sequential model is trained. best val loss is: [0.34473815822601317, 0.857]
# sequential model is trained. best val loss is: [0.3395554296970367, 0.864]
# sequential model is trained. best val loss is: [0.3414430503845215, 0.861]
# sequential model is trained. best val loss is: [0.33880638527870177, 0.8595]
# sequential model is trained. best val loss is: [0.46954252195358276, 0.8035]
# sequential model is trained. best val loss is: [0.35604823207855224, 0.857]
# sequential model is trained. best val loss is: [0.3415765378475189, 0.86]
# sequential model is trained. best val loss is: [0.3361461617946625, 0.8655]
# sequential model is trained. best val loss is: [0.5040331926345826, 0.8035]
# sequential model is trained. best val loss is: [0.39611687898635867, 0.8285]
# sequential model is trained. best val loss is: [0.36478206849098205, 0.853]
# sequential model is trained. best val loss is: [0.33853730535507204, 0.861]
# sequential model is trained. best val loss is: [0.339894385099411, 0.862]
# sequential model is trained. best val loss is: [0.34549207735061643, 0.861]
# sequential model is trained. best val loss is: [0.3401134641170502, 0.865]
# sequential model is trained. best val loss is: [0.3560570275783539, 0.8575]
# sequential model is trained. best val loss is: [0.33381259179115297, 0.859]
# sequential model is trained. best val loss is: [0.3492285623550415, 0.8595]
# sequential model is trained. best val loss is: [0.3370769267082214, 0.8675]
# sequential model is trained. best val loss is: [0.3559045302867889, 0.8535]
# sequential model is trained. best val loss is: [0.6861554226875305, 0.552]
# sequential model is trained. best val loss is: [0.4702427930831909, 0.8035]
# sequential model is trained. best val loss is: [0.434543231010437, 0.809]
# sequential model is trained. best val loss is: [0.36561774373054506, 0.849]
# sequential model is trained. best val loss is: [0.3383485298156738, 0.8625]
# sequential model is trained. best val loss is: [0.3409957897663116, 0.858]
# sequential model is trained. best val loss is: [0.33786102652549743, 0.859]
# sequential model is trained. best val loss is: [0.3370995397567749, 0.858]
# sequential model is trained. best val loss is: [0.46124924516677857, 0.8035]
# sequential model is trained. best val loss is: [0.3546276483535767, 0.854]
# sequential model is trained. best val loss is: [0.34116697335243223, 0.862]
# sequential model is trained. best val loss is: [0.33527755331993103, 0.8665]
# sequential model is trained. best val loss is: [0.5003662648200988, 0.8035]
# sequential model is trained. best val loss is: [0.3999433624744415, 0.8275]
# sequential model is trained. best val loss is: [0.3688262813091278, 0.8455]
# sequential model is trained. best val loss is: [0.339722341299057, 0.8645]
# sequential model is trained. best val loss is: [0.3360039014816284, 0.8645]
# sequential model is trained. best val loss is: [0.35655968165397645, 0.858]
# sequential model is trained. best val loss is: [0.3645406928062439, 0.8555]
# sequential model is trained. best val loss is: [0.3611733469963074, 0.8655]
# sequential model is trained. best val loss is: [0.3364314787387848, 0.8635]
# sequential model is trained. best val loss is: [0.33469959926605225, 0.8645]
# sequential model is trained. best val loss is: [0.34087975311279295, 0.8655]
# sequential model is trained. best val loss is: [0.3537864151000977, 0.854]
# sequential model is trained. best val loss is: [0.5826225085258484, 0.8035]
# sequential model is trained. best val loss is: [0.44294626379013063, 0.8045]
# sequential model is trained. best val loss is: [0.4124683184623718, 0.8235]
# sequential model is trained. best val loss is: [0.3498211660385132, 0.8605]
# sequential model is trained. best val loss is: [0.3377109375, 0.868]
# sequential model is trained. best val loss is: [0.34196380162239076, 0.8635]
# sequential model is trained. best val loss is: [0.33961841177940366, 0.868]
# sequential model is trained. best val loss is: [0.35404199731349945, 0.8595]
# sequential model is trained. best val loss is: [0.44952448225021363, 0.8035]
# sequential model is trained. best val loss is: [0.348703444480896, 0.858]
# sequential model is trained. best val loss is: [0.338985319852829, 0.8645]
# sequential model is trained. best val loss is: [0.3362452290058136, 0.866]
# sequential model is trained. best val loss is: [0.486974102973938, 0.8035]
# sequential model is trained. best val loss is: [0.394911509513855, 0.8325]
# sequential model is trained. best val loss is: [0.364342761516571, 0.851]
# sequential model is trained. best val loss is: [0.33683900237083436, 0.869]
# sequential model is trained. best val loss is: [0.34172933459281923, 0.864]
# sequential model is trained. best val loss is: [0.3370696997642517, 0.8615]
# sequential model is trained. best val loss is: [0.3431547198295593, 0.8645]
# sequential model is trained. best val loss is: [0.37255677723884584, 0.8545]
# sequential model is trained. best val loss is: [0.34168018484115603, 0.8625]
# sequential model is trained. best val loss is: [0.33630736875534056, 0.8625]
# sequential model is trained. best val loss is: [0.3294893183708191, 0.865]
# sequential model is trained. best val loss is: [0.34438669395446775, 0.8615]
# sequential model is trained. best val loss is: [0.7286284413337708, 0.3065]
# sequential model is trained. best val loss is: [0.6285824313163757, 0.7805]
# sequential model is trained. best val loss is: [0.5395589423179626, 0.803]
# sequential model is trained. best val loss is: [0.41757405328750613, 0.8225]
# sequential model is trained. best val loss is: [0.38724125051498415, 0.835]
# sequential model is trained. best val loss is: [0.3363655550479889, 0.86]
# sequential model is trained. best val loss is: [0.3355809075832367, 0.8615]
# sequential model is trained. best val loss is: [0.3467286956310272, 0.86]
# sequential model is trained. best val loss is: [0.5517920227050781, 0.8025]
# sequential model is trained. best val loss is: [0.3983908171653748, 0.8285]
# sequential model is trained. best val loss is: [0.36585642099380494, 0.852]
# sequential model is trained. best val loss is: [0.3337524435520172, 0.862]
# sequential model is trained. best val loss is: [0.5391926221847534, 0.8035]
# sequential model is trained. best val loss is: [0.42197178268432617, 0.823]
# sequential model is trained. best val loss is: [0.39861790418624876, 0.828]
# sequential model is trained. best val loss is: [0.33586956071853635, 0.8665]
# sequential model is trained. best val loss is: [0.34367840814590456, 0.86]
# sequential model is trained. best val loss is: [0.34278009247779845, 0.8585]
# sequential model is trained. best val loss is: [0.3530842580795288, 0.861]
# sequential model is trained. best val loss is: [0.37209467029571536, 0.85]
# sequential model is trained. best val loss is: [0.34076971650123594, 0.8565]
# sequential model is trained. best val loss is: [0.3376878345012665, 0.8665]
# sequential model is trained. best val loss is: [0.33900523209571837, 0.861]
# sequential model is trained. best val loss is: [0.42272825503349304, 0.8035]
# sequential model is trained. best val loss is: [0.6873775420188903, 0.5715]
# sequential model is trained. best val loss is: [0.5491091666221619, 0.8035]
# sequential model is trained. best val loss is: [0.48689995670318603, 0.8035]
# sequential model is trained. best val loss is: [0.40494096422195436, 0.8215]
# sequential model is trained. best val loss is: [0.35416459608078005, 0.853]
# sequential model is trained. best val loss is: [0.3384857120513916, 0.859]
# sequential model is trained. best val loss is: [0.34029663395881654, 0.8575]
# sequential model is trained. best val loss is: [0.34120143628120425, 0.863]
# sequential model is trained. best val loss is: [0.5058920497894287, 0.8035]
# sequential model is trained. best val loss is: [0.37701179122924805, 0.841]
# sequential model is trained. best val loss is: [0.34651364374160765, 0.8565]
# sequential model is trained. best val loss is: [0.34280750584602354, 0.8605]
# sequential model is trained. best val loss is: [0.52804891872406, 0.8035]
# sequential model is trained. best val loss is: [0.4299490466117859, 0.8085]
# sequential model is trained. best val loss is: [0.3926476924419403, 0.829]
# sequential model is trained. best val loss is: [0.340139963388443, 0.8595]
# sequential model is trained. best val loss is: [0.3400753011703491, 0.8585]
# sequential model is trained. best val loss is: [0.36037680435180663, 0.8565]
# sequential model is trained. best val loss is: [0.34611203575134275, 0.8625]
# sequential model is trained. best val loss is: [0.3668763692378998, 0.8575]
# sequential model is trained. best val loss is: [0.33809093189239503, 0.8625]
# sequential model is trained. best val loss is: [0.3405708465576172, 0.8625]
# sequential model is trained. best val loss is: [0.34201200485229494, 0.86]
# sequential model is trained. best val loss is: [0.38479546546936033, 0.8565]
# sequential model is trained. best val loss is: [0.6854655599594116, 0.5485]
# sequential model is trained. best val loss is: [0.5032217602729797, 0.8035]
# sequential model is trained. best val loss is: [0.45226026248931883, 0.8035]
# sequential model is trained. best val loss is: [0.3655004167556763, 0.8475]
# sequential model is trained. best val loss is: [0.341049480676651, 0.8625]
# sequential model is trained. best val loss is: [0.342458785533905, 0.859]
# sequential model is trained. best val loss is: [0.34166471266746523, 0.8635]
# sequential model is trained. best val loss is: [0.3389019021987915, 0.863]
# sequential model is trained. best val loss is: [0.48864016246795655, 0.8035]
# sequential model is trained. best val loss is: [0.3505604462623596, 0.8555]
# sequential model is trained. best val loss is: [0.33928171229362486, 0.8635]
# sequential model is trained. best val loss is: [0.3400972282886505, 0.864]
# sequential model is trained. best val loss is: [0.5292774529457093, 0.8035]
# sequential model is trained. best val loss is: [0.40058211660385135, 0.822]
# sequential model is trained. best val loss is: [0.36194312930107114, 0.8485]
# sequential model is trained. best val loss is: [0.3372562265396118, 0.865]
# sequential model is trained. best val loss is: [0.3376403415203095, 0.8675]
# sequential model is trained. best val loss is: [0.3430478720664978, 0.8565]
# sequential model is trained. best val loss is: [0.3786679146289825, 0.8645]
# sequential model is trained. best val loss is: [0.3670633263587952, 0.8455]
# sequential model is trained. best val loss is: [0.344237566947937, 0.866]
# sequential model is trained. best val loss is: [0.3418402042388916, 0.8645]
# sequential model is trained. best val loss is: [0.3401305208206177, 0.8605]
# sequential model is trained. best val loss is: [0.3989076013565063, 0.8035]
# sequential model is trained. best val loss is: [0.6356420826911926, 0.796]
# sequential model is trained. best val loss is: [0.4638538074493408, 0.8035]
# sequential model is trained. best val loss is: [0.4225048336982727, 0.814]
# sequential model is trained. best val loss is: [0.3469461815357208, 0.862]
# sequential model is trained. best val loss is: [0.3396451804637909, 0.863]
# sequential model is trained. best val loss is: [0.3423334345817566, 0.8615]
# sequential model is trained. best val loss is: [0.34730140161514284, 0.861]
# sequential model is trained. best val loss is: [0.34013481211662294, 0.86]
# sequential model is trained. best val loss is: [0.4699295196533203, 0.8035]
# sequential model is trained. best val loss is: [0.34431348013877866, 0.865]
# sequential model is trained. best val loss is: [0.3381347680091858, 0.8655]
# sequential model is trained. best val loss is: [0.3427526230812073, 0.8635]
# sequential model is trained. best val loss is: [0.5120488276481628, 0.8035]
# sequential model is trained. best val loss is: [0.39739963483810425, 0.833]
# sequential model is trained. best val loss is: [0.35847645497322084, 0.856]
# sequential model is trained. best val loss is: [0.3363306658267975, 0.863]
# sequential model is trained. best val loss is: [0.3449959456920624, 0.863]
# sequential model is trained. best val loss is: [0.3421877088546753, 0.8635]
# sequential model is trained. best val loss is: [0.34552208304405213, 0.8595]
# sequential model is trained. best val loss is: [0.49553321266174316, 0.8035]
# sequential model is trained. best val loss is: [0.3432727949619293, 0.861]
# sequential model is trained. best val loss is: [0.33961699771881104, 0.861]
# sequential model is trained. best val loss is: [0.33240885066986087, 0.87]
# sequential model is trained. best val loss is: [0.4962010521888733, 0.8035]
# sequential model is trained. best val loss is: [0.5706160955429077, 0.8035]
# sequential model is trained. best val loss is: [0.43493961000442505, 0.804]
# sequential model is trained. best val loss is: [0.4012244100570679, 0.8285]
# sequential model is trained. best val loss is: [0.34128023862838747, 0.8595]
# sequential model is trained. best val loss is: [0.3418869032859802, 0.863]
# sequential model is trained. best val loss is: [0.34094539713859556, 0.8625]
# sequential model is trained. best val loss is: [0.33861157751083376, 0.8615]
# sequential model is trained. best val loss is: [0.34714808106422423, 0.862]
# sequential model is trained. best val loss is: [0.4539008722305298, 0.8035]
# sequential model is trained. best val loss is: [0.3419352521896362, 0.862]
# sequential model is trained. best val loss is: [0.3378216640949249, 0.8635]
# sequential model is trained. best val loss is: [0.34162600207328797, 0.8615]
# sequential model is trained. best val loss is: [0.4938482656478882, 0.8035]
# sequential model is trained. best val loss is: [0.3911454372406006, 0.835]
# sequential model is trained. best val loss is: [0.3538832519054413, 0.8575]
# sequential model is trained. best val loss is: [0.3375136570930481, 0.865]
# sequential model is trained. best val loss is: [0.3657088048458099, 0.855]
# sequential model is trained. best val loss is: [0.345409969329834, 0.8645]
# sequential model is trained. best val loss is: [0.3538643620014191, 0.863]
# sequential model is trained. best val loss is: [0.49553321266174316, 0.8035]
# ==== 17.388740015029907 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adam', 'lr': 0.01}
