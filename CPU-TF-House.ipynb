# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename="./data/sberbank_train_reduced_10k.csv"
ds = DataSource(filename)
ds.data_load_split(target=['price_doc'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [73454360721358.84, 73454350000000.0, 7172278.0]
# sequential model is trained. best val loss is: [72842542126727.17, 72842540000000.0, 7130851.5]
# sequential model is trained. best val loss is: [70673530324254.72, 70673530000000.0, 6984946.5]
# sequential model is trained. best val loss is: [37304535550525.44, 37304534000000.0, 4253294.0]
# sequential model is trained. best val loss is: [73460333578027.02, 73460350000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460324585439.23, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460310291251.2, 73460310000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73453120952205.31, 73453130000000.0, 7172219.5]
# sequential model is trained. best val loss is: [73459108472160.25, 73459110000000.0, 7172580.5]
# sequential model is trained. best val loss is: [73358350082899.97, 73358350000000.0, 7165288.0]
# sequential model is trained. best val loss is: [73026440278310.9, 73026440000000.0, 7141787.5]
# sequential model is trained. best val loss is: [60950478048985.086, 60950485000000.0, 6172782.5]
# sequential model is trained. best val loss is: [73460292071194.62, 73460290000000.0, 7172666.0]
# sequential model is trained. best val loss is: [73458669949288.45, 73458670000000.0, 7172558.0]
# sequential model is trained. best val loss is: [73454128457580.55, 73454120000000.0, 7172253.0]
# sequential model is trained. best val loss is: [73300535897227.27, 73300550000000.0, 7161886.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73457184058376.19, 73457190000000.0, 7172461.0]
# sequential model is trained. best val loss is: [73174215674560.52, 73174220000000.0, 7153238.5]
# sequential model is trained. best val loss is: [72255905143455.75, 72255910000000.0, 7089736.5]
# sequential model is trained. best val loss is: [49672072791588.87, 49672073000000.0, 5451787.5]
# sequential model is trained. best val loss is: [73448963591634.94, 73448960000000.0, 7171946.0]
# sequential model is trained. best val loss is: [72177735178387.45, 72177740000000.0, 7089575.0]
# sequential model is trained. best val loss is: [68013111315005.44, 68013106000000.0, 6801622.0]
# sequential model is trained. best val loss is: [26879594963402.754, 26879600000000.0, 3392132.5]
# sequential model is trained. best val loss is: [73460331866750.97, 73460340000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460317237018.62, 73460315000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73460271938535.42, 73460265000000.0, 7172664.5]
# sequential model is trained. best val loss is: [40137663465914.37, 40137665000000.0, 3970543.0]
# sequential model is trained. best val loss is: [73458260551663.61, 73458260000000.0, 7172527.0]
# sequential model is trained. best val loss is: [73283731200147.45, 73283735000000.0, 7160598.5]
# sequential model is trained. best val loss is: [72659349322858.5, 72659350000000.0, 7116644.5]
# sequential model is trained. best val loss is: [54125291160731.65, 54125287000000.0, 5685481.5]
# sequential model is trained. best val loss is: [73460264992768.0, 73460260000000.0, 7172664.5]
# sequential model is trained. best val loss is: [73457187480928.25, 73457195000000.0, 7172474.0]
# sequential model is trained. best val loss is: [73448047186542.6, 73448040000000.0, 7171891.0]
# sequential model is trained. best val loss is: [73111089218322.44, 73111090000000.0, 7150693.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73454491080327.17, 73454490000000.0, 7172295.0]
# sequential model is trained. best val loss is: [72888583874150.4, 72888570000000.0, 7136883.0]
# sequential model is trained. best val loss is: [70906582396829.7, 70906590000000.0, 7003944.0]
# sequential model is trained. best val loss is: [37445981003841.54, 37445974000000.0, 4380790.0]
# sequential model is trained. best val loss is: [73437080557977.6, 73437080000000.0, 7171176.5]
# sequential model is trained. best val loss is: [70815874633695.23, 70815865000000.0, 6995723.5]
# sequential model is trained. best val loss is: [63068126455005.19, 63068130000000.0, 6436084.0]
# sequential model is trained. best val loss is: [19494551739695.105, 19494552000000.0, 2630094.8]
# sequential model is trained. best val loss is: [73460332672057.34, 73460340000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460311063003.14, 73460310000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73460268415320.06, 73460265000000.0, 7172664.5]
# sequential model is trained. best val loss is: [42408271042052.09, 42408272000000.0, 4239049.5]
# sequential model is trained. best val loss is: [73456483274063.88, 73456490000000.0, 7172399.0]
# sequential model is trained. best val loss is: [73056888811421.7, 73056900000000.0, 7143662.0]
# sequential model is trained. best val loss is: [71784687118319.61, 71784690000000.0, 7053269.5]
# sequential model is trained. best val loss is: [40872353172815.875, 40872356000000.0, 4444555.5]
# sequential model is trained. best val loss is: [73460232746958.84, 73460240000000.0, 7172662.5]
# sequential model is trained. best val loss is: [73454265158336.52, 73454250000000.0, 7172267.5]
# sequential model is trained. best val loss is: [73436516776411.14, 73436510000000.0, 7171086.0]
# sequential model is trained. best val loss is: [72697286030786.56, 72697290000000.0, 7121981.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73449272560844.8, 73449270000000.0, 7171944.5]
# sequential model is trained. best val loss is: [72265774055555.08, 72265760000000.0, 7090831.5]
# sequential model is trained. best val loss is: [68474271885688.83, 68474274000000.0, 6826311.5]
# sequential model is trained. best val loss is: [24340724459765.76, 24340725000000.0, 3004312.2]
# sequential model is trained. best val loss is: [73413328549969.92, 73413320000000.0, 7169654.0]
# sequential model is trained. best val loss is: [67883606759964.67, 67883615000000.0, 6787583.0]
# sequential model is trained. best val loss is: [55503181194461.19, 55503187000000.0, 5909132.0]
# sequential model is trained. best val loss is: [15983363714187.264, 15983366000000.0, 2351654.8]
# sequential model is trained. best val loss is: [73460328511307.78, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460288615088.12, 73460290000000.0, 7172665.5]
# sequential model is trained. best val loss is: [73458687263375.36, 73458690000000.0, 7172541.0]
# sequential model is trained. best val loss is: [37398929360289.79, 37398927000000.0, 3702373.0]
# sequential model is trained. best val loss is: [73452609515552.77, 73452610000000.0, 7172130.0]
# sequential model is trained. best val loss is: [72632426806902.78, 72632430000000.0, 7113848.5]
# sequential model is trained. best val loss is: [69581977254100.99, 69581972000000.0, 6888334.5]
# sequential model is trained. best val loss is: [30776762354892.8, 30776763000000.0, 3469015.2]
# sequential model is trained. best val loss is: [73460157652140.03, 73460140000000.0, 7172657.5]
# sequential model is trained. best val loss is: [73448053696102.4, 73448030000000.0, 7171879.5]
# sequential model is trained. best val loss is: [73411482787774.47, 73411490000000.0, 7169491.0]
# sequential model is trained. best val loss is: [71909034474602.5, 71909050000000.0, 7070348.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73436784507224.06, 73436780000000.0, 7171141.5]
# sequential model is trained. best val loss is: [71003574686973.95, 71003560000000.0, 7005213.5]
# sequential model is trained. best val loss is: [63879909835014.14, 63879913000000.0, 6493071.0]
# sequential model is trained. best val loss is: [17580902427131.904, 17580900000000.0, 2500217.8]
# sequential model is trained. best val loss is: [73357305566986.23, 73357295000000.0, 7165961.0]
# sequential model is trained. best val loss is: [63070330746306.56, 63070324000000.0, 6444950.0]
# sequential model is trained. best val loss is: [45087626176233.47, 45087630000000.0, 5035030.5]
# sequential model is trained. best val loss is: [13814331617574.912, 13814330000000.0, 2108430.5]
# sequential model is trained. best val loss is: [73460328041545.73, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73458974321541.12, 73458970000000.0, 7172562.0]
# sequential model is trained. best val loss is: [67260550400180.23, 67260560000000.0, 6657318.5]
# sequential model is trained. best val loss is: [27867883069505.535, 27867885000000.0, 3063017.0]
# sequential model is trained. best val loss is: [73444540479963.14, 73444545000000.0, 7171561.0]
# sequential model is trained. best val loss is: [71655246333476.86, 71655250000000.0, 7043820.0]
# sequential model is trained. best val loss is: [65719108229922.81, 65719120000000.0, 6587923.0]
# sequential model is trained. best val loss is: [24994399473631.23, 24994397000000.0, 3008378.2]
# sequential model is trained. best val loss is: [73460044338823.17, 73460055000000.0, 7172647.5]
# sequential model is trained. best val loss is: [73434009555697.66, 73434000000000.0, 7170953.0]
# sequential model is trained. best val loss is: [73350400333316.1, 73350420000000.0, 7165411.0]
# sequential model is trained. best val loss is: [70433798302466.05, 70433800000000.0, 6970089.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73410376531705.86, 73410380000000.0, 7169386.5]
# sequential model is trained. best val loss is: [68425611365842.945, 68425603000000.0, 6821255.0]
# sequential model is trained. best val loss is: [56591411872530.43, 56591403000000.0, 6019046.0]
# sequential model is trained. best val loss is: [14250168777965.568, 14250168000000.0, 2166776.8]
# sequential model is trained. best val loss is: [73217865729179.64, 73217860000000.0, 7156505.5]
# sequential model is trained. best val loss is: [26332453660524.543, 26332455000000.0, 3167962.5]
# sequential model is trained. best val loss is: [15735182799667.2, 15735181000000.0, 2317614.0]
# sequential model is trained. best val loss is: [11590637539295.232, 11590637000000.0, 1796566.8]
# sequential model is trained. best val loss is: [73460342167961.6, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460334282670.08, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460287373574.14, 73460280000000.0, 7172665.5]
# sequential model is trained. best val loss is: [11377665856503.809, 11377665000000.0, 1804408.6]
# sequential model is trained. best val loss is: [73448893295099.9, 73448900000000.0, 7171835.5]
# sequential model is trained. best val loss is: [62816239927427.07, 62816237000000.0, 6353838.0]
# sequential model is trained. best val loss is: [32264867440230.4, 32264866000000.0, 3568986.0]
# sequential model is trained. best val loss is: [13419326958731.264, 13419324000000.0, 2024516.4]
# sequential model is trained. best val loss is: [73460297641230.34, 73460310000000.0, 7172666.0]
# sequential model is trained. best val loss is: [73428843448238.08, 73428830000000.0, 7170611.0]
# sequential model is trained. best val loss is: [73208477769531.39, 73208470000000.0, 7155890.0]
# sequential model is trained. best val loss is: [52838686462574.59, 52838690000000.0, 5708425.0]
# sequential model is trained. best val loss is: [1.3354121223932478e+16, 1.3354121e+16, 115464744.0]
# sequential model is trained. best val loss is: [22014006659121.152, 22014004000000.0, 2858566.2]
# sequential model is trained. best val loss is: [22013184994967.55, 22013182000000.0, 2864901.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73418448285204.48, 73418460000000.0, 7169860.0]
# sequential model is trained. best val loss is: [45761566036983.805, 45761572000000.0, 5064145.0]
# sequential model is trained. best val loss is: [19937841429610.496, 19937840000000.0, 2663198.5]
# sequential model is trained. best val loss is: [11722876751183.871, 11722876000000.0, 1795157.5]
# sequential model is trained. best val loss is: [72575901698621.44, 72575900000000.0, 7114646.0]
# sequential model is trained. best val loss is: [18036723837566.977, 18036724000000.0, 2523395.8]
# sequential model is trained. best val loss is: [12946846045437.951, 12946844000000.0, 1954558.6]
# sequential model is trained. best val loss is: [11261688057692.16, 11261687000000.0, 1778291.5]
# sequential model is trained. best val loss is: [73460338141429.77, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460315727069.19, 73460315000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73456022236168.19, 73456010000000.0, 7172336.5]
# sequential model is trained. best val loss is: [11327822805073.92, 11327825000000.0, 1768674.9]
# sequential model is trained. best val loss is: [73420154393853.95, 73420160000000.0, 7169881.5]
# sequential model is trained. best val loss is: [45005650870140.93, 45005658000000.0, 4850707.5]
# sequential model is trained. best val loss is: [25125509625020.414, 25125508000000.0, 3013628.2]
# sequential model is trained. best val loss is: [12374193689591.809, 12374193000000.0, 1842626.5]
# sequential model is trained. best val loss is: [73460172785188.86, 73460170000000.0, 7172658.0]
# sequential model is trained. best val loss is: [73343546337263.61, 73343554000000.0, 7165083.5]
# sequential model is trained. best val loss is: [72517254440288.25, 72517260000000.0, 7111980.5]
# sequential model is trained. best val loss is: [34073893111070.72, 34073897000000.0, 3937012.5]
# sequential model is trained. best val loss is: [8.838061133650094e+16, 8.838063e+16, 297251700.0]
# sequential model is trained. best val loss is: [22014021599232.0, 22014023000000.0, 2858505.2]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73300903049822.2, 73300900000000.0, 7162451.5]
# sequential model is trained. best val loss is: [26409093367332.863, 26409093000000.0, 3152820.2]
# sequential model is trained. best val loss is: [13784437196062.72, 13784434000000.0, 2083258.8]
# sequential model is trained. best val loss is: [11424601711050.752, 11424600000000.0, 1773522.8]
# sequential model is trained. best val loss is: [70235347207847.94, 70235353000000.0, 6955708.0]
# sequential model is trained. best val loss is: [14028461972652.031, 14028460000000.0, 2146539.8]
# sequential model is trained. best val loss is: [11956121396838.4, 11956120000000.0, 1832451.8]
# sequential model is trained. best val loss is: [11073929342877.695, 11073930000000.0, 1765685.8]
# sequential model is trained. best val loss is: [73460338443419.64, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460204561235.97, 73460215000000.0, 7172660.5]
# sequential model is trained. best val loss is: [10952189283401.729, 10952188000000.0, 1807911.8]
# sequential model is trained. best val loss is: [10961471196364.8, 10961473000000.0, 1735131.9]
# sequential model is trained. best val loss is: [73299849910419.45, 73299840000000.0, 7161201.5]
# sequential model is trained. best val loss is: [29903305844981.76, 29903310000000.0, 3416255.8]
# sequential model is trained. best val loss is: [18759431919501.312, 18759431000000.0, 2592560.8]
# sequential model is trained. best val loss is: [11805324608536.576, 11805326000000.0, 1786714.4]
# sequential model is trained. best val loss is: [73459735537385.47, 73459740000000.0, 7172628.5]
# sequential model is trained. best val loss is: [73034000830038.02, 73034015000000.0, 7144782.5]
# sequential model is trained. best val loss is: [70087338222419.97, 70087344000000.0, 6948625.0]
# sequential model is trained. best val loss is: [21891872494452.734, 21891874000000.0, 2834313.8]
# sequential model is trained. best val loss is: [2.401247380268143e+17, 2.4012475e+17, 490002800.0]
# sequential model is trained. best val loss is: [22014036455456.77, 22014040000000.0, 2858439.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72852718112210.94, 72852710000000.0, 7132899.5]
# sequential model is trained. best val loss is: [15988755500367.871, 15988756000000.0, 2385932.2]
# sequential model is trained. best val loss is: [12205807391211.52, 12205806000000.0, 1858724.0]
# sequential model is trained. best val loss is: [11290615899750.4, 11290615000000.0, 1767952.5]
# sequential model is trained. best val loss is: [61206990105346.05, 61206988000000.0, 6339532.0]
# sequential model is trained. best val loss is: [12246294663790.592, 12246294000000.0, 1866650.1]
# sequential model is trained. best val loss is: [11566178900115.455, 11566177000000.0, 1789515.5]
# sequential model is trained. best val loss is: [11132948073938.943, 11132951000000.0, 1748989.1]
# sequential model is trained. best val loss is: [73460327202684.92, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [11045297224417.28, 11045298000000.0, 1800413.5]
# sequential model is trained. best val loss is: [10966620260270.08, 10966620000000.0, 1767259.0]
# sequential model is trained. best val loss is: [10848870177177.6, 10848868000000.0, 1710418.0]
# sequential model is trained. best val loss is: [72806473696018.44, 72806470000000.0, 7126947.5]
# sequential model is trained. best val loss is: [21352848977559.55, 21352850000000.0, 2766184.0]
# sequential model is trained. best val loss is: [14087823770517.504, 14087819000000.0, 2132926.5]
# sequential model is trained. best val loss is: [11441003925864.447, 11441003000000.0, 1774817.5]
# sequential model is trained. best val loss is: [73457607280427.02, 73457610000000.0, 7172496.0]
# sequential model is trained. best val loss is: [71564546153644.03, 71564540000000.0, 7049055.0]
# sequential model is trained. best val loss is: [61283767762812.93, 61283770000000.0, 6342422.0]
# sequential model is trained. best val loss is: [15223062848864.256, 15223064000000.0, 2287979.0]
# sequential model is trained. best val loss is: [9.054711577787805e+20, 9.054711e+20, 30091047000.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [70856913348198.4, 70856920000000.0, 7002238.0]
# sequential model is trained. best val loss is: [12591315426476.031, 12591314000000.0, 1926443.8]
# sequential model is trained. best val loss is: [11832849877434.367, 11832852000000.0, 1796605.1]
# sequential model is trained. best val loss is: [11087882065281.023, 11087881000000.0, 1739277.2]
# sequential model is trained. best val loss is: [45075256955633.664, 45075254000000.0, 5074228.0]
# sequential model is trained. best val loss is: [11736458148708.352, 11736460000000.0, 1798258.1]
# sequential model is trained. best val loss is: [11276673777401.855, 11276674000000.0, 1777323.9]
# sequential model is trained. best val loss is: [11655553809907.713, 11655555000000.0, 1807687.5]
# sequential model is trained. best val loss is: [73460321431322.62, 73460320000000.0, 7172667.5]
# sequential model is trained. best val loss is: [10951374573404.16, 10951375000000.0, 1767122.0]
# sequential model is trained. best val loss is: [10869273777930.24, 10869277000000.0, 1738033.6]
# sequential model is trained. best val loss is: [10912922169507.84, 10912922000000.0, 1704927.9]
# sequential model is trained. best val loss is: [70934076210544.64, 70934070000000.0, 6991733.0]
# sequential model is trained. best val loss is: [16042964883079.168, 16042966000000.0, 2361737.2]
# sequential model is trained. best val loss is: [12553685466873.855, 12553687000000.0, 1908641.6]
# sequential model is trained. best val loss is: [11232369174380.545, 11232369000000.0, 1758575.0]
# sequential model is trained. best val loss is: [73451137381957.62, 73451155000000.0, 7172063.0]
# sequential model is trained. best val loss is: [66780452093952.0, 66780450000000.0, 6709507.5]
# sequential model is trained. best val loss is: [46196014494777.34, 46195997000000.0, 5183235.5]
# sequential model is trained. best val loss is: [12679240556216.32, 12679242000000.0, 1955776.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [64512351402983.42, 64512347000000.0, 6549086.0]
# sequential model is trained. best val loss is: [11887368193703.936, 11887366000000.0, 1812527.6]
# sequential model is trained. best val loss is: [11483286947758.08, 11483286000000.0, 1775301.8]
# sequential model is trained. best val loss is: [11023172981751.809, 11023173000000.0, 1723629.1]
# sequential model is trained. best val loss is: [62430336092471.3, 62430344000000.0, 6385551.5]
# sequential model is trained. best val loss is: [12087407411200.0, 12087408000000.0, 1845538.2]
# sequential model is trained. best val loss is: [11509819187920.896, 11509818000000.0, 1796827.5]
# sequential model is trained. best val loss is: [11581267392856.064, 11581268000000.0, 1798540.9]
# sequential model is trained. best val loss is: [73460338342756.36, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460321733312.52, 73460320000000.0, 7172668.0]
# sequential model is trained. best val loss is: [12395680500809.729, 12395679000000.0, 1858575.6]
# sequential model is trained. best val loss is: [11106030345781.248, 11106030000000.0, 1742791.2]
# sequential model is trained. best val loss is: [73313184877903.88, 73313190000000.0, 7162021.0]
# sequential model is trained. best val loss is: [21286805227700.223, 21286806000000.0, 2760589.0]
# sequential model is trained. best val loss is: [13739656889761.793, 13739656000000.0, 2076164.2]
# sequential model is trained. best val loss is: [11423288706203.648, 11423287000000.0, 1777968.0]
# sequential model is trained. best val loss is: [73460204997443.58, 73460230000000.0, 7172661.0]
# sequential model is trained. best val loss is: [72571878018908.16, 72571895000000.0, 7111825.5]
# sequential model is trained. best val loss is: [61672491965218.81, 61672490000000.0, 6313068.0]
# sequential model is trained. best val loss is: [14314645990932.48, 14314645000000.0, 2200898.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72647429194776.58, 72647430000000.0, 7116871.5]
# sequential model is trained. best val loss is: [12504029804363.775, 12504033000000.0, 1904300.2]
# sequential model is trained. best val loss is: [11650634811965.44, 11650635000000.0, 1779921.8]
# sequential model is trained. best val loss is: [11073215048712.191, 11073215000000.0, 1731488.8]
# sequential model is trained. best val loss is: [35188840163442.69, 35188840000000.0, 4004291.2]
# sequential model is trained. best val loss is: [11464892361998.336, 11464892000000.0, 1781515.9]
# sequential model is trained. best val loss is: [11125213961912.32, 11125213000000.0, 1769042.4]
# sequential model is trained. best val loss is: [11811844593287.168, 11811846000000.0, 1829442.5]
# sequential model is trained. best val loss is: [73460338745409.53, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460261872205.83, 73460260000000.0, 7172663.0]
# sequential model is trained. best val loss is: [11051517555507.2, 11051518000000.0, 1767572.2]
# sequential model is trained. best val loss is: [11083618078162.943, 11083618000000.0, 1716327.8]
# sequential model is trained. best val loss is: [72276948352499.72, 72276940000000.0, 7087588.0]
# sequential model is trained. best val loss is: [14912265497083.904, 14912266000000.0, 2162494.0]
# sequential model is trained. best val loss is: [12420308751351.809, 12420311000000.0, 1844100.4]
# sequential model is trained. best val loss is: [11230149445943.297, 11230146000000.0, 1762841.5]
# sequential model is trained. best val loss is: [73459589105844.22, 73459590000000.0, 7172620.5]
# sequential model is trained. best val loss is: [65926284751929.34, 65926280000000.0, 6621575.0]
# sequential model is trained. best val loss is: [33896689806868.48, 33896685000000.0, 3853743.5]
# sequential model is trained. best val loss is: [12600698392805.377, 12600699000000.0, 1879683.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [66863877102501.89, 66863883000000.0, 6703957.5]
# sequential model is trained. best val loss is: [11906909139369.984, 11906908000000.0, 1799747.6]
# sequential model is trained. best val loss is: [11462334335680.512, 11462331000000.0, 1775799.1]
# sequential model is trained. best val loss is: [10925492576190.465, 10925492000000.0, 1714300.8]
# sequential model is trained. best val loss is: [20901461219082.24, 20901463000000.0, 2746700.8]
# sequential model is trained. best val loss is: [11281920140771.328, 11281919000000.0, 1780723.2]
# sequential model is trained. best val loss is: [11084918207545.344, 11084916000000.0, 1752460.2]
# sequential model is trained. best val loss is: [11348592950247.424, 11348592000000.0, 1850760.9]
# sequential model is trained. best val loss is: [73460337571004.42, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [11076915926401.023, 11076915000000.0, 1751428.8]
# sequential model is trained. best val loss is: [10950192387850.24, 10950193000000.0, 1716047.0]
# sequential model is trained. best val loss is: [10945254041583.615, 10945255000000.0, 1720362.6]
# sequential model is trained. best val loss is: [63796643991912.445, 63796656000000.0, 6431218.0]
# sequential model is trained. best val loss is: [12627174085361.664, 12627171000000.0, 1909161.1]
# sequential model is trained. best val loss is: [11789561013207.04, 11789559000000.0, 1785668.8]
# sequential model is trained. best val loss is: [11063773406167.04, 11063774000000.0, 1748757.1]
# sequential model is trained. best val loss is: [73453473575731.2, 73453480000000.0, 7172209.5]
# sequential model is trained. best val loss is: [44799682139914.24, 44799684000000.0, 5007674.0]
# sequential model is trained. best val loss is: [20768492991021.055, 20768495000000.0, 2753148.0]
# sequential model is trained. best val loss is: [11812346909425.664, 11812345000000.0, 1792807.4]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [41211808530300.93, 41211805000000.0, 4620323.0]
# sequential model is trained. best val loss is: [11483807049842.688, 11483804000000.0, 1772751.2]
# sequential model is trained. best val loss is: [11258619251130.367, 11258618000000.0, 1763616.1]
# sequential model is trained. best val loss is: [10962900686471.168, 10962899000000.0, 1694026.4]
# sequential model is trained. best val loss is: [14653814825025.535, 14653816000000.0, 2225911.5]
# sequential model is trained. best val loss is: [11079370803249.152, 11079373000000.0, 1756459.1]
# sequential model is trained. best val loss is: [11308470791831.553, 11308471000000.0, 1768304.0]
# sequential model is trained. best val loss is: [13709361671045.12, 13709364000000.0, 2576424.2]
# sequential model is trained. best val loss is: [73460332000968.7, 73460350000000.0, 7172668.0]
# sequential model is trained. best val loss is: [10976789318860.8, 10976789000000.0, 1725826.4]
# sequential model is trained. best val loss is: [11040995869196.287, 11040998000000.0, 1716316.8]
# sequential model is trained. best val loss is: [11014251135107.072, 11014252000000.0, 1708108.4]
# sequential model is trained. best val loss is: [38892015391342.59, 38892020000000.0, 4306989.5]
# sequential model is trained. best val loss is: [11919667576700.928, 11919668000000.0, 1794169.8]
# sequential model is trained. best val loss is: [11345281559822.336, 11345281000000.0, 1769816.9]
# sequential model is trained. best val loss is: [11239946257956.863, 11239947000000.0, 1753629.2]
# sequential model is trained. best val loss is: [73405971505872.89, 73405960000000.0, 7169166.0]
# sequential model is trained. best val loss is: [24655018858643.457, 24655019000000.0, 3026782.0]
# sequential model is trained. best val loss is: [14839333223661.568, 14839333000000.0, 2248148.2]
# sequential model is trained. best val loss is: [11403022219345.92, 11403019000000.0, 1756703.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [21098101360033.793, 21098102000000.0, 2774973.5]
# sequential model is trained. best val loss is: [11243810383200.256, 11243811000000.0, 1760631.1]
# sequential model is trained. best val loss is: [11057204375322.623, 11057206000000.0, 1738587.0]
# sequential model is trained. best val loss is: [10613516941656.064, 10613517000000.0, 1672526.6]
# sequential model is trained. best val loss is: [12368638682071.04, 12368637000000.0, 1879768.6]
# sequential model is trained. best val loss is: [11166552606900.225, 11166555000000.0, 1748464.0]
# sequential model is trained. best val loss is: [11837112575852.545, 11837114000000.0, 1828312.8]
# sequential model is trained. best val loss is: [15234254527004.672, 15234254000000.0, 2810975.8]
# sequential model is trained. best val loss is: [73460318176542.72, 73460315000000.0, 7172667.0]
# sequential model is trained. best val loss is: [11020664588730.367, 11020665000000.0, 1716940.5]
# sequential model is trained. best val loss is: [11001380827299.84, 11001383000000.0, 1708731.4]
# sequential model is trained. best val loss is: [11055599141781.504, 11055597000000.0, 1705980.0]
# sequential model is trained. best val loss is: [24433551889924.098, 24433549000000.0, 2981559.0]
# sequential model is trained. best val loss is: [11438439522107.393, 11438440000000.0, 1770133.2]
# sequential model is trained. best val loss is: [11142858037788.672, 11142857000000.0, 1752001.1]
# sequential model is trained. best val loss is: [11623064206835.713, 11623063000000.0, 1787180.0]
# sequential model is trained. best val loss is: [73018475831885.83, 73018470000000.0, 7143322.5]
# sequential model is trained. best val loss is: [16389514901585.92, 16389516000000.0, 2410472.0]
# sequential model is trained. best val loss is: [12606277089755.137, 12606275000000.0, 1921530.4]
# sequential model is trained. best val loss is: [11126241421688.832, 11126242000000.0, 1732818.1]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [13363303283687.424, 13363302000000.0, 2035045.8]
# sequential model is trained. best val loss is: [11135056340844.545, 11135053000000.0, 1747744.0]
# sequential model is trained. best val loss is: [10995941368659.969, 10995940000000.0, 1717230.4]
# sequential model is trained. best val loss is: [9834562278391.809, 9834561000000.0, 1659131.2]
# ==== 16.849168753623964 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info['hidden_layer']], units=[best_model_info['unit']],
         optimizers=[best_model_info['optimizer']], lrs=[best_model_info['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [9834562278391.809, 9834561000000.0, 1659131.2]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x137106f10>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}],
#  [9834562278391.809])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [73454360721358.84, 73454350000000.0, 7172278.0]
# sequential model is trained. best val loss is: [72842542126727.17, 72842540000000.0, 7130851.5]
# sequential model is trained. best val loss is: [70673530324254.72, 70673530000000.0, 6984946.5]
# sequential model is trained. best val loss is: [37304535550525.44, 37304534000000.0, 4253294.0]
# sequential model is trained. best val loss is: [73460333578027.02, 73460350000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460324585439.23, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460310291251.2, 73460310000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73453120952205.31, 73453130000000.0, 7172219.5]
# sequential model is trained. best val loss is: [73459108472160.25, 73459110000000.0, 7172580.5]
# sequential model is trained. best val loss is: [73358350082899.97, 73358350000000.0, 7165288.0]
# sequential model is trained. best val loss is: [73026440278310.9, 73026440000000.0, 7141787.5]
# sequential model is trained. best val loss is: [60950478048985.086, 60950485000000.0, 6172782.5]
# sequential model is trained. best val loss is: [73460292071194.62, 73460290000000.0, 7172666.0]
# sequential model is trained. best val loss is: [73458669949288.45, 73458670000000.0, 7172558.0]
# sequential model is trained. best val loss is: [73454128457580.55, 73454120000000.0, 7172253.0]
# sequential model is trained. best val loss is: [73300535897227.27, 73300550000000.0, 7161886.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73457184058376.19, 73457190000000.0, 7172461.0]
# sequential model is trained. best val loss is: [73174215674560.52, 73174220000000.0, 7153238.5]
# sequential model is trained. best val loss is: [72255905143455.75, 72255910000000.0, 7089736.5]
# sequential model is trained. best val loss is: [49672072791588.87, 49672073000000.0, 5451787.5]
# sequential model is trained. best val loss is: [73448963591634.94, 73448960000000.0, 7171946.0]
# sequential model is trained. best val loss is: [72177735178387.45, 72177740000000.0, 7089575.0]
# sequential model is trained. best val loss is: [68013111315005.44, 68013106000000.0, 6801622.0]
# sequential model is trained. best val loss is: [26879594963402.754, 26879600000000.0, 3392132.5]
# sequential model is trained. best val loss is: [73460331866750.97, 73460340000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460317237018.62, 73460315000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73460271938535.42, 73460265000000.0, 7172664.5]
# sequential model is trained. best val loss is: [40137663465914.37, 40137665000000.0, 3970543.0]
# sequential model is trained. best val loss is: [73458260551663.61, 73458260000000.0, 7172527.0]
# sequential model is trained. best val loss is: [73283731200147.45, 73283735000000.0, 7160598.5]
# sequential model is trained. best val loss is: [72659349322858.5, 72659350000000.0, 7116644.5]
# sequential model is trained. best val loss is: [54125291160731.65, 54125287000000.0, 5685481.5]
# sequential model is trained. best val loss is: [73460264992768.0, 73460260000000.0, 7172664.5]
# sequential model is trained. best val loss is: [73457187480928.25, 73457195000000.0, 7172474.0]
# sequential model is trained. best val loss is: [73448047186542.6, 73448040000000.0, 7171891.0]
# sequential model is trained. best val loss is: [73111089218322.44, 73111090000000.0, 7150693.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73454491080327.17, 73454490000000.0, 7172295.0]
# sequential model is trained. best val loss is: [72888583874150.4, 72888570000000.0, 7136883.0]
# sequential model is trained. best val loss is: [70906582396829.7, 70906590000000.0, 7003944.0]
# sequential model is trained. best val loss is: [37445981003841.54, 37445974000000.0, 4380790.0]
# sequential model is trained. best val loss is: [73437080557977.6, 73437080000000.0, 7171176.5]
# sequential model is trained. best val loss is: [70815874633695.23, 70815865000000.0, 6995723.5]
# sequential model is trained. best val loss is: [63068126455005.19, 63068130000000.0, 6436084.0]
# sequential model is trained. best val loss is: [19494551739695.105, 19494552000000.0, 2630094.8]
# sequential model is trained. best val loss is: [73460332672057.34, 73460340000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460311063003.14, 73460310000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73460268415320.06, 73460265000000.0, 7172664.5]
# sequential model is trained. best val loss is: [42408271042052.09, 42408272000000.0, 4239049.5]
# sequential model is trained. best val loss is: [73456483274063.88, 73456490000000.0, 7172399.0]
# sequential model is trained. best val loss is: [73056888811421.7, 73056900000000.0, 7143662.0]
# sequential model is trained. best val loss is: [71784687118319.61, 71784690000000.0, 7053269.5]
# sequential model is trained. best val loss is: [40872353172815.875, 40872356000000.0, 4444555.5]
# sequential model is trained. best val loss is: [73460232746958.84, 73460240000000.0, 7172662.5]
# sequential model is trained. best val loss is: [73454265158336.52, 73454250000000.0, 7172267.5]
# sequential model is trained. best val loss is: [73436516776411.14, 73436510000000.0, 7171086.0]
# sequential model is trained. best val loss is: [72697286030786.56, 72697290000000.0, 7121981.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73449272560844.8, 73449270000000.0, 7171944.5]
# sequential model is trained. best val loss is: [72265774055555.08, 72265760000000.0, 7090831.5]
# sequential model is trained. best val loss is: [68474271885688.83, 68474274000000.0, 6826311.5]
# sequential model is trained. best val loss is: [24340724459765.76, 24340725000000.0, 3004312.2]
# sequential model is trained. best val loss is: [73413328549969.92, 73413320000000.0, 7169654.0]
# sequential model is trained. best val loss is: [67883606759964.67, 67883615000000.0, 6787583.0]
# sequential model is trained. best val loss is: [55503181194461.19, 55503187000000.0, 5909132.0]
# sequential model is trained. best val loss is: [15983363714187.264, 15983366000000.0, 2351654.8]
# sequential model is trained. best val loss is: [73460328511307.78, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73460288615088.12, 73460290000000.0, 7172665.5]
# sequential model is trained. best val loss is: [73458687263375.36, 73458690000000.0, 7172541.0]
# sequential model is trained. best val loss is: [37398929360289.79, 37398927000000.0, 3702373.0]
# sequential model is trained. best val loss is: [73452609515552.77, 73452610000000.0, 7172130.0]
# sequential model is trained. best val loss is: [72632426806902.78, 72632430000000.0, 7113848.5]
# sequential model is trained. best val loss is: [69581977254100.99, 69581972000000.0, 6888334.5]
# sequential model is trained. best val loss is: [30776762354892.8, 30776763000000.0, 3469015.2]
# sequential model is trained. best val loss is: [73460157652140.03, 73460140000000.0, 7172657.5]
# sequential model is trained. best val loss is: [73448053696102.4, 73448030000000.0, 7171879.5]
# sequential model is trained. best val loss is: [73411482787774.47, 73411490000000.0, 7169491.0]
# sequential model is trained. best val loss is: [71909034474602.5, 71909050000000.0, 7070348.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73436784507224.06, 73436780000000.0, 7171141.5]
# sequential model is trained. best val loss is: [71003574686973.95, 71003560000000.0, 7005213.5]
# sequential model is trained. best val loss is: [63879909835014.14, 63879913000000.0, 6493071.0]
# sequential model is trained. best val loss is: [17580902427131.904, 17580900000000.0, 2500217.8]
# sequential model is trained. best val loss is: [73357305566986.23, 73357295000000.0, 7165961.0]
# sequential model is trained. best val loss is: [63070330746306.56, 63070324000000.0, 6444950.0]
# sequential model is trained. best val loss is: [45087626176233.47, 45087630000000.0, 5035030.5]
# sequential model is trained. best val loss is: [13814331617574.912, 13814330000000.0, 2108430.5]
# sequential model is trained. best val loss is: [73460328041545.73, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [73458974321541.12, 73458970000000.0, 7172562.0]
# sequential model is trained. best val loss is: [67260550400180.23, 67260560000000.0, 6657318.5]
# sequential model is trained. best val loss is: [27867883069505.535, 27867885000000.0, 3063017.0]
# sequential model is trained. best val loss is: [73444540479963.14, 73444545000000.0, 7171561.0]
# sequential model is trained. best val loss is: [71655246333476.86, 71655250000000.0, 7043820.0]
# sequential model is trained. best val loss is: [65719108229922.81, 65719120000000.0, 6587923.0]
# sequential model is trained. best val loss is: [24994399473631.23, 24994397000000.0, 3008378.2]
# sequential model is trained. best val loss is: [73460044338823.17, 73460055000000.0, 7172647.5]
# sequential model is trained. best val loss is: [73434009555697.66, 73434000000000.0, 7170953.0]
# sequential model is trained. best val loss is: [73350400333316.1, 73350420000000.0, 7165411.0]
# sequential model is trained. best val loss is: [70433798302466.05, 70433800000000.0, 6970089.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73410376531705.86, 73410380000000.0, 7169386.5]
# sequential model is trained. best val loss is: [68425611365842.945, 68425603000000.0, 6821255.0]
# sequential model is trained. best val loss is: [56591411872530.43, 56591403000000.0, 6019046.0]
# sequential model is trained. best val loss is: [14250168777965.568, 14250168000000.0, 2166776.8]
# sequential model is trained. best val loss is: [73217865729179.64, 73217860000000.0, 7156505.5]
# sequential model is trained. best val loss is: [26332453660524.543, 26332455000000.0, 3167962.5]
# sequential model is trained. best val loss is: [15735182799667.2, 15735181000000.0, 2317614.0]
# sequential model is trained. best val loss is: [11590637539295.232, 11590637000000.0, 1796566.8]
# sequential model is trained. best val loss is: [73460342167961.6, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460334282670.08, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460287373574.14, 73460280000000.0, 7172665.5]
# sequential model is trained. best val loss is: [11377665856503.809, 11377665000000.0, 1804408.6]
# sequential model is trained. best val loss is: [73448893295099.9, 73448900000000.0, 7171835.5]
# sequential model is trained. best val loss is: [62816239927427.07, 62816237000000.0, 6353838.0]
# sequential model is trained. best val loss is: [32264867440230.4, 32264866000000.0, 3568986.0]
# sequential model is trained. best val loss is: [13419326958731.264, 13419324000000.0, 2024516.4]
# sequential model is trained. best val loss is: [73460297641230.34, 73460310000000.0, 7172666.0]
# sequential model is trained. best val loss is: [73428843448238.08, 73428830000000.0, 7170611.0]
# sequential model is trained. best val loss is: [73208477769531.39, 73208470000000.0, 7155890.0]
# sequential model is trained. best val loss is: [52838686462574.59, 52838690000000.0, 5708425.0]
# sequential model is trained. best val loss is: [1.3354121223932478e+16, 1.3354121e+16, 115464744.0]
# sequential model is trained. best val loss is: [22014006659121.152, 22014004000000.0, 2858566.2]
# sequential model is trained. best val loss is: [22013184994967.55, 22013182000000.0, 2864901.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73418448285204.48, 73418460000000.0, 7169860.0]
# sequential model is trained. best val loss is: [45761566036983.805, 45761572000000.0, 5064145.0]
# sequential model is trained. best val loss is: [19937841429610.496, 19937840000000.0, 2663198.5]
# sequential model is trained. best val loss is: [11722876751183.871, 11722876000000.0, 1795157.5]
# sequential model is trained. best val loss is: [72575901698621.44, 72575900000000.0, 7114646.0]
# sequential model is trained. best val loss is: [18036723837566.977, 18036724000000.0, 2523395.8]
# sequential model is trained. best val loss is: [12946846045437.951, 12946844000000.0, 1954558.6]
# sequential model is trained. best val loss is: [11261688057692.16, 11261687000000.0, 1778291.5]
# sequential model is trained. best val loss is: [73460338141429.77, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460315727069.19, 73460315000000.0, 7172667.0]
# sequential model is trained. best val loss is: [73456022236168.19, 73456010000000.0, 7172336.5]
# sequential model is trained. best val loss is: [11327822805073.92, 11327825000000.0, 1768674.9]
# sequential model is trained. best val loss is: [73420154393853.95, 73420160000000.0, 7169881.5]
# sequential model is trained. best val loss is: [45005650870140.93, 45005658000000.0, 4850707.5]
# sequential model is trained. best val loss is: [25125509625020.414, 25125508000000.0, 3013628.2]
# sequential model is trained. best val loss is: [12374193689591.809, 12374193000000.0, 1842626.5]
# sequential model is trained. best val loss is: [73460172785188.86, 73460170000000.0, 7172658.0]
# sequential model is trained. best val loss is: [73343546337263.61, 73343554000000.0, 7165083.5]
# sequential model is trained. best val loss is: [72517254440288.25, 72517260000000.0, 7111980.5]
# sequential model is trained. best val loss is: [34073893111070.72, 34073897000000.0, 3937012.5]
# sequential model is trained. best val loss is: [8.838061133650094e+16, 8.838063e+16, 297251700.0]
# sequential model is trained. best val loss is: [22014021599232.0, 22014023000000.0, 2858505.2]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [73300903049822.2, 73300900000000.0, 7162451.5]
# sequential model is trained. best val loss is: [26409093367332.863, 26409093000000.0, 3152820.2]
# sequential model is trained. best val loss is: [13784437196062.72, 13784434000000.0, 2083258.8]
# sequential model is trained. best val loss is: [11424601711050.752, 11424600000000.0, 1773522.8]
# sequential model is trained. best val loss is: [70235347207847.94, 70235353000000.0, 6955708.0]
# sequential model is trained. best val loss is: [14028461972652.031, 14028460000000.0, 2146539.8]
# sequential model is trained. best val loss is: [11956121396838.4, 11956120000000.0, 1832451.8]
# sequential model is trained. best val loss is: [11073929342877.695, 11073930000000.0, 1765685.8]
# sequential model is trained. best val loss is: [73460338443419.64, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460204561235.97, 73460215000000.0, 7172660.5]
# sequential model is trained. best val loss is: [10952189283401.729, 10952188000000.0, 1807911.8]
# sequential model is trained. best val loss is: [10961471196364.8, 10961473000000.0, 1735131.9]
# sequential model is trained. best val loss is: [73299849910419.45, 73299840000000.0, 7161201.5]
# sequential model is trained. best val loss is: [29903305844981.76, 29903310000000.0, 3416255.8]
# sequential model is trained. best val loss is: [18759431919501.312, 18759431000000.0, 2592560.8]
# sequential model is trained. best val loss is: [11805324608536.576, 11805326000000.0, 1786714.4]
# sequential model is trained. best val loss is: [73459735537385.47, 73459740000000.0, 7172628.5]
# sequential model is trained. best val loss is: [73034000830038.02, 73034015000000.0, 7144782.5]
# sequential model is trained. best val loss is: [70087338222419.97, 70087344000000.0, 6948625.0]
# sequential model is trained. best val loss is: [21891872494452.734, 21891874000000.0, 2834313.8]
# sequential model is trained. best val loss is: [2.401247380268143e+17, 2.4012475e+17, 490002800.0]
# sequential model is trained. best val loss is: [22014036455456.77, 22014040000000.0, 2858439.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72852718112210.94, 72852710000000.0, 7132899.5]
# sequential model is trained. best val loss is: [15988755500367.871, 15988756000000.0, 2385932.2]
# sequential model is trained. best val loss is: [12205807391211.52, 12205806000000.0, 1858724.0]
# sequential model is trained. best val loss is: [11290615899750.4, 11290615000000.0, 1767952.5]
# sequential model is trained. best val loss is: [61206990105346.05, 61206988000000.0, 6339532.0]
# sequential model is trained. best val loss is: [12246294663790.592, 12246294000000.0, 1866650.1]
# sequential model is trained. best val loss is: [11566178900115.455, 11566177000000.0, 1789515.5]
# sequential model is trained. best val loss is: [11132948073938.943, 11132951000000.0, 1748989.1]
# sequential model is trained. best val loss is: [73460327202684.92, 73460330000000.0, 7172668.0]
# sequential model is trained. best val loss is: [11045297224417.28, 11045298000000.0, 1800413.5]
# sequential model is trained. best val loss is: [10966620260270.08, 10966620000000.0, 1767259.0]
# sequential model is trained. best val loss is: [10848870177177.6, 10848868000000.0, 1710418.0]
# sequential model is trained. best val loss is: [72806473696018.44, 72806470000000.0, 7126947.5]
# sequential model is trained. best val loss is: [21352848977559.55, 21352850000000.0, 2766184.0]
# sequential model is trained. best val loss is: [14087823770517.504, 14087819000000.0, 2132926.5]
# sequential model is trained. best val loss is: [11441003925864.447, 11441003000000.0, 1774817.5]
# sequential model is trained. best val loss is: [73457607280427.02, 73457610000000.0, 7172496.0]
# sequential model is trained. best val loss is: [71564546153644.03, 71564540000000.0, 7049055.0]
# sequential model is trained. best val loss is: [61283767762812.93, 61283770000000.0, 6342422.0]
# sequential model is trained. best val loss is: [15223062848864.256, 15223064000000.0, 2287979.0]
# sequential model is trained. best val loss is: [9.054711577787805e+20, 9.054711e+20, 30091047000.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [70856913348198.4, 70856920000000.0, 7002238.0]
# sequential model is trained. best val loss is: [12591315426476.031, 12591314000000.0, 1926443.8]
# sequential model is trained. best val loss is: [11832849877434.367, 11832852000000.0, 1796605.1]
# sequential model is trained. best val loss is: [11087882065281.023, 11087881000000.0, 1739277.2]
# sequential model is trained. best val loss is: [45075256955633.664, 45075254000000.0, 5074228.0]
# sequential model is trained. best val loss is: [11736458148708.352, 11736460000000.0, 1798258.1]
# sequential model is trained. best val loss is: [11276673777401.855, 11276674000000.0, 1777323.9]
# sequential model is trained. best val loss is: [11655553809907.713, 11655555000000.0, 1807687.5]
# sequential model is trained. best val loss is: [73460321431322.62, 73460320000000.0, 7172667.5]
# sequential model is trained. best val loss is: [10951374573404.16, 10951375000000.0, 1767122.0]
# sequential model is trained. best val loss is: [10869273777930.24, 10869277000000.0, 1738033.6]
# sequential model is trained. best val loss is: [10912922169507.84, 10912922000000.0, 1704927.9]
# sequential model is trained. best val loss is: [70934076210544.64, 70934070000000.0, 6991733.0]
# sequential model is trained. best val loss is: [16042964883079.168, 16042966000000.0, 2361737.2]
# sequential model is trained. best val loss is: [12553685466873.855, 12553687000000.0, 1908641.6]
# sequential model is trained. best val loss is: [11232369174380.545, 11232369000000.0, 1758575.0]
# sequential model is trained. best val loss is: [73451137381957.62, 73451155000000.0, 7172063.0]
# sequential model is trained. best val loss is: [66780452093952.0, 66780450000000.0, 6709507.5]
# sequential model is trained. best val loss is: [46196014494777.34, 46195997000000.0, 5183235.5]
# sequential model is trained. best val loss is: [12679240556216.32, 12679242000000.0, 1955776.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [64512351402983.42, 64512347000000.0, 6549086.0]
# sequential model is trained. best val loss is: [11887368193703.936, 11887366000000.0, 1812527.6]
# sequential model is trained. best val loss is: [11483286947758.08, 11483286000000.0, 1775301.8]
# sequential model is trained. best val loss is: [11023172981751.809, 11023173000000.0, 1723629.1]
# sequential model is trained. best val loss is: [62430336092471.3, 62430344000000.0, 6385551.5]
# sequential model is trained. best val loss is: [12087407411200.0, 12087408000000.0, 1845538.2]
# sequential model is trained. best val loss is: [11509819187920.896, 11509818000000.0, 1796827.5]
# sequential model is trained. best val loss is: [11581267392856.064, 11581268000000.0, 1798540.9]
# sequential model is trained. best val loss is: [73460338342756.36, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460321733312.52, 73460320000000.0, 7172668.0]
# sequential model is trained. best val loss is: [12395680500809.729, 12395679000000.0, 1858575.6]
# sequential model is trained. best val loss is: [11106030345781.248, 11106030000000.0, 1742791.2]
# sequential model is trained. best val loss is: [73313184877903.88, 73313190000000.0, 7162021.0]
# sequential model is trained. best val loss is: [21286805227700.223, 21286806000000.0, 2760589.0]
# sequential model is trained. best val loss is: [13739656889761.793, 13739656000000.0, 2076164.2]
# sequential model is trained. best val loss is: [11423288706203.648, 11423287000000.0, 1777968.0]
# sequential model is trained. best val loss is: [73460204997443.58, 73460230000000.0, 7172661.0]
# sequential model is trained. best val loss is: [72571878018908.16, 72571895000000.0, 7111825.5]
# sequential model is trained. best val loss is: [61672491965218.81, 61672490000000.0, 6313068.0]
# sequential model is trained. best val loss is: [14314645990932.48, 14314645000000.0, 2200898.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [72647429194776.58, 72647430000000.0, 7116871.5]
# sequential model is trained. best val loss is: [12504029804363.775, 12504033000000.0, 1904300.2]
# sequential model is trained. best val loss is: [11650634811965.44, 11650635000000.0, 1779921.8]
# sequential model is trained. best val loss is: [11073215048712.191, 11073215000000.0, 1731488.8]
# sequential model is trained. best val loss is: [35188840163442.69, 35188840000000.0, 4004291.2]
# sequential model is trained. best val loss is: [11464892361998.336, 11464892000000.0, 1781515.9]
# sequential model is trained. best val loss is: [11125213961912.32, 11125213000000.0, 1769042.4]
# sequential model is trained. best val loss is: [11811844593287.168, 11811846000000.0, 1829442.5]
# sequential model is trained. best val loss is: [73460338745409.53, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [73460261872205.83, 73460260000000.0, 7172663.0]
# sequential model is trained. best val loss is: [11051517555507.2, 11051518000000.0, 1767572.2]
# sequential model is trained. best val loss is: [11083618078162.943, 11083618000000.0, 1716327.8]
# sequential model is trained. best val loss is: [72276948352499.72, 72276940000000.0, 7087588.0]
# sequential model is trained. best val loss is: [14912265497083.904, 14912266000000.0, 2162494.0]
# sequential model is trained. best val loss is: [12420308751351.809, 12420311000000.0, 1844100.4]
# sequential model is trained. best val loss is: [11230149445943.297, 11230146000000.0, 1762841.5]
# sequential model is trained. best val loss is: [73459589105844.22, 73459590000000.0, 7172620.5]
# sequential model is trained. best val loss is: [65926284751929.34, 65926280000000.0, 6621575.0]
# sequential model is trained. best val loss is: [33896689806868.48, 33896685000000.0, 3853743.5]
# sequential model is trained. best val loss is: [12600698392805.377, 12600699000000.0, 1879683.5]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [66863877102501.89, 66863883000000.0, 6703957.5]
# sequential model is trained. best val loss is: [11906909139369.984, 11906908000000.0, 1799747.6]
# sequential model is trained. best val loss is: [11462334335680.512, 11462331000000.0, 1775799.1]
# sequential model is trained. best val loss is: [10925492576190.465, 10925492000000.0, 1714300.8]
# sequential model is trained. best val loss is: [20901461219082.24, 20901463000000.0, 2746700.8]
# sequential model is trained. best val loss is: [11281920140771.328, 11281919000000.0, 1780723.2]
# sequential model is trained. best val loss is: [11084918207545.344, 11084916000000.0, 1752460.2]
# sequential model is trained. best val loss is: [11348592950247.424, 11348592000000.0, 1850760.9]
# sequential model is trained. best val loss is: [73460337571004.42, 73460350000000.0, 7172668.5]
# sequential model is trained. best val loss is: [11076915926401.023, 11076915000000.0, 1751428.8]
# sequential model is trained. best val loss is: [10950192387850.24, 10950193000000.0, 1716047.0]
# sequential model is trained. best val loss is: [10945254041583.615, 10945255000000.0, 1720362.6]
# sequential model is trained. best val loss is: [63796643991912.445, 63796656000000.0, 6431218.0]
# sequential model is trained. best val loss is: [12627174085361.664, 12627171000000.0, 1909161.1]
# sequential model is trained. best val loss is: [11789561013207.04, 11789559000000.0, 1785668.8]
# sequential model is trained. best val loss is: [11063773406167.04, 11063774000000.0, 1748757.1]
# sequential model is trained. best val loss is: [73453473575731.2, 73453480000000.0, 7172209.5]
# sequential model is trained. best val loss is: [44799682139914.24, 44799684000000.0, 5007674.0]
# sequential model is trained. best val loss is: [20768492991021.055, 20768495000000.0, 2753148.0]
# sequential model is trained. best val loss is: [11812346909425.664, 11812345000000.0, 1792807.4]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [41211808530300.93, 41211805000000.0, 4620323.0]
# sequential model is trained. best val loss is: [11483807049842.688, 11483804000000.0, 1772751.2]
# sequential model is trained. best val loss is: [11258619251130.367, 11258618000000.0, 1763616.1]
# sequential model is trained. best val loss is: [10962900686471.168, 10962899000000.0, 1694026.4]
# sequential model is trained. best val loss is: [14653814825025.535, 14653816000000.0, 2225911.5]
# sequential model is trained. best val loss is: [11079370803249.152, 11079373000000.0, 1756459.1]
# sequential model is trained. best val loss is: [11308470791831.553, 11308471000000.0, 1768304.0]
# sequential model is trained. best val loss is: [13709361671045.12, 13709364000000.0, 2576424.2]
# sequential model is trained. best val loss is: [73460332000968.7, 73460350000000.0, 7172668.0]
# sequential model is trained. best val loss is: [10976789318860.8, 10976789000000.0, 1725826.4]
# sequential model is trained. best val loss is: [11040995869196.287, 11040998000000.0, 1716316.8]
# sequential model is trained. best val loss is: [11014251135107.072, 11014252000000.0, 1708108.4]
# sequential model is trained. best val loss is: [38892015391342.59, 38892020000000.0, 4306989.5]
# sequential model is trained. best val loss is: [11919667576700.928, 11919668000000.0, 1794169.8]
# sequential model is trained. best val loss is: [11345281559822.336, 11345281000000.0, 1769816.9]
# sequential model is trained. best val loss is: [11239946257956.863, 11239947000000.0, 1753629.2]
# sequential model is trained. best val loss is: [73405971505872.89, 73405960000000.0, 7169166.0]
# sequential model is trained. best val loss is: [24655018858643.457, 24655019000000.0, 3026782.0]
# sequential model is trained. best val loss is: [14839333223661.568, 14839333000000.0, 2248148.2]
# sequential model is trained. best val loss is: [11403022219345.92, 11403019000000.0, 1756703.0]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [21098101360033.793, 21098102000000.0, 2774973.5]
# sequential model is trained. best val loss is: [11243810383200.256, 11243811000000.0, 1760631.1]
# sequential model is trained. best val loss is: [11057204375322.623, 11057206000000.0, 1738587.0]
# sequential model is trained. best val loss is: [10613516941656.064, 10613517000000.0, 1672526.6]
# sequential model is trained. best val loss is: [12368638682071.04, 12368637000000.0, 1879768.6]
# sequential model is trained. best val loss is: [11166552606900.225, 11166555000000.0, 1748464.0]
# sequential model is trained. best val loss is: [11837112575852.545, 11837114000000.0, 1828312.8]
# sequential model is trained. best val loss is: [15234254527004.672, 15234254000000.0, 2810975.8]
# sequential model is trained. best val loss is: [73460318176542.72, 73460315000000.0, 7172667.0]
# sequential model is trained. best val loss is: [11020664588730.367, 11020665000000.0, 1716940.5]
# sequential model is trained. best val loss is: [11001380827299.84, 11001383000000.0, 1708731.4]
# sequential model is trained. best val loss is: [11055599141781.504, 11055597000000.0, 1705980.0]
# sequential model is trained. best val loss is: [24433551889924.098, 24433549000000.0, 2981559.0]
# sequential model is trained. best val loss is: [11438439522107.393, 11438440000000.0, 1770133.2]
# sequential model is trained. best val loss is: [11142858037788.672, 11142857000000.0, 1752001.1]
# sequential model is trained. best val loss is: [11623064206835.713, 11623063000000.0, 1787180.0]
# sequential model is trained. best val loss is: [73018475831885.83, 73018470000000.0, 7143322.5]
# sequential model is trained. best val loss is: [16389514901585.92, 16389516000000.0, 2410472.0]
# sequential model is trained. best val loss is: [12606277089755.137, 12606275000000.0, 1921530.4]
# sequential model is trained. best val loss is: [11126241421688.832, 11126242000000.0, 1732818.1]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [nan, nan, nan]
# sequential model is trained. best val loss is: [13363303283687.424, 13363302000000.0, 2035045.8]
# sequential model is trained. best val loss is: [11135056340844.545, 11135053000000.0, 1747744.0]
# sequential model is trained. best val loss is: [10995941368659.969, 10995940000000.0, 1717230.4]
# sequential model is trained. best val loss is: [9834562278391.809, 9834561000000.0, 1659131.2]
# ==== 16.879134714603424 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}

# %% [markdown]
# ### The more the number of parameters, the worse the reproducibility.

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[3], units=[256],
         optimizers=['rmsprop'], lrs=[0.1],
         batch_size=64, epochs=10, verbose=0)

auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[3], units=[256],
         optimizers=['rmsprop'], lrs=[0.1],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [9834562278391.809, 9834561000000.0, 1659131.2]
# sequential model is trained. best val loss is: [9834562278391.809, 9834561000000.0, 1659131.2]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x177de9850>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}],
#  [9834562278391.809])

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[3], units=[256],
         optimizers=['rmsprop'], lrs=[0.1],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [9834562278391.809, 9834561000000.0, 1659131.2]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x177c1fc10>],
#  [{'hidden_layer': 3, 'unit': 256, 'optimizer': 'rmsprop', 'lr': 0.1}],
#  [9834562278391.809])

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[1], units=[64],
         optimizers=['adam'], lrs=[0.01],
         batch_size=64, epochs=10, verbose=0)

auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[1], units=[64],
         optimizers=['adam'], lrs=[0.01],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [70815874633695.23, 70815865000000.0, 6995723.5]
# sequential model is trained. best val loss is: [70815874633695.23, 70815865000000.0, 6995723.5]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x17821d750>],
#  [{'hidden_layer': 1, 'unit': 64, 'optimizer': 'adam', 'lr': 0.01}],
#  [70815874633695.23])
