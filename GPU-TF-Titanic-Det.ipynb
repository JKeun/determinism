# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename = "./data/titanic_train.csv"
ds = DataSource(filename)
ds.data_load_split(target=['Survived'],
                   ignore=['Name', 'Cabin', 'Ticket'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)

# %%
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.5236441493034363, 0.776190459728241]
# sequential model is trained. best val loss is: [0.44984200596809387, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.5536462664604187, 0.7809523940086365]
# sequential model is trained. best val loss is: [1.1796329021453857, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.7054762840270996, 0.4285714328289032]
# sequential model is trained. best val loss is: [0.7019086480140686, 0.4571428596973419]
# sequential model is trained. best val loss is: [0.6982108950614929, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6750959753990173, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.6232395172119141, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.4445045590400696, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.4247000515460968, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.4618394076824188, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6871144771575928, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.582256555557251, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.5090085864067078, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4726611077785492, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.6954167485237122, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.6425380706787109, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.598693311214447, 0.723809540271759]
# sequential model is trained. best val loss is: [0.48558858036994934, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5198189616203308, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5356467962265015, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5750561356544495, 0.776190459728241]
# sequential model is trained. best val loss is: [0.581124484539032, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.4690227210521698, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.4658220112323761, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6725627183914185, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.7875818014144897, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.7029011249542236, 0.39047619700431824]
# sequential model is trained. best val loss is: [0.6975502371788025, 0.43809524178504944]
# sequential model is trained. best val loss is: [0.6919435858726501, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6519152522087097, 0.699999988079071]
# sequential model is trained. best val loss is: [0.5696399211883545, 0.776190459728241]
# sequential model is trained. best val loss is: [0.42394840717315674, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.40968719124794006, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.5197750926017761, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6786412000656128, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.5527942180633545, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.49501654505729675, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.4751594662666321, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.6911841034889221, 0.5142857432365417]
# sequential model is trained. best val loss is: [0.6249615550041199, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.5793747901916504, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.4831855893135071, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4679534137248993, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.535660982131958, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5877829194068909, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6071599721908569, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.4577539265155792, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6136528253555298, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5754799842834473, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.9458339214324951, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.7116197347640991, 0.41428571939468384]
# sequential model is trained. best val loss is: [0.7019985914230347, 0.4571428596973419]
# sequential model is trained. best val loss is: [0.6921753883361816, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6316068172454834, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.5401442050933838, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.42338529229164124, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.4327084720134735, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.5667939186096191, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6738825440406799, 0.723809540271759]
# sequential model is trained. best val loss is: [0.5410339832305908, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.4908830523490906, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.4719608724117279, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6940204501152039, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6095427870750427, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.5663203597068787, 0.761904776096344]
# sequential model is trained. best val loss is: [0.47769179940223694, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4551785886287689, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.5593675971031189, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.5383251905441284, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.7209217548370361, 0.738095223903656]
# sequential model is trained. best val loss is: [0.44719311594963074, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6698389649391174, 0.761904776096344]
# sequential model is trained. best val loss is: [0.5442233681678772, 0.8380952477455139]
# sequential model is trained. best val loss is: [0.772563636302948, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.7427284121513367, 0.3523809611797333]
# sequential model is trained. best val loss is: [0.7279643416404724, 0.3619047701358795]
# sequential model is trained. best val loss is: [0.7130404710769653, 0.3857142925262451]
# sequential model is trained. best val loss is: [0.6248354315757751, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.5164544582366943, 0.776190459728241]
# sequential model is trained. best val loss is: [0.41508302092552185, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.4387325048446655, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.49208933115005493, 0.8523809313774109]
# sequential model is trained. best val loss is: [0.6948162317276001, 0.4523809552192688]
# sequential model is trained. best val loss is: [0.5448685884475708, 0.776190459728241]
# sequential model is trained. best val loss is: [0.49550512433052063, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.4838320314884186, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.7215789556503296, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.6234326958656311, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.5762282013893127, 0.761904776096344]
# sequential model is trained. best val loss is: [0.48298513889312744, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4449814260005951, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.5332687497138977, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.5367350578308105, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.7197092175483704, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4317672848701477, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.5138576626777649, 0.8285714387893677]
# sequential model is trained. best val loss is: [0.8845305442810059, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.780218243598938, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.7135171294212341, 0.39523810148239136]
# sequential model is trained. best val loss is: [0.6941478848457336, 0.4095238149166107]
# sequential model is trained. best val loss is: [0.6754021048545837, 0.6285714507102966]
# sequential model is trained. best val loss is: [0.5802671909332275, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.48010948300361633, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.419903963804245, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.4490291476249695, 0.8285714387893677]
# sequential model is trained. best val loss is: [0.4911484122276306, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6636224389076233, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.5236836671829224, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.48632457852363586, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.47696372866630554, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.6925317645072937, 0.41428571939468384]
# sequential model is trained. best val loss is: [0.5961538553237915, 0.761904776096344]
# sequential model is trained. best val loss is: [0.5525540113449097, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.47861215472221375, 0.776190459728241]
# sequential model is trained. best val loss is: [0.43111923336982727, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.5598072409629822, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.5500258803367615, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.9498938322067261, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.4739666283130646, 0.800000011920929]
# sequential model is trained. best val loss is: [0.900299072265625, 0.699999988079071]
# sequential model is trained. best val loss is: [0.7750986814498901, 0.7333333492279053]
# sequential model is trained. best val loss is: [1.0811867713928223, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.6893821358680725, 0.5523809790611267]
# sequential model is trained. best val loss is: [0.6877630949020386, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.6859235763549805, 0.6285714507102966]
# sequential model is trained. best val loss is: [0.663170576095581, 0.6714285612106323]
# sequential model is trained. best val loss is: [0.5874068140983582, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.43260759115219116, 0.800000011920929]
# sequential model is trained. best val loss is: [0.47415611147880554, 0.800000011920929]
# sequential model is trained. best val loss is: [0.6491904258728027, 0.7285714149475098]
# sequential model is trained. best val loss is: [0.6814837455749512, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.568920910358429, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.5075727105140686, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4970230162143707, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6855770945549011, 0.6285714507102966]
# sequential model is trained. best val loss is: [0.6323356032371521, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.5876158475875854, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.5012235641479492, 0.776190459728241]
# sequential model is trained. best val loss is: [0.47897326946258545, 0.8047618865966797]
# sequential model is trained. best val loss is: [1.114980697631836, 0.738095223903656]
# sequential model is trained. best val loss is: [0.8440230488777161, 0.7047619223594666]
# sequential model is trained. best val loss is: [1.750018835067749, 0.723809540271759]
# sequential model is trained. best val loss is: [0.4521600902080536, 0.800000011920929]
# sequential model is trained. best val loss is: [0.8710700869560242, 0.6571428775787354]
# sequential model is trained. best val loss is: [1.031983494758606, 0.699999988079071]
# sequential model is trained. best val loss is: [1.0643324851989746, 0.699999988079071]
# sequential model is trained. best val loss is: [0.6842126846313477, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.6786340475082397, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.6726757884025574, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6283708214759827, 0.6523809432983398]
# sequential model is trained. best val loss is: [0.5492026209831238, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4446987807750702, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.4671473801136017, 0.8238095045089722]
# sequential model is trained. best val loss is: [0.9400518536567688, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.664980411529541, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.5626171827316284, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5033860802650452, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5228838920593262, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.675970196723938, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6269629597663879, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5885687470436096, 0.738095223903656]
# sequential model is trained. best val loss is: [0.49299395084381104, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4531661868095398, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6438691020011902, 0.723809540271759]
# sequential model is trained. best val loss is: [0.6183207631111145, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.9068410992622375, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.4491502642631531, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.7456880211830139, 0.7142857313156128]
# sequential model is trained. best val loss is: [1.2325750589370728, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.9769684672355652, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6809695959091187, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.6733033657073975, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.6649062633514404, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.5976273417472839, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.500859260559082, 0.800000011920929]
# sequential model is trained. best val loss is: [0.4902643859386444, 0.800000011920929]
# sequential model is trained. best val loss is: [0.7039867639541626, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.6749789118766785, 0.800000011920929]
# sequential model is trained. best val loss is: [0.662911057472229, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.5519241690635681, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4956025183200836, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.5416987538337708, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.6743074655532837, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.6247829794883728, 0.6380952596664429]
# sequential model is trained. best val loss is: [0.5838363170623779, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.4899233281612396, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.454750657081604, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6742089986801147, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.685879647731781, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.6489527225494385, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.43624019622802734, 0.800000011920929]
# sequential model is trained. best val loss is: [0.6822841167449951, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.899135172367096, 0.800000011920929]
# sequential model is trained. best val loss is: [1.3096917867660522, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.7030696868896484, 0.380952388048172]
# sequential model is trained. best val loss is: [0.688737690448761, 0.5809524059295654]
# sequential model is trained. best val loss is: [0.6748461127281189, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.5778040289878845, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4614669680595398, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.5050138235092163, 0.8238095045089722]
# sequential model is trained. best val loss is: [0.8112708926200867, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6075214743614197, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6787875294685364, 0.6761904954910278]
# sequential model is trained. best val loss is: [0.5530125498771667, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4925912320613861, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5524036288261414, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.6933740377426147, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.6360782980918884, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.5939497351646423, 0.7285714149475098]
# sequential model is trained. best val loss is: [0.4891030490398407, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.48604074120521545, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6777418851852417, 0.723809540271759]
# sequential model is trained. best val loss is: [0.8088708519935608, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.8411264419555664, 0.761904776096344]
# sequential model is trained. best val loss is: [0.4563804268836975, 0.8476190567016602]
# sequential model is trained. best val loss is: [0.7658621072769165, 0.723809540271759]
# sequential model is trained. best val loss is: [1.1855204105377197, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.6256667375564575, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.6912043690681458, 0.561904788017273]
# sequential model is trained. best val loss is: [0.6682826280593872, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6478891372680664, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.5344844460487366, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.4494185745716095, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.8208006620407104, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.7887061238288879, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.8543478846549988, 0.776190459728241]
# sequential model is trained. best val loss is: [0.6652560830116272, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.5363773703575134, 0.776190459728241]
# sequential model is trained. best val loss is: [0.48865580558776855, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6241915822029114, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.6823717951774597, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6227782964706421, 0.6523809432983398]
# sequential model is trained. best val loss is: [0.5777419805526733, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.4909880459308624, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5395037531852722, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.7195801734924316, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.8322157859802246, 0.7952380776405334]
# sequential model is trained. best val loss is: [1.378700852394104, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.46949297189712524, 0.776190459728241]
# sequential model is trained. best val loss is: [0.9176360964775085, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.8564992547035217, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.7377791404724121, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.695397138595581, 0.3857142925262451]
# sequential model is trained. best val loss is: [0.6940469145774841, 0.4809523820877075]
# sequential model is trained. best val loss is: [0.6925683617591858, 0.561904788017273]
# sequential model is trained. best val loss is: [0.680272102355957, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.6205865144729614, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.43494802713394165, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6699437499046326, 0.7095237970352173]
# sequential model is trained. best val loss is: [1.0708595514297485, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.6899334788322449, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6519451141357422, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.5755162835121155, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5539175271987915, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.6921356916427612, 0.5809524059295654]
# sequential model is trained. best val loss is: [0.6733372807502747, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6593385934829712, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.49917474389076233, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4697186350822449, 0.776190459728241]
# sequential model is trained. best val loss is: [0.7428425550460815, 0.7523809671401978]
# sequential model is trained. best val loss is: [1.3352967500686646, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.5926985144615173, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.44517216086387634, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.7724034190177917, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.803955078125, 0.699999988079071]
# sequential model is trained. best val loss is: [1.2274430990219116, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.6940968036651611, 0.5095238089561462]
# sequential model is trained. best val loss is: [0.6915002465248108, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.6883437633514404, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6362475156784058, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.5568543672561646, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.5007973313331604, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.6789624094963074, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.656213641166687, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.687425434589386, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.6082226634025574, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.5136072635650635, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6132938861846924, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.6908335089683533, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.6650025844573975, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6409140229225159, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5109382271766663, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4541616141796112, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6416134834289551, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.7293736934661865, 0.761904776096344]
# sequential model is trained. best val loss is: [2.433798313140869, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.4613470137119293, 0.7857142686843872]
# sequential model is trained. best val loss is: [1.7090787887573242, 0.5476190447807312]
# sequential model is trained. best val loss is: [1.2888017892837524, 0.7047619223594666]
# sequential model is trained. best val loss is: [1.214474081993103, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6879622936248779, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.6821057796478271, 0.7285714149475098]
# sequential model is trained. best val loss is: [0.6751369833946228, 0.761904776096344]
# sequential model is trained. best val loss is: [0.5804718136787415, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.475903183221817, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5727840065956116, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.7580426335334778, 0.7714285850524902]
# sequential model is trained. best val loss is: [1.042327880859375, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6761795878410339, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.5619539618492126, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.4957738518714905, 0.776190459728241]
# sequential model is trained. best val loss is: [0.6857266426086426, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.6830801963806152, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.6446589827537537, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6060425639152527, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.5105578303337097, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.48361456394195557, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.5899633169174194, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.6805515885353088, 0.7952380776405334]
# sequential model is trained. best val loss is: [1.6424778699874878, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.5409704446792603, 0.800000011920929]
# sequential model is trained. best val loss is: [1.8145538568496704, 0.6142857074737549]
# sequential model is trained. best val loss is: [1.2962415218353271, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.969113826751709, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.6947028636932373, 0.44285714626312256]
# sequential model is trained. best val loss is: [0.6835015416145325, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.6716740131378174, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.5595859289169312, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4569443464279175, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.847156286239624, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.8238124251365662, 0.7571428418159485]
# sequential model is trained. best val loss is: [1.0771710872650146, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6791039109230042, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.5666626691818237, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4916554391384125, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.6637406945228577, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.6885160207748413, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.648892343044281, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.614109456539154, 0.6761904954910278]
# sequential model is trained. best val loss is: [0.5067696571350098, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.6324516534805298, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.8847567439079285, 0.699999988079071]
# sequential model is trained. best val loss is: [0.6330744624137878, 0.7857142686843872]
# sequential model is trained. best val loss is: [1.469066858291626, 0.738095223903656]
# sequential model is trained. best val loss is: [0.7109050750732422, 0.7571428418159485]
# sequential model is trained. best val loss is: [1.1075903177261353, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.9319919943809509, 0.7095237970352173]
# sequential model is trained. best val loss is: [1.5219910144805908, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6905570030212402, 0.5809524059295654]
# sequential model is trained. best val loss is: [0.6734117269515991, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6551239490509033, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5159468650817871, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4451650083065033, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.9081029295921326, 0.7047619223594666]
# sequential model is trained. best val loss is: [1.5260943174362183, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.7854076623916626, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.6762247085571289, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5683732628822327, 0.761904776096344]
# sequential model is trained. best val loss is: [0.492428719997406, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.6393216848373413, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.6859965920448303, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.6481156349182129, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6139432787895203, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5000131726264954, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.5269296765327454, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.8724847435951233, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.9238479137420654, 0.7809523940086365]
# sequential model is trained. best val loss is: [8.761871337890625, 0.4714285731315613]
# ==== 3.793680183092753 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.02}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info['hidden_layer']], units=[best_model_info['unit']],
         optimizers=[best_model_info['optimizer']], lrs=[best_model_info['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.40968719124794006, 0.8095238208770752]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7fd9f1dce940>],
#  [{'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.02}],
#  [0.40968719124794006])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.5236441493034363, 0.776190459728241]
# sequential model is trained. best val loss is: [0.44984200596809387, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.5536462664604187, 0.7809523940086365]
# sequential model is trained. best val loss is: [1.1796329021453857, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.7054762840270996, 0.4285714328289032]
# sequential model is trained. best val loss is: [0.7019086480140686, 0.4571428596973419]
# sequential model is trained. best val loss is: [0.6982108950614929, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6750959753990173, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.6232395172119141, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.4445045590400696, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.4247000515460968, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.4618394076824188, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6871144771575928, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.582256555557251, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.5090085864067078, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4726611077785492, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.6954167485237122, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.6425380706787109, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.598693311214447, 0.723809540271759]
# sequential model is trained. best val loss is: [0.48558858036994934, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5198189616203308, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5356467962265015, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5750561356544495, 0.776190459728241]
# sequential model is trained. best val loss is: [0.581124484539032, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.4690227210521698, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.4658220112323761, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6725627183914185, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.7875818014144897, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.7029011249542236, 0.39047619700431824]
# sequential model is trained. best val loss is: [0.6975502371788025, 0.43809524178504944]
# sequential model is trained. best val loss is: [0.6919435858726501, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6519152522087097, 0.699999988079071]
# sequential model is trained. best val loss is: [0.5696399211883545, 0.776190459728241]
# sequential model is trained. best val loss is: [0.42394840717315674, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.40968719124794006, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.5197750926017761, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6786412000656128, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.5527942180633545, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.49501654505729675, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.4751594662666321, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.6911841034889221, 0.5142857432365417]
# sequential model is trained. best val loss is: [0.6249615550041199, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.5793747901916504, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.4831855893135071, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4679534137248993, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.535660982131958, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5877829194068909, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6071599721908569, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.4577539265155792, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6136528253555298, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5754799842834473, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.9458339214324951, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.7116197347640991, 0.41428571939468384]
# sequential model is trained. best val loss is: [0.7019985914230347, 0.4571428596973419]
# sequential model is trained. best val loss is: [0.6921753883361816, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6316068172454834, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.5401442050933838, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.42338529229164124, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.4327084720134735, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.5667939186096191, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6738825440406799, 0.723809540271759]
# sequential model is trained. best val loss is: [0.5410339832305908, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.4908830523490906, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.4719608724117279, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6940204501152039, 0.48571428656578064]
# sequential model is trained. best val loss is: [0.6095427870750427, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.5663203597068787, 0.761904776096344]
# sequential model is trained. best val loss is: [0.47769179940223694, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4551785886287689, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.5593675971031189, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.5383251905441284, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.7209217548370361, 0.738095223903656]
# sequential model is trained. best val loss is: [0.44719311594963074, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6698389649391174, 0.761904776096344]
# sequential model is trained. best val loss is: [0.5442233681678772, 0.8380952477455139]
# sequential model is trained. best val loss is: [0.772563636302948, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.7427284121513367, 0.3523809611797333]
# sequential model is trained. best val loss is: [0.7279643416404724, 0.3619047701358795]
# sequential model is trained. best val loss is: [0.7130404710769653, 0.3857142925262451]
# sequential model is trained. best val loss is: [0.6248354315757751, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.5164544582366943, 0.776190459728241]
# sequential model is trained. best val loss is: [0.41508302092552185, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.4387325048446655, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.49208933115005493, 0.8523809313774109]
# sequential model is trained. best val loss is: [0.6948162317276001, 0.4523809552192688]
# sequential model is trained. best val loss is: [0.5448685884475708, 0.776190459728241]
# sequential model is trained. best val loss is: [0.49550512433052063, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.4838320314884186, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.7215789556503296, 0.36666667461395264]
# sequential model is trained. best val loss is: [0.6234326958656311, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.5762282013893127, 0.761904776096344]
# sequential model is trained. best val loss is: [0.48298513889312744, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4449814260005951, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.5332687497138977, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.5367350578308105, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.7197092175483704, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4317672848701477, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.5138576626777649, 0.8285714387893677]
# sequential model is trained. best val loss is: [0.8845305442810059, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.780218243598938, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.7135171294212341, 0.39523810148239136]
# sequential model is trained. best val loss is: [0.6941478848457336, 0.4095238149166107]
# sequential model is trained. best val loss is: [0.6754021048545837, 0.6285714507102966]
# sequential model is trained. best val loss is: [0.5802671909332275, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.48010948300361633, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.419903963804245, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.4490291476249695, 0.8285714387893677]
# sequential model is trained. best val loss is: [0.4911484122276306, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6636224389076233, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.5236836671829224, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.48632457852363586, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.47696372866630554, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.6925317645072937, 0.41428571939468384]
# sequential model is trained. best val loss is: [0.5961538553237915, 0.761904776096344]
# sequential model is trained. best val loss is: [0.5525540113449097, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.47861215472221375, 0.776190459728241]
# sequential model is trained. best val loss is: [0.43111923336982727, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.5598072409629822, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.5500258803367615, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.9498938322067261, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.4739666283130646, 0.800000011920929]
# sequential model is trained. best val loss is: [0.900299072265625, 0.699999988079071]
# sequential model is trained. best val loss is: [0.7750986814498901, 0.7333333492279053]
# sequential model is trained. best val loss is: [1.0811867713928223, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.6893821358680725, 0.5523809790611267]
# sequential model is trained. best val loss is: [0.6877630949020386, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.6859235763549805, 0.6285714507102966]
# sequential model is trained. best val loss is: [0.663170576095581, 0.6714285612106323]
# sequential model is trained. best val loss is: [0.5874068140983582, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.43260759115219116, 0.800000011920929]
# sequential model is trained. best val loss is: [0.47415611147880554, 0.800000011920929]
# sequential model is trained. best val loss is: [0.6491904258728027, 0.7285714149475098]
# sequential model is trained. best val loss is: [0.6814837455749512, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.568920910358429, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.5075727105140686, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4970230162143707, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6855770945549011, 0.6285714507102966]
# sequential model is trained. best val loss is: [0.6323356032371521, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.5876158475875854, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.5012235641479492, 0.776190459728241]
# sequential model is trained. best val loss is: [0.47897326946258545, 0.8047618865966797]
# sequential model is trained. best val loss is: [1.114980697631836, 0.738095223903656]
# sequential model is trained. best val loss is: [0.8440230488777161, 0.7047619223594666]
# sequential model is trained. best val loss is: [1.750018835067749, 0.723809540271759]
# sequential model is trained. best val loss is: [0.4521600902080536, 0.800000011920929]
# sequential model is trained. best val loss is: [0.8710700869560242, 0.6571428775787354]
# sequential model is trained. best val loss is: [1.031983494758606, 0.699999988079071]
# sequential model is trained. best val loss is: [1.0643324851989746, 0.699999988079071]
# sequential model is trained. best val loss is: [0.6842126846313477, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.6786340475082397, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.6726757884025574, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6283708214759827, 0.6523809432983398]
# sequential model is trained. best val loss is: [0.5492026209831238, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4446987807750702, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.4671473801136017, 0.8238095045089722]
# sequential model is trained. best val loss is: [0.9400518536567688, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.664980411529541, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.5626171827316284, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5033860802650452, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5228838920593262, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.675970196723938, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6269629597663879, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5885687470436096, 0.738095223903656]
# sequential model is trained. best val loss is: [0.49299395084381104, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4531661868095398, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6438691020011902, 0.723809540271759]
# sequential model is trained. best val loss is: [0.6183207631111145, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.9068410992622375, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.4491502642631531, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.7456880211830139, 0.7142857313156128]
# sequential model is trained. best val loss is: [1.2325750589370728, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.9769684672355652, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6809695959091187, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.6733033657073975, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.6649062633514404, 0.6333333253860474]
# sequential model is trained. best val loss is: [0.5976273417472839, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.500859260559082, 0.800000011920929]
# sequential model is trained. best val loss is: [0.4902643859386444, 0.800000011920929]
# sequential model is trained. best val loss is: [0.7039867639541626, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.6749789118766785, 0.800000011920929]
# sequential model is trained. best val loss is: [0.662911057472229, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.5519241690635681, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4956025183200836, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.5416987538337708, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.6743074655532837, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.6247829794883728, 0.6380952596664429]
# sequential model is trained. best val loss is: [0.5838363170623779, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.4899233281612396, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.454750657081604, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6742089986801147, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.685879647731781, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.6489527225494385, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.43624019622802734, 0.800000011920929]
# sequential model is trained. best val loss is: [0.6822841167449951, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.899135172367096, 0.800000011920929]
# sequential model is trained. best val loss is: [1.3096917867660522, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.7030696868896484, 0.380952388048172]
# sequential model is trained. best val loss is: [0.688737690448761, 0.5809524059295654]
# sequential model is trained. best val loss is: [0.6748461127281189, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.5778040289878845, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4614669680595398, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.5050138235092163, 0.8238095045089722]
# sequential model is trained. best val loss is: [0.8112708926200867, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6075214743614197, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6787875294685364, 0.6761904954910278]
# sequential model is trained. best val loss is: [0.5530125498771667, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4925912320613861, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5524036288261414, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.6933740377426147, 0.5333333611488342]
# sequential model is trained. best val loss is: [0.6360782980918884, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.5939497351646423, 0.7285714149475098]
# sequential model is trained. best val loss is: [0.4891030490398407, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.48604074120521545, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.6777418851852417, 0.723809540271759]
# sequential model is trained. best val loss is: [0.8088708519935608, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.8411264419555664, 0.761904776096344]
# sequential model is trained. best val loss is: [0.4563804268836975, 0.8476190567016602]
# sequential model is trained. best val loss is: [0.7658621072769165, 0.723809540271759]
# sequential model is trained. best val loss is: [1.1855204105377197, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.6256667375564575, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.6912043690681458, 0.561904788017273]
# sequential model is trained. best val loss is: [0.6682826280593872, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6478891372680664, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.5344844460487366, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.4494185745716095, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.8208006620407104, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.7887061238288879, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.8543478846549988, 0.776190459728241]
# sequential model is trained. best val loss is: [0.6652560830116272, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.5363773703575134, 0.776190459728241]
# sequential model is trained. best val loss is: [0.48865580558776855, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6241915822029114, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.6823717951774597, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6227782964706421, 0.6523809432983398]
# sequential model is trained. best val loss is: [0.5777419805526733, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.4909880459308624, 0.776190459728241]
# sequential model is trained. best val loss is: [0.5395037531852722, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.7195801734924316, 0.7952380776405334]
# sequential model is trained. best val loss is: [0.8322157859802246, 0.7952380776405334]
# sequential model is trained. best val loss is: [1.378700852394104, 0.7476190328598022]
# sequential model is trained. best val loss is: [0.46949297189712524, 0.776190459728241]
# sequential model is trained. best val loss is: [0.9176360964775085, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.8564992547035217, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.7377791404724121, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.695397138595581, 0.3857142925262451]
# sequential model is trained. best val loss is: [0.6940469145774841, 0.4809523820877075]
# sequential model is trained. best val loss is: [0.6925683617591858, 0.561904788017273]
# sequential model is trained. best val loss is: [0.680272102355957, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.6205865144729614, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.43494802713394165, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.6699437499046326, 0.7095237970352173]
# sequential model is trained. best val loss is: [1.0708595514297485, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.6899334788322449, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6519451141357422, 0.6238095164299011]
# sequential model is trained. best val loss is: [0.5755162835121155, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.5539175271987915, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.6921356916427612, 0.5809524059295654]
# sequential model is trained. best val loss is: [0.6733372807502747, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6593385934829712, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.49917474389076233, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4697186350822449, 0.776190459728241]
# sequential model is trained. best val loss is: [0.7428425550460815, 0.7523809671401978]
# sequential model is trained. best val loss is: [1.3352967500686646, 0.7428571581840515]
# sequential model is trained. best val loss is: [0.5926985144615173, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.44517216086387634, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.7724034190177917, 0.7333333492279053]
# sequential model is trained. best val loss is: [0.803955078125, 0.699999988079071]
# sequential model is trained. best val loss is: [1.2274430990219116, 0.8333333134651184]
# sequential model is trained. best val loss is: [0.6940968036651611, 0.5095238089561462]
# sequential model is trained. best val loss is: [0.6915002465248108, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.6883437633514404, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6362475156784058, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.5568543672561646, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.5007973313331604, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.6789624094963074, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.656213641166687, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.687425434589386, 0.6190476417541504]
# sequential model is trained. best val loss is: [0.6082226634025574, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.5136072635650635, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6132938861846924, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.6908335089683533, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.6650025844573975, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6409140229225159, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5109382271766663, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.4541616141796112, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.6416134834289551, 0.7571428418159485]
# sequential model is trained. best val loss is: [0.7293736934661865, 0.761904776096344]
# sequential model is trained. best val loss is: [2.433798313140869, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.4613470137119293, 0.7857142686843872]
# sequential model is trained. best val loss is: [1.7090787887573242, 0.5476190447807312]
# sequential model is trained. best val loss is: [1.2888017892837524, 0.7047619223594666]
# sequential model is trained. best val loss is: [1.214474081993103, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.6879622936248779, 0.6857143044471741]
# sequential model is trained. best val loss is: [0.6821057796478271, 0.7285714149475098]
# sequential model is trained. best val loss is: [0.6751369833946228, 0.761904776096344]
# sequential model is trained. best val loss is: [0.5804718136787415, 0.7523809671401978]
# sequential model is trained. best val loss is: [0.475903183221817, 0.800000011920929]
# sequential model is trained. best val loss is: [0.5727840065956116, 0.8190476298332214]
# sequential model is trained. best val loss is: [0.7580426335334778, 0.7714285850524902]
# sequential model is trained. best val loss is: [1.042327880859375, 0.6428571343421936]
# sequential model is trained. best val loss is: [0.6761795878410339, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.5619539618492126, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.4957738518714905, 0.776190459728241]
# sequential model is trained. best val loss is: [0.6857266426086426, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.6830801963806152, 0.7095237970352173]
# sequential model is trained. best val loss is: [0.6446589827537537, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6060425639152527, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.5105578303337097, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.48361456394195557, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.5899633169174194, 0.7666666507720947]
# sequential model is trained. best val loss is: [0.6805515885353088, 0.7952380776405334]
# sequential model is trained. best val loss is: [1.6424778699874878, 0.6476190686225891]
# sequential model is trained. best val loss is: [0.5409704446792603, 0.800000011920929]
# sequential model is trained. best val loss is: [1.8145538568496704, 0.6142857074737549]
# sequential model is trained. best val loss is: [1.2962415218353271, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.969113826751709, 0.6809523701667786]
# sequential model is trained. best val loss is: [0.6947028636932373, 0.44285714626312256]
# sequential model is trained. best val loss is: [0.6835015416145325, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.6716740131378174, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.5595859289169312, 0.776190459728241]
# sequential model is trained. best val loss is: [0.4569443464279175, 0.8142856955528259]
# sequential model is trained. best val loss is: [0.847156286239624, 0.6904761791229248]
# sequential model is trained. best val loss is: [0.8238124251365662, 0.7571428418159485]
# sequential model is trained. best val loss is: [1.0771710872650146, 0.6142857074737549]
# sequential model is trained. best val loss is: [0.6791039109230042, 0.6666666865348816]
# sequential model is trained. best val loss is: [0.5666626691818237, 0.7714285850524902]
# sequential model is trained. best val loss is: [0.4916554391384125, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.6637406945228577, 0.6952381134033203]
# sequential model is trained. best val loss is: [0.6885160207748413, 0.6571428775787354]
# sequential model is trained. best val loss is: [0.648892343044281, 0.6095238327980042]
# sequential model is trained. best val loss is: [0.614109456539154, 0.6761904954910278]
# sequential model is trained. best val loss is: [0.5067696571350098, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.6324516534805298, 0.7047619223594666]
# sequential model is trained. best val loss is: [0.8847567439079285, 0.699999988079071]
# sequential model is trained. best val loss is: [0.6330744624137878, 0.7857142686843872]
# sequential model is trained. best val loss is: [1.469066858291626, 0.738095223903656]
# sequential model is trained. best val loss is: [0.7109050750732422, 0.7571428418159485]
# sequential model is trained. best val loss is: [1.1075903177261353, 0.7190476059913635]
# sequential model is trained. best val loss is: [0.9319919943809509, 0.7095237970352173]
# sequential model is trained. best val loss is: [1.5219910144805908, 0.761904776096344]
# sequential model is trained. best val loss is: [0.6905570030212402, 0.5809524059295654]
# sequential model is trained. best val loss is: [0.6734117269515991, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6551239490509033, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5159468650817871, 0.7857142686843872]
# sequential model is trained. best val loss is: [0.4451650083065033, 0.8047618865966797]
# sequential model is trained. best val loss is: [0.9081029295921326, 0.7047619223594666]
# sequential model is trained. best val loss is: [1.5260943174362183, 0.5857142806053162]
# sequential model is trained. best val loss is: [0.7854076623916626, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.6762247085571289, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5683732628822327, 0.761904776096344]
# sequential model is trained. best val loss is: [0.492428719997406, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.6393216848373413, 0.7142857313156128]
# sequential model is trained. best val loss is: [0.6859965920448303, 0.6000000238418579]
# sequential model is trained. best val loss is: [0.6481156349182129, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.6139432787895203, 0.6047618985176086]
# sequential model is trained. best val loss is: [0.5000131726264954, 0.7904762029647827]
# sequential model is trained. best val loss is: [0.5269296765327454, 0.8095238208770752]
# sequential model is trained. best val loss is: [0.8724847435951233, 0.7809523940086365]
# sequential model is trained. best val loss is: [0.9238479137420654, 0.7809523940086365]
# sequential model is trained. best val loss is: [8.761871337890625, 0.4714285731315613]
# ==== 3.6830703973770142 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.02}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info_2nd['hidden_layer']], units=[best_model_info_2nd['unit']],
         optimizers=[best_model_info_2nd['optimizer']], lrs=[best_model_info_2nd['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.40968719124794006, 0.8095238208770752]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x7fd9cc1d5e48>],
#  [{'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.02}],
#  [0.40968719124794006])
