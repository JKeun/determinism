# %%
from src.DataSource import DataSource
from src.MLP import get_single_mlp, compile_model, train_model, auto_fit, select_best_model

# %%
filename = "./data/titanic_train.csv"
ds = DataSource(filename)
ds.data_load_split(target=['Survived'],
                   ignore=['Name', 'Cabin', 'Ticket'])
ds.define_problem()
ds.train_val_split(ratio=0.2, random_state=42)

# %%
ds.data_preprocess(ds.X_train, ds.y_train, train_set=True)
ds.data_preprocess(ds.X_val, ds.y_val, train_set=False)

# %%
X_train = ds.trans_X_train
y_train = ds.trans_y_train
X_val = ds.trans_X_val
y_val = ds.trans_y_val

# %%
# restore weights = True
# models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
#                                           hidden_layers=[1], units=[16],
#                                           optimizers=['adam'], lrs=[0.01],
#                                           batch_size=64, epochs=10, verbose=0,
#                                           use_all=True)

# %%
import time
start_time = time.time()
models, param_info, val_losses = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                          hidden_layers=[1], units=[16],
                                          optimizers=['adam'], lrs=[0.01],
                                          batch_size=64, epochs=10, verbose=0,
                                          use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.5216480334599812, 0.7714286]
# sequential model is trained. best val loss is: [0.41401143272717794, 0.8]
# sequential model is trained. best val loss is: [0.46487523260570707, 0.8238095]
# sequential model is trained. best val loss is: [0.6647860674631028, 0.8]
# sequential model is trained. best val loss is: [0.7054895781335376, 0.42857143]
# sequential model is trained. best val loss is: [0.702023586772737, 0.45714286]
# sequential model is trained. best val loss is: [0.6984167405537196, 0.4857143]
# sequential model is trained. best val loss is: [0.6754059984570457, 0.62857145]
# sequential model is trained. best val loss is: [0.6222717080797467, 0.7190476]
# sequential model is trained. best val loss is: [0.4424103966781071, 0.7952381]
# sequential model is trained. best val loss is: [0.4202179602214268, 0.81904763]
# sequential model is trained. best val loss is: [0.45611048482713246, 0.82857144]
# sequential model is trained. best val loss is: [0.6870668036597115, 0.5904762]
# sequential model is trained. best val loss is: [0.5833981718335833, 0.74285716]
# sequential model is trained. best val loss is: [0.5105543704259963, 0.7714286]
# sequential model is trained. best val loss is: [0.45822802782058714, 0.7952381]
# sequential model is trained. best val loss is: [0.6951618819009691, 0.53809524]
# sequential model is trained. best val loss is: [0.6425403980981736, 0.68095237]
# sequential model is trained. best val loss is: [0.5992390519096737, 0.7285714]
# sequential model is trained. best val loss is: [0.4787083080836705, 0.7809524]
# sequential model is trained. best val loss is: [0.5190129949933007, 0.77619046]
# sequential model is trained. best val loss is: [0.4448046408948444, 0.8047619]
# sequential model is trained. best val loss is: [0.6658132484980992, 0.7714286]
# sequential model is trained. best val loss is: [0.7035849730173747, 0.8]
# sequential model is trained. best val loss is: [0.468669601281484, 0.8142857]
# sequential model is trained. best val loss is: [0.4498437836056664, 0.8047619]
# sequential model is trained. best val loss is: [0.5179428492273603, 0.7952381]
# sequential model is trained. best val loss is: [0.787579045409248, 0.76666665]
# sequential model is trained. best val loss is: [0.7029132411593483, 0.3904762]
# sequential model is trained. best val loss is: [0.6976602474848429, 0.43333334]
# sequential model is trained. best val loss is: [0.6921516980443682, 0.47619048]
# sequential model is trained. best val loss is: [0.652977758929843, 0.7095238]
# sequential model is trained. best val loss is: [0.574565965788705, 0.77619046]
# sequential model is trained. best val loss is: [0.42270156741142273, 0.8095238]
# sequential model is trained. best val loss is: [0.4036279746464321, 0.8333333]
# sequential model is trained. best val loss is: [0.511861270949954, 0.8095238]
# sequential model is trained. best val loss is: [0.6786152504739307, 0.67142856]
# sequential model is trained. best val loss is: [0.5539989800680252, 0.7714286]
# sequential model is trained. best val loss is: [0.4956725688207717, 0.7714286]
# sequential model is trained. best val loss is: [0.45991553692590625, 0.8095238]
# sequential model is trained. best val loss is: [0.6910293204443795, 0.5285714]
# sequential model is trained. best val loss is: [0.6237222978046962, 0.7285714]
# sequential model is trained. best val loss is: [0.5794687537919907, 0.74285716]
# sequential model is trained. best val loss is: [0.4753768529210772, 0.77619046]
# sequential model is trained. best val loss is: [0.469087236835843, 0.8142857]
# sequential model is trained. best val loss is: [0.5694965595290774, 0.76666665]
# sequential model is trained. best val loss is: [0.8240238263493492, 0.7904762]
# sequential model is trained. best val loss is: [0.6551012050537836, 0.75714284]
# sequential model is trained. best val loss is: [0.4544494901384626, 0.78571427]
# sequential model is trained. best val loss is: [0.47108563014439175, 0.8238095]
# sequential model is trained. best val loss is: [0.5387262321653821, 0.7952381]
# sequential model is trained. best val loss is: [0.673859243165879, 0.8238095]
# sequential model is trained. best val loss is: [0.71166030111767, 0.41428572]
# sequential model is trained. best val loss is: [0.702361105737232, 0.45714286]
# sequential model is trained. best val loss is: [0.6928076630546933, 0.47619048]
# sequential model is trained. best val loss is: [0.634059054510934, 0.74761903]
# sequential model is trained. best val loss is: [0.5395273327827453, 0.7714286]
# sequential model is trained. best val loss is: [0.4170151855264391, 0.8095238]
# sequential model is trained. best val loss is: [0.4154530173256284, 0.8238095]
# sequential model is trained. best val loss is: [0.4955712954203288, 0.81904763]
# sequential model is trained. best val loss is: [0.6737751563390096, 0.72380954]
# sequential model is trained. best val loss is: [0.5436244073368254, 0.77619046]
# sequential model is trained. best val loss is: [0.49201955397923786, 0.8142857]
# sequential model is trained. best val loss is: [0.4603050390879313, 0.8095238]
# sequential model is trained. best val loss is: [0.6937197810127622, 0.48095238]
# sequential model is trained. best val loss is: [0.6095021463575817, 0.7190476]
# sequential model is trained. best val loss is: [0.5680189478965033, 0.7619048]
# sequential model is trained. best val loss is: [0.47325457561583745, 0.7904762]
# sequential model is trained. best val loss is: [0.4548120896021525, 0.8142857]
# sequential model is trained. best val loss is: [0.7600104899633499, 0.78571427]
# sequential model is trained. best val loss is: [1.2193409533727737, 0.7714286]
# sequential model is trained. best val loss is: [0.699330837385995, 0.7714286]
# sequential model is trained. best val loss is: [0.44433728201048717, 0.78571427]
# sequential model is trained. best val loss is: [0.5383356514431181, 0.77619046]
# sequential model is trained. best val loss is: [0.662613028004056, 0.7380952]
# sequential model is trained. best val loss is: [0.7489157659666879, 0.7809524]
# sequential model is trained. best val loss is: [0.7427788615226746, 0.35238096]
# sequential model is trained. best val loss is: [0.7284241188140143, 0.36190477]
# sequential model is trained. best val loss is: [0.7138302570297604, 0.3809524]
# sequential model is trained. best val loss is: [0.6280910230818249, 0.72380954]
# sequential model is trained. best val loss is: [0.5130737860997517, 0.78571427]
# sequential model is trained. best val loss is: [0.4121404102870396, 0.82857144]
# sequential model is trained. best val loss is: [0.42704890427135284, 0.83809525]
# sequential model is trained. best val loss is: [0.564191646802993, 0.7714286]
# sequential model is trained. best val loss is: [0.6945589428856259, 0.44761905]
# sequential model is trained. best val loss is: [0.5472848994391305, 0.76666665]
# sequential model is trained. best val loss is: [0.4961641169729687, 0.78571427]
# sequential model is trained. best val loss is: [0.46788931120009647, 0.8142857]
# sequential model is trained. best val loss is: [0.721152511097136, 0.36190477]
# sequential model is trained. best val loss is: [0.6235766178085691, 0.7]
# sequential model is trained. best val loss is: [0.5781598732584998, 0.75238097]
# sequential model is trained. best val loss is: [0.47796276921317693, 0.78571427]
# sequential model is trained. best val loss is: [0.4421362207049415, 0.8095238]
# sequential model is trained. best val loss is: [0.8914750190008254, 0.7714286]
# sequential model is trained. best val loss is: [1.1008046025321596, 0.7809524]
# sequential model is trained. best val loss is: [2.224304687409174, 0.7714286]
# sequential model is trained. best val loss is: [0.4283891308875311, 0.8095238]
# sequential model is trained. best val loss is: [0.5276566965239389, 0.8]
# sequential model is trained. best val loss is: [0.5952918438684373, 0.8142857]
# sequential model is trained. best val loss is: [0.6361395194416954, 0.8428571]
# sequential model is trained. best val loss is: [0.7136010578700475, 0.3952381]
# sequential model is trained. best val loss is: [0.6948787734622047, 0.4047619]
# sequential model is trained. best val loss is: [0.6766749211720058, 0.6142857]
# sequential model is trained. best val loss is: [0.5841768713224502, 0.74285716]
# sequential model is trained. best val loss is: [0.47681383575711933, 0.7952381]
# sequential model is trained. best val loss is: [0.4092033698445275, 0.83809525]
# sequential model is trained. best val loss is: [0.4415646763074966, 0.8333333]
# sequential model is trained. best val loss is: [0.5410377161843436, 0.8]
# sequential model is trained. best val loss is: [0.6631792908623105, 0.7190476]
# sequential model is trained. best val loss is: [0.5260227771032424, 0.7809524]
# sequential model is trained. best val loss is: [0.4864517961229597, 0.8095238]
# sequential model is trained. best val loss is: [0.46830630472728185, 0.81904763]
# sequential model is trained. best val loss is: [0.6920536523773557, 0.43333334]
# sequential model is trained. best val loss is: [0.5964915485609146, 0.75238097]
# sequential model is trained. best val loss is: [0.5545341832297189, 0.7619048]
# sequential model is trained. best val loss is: [0.4745636843499683, 0.78571427]
# sequential model is trained. best val loss is: [0.42503616497630164, 0.8142857]
# sequential model is trained. best val loss is: [1.0893146923610142, 0.7904762]
# sequential model is trained. best val loss is: [1.5529774132229033, 0.76666665]
# sequential model is trained. best val loss is: [2.482149026507423, 0.78571427]
# sequential model is trained. best val loss is: [0.47179403305053713, 0.8047619]
# sequential model is trained. best val loss is: [0.5951206190245492, 0.8095238]
# sequential model is trained. best val loss is: [0.8736031373341878, 0.75714284]
# sequential model is trained. best val loss is: [0.897088783127921, 0.8142857]
# sequential model is trained. best val loss is: [0.6893708212035042, 0.552381]
# sequential model is trained. best val loss is: [0.6876233736673991, 0.6]
# sequential model is trained. best val loss is: [0.6856586984225682, 0.6333333]
# sequential model is trained. best val loss is: [0.660318222500029, 0.67142856]
# sequential model is trained. best val loss is: [0.5825183471043904, 0.73333335]
# sequential model is trained. best val loss is: [0.4270533573059809, 0.8]
# sequential model is trained. best val loss is: [0.4588514878636315, 0.8]
# sequential model is trained. best val loss is: [0.7001614882832482, 0.72380954]
# sequential model is trained. best val loss is: [0.6812709638050625, 0.64285713]
# sequential model is trained. best val loss is: [0.569833737327939, 0.74761903]
# sequential model is trained. best val loss is: [0.5077874183654785, 0.8095238]
# sequential model is trained. best val loss is: [0.46816138539995467, 0.8238095]
# sequential model is trained. best val loss is: [0.6853580452146985, 0.6238095]
# sequential model is trained. best val loss is: [0.6309904910269237, 0.6047619]
# sequential model is trained. best val loss is: [0.5886186866533188, 0.6666667]
# sequential model is trained. best val loss is: [0.48616047075816565, 0.7952381]
# sequential model is trained. best val loss is: [0.4805666889463152, 0.81904763]
# sequential model is trained. best val loss is: [1.1957832484018236, 0.7714286]
# sequential model is trained. best val loss is: [0.5728761110986982, 0.81904763]
# sequential model is trained. best val loss is: [0.6315166723160517, 0.8142857]
# sequential model is trained. best val loss is: [0.44637546908287773, 0.8]
# sequential model is trained. best val loss is: [0.6556165712220329, 0.8047619]
# sequential model is trained. best val loss is: [0.7097691904930842, 0.8333333]
# sequential model is trained. best val loss is: [0.8343267049108233, 0.8142857]
# sequential model is trained. best val loss is: [0.6842558219319298, 0.60952383]
# sequential model is trained. best val loss is: [0.6790816954204014, 0.60952383]
# sequential model is trained. best val loss is: [0.6735595629328773, 0.60952383]
# sequential model is trained. best val loss is: [0.6328457809629895, 0.66190475]
# sequential model is trained. best val loss is: [0.5524626845405215, 0.78571427]
# sequential model is trained. best val loss is: [0.4217139286654336, 0.83809525]
# sequential model is trained. best val loss is: [0.5028691734586443, 0.8238095]
# sequential model is trained. best val loss is: [0.5844571624483381, 0.81904763]
# sequential model is trained. best val loss is: [0.6648802978651864, 0.61904764]
# sequential model is trained. best val loss is: [0.5650347760745458, 0.76666665]
# sequential model is trained. best val loss is: [0.5021441192854018, 0.8]
# sequential model is trained. best val loss is: [0.4717897585460118, 0.8095238]
# sequential model is trained. best val loss is: [0.6757987124579293, 0.6]
# sequential model is trained. best val loss is: [0.6265391656330653, 0.6047619]
# sequential model is trained. best val loss is: [0.5892682370685396, 0.71428573]
# sequential model is trained. best val loss is: [0.4791120426995414, 0.7952381]
# sequential model is trained. best val loss is: [0.4490985467320397, 0.81904763]
# sequential model is trained. best val loss is: [0.6098131378491719, 0.7809524]
# sequential model is trained. best val loss is: [1.1926907039823986, 0.7809524]
# sequential model is trained. best val loss is: [0.8514958886873154, 0.8]
# sequential model is trained. best val loss is: [0.43561535903385706, 0.8095238]
# sequential model is trained. best val loss is: [0.7161270845504034, 0.8047619]
# sequential model is trained. best val loss is: [0.6617667300360544, 0.8238095]
# sequential model is trained. best val loss is: [0.9195612084297907, 0.77619046]
# sequential model is trained. best val loss is: [0.6809890298616319, 0.61904764]
# sequential model is trained. best val loss is: [0.6734799424807231, 0.62857145]
# sequential model is trained. best val loss is: [0.6652290457770937, 0.6333333]
# sequential model is trained. best val loss is: [0.598139146396092, 0.73333335]
# sequential model is trained. best val loss is: [0.4960847014472598, 0.7904762]
# sequential model is trained. best val loss is: [0.4561521473385039, 0.8095238]
# sequential model is trained. best val loss is: [0.6184493184089661, 0.77619046]
# sequential model is trained. best val loss is: [0.690933837209429, 0.8047619]
# sequential model is trained. best val loss is: [0.6627358277638753, 0.61904764]
# sequential model is trained. best val loss is: [0.5547985423178899, 0.7714286]
# sequential model is trained. best val loss is: [0.49429549603235157, 0.8047619]
# sequential model is trained. best val loss is: [0.47486876306079684, 0.8095238]
# sequential model is trained. best val loss is: [0.6741031266394115, 0.61904764]
# sequential model is trained. best val loss is: [0.624913858232044, 0.6142857]
# sequential model is trained. best val loss is: [0.5857920039267767, 0.71428573]
# sequential model is trained. best val loss is: [0.47753263484864006, 0.7952381]
# sequential model is trained. best val loss is: [0.43721374784197126, 0.8142857]
# sequential model is trained. best val loss is: [0.5715264825593858, 0.8333333]
# sequential model is trained. best val loss is: [0.6616735804648627, 0.81904763]
# sequential model is trained. best val loss is: [0.8740024226052421, 0.8142857]
# sequential model is trained. best val loss is: [0.4130572333222344, 0.84761906]
# sequential model is trained. best val loss is: [0.7189576926685515, 0.8428571]
# sequential model is trained. best val loss is: [0.8839141987618946, 0.8047619]
# sequential model is trained. best val loss is: [0.6440638127781096, 0.71428573]
# sequential model is trained. best val loss is: [0.7031318687257313, 0.3857143]
# sequential model is trained. best val loss is: [0.6892438644454593, 0.5761905]
# sequential model is trained. best val loss is: [0.6757660417329697, 0.6857143]
# sequential model is trained. best val loss is: [0.5808019462085906, 0.76666665]
# sequential model is trained. best val loss is: [0.4610039219969795, 0.7952381]
# sequential model is trained. best val loss is: [0.4780346180711474, 0.8047619]
# sequential model is trained. best val loss is: [0.5548933256240118, 0.8238095]
# sequential model is trained. best val loss is: [0.869623605410258, 0.8142857]
# sequential model is trained. best val loss is: [0.678410534063975, 0.6666667]
# sequential model is trained. best val loss is: [0.55562253509249, 0.7714286]
# sequential model is trained. best val loss is: [0.489989976088206, 0.8047619]
# sequential model is trained. best val loss is: [0.47923005649021694, 0.81904763]
# sequential model is trained. best val loss is: [0.6930054534049261, 0.55714285]
# sequential model is trained. best val loss is: [0.6357636548223949, 0.6238095]
# sequential model is trained. best val loss is: [0.5954043456486293, 0.71428573]
# sequential model is trained. best val loss is: [0.47602823745636713, 0.8047619]
# sequential model is trained. best val loss is: [0.4186237110978081, 0.85714287]
# sequential model is trained. best val loss is: [0.8929938157399495, 0.8047619]
# sequential model is trained. best val loss is: [0.6797832420894078, 0.8142857]
# sequential model is trained. best val loss is: [2.4190368379865372, 0.77619046]
# sequential model is trained. best val loss is: [0.4457178961663019, 0.8333333]
# sequential model is trained. best val loss is: [0.9093710070564633, 0.73333335]
# sequential model is trained. best val loss is: [1.091149123509725, 0.73333335]
# sequential model is trained. best val loss is: [1.0122396911893572, 0.7809524]
# sequential model is trained. best val loss is: [0.6912863952772957, 0.55714285]
# sequential model is trained. best val loss is: [0.668831167334602, 0.64761907]
# sequential model is trained. best val loss is: [0.6487165592965626, 0.6761905]
# sequential model is trained. best val loss is: [0.537216610000247, 0.77619046]
# sequential model is trained. best val loss is: [0.44794217944145204, 0.81904763]
# sequential model is trained. best val loss is: [0.5549222037905739, 0.8]
# sequential model is trained. best val loss is: [0.5938845293862479, 0.81904763]
# sequential model is trained. best val loss is: [0.7652454257011414, 0.78571427]
# sequential model is trained. best val loss is: [0.6650066829863048, 0.61904764]
# sequential model is trained. best val loss is: [0.5389456686519442, 0.7714286]
# sequential model is trained. best val loss is: [0.48462289344696774, 0.7952381]
# sequential model is trained. best val loss is: [0.4934125854855492, 0.8142857]
# sequential model is trained. best val loss is: [0.6821186253002711, 0.6047619]
# sequential model is trained. best val loss is: [0.6231334073202951, 0.64285713]
# sequential model is trained. best val loss is: [0.5798649566514151, 0.74285716]
# sequential model is trained. best val loss is: [0.47757564442498346, 0.8]
# sequential model is trained. best val loss is: [0.5903634497097561, 0.7904762]
# sequential model is trained. best val loss is: [1.4272240161895753, 0.78571427]
# sequential model is trained. best val loss is: [0.637787279628572, 0.7714286]
# sequential model is trained. best val loss is: [1.0927198586009799, 0.76666665]
# sequential model is trained. best val loss is: [0.4596924270902361, 0.7904762]
# sequential model is trained. best val loss is: [0.7373355399994623, 0.7714286]
# sequential model is trained. best val loss is: [0.8199510341598875, 0.7809524]
# sequential model is trained. best val loss is: [1.3177626541682652, 0.7285714]
# sequential model is trained. best val loss is: [0.6953974139122736, 0.3857143]
# sequential model is trained. best val loss is: [0.6940556560243879, 0.4857143]
# sequential model is trained. best val loss is: [0.6926259125982012, 0.55714285]
# sequential model is trained. best val loss is: [0.6807064913568043, 0.7285714]
# sequential model is trained. best val loss is: [0.6171686558496384, 0.77619046]
# sequential model is trained. best val loss is: [0.41802545956202913, 0.8095238]
# sequential model is trained. best val loss is: [0.4747291922569275, 0.8095238]
# sequential model is trained. best val loss is: [0.7455274445669992, 0.81904763]
# sequential model is trained. best val loss is: [0.6898028759729294, 0.6142857]
# sequential model is trained. best val loss is: [0.651955236707415, 0.60952383]
# sequential model is trained. best val loss is: [0.580450147106534, 0.77619046]
# sequential model is trained. best val loss is: [0.457040502343859, 0.8]
# sequential model is trained. best val loss is: [0.6918935911996024, 0.5952381]
# sequential model is trained. best val loss is: [0.672469136828468, 0.6047619]
# sequential model is trained. best val loss is: [0.6591604669888814, 0.6047619]
# sequential model is trained. best val loss is: [0.477316004889352, 0.7904762]
# sequential model is trained. best val loss is: [0.4716858954656692, 0.78571427]
# sequential model is trained. best val loss is: [0.6813210368156433, 0.75714284]
# sequential model is trained. best val loss is: [0.6392375304585411, 0.8047619]
# sequential model is trained. best val loss is: [0.6659961706116087, 0.7190476]
# sequential model is trained. best val loss is: [0.4327904647304898, 0.8238095]
# sequential model is trained. best val loss is: [0.8582763104211717, 0.8142857]
# sequential model is trained. best val loss is: [0.9516743262608846, 0.6666667]
# sequential model is trained. best val loss is: [1.1121703931263516, 0.8238095]
# sequential model is trained. best val loss is: [0.6941059441793532, 0.50476193]
# sequential model is trained. best val loss is: [0.6916088342666626, 0.5857143]
# sequential model is trained. best val loss is: [0.6885390213557652, 0.65238094]
# sequential model is trained. best val loss is: [0.6409919341405232, 0.67142856]
# sequential model is trained. best val loss is: [0.5531091173489888, 0.78571427]
# sequential model is trained. best val loss is: [0.46888459239687236, 0.84761906]
# sequential model is trained. best val loss is: [0.6212150244485765, 0.78571427]
# sequential model is trained. best val loss is: [0.8071846087773641, 0.76666665]
# sequential model is trained. best val loss is: [0.6871953776904515, 0.61904764]
# sequential model is trained. best val loss is: [0.6086993251528059, 0.65238094]
# sequential model is trained. best val loss is: [0.5120110006559463, 0.7952381]
# sequential model is trained. best val loss is: [0.46915031841823035, 0.8238095]
# sequential model is trained. best val loss is: [0.6906266252199809, 0.6]
# sequential model is trained. best val loss is: [0.6637850023451306, 0.6047619]
# sequential model is trained. best val loss is: [0.6407267791884286, 0.6047619]
# sequential model is trained. best val loss is: [0.4784350491705395, 0.7952381]
# sequential model is trained. best val loss is: [0.44217809438705447, 0.81904763]
# sequential model is trained. best val loss is: [0.6294456476256961, 0.8238095]
# sequential model is trained. best val loss is: [0.8170568761371431, 0.8238095]
# sequential model is trained. best val loss is: [1.6086258479527065, 0.8047619]
# sequential model is trained. best val loss is: [0.422569952976136, 0.8142857]
# sequential model is trained. best val loss is: [0.8111468570572989, 0.84761906]
# sequential model is trained. best val loss is: [1.1475471905299595, 0.5952381]
# sequential model is trained. best val loss is: [0.8308311746233985, 0.7809524]
# sequential model is trained. best val loss is: [0.6879860435213362, 0.6857143]
# sequential model is trained. best val loss is: [0.682319180170695, 0.7285714]
# sequential model is trained. best val loss is: [0.67562449829919, 0.7619048]
# sequential model is trained. best val loss is: [0.5858546007247198, 0.7285714]
# sequential model is trained. best val loss is: [0.4691631867772057, 0.8047619]
# sequential model is trained. best val loss is: [0.521924562681289, 0.8142857]
# sequential model is trained. best val loss is: [0.640101488998958, 0.8047619]
# sequential model is trained. best val loss is: [0.8052383854275658, 0.7]
# sequential model is trained. best val loss is: [0.6760820371764047, 0.6857143]
# sequential model is trained. best val loss is: [0.5650696595509846, 0.74285716]
# sequential model is trained. best val loss is: [0.49388040474482947, 0.7904762]
# sequential model is trained. best val loss is: [0.4849682989574614, 0.8142857]
# sequential model is trained. best val loss is: [0.6828931973094032, 0.68095237]
# sequential model is trained. best val loss is: [0.6445352628117516, 0.6047619]
# sequential model is trained. best val loss is: [0.6076040801547823, 0.6333333]
# sequential model is trained. best val loss is: [0.48488180864424935, 0.8095238]
# sequential model is trained. best val loss is: [0.4281313793999808, 0.84761906]
# sequential model is trained. best val loss is: [1.1512308756510417, 0.7952381]
# sequential model is trained. best val loss is: [0.592362972668239, 0.8095238]
# sequential model is trained. best val loss is: [1.5342217127482096, 0.6238095]
# sequential model is trained. best val loss is: [0.49000980740501765, 0.81904763]
# sequential model is trained. best val loss is: [0.7720283814838954, 0.81904763]
# sequential model is trained. best val loss is: [0.8169363896052043, 0.84761906]
# sequential model is trained. best val loss is: [1.6877521900903611, 0.53809524]
# sequential model is trained. best val loss is: [0.6947421936761765, 0.43333334]
# sequential model is trained. best val loss is: [0.6838922869591486, 0.6904762]
# sequential model is trained. best val loss is: [0.6724379732495263, 0.6952381]
# sequential model is trained. best val loss is: [0.5622120346341815, 0.7619048]
# sequential model is trained. best val loss is: [0.4537565540699732, 0.8]
# sequential model is trained. best val loss is: [0.6651959067299252, 0.75238097]
# sequential model is trained. best val loss is: [0.8245124243554615, 0.76666665]
# sequential model is trained. best val loss is: [0.9523462931315104, 0.73333335]
# sequential model is trained. best val loss is: [0.6788325559525262, 0.6571429]
# sequential model is trained. best val loss is: [0.5703061296826317, 0.74761903]
# sequential model is trained. best val loss is: [0.48483958528155374, 0.8]
# sequential model is trained. best val loss is: [0.4752726520810808, 0.8238095]
# sequential model is trained. best val loss is: [0.6882205253555661, 0.66190475]
# sequential model is trained. best val loss is: [0.6485034868830726, 0.6047619]
# sequential model is trained. best val loss is: [0.6158233404159545, 0.62857145]
# sequential model is trained. best val loss is: [0.4768108214650835, 0.8142857]
# sequential model is trained. best val loss is: [0.6149440634818304, 0.7952381]
# sequential model is trained. best val loss is: [0.7122398541087196, 0.7952381]
# sequential model is trained. best val loss is: [1.5504639387130736, 0.8]
# sequential model is trained. best val loss is: [1.3605305399213519, 0.7904762]
# sequential model is trained. best val loss is: [0.5189140035992577, 0.8142857]
# sequential model is trained. best val loss is: [0.8105261371249244, 0.7047619]
# sequential model is trained. best val loss is: [0.585700511932373, 0.8428571]
# sequential model is trained. best val loss is: [0.7647955139478048, 0.7809524]
# sequential model is trained. best val loss is: [0.6905951795123872, 0.5809524]
# sequential model is trained. best val loss is: [0.6736838170460292, 0.6047619]
# sequential model is trained. best val loss is: [0.6556881654830206, 0.6047619]
# sequential model is trained. best val loss is: [0.518976498785473, 0.7809524]
# sequential model is trained. best val loss is: [0.439913870323272, 0.8142857]
# sequential model is trained. best val loss is: [0.6458519736925761, 0.81904763]
# sequential model is trained. best val loss is: [0.8104258293197268, 0.72380954]
# sequential model is trained. best val loss is: [0.7244571651731219, 0.7904762]
# sequential model is trained. best val loss is: [0.6758497164362953, 0.6047619]
# sequential model is trained. best val loss is: [0.5719124311492556, 0.73333335]
# sequential model is trained. best val loss is: [0.49098436207998364, 0.8]
# sequential model is trained. best val loss is: [0.49512239013399395, 0.8238095]
# sequential model is trained. best val loss is: [0.6857244060153053, 0.6047619]
# sequential model is trained. best val loss is: [0.6479194164276123, 0.6047619]
# sequential model is trained. best val loss is: [0.6158331922122411, 0.6047619]
# sequential model is trained. best val loss is: [0.4890070529211135, 0.8142857]
# sequential model is trained. best val loss is: [1.0861877827417283, 0.76666665]
# sequential model is trained. best val loss is: [0.5928208839325678, 0.8095238]
# sequential model is trained. best val loss is: [2.483593967982701, 0.77619046]
# sequential model is trained. best val loss is: [0.7510544583910987, 0.7952381]
# ==== 6.495222167174021 mins ====

# %%
best_model, best_model_info = select_best_model(models, val_losses, param_info)

# %%
best_model_info
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.02}

# %%
auto_fit(ds.problem, X_train, y_train, X_val, y_val,
         hidden_layers=[best_model_info['hidden_layer']], units=[best_model_info['unit']],
         optimizers=[best_model_info['optimizer']], lrs=[best_model_info['lr']],
         batch_size=64, epochs=10, verbose=0)
# Out:
# sequential model is trained. best val loss is: [0.4036279746464321, 0.8333333]
# ([<tensorflow.python.keras.engine.sequential.Sequential at 0x15def9b50>],
#  [{'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.02}],
#  [0.4036279746464321])

# %%
# 2nd trial
start_time = time.time()
models_2nd, param_info_2nd, val_losses_2nd = auto_fit(ds.problem, X_train, y_train, X_val, y_val,
                                                      hidden_layers=[1], units=[16],
                                                      optimizers=['adam'], lrs=[0.01],
                                                      batch_size=64, epochs=10, verbose=0,
                                                      use_all=True)
print("==== %s mins ====" % ((time.time() - start_time) / 60))
# Out:
# sequential model is trained. best val loss is: [0.5216480334599812, 0.7714286]
# sequential model is trained. best val loss is: [0.41401143272717794, 0.8]
# sequential model is trained. best val loss is: [0.46487523260570707, 0.8238095]
# sequential model is trained. best val loss is: [0.6647860674631028, 0.8]
# sequential model is trained. best val loss is: [0.7054895781335376, 0.42857143]
# sequential model is trained. best val loss is: [0.702023586772737, 0.45714286]
# sequential model is trained. best val loss is: [0.6984167405537196, 0.4857143]
# sequential model is trained. best val loss is: [0.6754059984570457, 0.62857145]
# sequential model is trained. best val loss is: [0.6222717080797467, 0.7190476]
# sequential model is trained. best val loss is: [0.4424103966781071, 0.7952381]
# sequential model is trained. best val loss is: [0.4202179602214268, 0.81904763]
# sequential model is trained. best val loss is: [0.45611048482713246, 0.82857144]
# sequential model is trained. best val loss is: [0.6870668036597115, 0.5904762]
# sequential model is trained. best val loss is: [0.5833981718335833, 0.74285716]
# sequential model is trained. best val loss is: [0.5105543704259963, 0.7714286]
# sequential model is trained. best val loss is: [0.45822802782058714, 0.7952381]
# sequential model is trained. best val loss is: [0.6951618819009691, 0.53809524]
# sequential model is trained. best val loss is: [0.6425403980981736, 0.68095237]
# sequential model is trained. best val loss is: [0.5992390519096737, 0.7285714]
# sequential model is trained. best val loss is: [0.4787083080836705, 0.7809524]
# sequential model is trained. best val loss is: [0.5190129949933007, 0.77619046]
# sequential model is trained. best val loss is: [0.4448046408948444, 0.8047619]
# sequential model is trained. best val loss is: [0.6658132484980992, 0.7714286]
# sequential model is trained. best val loss is: [0.7035849730173747, 0.8]
# sequential model is trained. best val loss is: [0.468669601281484, 0.8142857]
# sequential model is trained. best val loss is: [0.4498437836056664, 0.8047619]
# sequential model is trained. best val loss is: [0.5179428492273603, 0.7952381]
# sequential model is trained. best val loss is: [0.787579045409248, 0.76666665]
# sequential model is trained. best val loss is: [0.7029132411593483, 0.3904762]
# sequential model is trained. best val loss is: [0.6976602474848429, 0.43333334]
# sequential model is trained. best val loss is: [0.6921516980443682, 0.47619048]
# sequential model is trained. best val loss is: [0.652977758929843, 0.7095238]
# sequential model is trained. best val loss is: [0.574565965788705, 0.77619046]
# sequential model is trained. best val loss is: [0.42270156741142273, 0.8095238]
# sequential model is trained. best val loss is: [0.4036279746464321, 0.8333333]
# sequential model is trained. best val loss is: [0.511861270949954, 0.8095238]
# sequential model is trained. best val loss is: [0.6786152504739307, 0.67142856]
# sequential model is trained. best val loss is: [0.5539989800680252, 0.7714286]
# sequential model is trained. best val loss is: [0.4956725688207717, 0.7714286]
# sequential model is trained. best val loss is: [0.45991553692590625, 0.8095238]
# sequential model is trained. best val loss is: [0.6910293204443795, 0.5285714]
# sequential model is trained. best val loss is: [0.6237222978046962, 0.7285714]
# sequential model is trained. best val loss is: [0.5794687537919907, 0.74285716]
# sequential model is trained. best val loss is: [0.4753768529210772, 0.77619046]
# sequential model is trained. best val loss is: [0.469087236835843, 0.8142857]
# sequential model is trained. best val loss is: [0.5694965595290774, 0.76666665]
# sequential model is trained. best val loss is: [0.8240238263493492, 0.7904762]
# sequential model is trained. best val loss is: [0.6551012050537836, 0.75714284]
# sequential model is trained. best val loss is: [0.4544494901384626, 0.78571427]
# sequential model is trained. best val loss is: [0.47108563014439175, 0.8238095]
# sequential model is trained. best val loss is: [0.5387262321653821, 0.7952381]
# sequential model is trained. best val loss is: [0.673859243165879, 0.8238095]
# sequential model is trained. best val loss is: [0.71166030111767, 0.41428572]
# sequential model is trained. best val loss is: [0.702361105737232, 0.45714286]
# sequential model is trained. best val loss is: [0.6928076630546933, 0.47619048]
# sequential model is trained. best val loss is: [0.634059054510934, 0.74761903]
# sequential model is trained. best val loss is: [0.5395273327827453, 0.7714286]
# sequential model is trained. best val loss is: [0.4170151855264391, 0.8095238]
# sequential model is trained. best val loss is: [0.4154530173256284, 0.8238095]
# sequential model is trained. best val loss is: [0.4955712954203288, 0.81904763]
# sequential model is trained. best val loss is: [0.6737751563390096, 0.72380954]
# sequential model is trained. best val loss is: [0.5436244073368254, 0.77619046]
# sequential model is trained. best val loss is: [0.49201955397923786, 0.8142857]
# sequential model is trained. best val loss is: [0.4603050390879313, 0.8095238]
# sequential model is trained. best val loss is: [0.6937197810127622, 0.48095238]
# sequential model is trained. best val loss is: [0.6095021463575817, 0.7190476]
# sequential model is trained. best val loss is: [0.5680189478965033, 0.7619048]
# sequential model is trained. best val loss is: [0.47325457561583745, 0.7904762]
# sequential model is trained. best val loss is: [0.4548120896021525, 0.8142857]
# sequential model is trained. best val loss is: [0.7600104899633499, 0.78571427]
# sequential model is trained. best val loss is: [1.2193409533727737, 0.7714286]
# sequential model is trained. best val loss is: [0.699330837385995, 0.7714286]
# sequential model is trained. best val loss is: [0.44433728201048717, 0.78571427]
# sequential model is trained. best val loss is: [0.5383356514431181, 0.77619046]
# sequential model is trained. best val loss is: [0.662613028004056, 0.7380952]
# sequential model is trained. best val loss is: [0.7489157659666879, 0.7809524]
# sequential model is trained. best val loss is: [0.7427788615226746, 0.35238096]
# sequential model is trained. best val loss is: [0.7284241188140143, 0.36190477]
# sequential model is trained. best val loss is: [0.7138302570297604, 0.3809524]
# sequential model is trained. best val loss is: [0.6280910230818249, 0.72380954]
# sequential model is trained. best val loss is: [0.5130737860997517, 0.78571427]
# sequential model is trained. best val loss is: [0.4121404102870396, 0.82857144]
# sequential model is trained. best val loss is: [0.42704890427135284, 0.83809525]
# sequential model is trained. best val loss is: [0.564191646802993, 0.7714286]
# sequential model is trained. best val loss is: [0.6945589428856259, 0.44761905]
# sequential model is trained. best val loss is: [0.5472848994391305, 0.76666665]
# sequential model is trained. best val loss is: [0.4961641169729687, 0.78571427]
# sequential model is trained. best val loss is: [0.46788931120009647, 0.8142857]
# sequential model is trained. best val loss is: [0.721152511097136, 0.36190477]
# sequential model is trained. best val loss is: [0.6235766178085691, 0.7]
# sequential model is trained. best val loss is: [0.5781598732584998, 0.75238097]
# sequential model is trained. best val loss is: [0.47796276921317693, 0.78571427]
# sequential model is trained. best val loss is: [0.4421362207049415, 0.8095238]
# sequential model is trained. best val loss is: [0.8914750190008254, 0.7714286]
# sequential model is trained. best val loss is: [1.1008046025321596, 0.7809524]
# sequential model is trained. best val loss is: [2.224304687409174, 0.7714286]
# sequential model is trained. best val loss is: [0.4283891308875311, 0.8095238]
# sequential model is trained. best val loss is: [0.5276566965239389, 0.8]
# sequential model is trained. best val loss is: [0.5952918438684373, 0.8142857]
# sequential model is trained. best val loss is: [0.6361395194416954, 0.8428571]
# sequential model is trained. best val loss is: [0.7136010578700475, 0.3952381]
# sequential model is trained. best val loss is: [0.6948787734622047, 0.4047619]
# sequential model is trained. best val loss is: [0.6766749211720058, 0.6142857]
# sequential model is trained. best val loss is: [0.5841768713224502, 0.74285716]
# sequential model is trained. best val loss is: [0.47681383575711933, 0.7952381]
# sequential model is trained. best val loss is: [0.4092033698445275, 0.83809525]
# sequential model is trained. best val loss is: [0.4415646763074966, 0.8333333]
# sequential model is trained. best val loss is: [0.5410377161843436, 0.8]
# sequential model is trained. best val loss is: [0.6631792908623105, 0.7190476]
# sequential model is trained. best val loss is: [0.5260227771032424, 0.7809524]
# sequential model is trained. best val loss is: [0.4864517961229597, 0.8095238]
# sequential model is trained. best val loss is: [0.46830630472728185, 0.81904763]
# sequential model is trained. best val loss is: [0.6920536523773557, 0.43333334]
# sequential model is trained. best val loss is: [0.5964915485609146, 0.75238097]
# sequential model is trained. best val loss is: [0.5545341832297189, 0.7619048]
# sequential model is trained. best val loss is: [0.4745636843499683, 0.78571427]
# sequential model is trained. best val loss is: [0.42503616497630164, 0.8142857]
# sequential model is trained. best val loss is: [1.0893146923610142, 0.7904762]
# sequential model is trained. best val loss is: [1.5529774132229033, 0.76666665]
# sequential model is trained. best val loss is: [2.482149026507423, 0.78571427]
# sequential model is trained. best val loss is: [0.47179403305053713, 0.8047619]
# sequential model is trained. best val loss is: [0.5951206190245492, 0.8095238]
# sequential model is trained. best val loss is: [0.8736031373341878, 0.75714284]
# sequential model is trained. best val loss is: [0.897088783127921, 0.8142857]
# sequential model is trained. best val loss is: [0.6893708212035042, 0.552381]
# sequential model is trained. best val loss is: [0.6876233736673991, 0.6]
# sequential model is trained. best val loss is: [0.6856586984225682, 0.6333333]
# sequential model is trained. best val loss is: [0.660318222500029, 0.67142856]
# sequential model is trained. best val loss is: [0.5825183471043904, 0.73333335]
# sequential model is trained. best val loss is: [0.4270533573059809, 0.8]
# sequential model is trained. best val loss is: [0.4588514878636315, 0.8]
# sequential model is trained. best val loss is: [0.7001614882832482, 0.72380954]
# sequential model is trained. best val loss is: [0.6812709638050625, 0.64285713]
# sequential model is trained. best val loss is: [0.569833737327939, 0.74761903]
# sequential model is trained. best val loss is: [0.5077874183654785, 0.8095238]
# sequential model is trained. best val loss is: [0.46816138539995467, 0.8238095]
# sequential model is trained. best val loss is: [0.6853580452146985, 0.6238095]
# sequential model is trained. best val loss is: [0.6309904910269237, 0.6047619]
# sequential model is trained. best val loss is: [0.5886186866533188, 0.6666667]
# sequential model is trained. best val loss is: [0.48616047075816565, 0.7952381]
# sequential model is trained. best val loss is: [0.4805666889463152, 0.81904763]
# sequential model is trained. best val loss is: [1.1957832484018236, 0.7714286]
# sequential model is trained. best val loss is: [0.5728761110986982, 0.81904763]
# sequential model is trained. best val loss is: [0.6315166723160517, 0.8142857]
# sequential model is trained. best val loss is: [0.44637546908287773, 0.8]
# sequential model is trained. best val loss is: [0.6556165712220329, 0.8047619]
# sequential model is trained. best val loss is: [0.7097691904930842, 0.8333333]
# sequential model is trained. best val loss is: [0.8343267049108233, 0.8142857]
# sequential model is trained. best val loss is: [0.6842558219319298, 0.60952383]
# sequential model is trained. best val loss is: [0.6790816954204014, 0.60952383]
# sequential model is trained. best val loss is: [0.6735595629328773, 0.60952383]
# sequential model is trained. best val loss is: [0.6328457809629895, 0.66190475]
# sequential model is trained. best val loss is: [0.5524626845405215, 0.78571427]
# sequential model is trained. best val loss is: [0.4217139286654336, 0.83809525]
# sequential model is trained. best val loss is: [0.5028691734586443, 0.8238095]
# sequential model is trained. best val loss is: [0.5844571624483381, 0.81904763]
# sequential model is trained. best val loss is: [0.6648802978651864, 0.61904764]
# sequential model is trained. best val loss is: [0.5650347760745458, 0.76666665]
# sequential model is trained. best val loss is: [0.5021441192854018, 0.8]
# sequential model is trained. best val loss is: [0.4717897585460118, 0.8095238]
# sequential model is trained. best val loss is: [0.6757987124579293, 0.6]
# sequential model is trained. best val loss is: [0.6265391656330653, 0.6047619]
# sequential model is trained. best val loss is: [0.5892682370685396, 0.71428573]
# sequential model is trained. best val loss is: [0.4791120426995414, 0.7952381]
# sequential model is trained. best val loss is: [0.4490985467320397, 0.81904763]
# sequential model is trained. best val loss is: [0.6098131378491719, 0.7809524]
# sequential model is trained. best val loss is: [1.1926907039823986, 0.7809524]
# sequential model is trained. best val loss is: [0.8514958886873154, 0.8]
# sequential model is trained. best val loss is: [0.43561535903385706, 0.8095238]
# sequential model is trained. best val loss is: [0.7161270845504034, 0.8047619]
# sequential model is trained. best val loss is: [0.6617667300360544, 0.8238095]
# sequential model is trained. best val loss is: [0.9195612084297907, 0.77619046]
# sequential model is trained. best val loss is: [0.6809890298616319, 0.61904764]
# sequential model is trained. best val loss is: [0.6734799424807231, 0.62857145]
# sequential model is trained. best val loss is: [0.6652290457770937, 0.6333333]
# sequential model is trained. best val loss is: [0.598139146396092, 0.73333335]
# sequential model is trained. best val loss is: [0.4960847014472598, 0.7904762]
# sequential model is trained. best val loss is: [0.4561521473385039, 0.8095238]
# sequential model is trained. best val loss is: [0.6184493184089661, 0.77619046]
# sequential model is trained. best val loss is: [0.690933837209429, 0.8047619]
# sequential model is trained. best val loss is: [0.6627358277638753, 0.61904764]
# sequential model is trained. best val loss is: [0.5547985423178899, 0.7714286]
# sequential model is trained. best val loss is: [0.49429549603235157, 0.8047619]
# sequential model is trained. best val loss is: [0.47486876306079684, 0.8095238]
# sequential model is trained. best val loss is: [0.6741031266394115, 0.61904764]
# sequential model is trained. best val loss is: [0.624913858232044, 0.6142857]
# sequential model is trained. best val loss is: [0.5857920039267767, 0.71428573]
# sequential model is trained. best val loss is: [0.47753263484864006, 0.7952381]
# sequential model is trained. best val loss is: [0.43721374784197126, 0.8142857]
# sequential model is trained. best val loss is: [0.5715264825593858, 0.8333333]
# sequential model is trained. best val loss is: [0.6616735804648627, 0.81904763]
# sequential model is trained. best val loss is: [0.8740024226052421, 0.8142857]
# sequential model is trained. best val loss is: [0.4130572333222344, 0.84761906]
# sequential model is trained. best val loss is: [0.7189576926685515, 0.8428571]
# sequential model is trained. best val loss is: [0.8839141987618946, 0.8047619]
# sequential model is trained. best val loss is: [0.6440638127781096, 0.71428573]
# sequential model is trained. best val loss is: [0.7031318687257313, 0.3857143]
# sequential model is trained. best val loss is: [0.6892438644454593, 0.5761905]
# sequential model is trained. best val loss is: [0.6757660417329697, 0.6857143]
# sequential model is trained. best val loss is: [0.5808019462085906, 0.76666665]
# sequential model is trained. best val loss is: [0.4610039219969795, 0.7952381]
# sequential model is trained. best val loss is: [0.4780346180711474, 0.8047619]
# sequential model is trained. best val loss is: [0.5548933256240118, 0.8238095]
# sequential model is trained. best val loss is: [0.869623605410258, 0.8142857]
# sequential model is trained. best val loss is: [0.678410534063975, 0.6666667]
# sequential model is trained. best val loss is: [0.55562253509249, 0.7714286]
# sequential model is trained. best val loss is: [0.489989976088206, 0.8047619]
# sequential model is trained. best val loss is: [0.47923005649021694, 0.81904763]
# sequential model is trained. best val loss is: [0.6930054534049261, 0.55714285]
# sequential model is trained. best val loss is: [0.6357636548223949, 0.6238095]
# sequential model is trained. best val loss is: [0.5954043456486293, 0.71428573]
# sequential model is trained. best val loss is: [0.47602823745636713, 0.8047619]
# sequential model is trained. best val loss is: [0.4186237110978081, 0.85714287]
# sequential model is trained. best val loss is: [0.8929938157399495, 0.8047619]
# sequential model is trained. best val loss is: [0.6797832420894078, 0.8142857]
# sequential model is trained. best val loss is: [2.4190368379865372, 0.77619046]
# sequential model is trained. best val loss is: [0.4457178961663019, 0.8333333]
# sequential model is trained. best val loss is: [0.9093710070564633, 0.73333335]
# sequential model is trained. best val loss is: [1.091149123509725, 0.73333335]
# sequential model is trained. best val loss is: [1.0122396911893572, 0.7809524]
# sequential model is trained. best val loss is: [0.6912863952772957, 0.55714285]
# sequential model is trained. best val loss is: [0.668831167334602, 0.64761907]
# sequential model is trained. best val loss is: [0.6487165592965626, 0.6761905]
# sequential model is trained. best val loss is: [0.537216610000247, 0.77619046]
# sequential model is trained. best val loss is: [0.44794217944145204, 0.81904763]
# sequential model is trained. best val loss is: [0.5549222037905739, 0.8]
# sequential model is trained. best val loss is: [0.5938845293862479, 0.81904763]
# sequential model is trained. best val loss is: [0.7652454257011414, 0.78571427]
# sequential model is trained. best val loss is: [0.6650066829863048, 0.61904764]
# sequential model is trained. best val loss is: [0.5389456686519442, 0.7714286]
# sequential model is trained. best val loss is: [0.48462289344696774, 0.7952381]
# sequential model is trained. best val loss is: [0.4934125854855492, 0.8142857]
# sequential model is trained. best val loss is: [0.6821186253002711, 0.6047619]
# sequential model is trained. best val loss is: [0.6231334073202951, 0.64285713]
# sequential model is trained. best val loss is: [0.5798649566514151, 0.74285716]
# sequential model is trained. best val loss is: [0.47757564442498346, 0.8]
# sequential model is trained. best val loss is: [0.5903634497097561, 0.7904762]
# sequential model is trained. best val loss is: [1.4272240161895753, 0.78571427]
# sequential model is trained. best val loss is: [0.637787279628572, 0.7714286]
# sequential model is trained. best val loss is: [1.0927198586009799, 0.76666665]
# sequential model is trained. best val loss is: [0.4596924270902361, 0.7904762]
# sequential model is trained. best val loss is: [0.7373355399994623, 0.7714286]
# sequential model is trained. best val loss is: [0.8199510341598875, 0.7809524]
# sequential model is trained. best val loss is: [1.3177626541682652, 0.7285714]
# sequential model is trained. best val loss is: [0.6953974139122736, 0.3857143]
# sequential model is trained. best val loss is: [0.6940556560243879, 0.4857143]
# sequential model is trained. best val loss is: [0.6926259125982012, 0.55714285]
# sequential model is trained. best val loss is: [0.6807064913568043, 0.7285714]
# sequential model is trained. best val loss is: [0.6171686558496384, 0.77619046]
# sequential model is trained. best val loss is: [0.41802545956202913, 0.8095238]
# sequential model is trained. best val loss is: [0.4747291922569275, 0.8095238]
# sequential model is trained. best val loss is: [0.7455274445669992, 0.81904763]
# sequential model is trained. best val loss is: [0.6898028759729294, 0.6142857]
# sequential model is trained. best val loss is: [0.651955236707415, 0.60952383]
# sequential model is trained. best val loss is: [0.580450147106534, 0.77619046]
# sequential model is trained. best val loss is: [0.457040502343859, 0.8]
# sequential model is trained. best val loss is: [0.6918935911996024, 0.5952381]
# sequential model is trained. best val loss is: [0.672469136828468, 0.6047619]
# sequential model is trained. best val loss is: [0.6591604669888814, 0.6047619]
# sequential model is trained. best val loss is: [0.477316004889352, 0.7904762]
# sequential model is trained. best val loss is: [0.4716858954656692, 0.78571427]
# sequential model is trained. best val loss is: [0.6813210368156433, 0.75714284]
# sequential model is trained. best val loss is: [0.6392375304585411, 0.8047619]
# sequential model is trained. best val loss is: [0.6659961706116087, 0.7190476]
# sequential model is trained. best val loss is: [0.4327904647304898, 0.8238095]
# sequential model is trained. best val loss is: [0.8582763104211717, 0.8142857]
# sequential model is trained. best val loss is: [0.9516743262608846, 0.6666667]
# sequential model is trained. best val loss is: [1.1121703931263516, 0.8238095]
# sequential model is trained. best val loss is: [0.6941059441793532, 0.50476193]
# sequential model is trained. best val loss is: [0.6916088342666626, 0.5857143]
# sequential model is trained. best val loss is: [0.6885390213557652, 0.65238094]
# sequential model is trained. best val loss is: [0.6409919341405232, 0.67142856]
# sequential model is trained. best val loss is: [0.5531091173489888, 0.78571427]
# sequential model is trained. best val loss is: [0.46888459239687236, 0.84761906]
# sequential model is trained. best val loss is: [0.6212150244485765, 0.78571427]
# sequential model is trained. best val loss is: [0.8071846087773641, 0.76666665]
# sequential model is trained. best val loss is: [0.6871953776904515, 0.61904764]
# sequential model is trained. best val loss is: [0.6086993251528059, 0.65238094]
# sequential model is trained. best val loss is: [0.5120110006559463, 0.7952381]
# sequential model is trained. best val loss is: [0.46915031841823035, 0.8238095]
# sequential model is trained. best val loss is: [0.6906266252199809, 0.6]
# sequential model is trained. best val loss is: [0.6637850023451306, 0.6047619]
# sequential model is trained. best val loss is: [0.6407267791884286, 0.6047619]
# sequential model is trained. best val loss is: [0.4784350491705395, 0.7952381]
# sequential model is trained. best val loss is: [0.44217809438705447, 0.81904763]
# sequential model is trained. best val loss is: [0.6294456476256961, 0.8238095]
# sequential model is trained. best val loss is: [0.8170568761371431, 0.8238095]
# sequential model is trained. best val loss is: [1.6086258479527065, 0.8047619]
# sequential model is trained. best val loss is: [0.422569952976136, 0.8142857]
# sequential model is trained. best val loss is: [0.8111468570572989, 0.84761906]
# sequential model is trained. best val loss is: [1.1475471905299595, 0.5952381]
# sequential model is trained. best val loss is: [0.8308311746233985, 0.7809524]
# sequential model is trained. best val loss is: [0.6879860435213362, 0.6857143]
# sequential model is trained. best val loss is: [0.682319180170695, 0.7285714]
# sequential model is trained. best val loss is: [0.67562449829919, 0.7619048]
# sequential model is trained. best val loss is: [0.5858546007247198, 0.7285714]
# sequential model is trained. best val loss is: [0.4691631867772057, 0.8047619]
# sequential model is trained. best val loss is: [0.521924562681289, 0.8142857]
# sequential model is trained. best val loss is: [0.640101488998958, 0.8047619]
# sequential model is trained. best val loss is: [0.8052383854275658, 0.7]
# sequential model is trained. best val loss is: [0.6760820371764047, 0.6857143]
# sequential model is trained. best val loss is: [0.5650696595509846, 0.74285716]
# sequential model is trained. best val loss is: [0.49388040474482947, 0.7904762]
# sequential model is trained. best val loss is: [0.4849682989574614, 0.8142857]
# sequential model is trained. best val loss is: [0.6828931973094032, 0.68095237]
# sequential model is trained. best val loss is: [0.6445352628117516, 0.6047619]
# sequential model is trained. best val loss is: [0.6076040801547823, 0.6333333]
# sequential model is trained. best val loss is: [0.48488180864424935, 0.8095238]
# sequential model is trained. best val loss is: [0.4281313793999808, 0.84761906]
# sequential model is trained. best val loss is: [1.1512308756510417, 0.7952381]
# sequential model is trained. best val loss is: [0.592362972668239, 0.8095238]
# sequential model is trained. best val loss is: [1.5342217127482096, 0.6238095]
# sequential model is trained. best val loss is: [0.49000980740501765, 0.81904763]
# sequential model is trained. best val loss is: [0.7720283814838954, 0.81904763]
# sequential model is trained. best val loss is: [0.8169363896052043, 0.84761906]
# sequential model is trained. best val loss is: [1.6877521900903611, 0.53809524]
# sequential model is trained. best val loss is: [0.6947421936761765, 0.43333334]
# sequential model is trained. best val loss is: [0.6838922869591486, 0.6904762]
# sequential model is trained. best val loss is: [0.6724379732495263, 0.6952381]
# sequential model is trained. best val loss is: [0.5622120346341815, 0.7619048]
# sequential model is trained. best val loss is: [0.4537565540699732, 0.8]
# sequential model is trained. best val loss is: [0.6651959067299252, 0.75238097]
# sequential model is trained. best val loss is: [0.8245124243554615, 0.76666665]
# sequential model is trained. best val loss is: [0.9523462931315104, 0.73333335]
# sequential model is trained. best val loss is: [0.6788325559525262, 0.6571429]
# sequential model is trained. best val loss is: [0.5703061296826317, 0.74761903]
# sequential model is trained. best val loss is: [0.48483958528155374, 0.8]
# sequential model is trained. best val loss is: [0.4752726520810808, 0.8238095]
# sequential model is trained. best val loss is: [0.6882205253555661, 0.66190475]
# sequential model is trained. best val loss is: [0.6485034868830726, 0.6047619]
# sequential model is trained. best val loss is: [0.6158233404159545, 0.62857145]
# sequential model is trained. best val loss is: [0.4768108214650835, 0.8142857]
# sequential model is trained. best val loss is: [0.6149440634818304, 0.7952381]
# sequential model is trained. best val loss is: [0.7122398541087196, 0.7952381]
# sequential model is trained. best val loss is: [1.5504639387130736, 0.8]
# sequential model is trained. best val loss is: [1.3605305399213519, 0.7904762]
# sequential model is trained. best val loss is: [0.5189140035992577, 0.8142857]
# sequential model is trained. best val loss is: [0.8105261371249244, 0.7047619]
# sequential model is trained. best val loss is: [0.585700511932373, 0.8428571]
# sequential model is trained. best val loss is: [0.7647955139478048, 0.7809524]
# sequential model is trained. best val loss is: [0.6905951795123872, 0.5809524]
# sequential model is trained. best val loss is: [0.6736838170460292, 0.6047619]
# sequential model is trained. best val loss is: [0.6556881654830206, 0.6047619]
# sequential model is trained. best val loss is: [0.518976498785473, 0.7809524]
# sequential model is trained. best val loss is: [0.439913870323272, 0.8142857]
# sequential model is trained. best val loss is: [0.6458519736925761, 0.81904763]
# sequential model is trained. best val loss is: [0.8104258293197268, 0.72380954]
# sequential model is trained. best val loss is: [0.7244571651731219, 0.7904762]
# sequential model is trained. best val loss is: [0.6758497164362953, 0.6047619]
# sequential model is trained. best val loss is: [0.5719124311492556, 0.73333335]
# sequential model is trained. best val loss is: [0.49098436207998364, 0.8]
# sequential model is trained. best val loss is: [0.49512239013399395, 0.8238095]
# sequential model is trained. best val loss is: [0.6857244060153053, 0.6047619]
# sequential model is trained. best val loss is: [0.6479194164276123, 0.6047619]
# sequential model is trained. best val loss is: [0.6158331922122411, 0.6047619]
# sequential model is trained. best val loss is: [0.4890070529211135, 0.8142857]
# sequential model is trained. best val loss is: [1.0861877827417283, 0.76666665]
# sequential model is trained. best val loss is: [0.5928208839325678, 0.8095238]
# sequential model is trained. best val loss is: [2.483593967982701, 0.77619046]
# sequential model is trained. best val loss is: [0.7510544583910987, 0.7952381]
# ==== 7.266896736621857 mins ====

# %%
best_model_2nd, best_model_info_2nd = select_best_model(models_2nd, val_losses_2nd, param_info_2nd)
best_model_info_2nd
# Out:
# {'hidden_layer': 1, 'unit': 32, 'optimizer': 'adamax', 'lr': 0.02}
